# %%
# process_files.py
from config import date_str, DOWNLOAD_DIR, DEST_DIR
from pathlib import Path  # Better path handling

print(f"date_str: {date_str}")
# Out:
# date_str: 2025-04-08

# %%
SOURCE_PATH = f'..\data\{date_str}_df_finviz.parquet'
DES_PATH = f'..\data\{date_str}_df_finviz_n_ratios.parquet'
COMMON_TICKERS_PATH = f'..\data\{date_str}_df_common_tickers.parquet'

# %%
import pandas as pd

# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000) 
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
# pd.set_option('display.width', None)        # Let the display adjust to the window
# pd.set_option('display.max_colwidth', None) # Show full content of each cell

# %%
# Load the parquet file into a DataFrame
df_finviz = pd.read_parquet(SOURCE_PATH)

# Display basic information about the DataFrame
print(f"df_finviz.shape: {df_finviz.shape}")
print("\nFirst few rows:")
df_finviz.head()
# Out:
# df_finviz.shape: (1560, 29)
#
# First few rows:
#                       Company                                               Info  MktCap AUM, M  Beta    RSI  Perf YTD %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %    ATR  Volatility W %  Volatility M %   Volume, M  Avg Volume, M  Rel Volume   Price  Change %  Dividend %
# Ticker
# MSFT    Microsoft Corporation              Technology, Software - Infrastructure      2642330.0  0.96  27.93      -15.67        -7.00         -6.50        -16.92       -14.57       -16.47    -6.74   -10.35    -15.36      -20.73       3.09      -24.11       3.09           -24.11       445991.96  11.57            3.77            2.43   33.164772          24.27        1.37  355.44     -0.68        0.92
# AAPL                Apple Inc                   Technology, Consumer Electronics      2596840.0  1.32  20.16      -30.97       -22.55        -24.01        -29.44       -23.78         1.94   -18.41   -23.86    -24.40      -30.85      -1.00      -33.54       5.36           -33.54       271636.63   9.46            5.01            3.36  116.315852          56.69        2.05  172.87     -4.73        0.60
# NVDA              NVIDIA Corp                         Technology, Semiconductors      2359720.0  2.05  32.54      -27.98       -12.20         -9.60        -35.28       -22.58         9.89   -13.58   -19.39    -23.67      -32.58      11.65      -36.84      27.91           -36.84       290029.98   7.05            7.70            4.91  463.407326         291.28        1.59   96.71     -0.95        0.04
# AMZN           Amazon.com Inc                 Consumer Cyclical, Internet Retail      1813170.0  1.26  29.94      -22.02       -10.97        -12.05        -24.83        -8.27        -7.55   -10.99   -18.46    -14.50      -29.45       6.02      -29.45      12.85           -29.45       260608.58   9.60            6.87            3.74   85.297522          44.34        1.92  171.09     -2.38         NaN
# GOOGL            Alphabet Inc  Communication Services, Internet Content & Inf...      1777390.0  0.98  28.49      -23.56        -7.88        -12.76        -26.50       -13.38        -5.11    -9.20   -16.57    -16.87      -30.11       2.97      -30.11       2.97           -30.11         5925.84   5.83            3.92            3.05   50.436666          32.93        1.53  144.70     -1.40        0.34

# %%
print(f'df_finviz.shape before removing duplicates: {df_finviz.shape}')
# Remove duplicates from df_finviz, keeping the first occurrence
df_finviz = df_finviz[~df_finviz.index.duplicated(keep='first')]

print(f'df_finviz.shape after removing duplicates: {df_finviz.shape}')
# Out:
# df_finviz.shape before removing duplicates: (1560, 29)
# df_finviz.shape after removing duplicates: (1550, 29)

# %%
# Load the parquet file into a DataFrame
df_perf_ratios= pd.read_parquet(f'..\data\{date_str}_df_perf_ratios.parquet')

# Display basic information about the DataFrame
print(f"df_perf_ratios.shape: {df_perf_ratios.shape}")
print("\nFirst few rows:")
df_perf_ratios.head()
# Out:
# df_perf_ratios.shape: (1520, 24)
#
# First few rows:
#       Sharpe 3d  Sortino 3d  Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# A     -8.578090   -9.724640  0.133660 -20.008903  -13.107840  0.035408  -11.769157    -9.978208   0.119172   -9.661497    -8.661607   0.159365   -6.955251    -6.948443   0.291651   -4.855183    -5.326868   0.423723    -2.725345     -3.339190    0.626001    -1.336009     -1.708551    0.791007
# AA   -13.990207  -12.381732  0.000000 -25.933875  -14.025664  0.000000  -14.362839   -11.082723   0.058044  -12.372732   -10.070277   0.065104   -5.089000    -5.450813   0.417912   -3.418318    -3.872694   0.556891    -2.385336     -2.861628    0.660848    -0.785485     -1.051124    0.877581
# AAL   -4.838442   -6.762121  0.397582 -10.084630   -9.605393  0.151291   -9.491234    -8.845306   0.195409   -6.814061    -6.963388   0.315075   -7.128093    -7.356382   0.341200   -5.481943    -5.795941   0.388179    -0.999738     -1.410956    0.832801    -0.720277     -1.007867    0.876188
# AAON  -7.370033   -8.897918  0.207310 -16.694801  -12.272320  0.033853   -5.860173    -6.609281   0.370952   -3.813488    -4.741976   0.533854   -2.947506    -3.298919   0.547436   -2.717638    -3.034727   0.575254    -1.140881     -1.454712    0.788239    -0.170917     -0.219438    0.965224
# AAPL -74.527717  -15.697459  0.000000 -40.588218  -15.035442  0.000000  -10.811616    -9.422383   0.133056   -6.792416    -6.644427   0.275136   -6.241941    -6.171364   0.313889   -3.271829    -3.593190   0.548504    -2.108200     -2.387532    0.672707     0.114515      0.150251    1.021098

# %%
# Find items in df_finviz.index that are not in df_perf_ratios.index
missing_tickers = df_finviz.index[~df_finviz.index.isin(df_perf_ratios.index)]
print("Tickers in df_finviz but not in df_perf_ratios:")
print(missing_tickers)
print(f"\nTotal missing tickers: {len(missing_tickers)}")
# Out:
# Tickers in df_finviz but not in df_perf_ratios:
# Index(['STRK', 'OXY', 'FER', 'CRWV', 'SW', 'DG', 'VG', 'HAL', 'VIK', 'DOCU', 'ITCI', 'LINE', 'ULS', 'RBRK', 'SAIL', 'JHX', 'LTM', 'TTAN', 'CX', 'SFD', 'SARO', 'LOAR', 'TEM', 'WAY', 'FLR', 'ALK', 'NMAX', 'TLX', 'FSEC', 'BTC'], dtype='object', name='Ticker')
#
# Total missing tickers: 30

# %%
# Find common tickers (tickers present in both DataFrames' indices)
common_tickers = df_finviz.index[df_finviz.index.isin(df_perf_ratios.index)].tolist() #Convert pandas index to list

print("\nTickers common to both df_finviz and df_perf_ratios:")
print(common_tickers)
print(f"\nTotal common tickers: {len(common_tickers)}")

# Create the empty DataFrame with the common tickers as the index
df_common_tickers = pd.DataFrame(index=common_tickers)
df_common_tickers.to_parquet(COMMON_TICKERS_PATH, engine='pyarrow', compression='zstd')
print(f'Saved df_common_tickers to {COMMON_TICKERS_PATH}')
# Out:
# Tickers common to both df_finviz and df_perf_ratios:
# ['MSFT', 'AAPL', 'NVDA', 'AMZN', 'GOOGL', 'GOOG', 'META', 'BRK-B', 'BRK-A', 'AVGO', 'TSM', 'TSLA', 'LLY', 'WMT', 'JPM', 'V', 'VOO', 'IVV', 'SPY', 'UNH', 'MA', 'XOM', 'COST', 'VTI', 'NFLX', 'PG', 'JNJ', 'ORCL', 'HD', 'ABBV', 'KO', 'TMUS', 'SAP', 'QQQ', 'BAC', 'CVX', 'BABA', 'CRM', 'ASML', 'PM', 'ABT', 'MCD', 'CSCO', 'TM', 'NVO', 'IBM', 'WFC', 'AZN', 'MRK', 'LIN', 'NVS', 'PEP', 'T', 'HDB', 'GE', 'PLTR', 'SHEL', 'VZ', 'ACN', 'HSBC', 'ISRG', 'AXP', 'MS', 'RTX', 'TMO', 'RY', 'PGR', 'INTU', 'NOW', 'AMGN', 'DIS', 'BX', 'UL', 'ADBE', 'GS', 'SPGI', 'QCOM', 'BKNG', 'UBER', 'TJX', 'BSX', 'TXN', 'NEE', 'VUG', 'CAT', 'PDD', 'SCHW', 'VEA', 'SYK', 'GILD', 'SONY', 'BND', 'AMD', 'BLK', 'MUFG', 'DHR', 'UNP', 'CMCSA', 'AGG', 'PFE', 'SNY', 'VRTX', 'VTV', 'HON', 'LOW', 'IEFA', 'ADP', 'DE', 'TTE', 'C', 'CB', 'FI', 'MMC', 'BMY', 'IBN', 'MDT', 'BA', 'AMAT', 'COP', 'LMT', 'SPOT', 'BUD', 'BHP', 'PANW', 'SHOP', 'ETN', 'TD', 'ELV', 'AMT', 'SO', 'MO', 'MELI', 'CME', 'SBUX', 'ARM', 'DUK', 'GLD', 'ENB', 'WELL', 'ANET', 'SAN', 'ICE', 'WM', 'BTI', 'IWF', 'CVS', 'CI', 'PLD', 'RELX', 'KKR', 'MDLZ', 'UBS', 'ADI', 'MCK', 'HCA', 'CRWD', 'IJH', 'APP', 'KLAC', 'AJG', 'INTC', 'SHW', 'NKE', 'SMFG', 'VIG', 'GEV', 'UPS', 'AON', 'LRCX', 'CTAS', 'IEMG', 'ORLY', 'VXUS', 'VWO', 'MU', 'APH', 'TRI', 'EQIX', 'CL', 'MCO', 'RACE', 'NOC', 'RSG', 'TT', 'BAM', 'IJR', 'DASH', 'GSK', 'TDG', 'BP', 'MMM', 'BBVA', 'GD', 'INFY', 'FTNT', 'PH', 'VGT', 'BN', 'ABNB', 'VO', 'WMB', 'RSP', 'MSI', 'RIO', 'ZTS', 'ITW', 'ECL', 'BMO', 'SCHD', 'CDNS', 'BNDX', 'EPD', 'APO', 'CP', 'CMG', 'IBKR', 'MSTR', 'NGG', 'REGN', 'EQNR', 'SCCO', 'PNC', 'SNPS', 'AZO', 'COF', 'MAR', 'CNI', 'CEG', 'EOG', 'BDX', 'IWM', 'NTES', 'XLK', 'PYPL', 'USB', 'DEO', 'ITOT', 'KMI', 'WDAY', 'SE', 'ROP', 'IWD', 'BNS', 'APD', 'MFG', 'AFL', 'CRH', 'AEP', 'SPLG', 'TRV', 'VYM', 'MNST', 'COR', 'EMR', 'ET', 'CNQ', 'SPG', 'VB', 'CPRT', 'BK', 'EFA', 'ING', 'VCIT', 'CM', 'CHTR', 'ADSK', 'NEM', 'DELL', 'CSX', 'AEM', 'LYG', 'TLT', 'PAYX', 'OKE', 'ALL', 'RCL', 'HLT', 'TEAM', 'MPLX', 'CARR', 'NU', 'FDX', 'WCN', 'JCI', 'NSC', 'PSA', 'MET', 'O', 'MFC', 'TRP', 'HWM', 'AIG', 'DLR', 'LNG', 'JD', 'IVW', 'TFC', 'KDP', 'BCS', 'PCAR', 'SCHX', 'IBIT', 'XLF', 'EXC', 'SNOW', 'TAK', 'GWW', 'KMB', 'BIL', 'KR', 'QUAL', 'SLB', 'MRVL', 'PBR', 'NWG', 'D', 'GM', 'HLN', 'FCX', 'ROST', 'SRE', 'IAU', 'SGOV', 'CCI', 'KVUE', 'AMX', 'ALC', 'FICO', 'FAST', 'AMP', 'TGT', 'YUM', 'HES', 'MSCI', 'EW', 'SU', 'HMC', 'MUB', 'NXPI', 'VRSK', 'ARES', 'PEG', 'AXON', 'XEL', 'COIN', 'SCHF', 'ED', 'NDAQ', 'CTVA', 'IEF', 'PSX', 'VT', 'DB', 'LHX', 'CCEP', 'CVNA', 'FLUT', 'DFS', 'E', 'MPC', 'CMI', 'TEL', 'MBB', 'PWR', 'DHI', 'QQQM', 'VEU', 'FIS', 'IXUS', 'URI', 'OTIS', 'JEPI', 'VTEB', 'CPNG', 'VALE', 'VV', 'XLV', 'PCG', 'AME', 'TRGP', 'VST', 'BSV', 'BKR', 'TTWO', 'IWR', 'F', 'EA', 'FANG', 'VCSH', 'ETR', 'RBLX', 'CBRE', 'HUM', 'VEEV', 'TCOM', 'IWB', 'NET', 'PRU', 'GLW', 'IVE', 'DIA', 'GRMN', 'SYY', 'ARGX', 'KHC', 'VLO', 'IUSB', 'CTSH', 'WEC', 'ACGL', 'HSY', 'BRO', 'WPM', 'SCHG', 'ODFL', 'HIG', 'VNQ', 'VGIT', 'JPST', 'LULU', 'VICI', 'GIS', 'CNC', 'STZ', 'CSGP', 'IMO', 'SLF', 'ITUB', 'XYZ', 'HOOD', 'CAH', 'GOLD', 'RMD', 'WTW', 'DDOG', 'VMC', 'TW', 'CHT', 'FERG', 'HEI-A', 'IDXX', 'ALNY', 'WIT', 'IT', 'LQD', 'HEI', 'DKNG', 'VTR', 'EQT', 'DFAC', 'A', 'K', 'PBR-A', 'EXR', 'EBAY', 'SCHB', 'DGRO', 'FNV', 'MLM', 'AWK', 'SPYG', 'LYV', 'WAB', 'ZS', 'XLE', 'LEN', 'CQP', 'IR', 'GEHC', 'AVB', 'GOVT', 'DTE', 'RKT', 'MTB', 'EFX', 'TPL', 'RJF', 'TSCO', 'IQV', 'AEE', 'BR', 'HUBS', 'VBR', 'XYL', 'CHD', 'ANSS', 'NOK', 'PPL', 'ROK', 'WRB', 'TEF', 'OWL', 'ROL', 'STLA', 'EQR', 'VRT', 'NUE', 'TKO', 'DXCM', 'IP', 'PUK', 'ATO', 'EXE', 'DAL', 'CNP', 'SHY', 'DD', 'LPLA', 'GDDY', 'NTR', 'SPYV', 'VGSH', 'IRM', 'CHKP', 'TYL', 'TTD', 'SBAC', 'FITB', 'FTS', 'VRSN', 'BIV', 'KEYS', 'FE', 'VONG', 'USMV', 'DRI', 'CBOE', 'WDS', 'MPWR', 'STT', 'GIB', 'LVS', 'CCL', 'BIDU', 'MKL', 'IGSB', 'FTV', 'SPDW', 'VLTO', 'RYAAY', 'FCNCA', 'CMS', 'TU', 'PPG', 'COWZ', 'BNTX', 'ERIC', 'JEPQ', 'FOX', 'DOV', 'ONC', 'HPQ', 'FOXA', 'JAAA', 'PB ...
#
# Total common tickers: 1520
# Saved df_common_tickers to ..\data\2025-04-08_df_common_tickers.parquet

# %%
print(f'df_finviz.shape before removing missing tickers: {df_finviz.shape}')
# Remove rows where the index matches missing_tickers
df_finviz = df_finviz.drop(missing_tickers)
print(f'df_finviz.shape after removing missing tickers: {df_finviz.shape}')
# Out:
# df_finviz.shape before removing missing tickers: (1550, 29)
# df_finviz.shape after removing missing tickers: (1520, 29)

# %%
print(f'df_perf_ratios.shape before removing duplicate tickers: {df_perf_ratios.shape}')
# Remove duplicates from df_perf_ratios, keeping the first occurrence
df_perf_ratios = df_perf_ratios[~df_perf_ratios.index.duplicated(keep='first')]
print(f'df_perf_ratios.shape after removing duplicate tickers: {df_perf_ratios.shape}')
# Out:
# df_perf_ratios.shape before removing duplicate tickers: (1520, 24)
# df_perf_ratios.shape after removing duplicate tickers: (1520, 24)

# %%
# Find duplicate columns *before* adding suffixes
duplicate_cols = list(set(df_finviz.columns) & set(df_perf_ratios.columns))  # Intersection

if duplicate_cols:
    print(f"Error: Duplicate columns found: {duplicate_cols}")
    raise ValueError(f"Duplicate columns found: {duplicate_cols}")

# Now, perform the join (WITHOUT suffixes)
try:
    df = df_finviz.join(df_perf_ratios)  # Simplified join
    print("Join successful!")
    display(df.head()) # Print first few lines.
    display(df.info())
except ValueError as e:
    print(f"Join failed: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Join successful!
#                       Company                                               Info  MktCap AUM, M  Beta    RSI  Perf YTD %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %    ATR  Volatility W %  Volatility M %   Volume, M  Avg Volume, M  Rel Volume   Price  Change %  Dividend %  Sharpe 3d  Sortino 3d  Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# Ticker
# MSFT    Microsoft Corporation              Technology, Software - Infrastructure      2642330.0  0.96  27.93      -15.67        -7.00         -6.50        -16.92       -14.57       -16.47    -6.74   -10.35    -15.36      -20.73       3.09      -24.11       3.09           -24.11       445991.96  11.57            3.77            2.43   33.164772          24.27        1.37  355.44     -0.68        0.92 -45.398618  -15.410442  0.000000 -21.416836  -13.359034  0.000000   -9.904789    -9.227598   0.169354   -6.646466    -6.807723   0.308928   -4.013925    -4.749789   0.515504   -2.550442    -3.152788   0.634901    -1.447593     -1.781442    0.770120    -0.847879     -1.065872    0.864585
# AAPL                Apple Inc                   Technology, Consumer Electronics      2596840.0  1.32  20.16      -30.97       -22.55        -24.01        -29.44       -23.78         1.94   -18.41   -23.86    -24.40      -30.85      -1.00      -33.54       5.36           -33.54       271636.63   9.46            5.01            3.36  116.315852          56.69        2.05  172.87     -4.73        0.60 -74.527717  -15.697459  0.000000 -40.588218  -15.035442  0.000000  -10.811616    -9.422383   0.133056   -6.792416    -6.644427   0.275136   -6.241941    -6.171364   0.313889   -3.271829    -3.593190   0.548504    -2.108200     -2.387532    0.672707     0.114515      0.150251    1.021098
# NVDA              NVIDIA Corp                         Technology, Semiconductors      2359720.0  2.05  32.54      -27.98       -12.20         -9.60        -35.28       -22.58         9.89   -13.58   -19.39    -23.67      -32.58      11.65      -36.84      27.91           -36.84       290029.98   7.05            7.70            4.91  463.407326         291.28        1.59   96.71     -0.95        0.04   4.868761   17.196317  2.531970  -9.623576   -9.570266  0.211952   -7.576488    -7.586079   0.250123   -6.216728    -6.437295   0.327553   -3.826445    -4.351068   0.534353   -1.732267    -2.077691   0.742901    -0.979389     -1.221932    0.845760     0.399320      0.549344    1.068518
# AMZN           Amazon.com Inc                 Consumer Cyclical, Internet Retail      1813170.0  1.26  29.94      -22.02       -10.97        -12.05        -24.83        -8.27        -7.55   -10.99   -18.46    -14.50      -29.45       6.02      -29.45      12.85           -29.45       260608.58   9.60            6.87            3.74   85.297522          44.34        1.92  171.09     -2.38         NaN  -0.362449   -0.702223  0.937441 -11.195898  -10.311919  0.156621   -7.593173    -7.491678   0.259029   -4.434308    -4.834319   0.456580   -4.477014    -4.865754   0.481137   -2.914220    -3.334242   0.613761    -0.568072     -0.733746    0.910078    -0.261786     -0.344120    0.957009
# GOOGL            Alphabet Inc  Communication Services, Internet Content & Inf...      1777390.0  0.98  28.49      -23.56        -7.88        -12.76        -26.50       -13.38        -5.11    -9.20   -16.57    -16.87      -30.11       2.97      -30.11       2.97           -30.11         5925.84   5.83            3.92            3.05   50.436666          32.93        1.53  144.70     -1.40        0.34  -3.279273   -5.075720  0.547819 -14.762706  -11.732755  0.087295  -10.113594    -9.123520   0.162050   -6.061152    -6.322021   0.368630   -4.376765    -4.835503   0.510890   -3.390199    -3.832010   0.574554    -0.818372     -1.079655    0.873508    -0.229662     -0.314995    0.961134
# <class 'pandas.core.frame.DataFrame'>
# Index: 1520 entries, MSFT to IYH
# Data columns (total 53 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          1520 non-null   object
#  1   Info             1520 non-null   object
#  2   MktCap AUM, M    1520 non-null   float64
#  3   Beta             1519 non-null   float64
#  4   RSI              1520 non-null   float64
#  5   Perf YTD %       1520 non-null   float64
#  6   Perf Week %      1520 non-null   float64
#  7   Perf Month %     1520 non-null   float64
#  8   Perf Quart %     1520 non-null   float64
#  9   Perf Half %      1520 non-null   float64
#  10  Perf Year %      1520 non-null   float64
#  11  SMA20 %          1520 non-null   float64
#  12  SMA50 %          1520 non-null   float64
#  13  SMA200 %         1520 non-null   float64
#  14  50D High %       1520 non-null   float64
#  15  50D Low %        1520 non-null   float64
#  16  52W High %       1520 non-null   float64
#  17  52W Low %        1520 non-null   float64
#  18  All-Time High %  1519 non-null   float64
#  19  All-Time Low %   1518 non-null   float64
#  20  ATR              1520 non-null   float64
#  21  Volatility W %   1520 non-null   float64
#  22  Volatility M %   1520 non-null   float64
#  23  Volume, M        1520 non-null   float64
#  24  Avg Volume, M    1520 non-null   float64
#  25  Rel Volume       1520 non-null   float64
#  26  Price            1520 non-null   float64
#  27  Change %         1520 non-null   float64
#  28  Dividend %       1199 non-null   float64
#  29  Sharpe 3d        1520 non-null   float64
#  30  Sortino 3d       1520 non-null   float64
#  31  Omega 3d         1520 non-null   float64
#  32  Sharpe 5d        1520 non-null   float64
#  33  Sortino 5d       1520 non-null   float64
#  34  Omega 5d         1520 non-null   float64
#  35  Sharpe 10d       1520 non-null   float64
#  36  Sortino 10d      1520 non-null   float64
#  37  Omega 10d        1520 non-null   float64
#  38  Sharpe 15d       1520 non-null   float64
#  39  Sortino 15d      1520 non-null   float64
#  40  Omega 15d        1520 non-null   float64
#  41  Sharpe 30d       1520 non-null   float64
#  42  Sortino 30d      1520 non-null   float64
#  43  Omega 30d        1520 non-null   float64
#  44  Sharpe 60d       1520 non-null   float64
#  45  Sortino 60d      1520 non-null   float64
#  46  Omega 60d        1520 non-null   float64
#  47  Sharpe 120d      1520 non-null   float64
#  48  Sortino 120d     1520 non-null   float64
#  49  Omega 120d       1520 non-null   float64
#  50  Sharpe 250d      1520 non-null   float64
#  51  Sortino 250d     1520 non-null   float64
#  52  Omega 250d       1520 non-null   float64
# dtypes: float64(51), object(2)
# memory usage: 673.5+ KB
# None

# %%
df.to_parquet(DES_PATH, engine='pyarrow', compression='zstd')

print(f"Merged dataframe saved to {DES_PATH}")
# Out:
# Merged dataframe saved to ..\data\2025-04-08_df_finviz_n_ratios.parquet
