# %%
import pandas as pd

# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
pd.set_option('display.width', 1000)

# %%
# process_files.py
from config import date_str, DOWNLOAD_DIR, DEST_DIR
from pathlib import Path  # Better path handling

# Build paths
# source_path = Path(DOWNLOAD_DIR) / f'df_finviz_{date_str}.pkl'
# dest_path = Path(DEST_DIR) / 'df_finviz.pkl'
source_path = Path(DOWNLOAD_DIR) / f'df_finviz_{date_str}.parquet'
dest_path = Path(DEST_DIR) / f'{date_str}_df_finviz.parquet'

print(f"source_path: {source_path}")
print(f"dest_path: {dest_path}")
# Out:
# source_path: C:\Users\ping\Downloads\df_finviz_2025-04-24.parquet
# dest_path: ..\data\2025-04-24_df_finviz.parquet

# %%
import pandas as pd

# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
# pd.set_option('display.width', None)        # Let the display adjust to the window
# pd.set_option('display.max_colwidth', None) # Show full content of each cell

# %%
df = pd.read_parquet(source_path, engine='pyarrow')
# df = pd.read_pickle(source_path)
display(df.info(), df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   No.            1160 non-null   object
#  1   Ticker         1160 non-null   object
#  2   Company        1160 non-null   object
#  3   Sector         1160 non-null   object
#  4   Industry       1160 non-null   object
#  5   Market Cap     1160 non-null   object
#  6   Fwd P/E        1160 non-null   object
#  7   P/S            1160 non-null   object
#  8   P/B            1160 non-null   object
#  9   P/FCF          1160 non-null   object
#  10  Dividend       1160 non-null   object
#  11  ROE            1160 non-null   object
#  12  Debt/Eq        1160 non-null   object
#  13  Oper M         1160 non-null   object
#  14  Perf Week      1160 non-null   object
#  15  Perf Month     1160 non-null   object
#  16  Perf Quart     1160 non-null   object
#  17  Perf Half      1160 non-null   object
#  18  Perf Year      1160 non-null   object
#  19  Perf YTD       1160 non-null   object
#  20  Beta           1160 non-null   object
#  21  ATR            1160 non-null   object
#  22  Volatility W   1160 non-null   object
#  23  Volatility M   1160 non-null   object
#  24  SMA20          1160 non-null   object
#  25  SMA50          1160 non-null   object
#  26  SMA200         1160 non-null   object
#  27  50D High       1160 non-null   object
#  28  50D Low        1160 non-null   object
#  29  52W High       1160 non-null   object
#  30  52W Low        1160 non-null   object
#  31  All-Time High  1160 non-null   object
#  32  All-Time Low   1160 non-null   object
#  33  RSI            1160 non-null   object
#  34  Gap            1160 non-null   object
#  35  Avg Volume     1160 non-null   object
#  36  Rel Volume     1160 non-null   object
#  37  Volume         1160 non-null   object
#  38  Price          1160 non-null   object
#  39  Change         1160 non-null   object
# dtypes: object(40)
# memory usage: 362.6+ KB
# None
#    No. Ticker               Company              Sector                        Industry Market Cap Fwd P/E   P/S    P/B   P/FCF Dividend     ROE Debt/Eq  Oper M Perf Week Perf Month Perf Quart Perf Half Perf Year Perf YTD  Beta   ATR Volatility W Volatility M   SMA20  SMA50  SMA200 50D High 50D Low 52W High 52W Low All-Time High All-Time Low    RSI     Gap Avg Volume Rel Volume      Volume  Price  Change
# 0  281   FAST           Fastenal Co         Industrials         Industrial Distribution     47.09B   34.19  6.19  12.76   54.22    2.08%  32.35%    0.13  19.89%     2.05%      6.50%      8.80%     5.57%    21.72%   14.17%  0.99  2.41        2.29%        3.46%   4.94%  7.06%  10.63%   -0.39%  16.27%   -3.28%  33.80%        -3.28%   164321.28%  60.29   0.19%      3.65M       0.91   3,310,737  82.10   2.38%
# 1  282    ALC             Alcon Inc          Healthcare  Medical Instruments & Supplies     46.83B   25.32  4.72   2.17   29.19    0.38%   4.83%    0.24  14.30%     2.86%      2.03%      6.25%     0.36%    17.45%   11.53%  1.05  2.59        2.05%        2.82%   4.14%  4.18%   3.70%   -2.79%  17.64%   -6.35%  22.10%        -6.35%      140.49%  58.77   0.26%      1.71M       0.84   1,436,243  94.68   1.05%
# 2  283    EXC           Exelon Corp           Utilities  Utilities - Regulated Electric     46.77B   16.46  2.03   1.73       -    3.50%   9.34%    1.75  18.71%    -0.39%      8.35%     18.07%    14.40%    22.99%   23.09%  0.40  1.20        2.34%        2.73%   0.91%  4.10%  15.71%   -3.70%  13.53%   -3.70%  36.24%       -29.22%     1349.16%  55.07  -0.34%      8.96M       0.70   6,241,345  46.33  -1.00%
# 3  284    KDP  Keurig Dr Pepper Inc  Consumer Defensive       Beverages - Non-Alcoholic     46.75B   15.83  3.01   1.91   28.23    2.68%   6.13%    0.65  23.17%    -1.85%      1.86%     10.98%    -6.69%     8.50%    7.29%  0.51  0.89        2.48%        2.68%  -0.92%  1.60%   1.44%   -4.60%  11.72%   -9.98%  14.41%       -16.58%     1709.21%  49.18  -3.18%     14.10M       1.12  15,723,550  34.46  -2.07%
# 4  285    HMC       Honda Motor ADR   Consumer Cyclical              Auto Manufacturers     46.61B    6.67  0.32   0.56  179.08    4.64%   8.11%    0.88   6.61%     5.90%      0.03%      5.38%    -1.18%   -12.76%    5.57%  0.53  0.85        1.49%        2.85%   8.79%  6.66%   2.88%   -0.94%  22.72%  -13.86%  28.75%       -32.36%     1699.40%  62.80   0.37%      1.22M       0.86   1,042,501  30.14   1.55%

# %%
import numpy as np

def convert_B_M_K_to_million(value_str):
  """
  Convert financial string values with suffixes to numeric values in billions
  Examples:
  '104.27B' -> 104,270
  '104.27M' -> 104.27
  '104.27K' -> 0.10427
  '-' -> np.nan
  """
  
  if not isinstance(value_str, str):
    return value_str  # Return the original value if not a string
    
  if value_str == '-':
    return np.nan
    
  # Remove any whitespace
  value_str = value_str.strip()
  
  # Handle suffixes
  multipliers = {
    'B': 1000,  
    'M': 1,
    'K': 0.001
  }
  
  try:
    # Extract the numeric part and suffix
    if value_str[-1] in multipliers:
      number = float(value_str[:-1])
      multiplier = multipliers[value_str[-1]]
      return number * multiplier
    else:
      # If no suffix, try to convert directly to float
      return float(value_str)
  except (ValueError, IndexError):
    return np.nan

# Example usage:
# df['Market Cap Numeric'] = df['Market Cap'].apply(convert_B_M_K_to_million)

# %%
import pandas as pd
import numpy as np

def process_percentage_columns(df):
    """
    Identifies and processes columns in a DataFrame where values end with '%'.
    The function cleans, converts to numeric, renames, and prints which columns were modified.

    Args:
        df (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: The modified DataFrame with processed percentage columns.
                      Returns the original DataFrame if no percentage columns are found.
    """

    # Identify columns where values END WITH '%'
    percent_cols = [
        col for col in df.columns
        if df[col].dtype == 'object'
        and df[col].str.strip().str.endswith('%', na=False).any()
    ]

    # If no percentage columns are found, return the original DataFrame
    if not percent_cols:
        print("No percentage columns found to modify.")  # Print message
        return df

    print("The following columns ending with % were modified:") #Print message before the loop

    # Process identified percentage columns
    for col in percent_cols:
        # Clean data: (1) Strip whitespace, (2) Handle '-', (3) Remove trailing %
        cleaned_series = (
            df[col].str.strip()
            .replace('-', np.nan)  # Convert '-' to NaN
            .str.replace(r'%$', '', regex=True)  # Remove only ENDING %
        )
        
        # Convert to numeric (coerce invalid values to NaN)
        df[col] = pd.to_numeric(cleaned_series, errors='coerce')
        
        # Rename column
        df.rename(columns={col: f"{col} %"}, inplace=True)
        print(f"- {col}")  # Print the column name
        
    return df

# Example Usage:
# Assuming you have a DataFrame called 'df'
# df = process_percentage_columns(df)

# %%
df = process_percentage_columns(df)
# Out:
# The following columns ending with % were modified:
# - Dividend
# - ROE
# - Oper M
# - Perf Week
# - Perf Month
# - Perf Quart
# - Perf Half
# - Perf Year
# - Perf YTD
# - Volatility W
# - Volatility M
# - SMA20
# - SMA50
# - SMA200
# - 50D High
# - 50D Low
# - 52W High
# - 52W Low
# - All-Time High
# - All-Time Low
# - Gap
# - Change

# %%
# List of columns to concatenate
# columns_to_concat = ["Sector", "Industry", "Single Category", "Asset Type"]
columns_to_concat = ["Sector", "Industry"]

# Replace '-' with empty string in specified columns
for col in columns_to_concat:
    df[col] = df[col].replace('-', '')

# Concatenate the columns, handling empty strings, and remove extra spaces
df['Info'] = df[columns_to_concat].apply(lambda row: ', '.join(filter(None, row.astype(str))), axis=1)

# %%
df
# Out:
#       No. Ticker                      Company              Sector                        Industry Market Cap Fwd P/E    P/S    P/B   P/FCF  Dividend %  ROE % Debt/Eq  Oper M %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  Perf YTD %  Beta    ATR  Volatility W %  Volatility M %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %    RSI  Gap % Avg Volume Rel Volume      Volume   Price  Change %                                           Info
# 0     281   FAST                  Fastenal Co         Industrials         Industrial Distribution     47.09B   34.19   6.19  12.76   54.22        2.08  32.35    0.13     19.89         2.05          6.50          8.80         5.57        21.72       14.17  0.99   2.41            2.29            3.46     4.94     7.06     10.63       -0.39      16.27       -3.28      33.80            -3.28       164321.28  60.29   0.19      3.65M       0.91   3,310,737   82.10      2.38           Industrials, Industrial Distribution
# 1     282    ALC                    Alcon Inc          Healthcare  Medical Instruments & Supplies     46.83B   25.32   4.72   2.17   29.19        0.38   4.83    0.24     14.30         2.86          2.03          6.25         0.36        17.45       11.53  1.05   2.59            2.05            2.82     4.14     4.18      3.70       -2.79      17.64       -6.35      22.10            -6.35          140.49  58.77   0.26      1.71M       0.84   1,436,243   94.68      1.05     Healthcare, Medical Instruments & Supplies
# 2     283    EXC                  Exelon Corp           Utilities  Utilities - Regulated Electric     46.77B   16.46   2.03   1.73       -        3.50   9.34    1.75     18.71        -0.39          8.35         18.07        14.40        22.99       23.09  0.40   1.20            2.34            2.73     0.91     4.10     15.71       -3.70      13.53       -3.70      36.24           -29.22         1349.16  55.07  -0.34      8.96M       0.70   6,241,345   46.33     -1.00      Utilities, Utilities - Regulated Electric
# 3     284    KDP         Keurig Dr Pepper Inc  Consumer Defensive       Beverages - Non-Alcoholic     46.75B   15.83   3.01   1.91   28.23        2.68   6.13    0.65     23.17        -1.85          1.86         10.98        -6.69         8.50        7.29  0.51   0.89            2.48            2.68    -0.92     1.60      1.44       -4.60      11.72       -9.98      14.41           -16.58         1709.21  49.18  -3.18     14.10M       1.12  15,723,550   34.46     -2.07  Consumer Defensive, Beverages - Non-Alcoholic
# 4     285    HMC              Honda Motor ADR   Consumer Cyclical              Auto Manufacturers     46.61B    6.67   0.32   0.56  179.08        4.64   8.11    0.88      6.61         5.90          0.03          5.38        -1.18       -12.76        5.57  0.53   0.85            1.49            2.85     8.79     6.66      2.88       -0.94      22.72      -13.86      28.75           -32.36         1699.40  62.80   0.37      1.22M       0.86   1,042,501   30.14      1.55          Consumer Cyclical, Auto Manufacturers
# ...   ...    ...                          ...                 ...                             ...        ...     ...    ...    ...     ...         ...    ...     ...       ...          ...           ...           ...          ...          ...         ...   ...    ...             ...             ...      ...      ...       ...         ...        ...         ...        ...              ...             ...    ...    ...        ...        ...         ...     ...       ...                                            ...
# 1155  596   KSPI             Kaspi.kz JSC ADR          Technology       Software - Infrastructure     16.79B    5.72   3.12   5.81    7.46        2.37  83.96    0.09     50.56         7.01         -8.19         -7.64       -20.34       -22.00       -6.68     -   4.10            3.75            4.61     1.20    -7.31    -17.73      -20.70      13.60      -38.51      13.60           -38.51          106.53  48.73   0.15    344.87K       0.42     145,922   88.38      0.01          Technology, Software - Infrastructure
# 1156  597   DECK         Deckers Outdoor Corp   Consumer Cyclical          Footwear & Accessories     16.79B   17.08   3.41   6.38   16.73         NaN  39.80    0.10     23.50         7.41        -10.02        -49.38       -30.85       -18.06      -45.52  1.11   6.75            4.28            6.37     2.05   -10.22    -30.99      -31.10      18.06      -50.60      18.06           -50.60       159235.69  47.03   0.49      3.61M       0.63   2,272,585  110.65      3.74      Consumer Cyclical, Footwear & Accessories
# 1157  598   GWRE       Guidewire Software Inc          Technology          Software - Application     16.77B   74.94  15.46  13.22   81.80         NaN  -1.34    0.70      0.01         4.10          0.83         -2.29         5.76        82.09       18.59  1.17   8.02            3.52            4.34     6.37     3.82     11.58       -8.92      21.10       -8.96      85.71            -8.96         1115.32  58.94   0.03      1.18M       0.73     867,947  199.92      3.11             Technology, Software - Application
# 1158  599    DPZ            Dominos Pizza Inc   Consumer Cyclical                     Restaurants     16.74B   25.19   3.56      -   32.69        1.45    NaN       -     18.71         5.56          6.02          8.98        13.14         3.54       16.25  1.13  16.56            2.66            3.88     5.39     5.19     10.51       -2.51      16.43      -10.09      23.21           -14.02        20101.90  61.07  -0.67    685.00K       0.74     506,858  487.97      0.43                 Consumer Cyclical, Restaurants
# 1159  600   CASY  Casey's General Stores, Inc   Consumer Cyclical                Specialty Retail     16.60B   28.47   1.07   4.86   31.71        0.45  16.82    0.91      4.98        -2.20          7.16          9.69        14.07        42.69       12.89  0.68  15.99            2.59            4.04     0.84     5.80     11.78       -4.60      20.21       -4.60      43.13            -4.60        51018.86  54.63  -0.31    370.35K       0.90     332,658  447.29     -1.78            Consumer Cyclical, Specialty Retail
#
# [1160 rows x 41 columns]

# %%
# # Replace '-' with empty string in both columns

# df['MktCap AUM'] = df['Market Cap'].replace('-', '') + df['AUM'].replace('-', '')

# %%
# # Concatenate the columns 'Market Cap' and 'AUM'
# # Replace '-' with empty string in both columns

# df['MktCap AUM'] = df['Market Cap'].replace('-', '') + df['AUM'].replace('-', '')

# %%
# Create new column by converting to numeric values in millions
df['MktCap, M'] = df['Market Cap'].apply(convert_B_M_K_to_million)
df['Avg Volume, M'] = df['Avg Volume'].apply(convert_B_M_K_to_million)
df['Volume, M'] = (pd.to_numeric(df['Volume'].str.replace(',', ''), errors='coerce') / 1_000_000)

# %%
# Convert 'Beta', 'ATR', 'Rel Volume', and 'Price' to float
for col in ['Beta', 'ATR', 'RSI', 'Rel Volume', 'Price', 'Fwd P/E', 'P/S', 'P/B', 'P/FCF', 'Debt/Eq']:
  # Clean and convert to numeric
  df[col] = pd.to_numeric(
    df[col].str.replace('$', '').str.replace(',', ''),
    errors='coerce'  # Convert invalid values to NaN
  )

# Verify the conversion
for col in ['Beta', 'ATR', 'Rel Volume', 'Price']:
  print(f"{col}: {df[col].dtype}")
# Out:
# Beta: float64
# ATR: float64
# Rel Volume: float64
# Price: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 44 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No.              1160 non-null   object
#  1   Ticker           1160 non-null   object
#  2   Company          1160 non-null   object
#  3   Sector           1160 non-null   object
#  4   Industry         1160 non-null   object
#  5   Market Cap       1160 non-null   object
#  6   Fwd P/E          1115 non-null   float64
#  7   P/S              1146 non-null   float64
#  8   P/B              1102 non-null   float64
#  9   P/FCF            987 non-null    float64
#  10  Dividend %       836 non-null    float64
#  11  ROE %            1095 non-null   float64
#  12  Debt/Eq          1100 non-null   float64
#  13  Oper M %         1143 non-null   float64
#  14  Perf Week %      1160 non-null   float64
#  15  Perf Month %     1159 non-null   float64
#  16  Perf Quart %     1156 non-null   float64
#  17  Perf Half %      1154 non-null   float64
#  18  Perf Year %      1146 non-null   float64
#  19  Perf YTD %       1160 non-null   float64
#  20  Beta             1145 non-null   float64
#  21  ATR              1160 non-null   float64
#  22  Volatility W %   1160 non-null   float64
#  23  Volatility M %   1159 non-null   float64
#  24  SMA20 %          1160 non-null   float64
#  25  SMA50 %          1160 non-null   float64
#  26  SMA200 %         1160 non-null   float64
#  27  50D High %       1160 non-null   float64
#  28  50D Low %        1160 non-null   float64
#  29  52W High %       1160 non-null   float64
#  30  52W Low %        1160 non-null   float64
#  31  All-Time High %  1159 non-null   float64
#  32  All-Time Low %   1158 non-null   float64
#  33  RSI              1160 non-null   float64
#  34  Gap %            1160 non-null   float64
#  35  Avg Volume       1160 non-null   object
#  36  Rel Volume       1160 non-null   float64
#  37  Volume           1160 non-null   object
#  38  Price            1160 non-null   float64
#  39  Change %         1160 non-null   float64
#  40  Info             1160 non-null   object
#  41  MktCap, M        1160 non-null   float64
#  42  Avg Volume, M    1160 non-null   float64
#  43  Volume, M        1160 non-null   float64
# dtypes: float64(35), object(9)
# memory usage: 398.9+ KB

# %%
df.columns
# Out:
# Index(['No.', 'Ticker', 'Company', 'Sector', 'Industry', 'Market Cap', 'Fwd P/E', 'P/S', 'P/B', 'P/FCF', 'Dividend %', 'ROE %', 'Debt/Eq', 'Oper M %', 'Perf Week %', 'Perf Month %', 'Perf Quart %', 'Perf Half %', 'Perf Year %', 'Perf YTD %', 'Beta', 'ATR', 'Volatility W %', 'Volatility M %', 'SMA20 %', 'SMA50 %', 'SMA200 %', '50D High %', '50D Low %', '52W High %', '52W Low %', 'All-Time High %', 'All-Time Low %', 'RSI', 'Gap %', 'Avg Volume', 'Rel Volume', 'Volume', 'Price', 'Change %', 'Info', 'MktCap, M', 'Avg Volume, M', 'Volume, M'], dtype='object')

# %%
df.head()
# Out:
#    No. Ticker               Company              Sector                        Industry Market Cap  Fwd P/E   P/S    P/B   P/FCF  Dividend %  ROE %  Debt/Eq  Oper M %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  Perf YTD %  Beta   ATR  Volatility W %  Volatility M %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %    RSI  Gap % Avg Volume  Rel Volume      Volume  Price  Change %                                           Info  MktCap, M  Avg Volume, M  Volume, M
# 0  281   FAST           Fastenal Co         Industrials         Industrial Distribution     47.09B    34.19  6.19  12.76   54.22        2.08  32.35     0.13     19.89         2.05          6.50          8.80         5.57        21.72       14.17  0.99  2.41            2.29            3.46     4.94     7.06     10.63       -0.39      16.27       -3.28      33.80            -3.28       164321.28  60.29   0.19      3.65M        0.91   3,310,737  82.10      2.38           Industrials, Industrial Distribution    47090.0           3.65   3.310737
# 1  282    ALC             Alcon Inc          Healthcare  Medical Instruments & Supplies     46.83B    25.32  4.72   2.17   29.19        0.38   4.83     0.24     14.30         2.86          2.03          6.25         0.36        17.45       11.53  1.05  2.59            2.05            2.82     4.14     4.18      3.70       -2.79      17.64       -6.35      22.10            -6.35          140.49  58.77   0.26      1.71M        0.84   1,436,243  94.68      1.05     Healthcare, Medical Instruments & Supplies    46830.0           1.71   1.436243
# 2  283    EXC           Exelon Corp           Utilities  Utilities - Regulated Electric     46.77B    16.46  2.03   1.73     NaN        3.50   9.34     1.75     18.71        -0.39          8.35         18.07        14.40        22.99       23.09  0.40  1.20            2.34            2.73     0.91     4.10     15.71       -3.70      13.53       -3.70      36.24           -29.22         1349.16  55.07  -0.34      8.96M        0.70   6,241,345  46.33     -1.00      Utilities, Utilities - Regulated Electric    46770.0           8.96   6.241345
# 3  284    KDP  Keurig Dr Pepper Inc  Consumer Defensive       Beverages - Non-Alcoholic     46.75B    15.83  3.01   1.91   28.23        2.68   6.13     0.65     23.17        -1.85          1.86         10.98        -6.69         8.50        7.29  0.51  0.89            2.48            2.68    -0.92     1.60      1.44       -4.60      11.72       -9.98      14.41           -16.58         1709.21  49.18  -3.18     14.10M        1.12  15,723,550  34.46     -2.07  Consumer Defensive, Beverages - Non-Alcoholic    46750.0          14.10  15.723550
# 4  285    HMC       Honda Motor ADR   Consumer Cyclical              Auto Manufacturers     46.61B     6.67  0.32   0.56  179.08        4.64   8.11     0.88      6.61         5.90          0.03          5.38        -1.18       -12.76        5.57  0.53  0.85            1.49            2.85     8.79     6.66      2.88       -0.94      22.72      -13.86      28.75           -32.36         1699.40  62.80   0.37      1.22M        0.86   1,042,501  30.14      1.55          Consumer Cyclical, Auto Manufacturers    46610.0           1.22   1.042501

# %%
my_cols = ['Ticker', 'Company', 'Info', 'MktCap, M', 'Beta',
          'RSI', 'Perf YTD %', 'Perf Week %', 'Perf Month %', 'Perf Quart %', 'Perf Half %', 'Perf Year %',
          'SMA20 %', 'SMA50 %', 'SMA200 %',   
          '50D High %', '50D Low %', '52W High %', '52W Low %', 'All-Time High %', 'All-Time Low %',
          'ATR', 'Volatility W %', 'Volatility M %',  
          'Volume, M', 'Avg Volume, M','Rel Volume',
          'Price', 'Change %', 'Dividend %', 
          'Fwd P/E', 'P/S', 'P/B', 'P/FCF', 'ROE %', 'Debt/Eq', 'Oper M %',
          ]

# %%
# Create new df with my_cols and set Ticker as index
new_df = df[my_cols].set_index('Ticker')

# Sort by 'MktCap, M' in descending order, with NaN values last
new_df = new_df.sort_values(by='MktCap, M', ascending=False, na_position='last')

# Display info and first few rows to verify
display(new_df.info(), new_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1160 entries, AAPL to VRNA
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          1160 non-null   object
#  1   Info             1160 non-null   object
#  2   MktCap, M        1160 non-null   float64
#  3   Beta             1145 non-null   float64
#  4   RSI              1160 non-null   float64
#  5   Perf YTD %       1160 non-null   float64
#  6   Perf Week %      1160 non-null   float64
#  7   Perf Month %     1159 non-null   float64
#  8   Perf Quart %     1156 non-null   float64
#  9   Perf Half %      1154 non-null   float64
#  10  Perf Year %      1146 non-null   float64
#  11  SMA20 %          1160 non-null   float64
#  12  SMA50 %          1160 non-null   float64
#  13  SMA200 %         1160 non-null   float64
#  14  50D High %       1160 non-null   float64
#  15  50D Low %        1160 non-null   float64
#  16  52W High %       1160 non-null   float64
#  17  52W Low %        1160 non-null   float64
#  18  All-Time High %  1159 non-null   float64
#  19  All-Time Low %   1158 non-null   float64
#  20  ATR              1160 non-null   float64
#  21  Volatility W %   1160 non-null   float64
#  22  Volatility M %   1159 non-null   float64
#  23  Volume, M        1160 non-null   float64
#  24  Avg Volume, M    1160 non-null   float64
#  25  Rel Volume       1160 non-null   float64
#  26  Price            1160 non-null   float64
#  27  Change %         1160 non-null   float64
#  28  Dividend %       836 non-null    float64
#  29  Fwd P/E          1115 non-null   float64
#  30  P/S              1146 non-null   float64
#  31  P/B              1102 non-null   float64
#  32  P/FCF            987 non-null    float64
#  33  ROE %            1095 non-null   float64
#  34  Debt/Eq          1100 non-null   float64
#  35  Oper M %         1143 non-null   float64
# dtypes: float64(34), object(2)
# memory usage: 335.3+ KB
# None
#                          Company                                               Info  MktCap, M  Beta    RSI  Perf YTD %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %    ATR  Volatility W %  Volatility M %   Volume, M  Avg Volume, M  Rel Volume   Price  Change %  Dividend %  Fwd P/E     P/S    P/B  P/FCF   ROE %  Debt/Eq  Oper M %
# Ticker
# AAPL                   Apple Inc                   Technology, Consumer Electronics  3130150.0  1.28  51.38      -16.79         7.26         -6.87         -6.84       -11.89        25.65     3.01    -5.08     -8.50      -16.65      23.14      -19.89      25.37           -19.89       327443.34   9.70            2.54            4.95   47.068219       61.27000        0.77  208.37      1.84        0.50    26.19    7.91  46.95  31.84  136.52     1.45     31.76
# MSFT       Microsoft Corporation              Technology, Software - Infrastructure  2879180.0  0.98  53.88       -8.11         4.22         -1.99        -13.30        -7.52        -3.41     3.07    -0.07     -6.83       -7.63      12.33      -17.31      12.33           -17.31       485977.56  12.96            2.44            3.51   22.112266       25.25000        0.88  387.30      3.45        0.84    26.05   11.00   9.51  41.11   34.29     0.34     44.96
# NVDA                 NVIDIA Corp                         Technology, Semiconductors  2596890.0  2.11  48.24      -20.75         1.86        -11.82        -27.71       -25.94        33.84     1.04    -7.97    -15.31      -25.80      22.87      -30.50      36.06           -30.50       319189.98   6.87            3.54            6.44  217.554746      315.27000        0.69  106.43      3.62        0.04    18.89   19.90  32.84  42.67  119.18     0.13     62.42
# AMZN              Amazon.com Inc                 Consumer Cyclical, Internet Retail  1979630.0  1.30  50.46      -14.97         7.00         -9.32        -20.76        -1.34         5.25     2.46    -5.48     -6.39      -20.09      15.59      -23.08      23.04           -23.08       284151.43   9.48            3.42            5.25   41.939276       49.43000        0.85  186.54      3.29         NaN    24.99    3.10   6.91  60.21   24.29     0.52     10.87
# GOOGL               Alphabet Inc  Communication Services, Internet Content & Inf...  1954980.0  1.00  51.72      -15.86         3.88         -6.61        -19.55        -2.92         1.92     3.58    -3.25     -7.62      -14.80      13.34      -23.07      13.34           -23.07         6533.01   5.86            2.68            3.84   42.683931       35.08000        1.22  159.28      2.53        0.31    15.90    5.59   5.98  26.87   32.91     0.09     32.46
# ...                          ...                                                ...        ...   ...    ...         ...          ...           ...           ...          ...          ...      ...      ...       ...         ...        ...         ...        ...              ...             ...    ...             ...             ...         ...            ...         ...     ...       ...         ...      ...     ...    ...    ...     ...      ...       ...
# HOMB         Home Bancshares Inc                        Financial, Banks - Regional     5520.0  0.77  56.04       -1.70         7.08         -2.35         -7.39         4.98        14.49     4.38    -0.89     -1.26      -10.95      14.86      -15.45      24.09           -15.45          761.82   1.00            2.92            3.91    0.931559        1.13000        0.83   27.82      1.05        2.85    12.04    3.77   1.36  13.19   10.63     0.30     36.71
# JXN        Jackson Financial Inc                        Financial, Insurance - Life     5510.0  1.54  48.53      -12.29         6.62        -13.86        -19.79       -21.59        13.91     0.69    -7.10    -14.22      -22.08      18.05      -33.71      18.05           -33.71          242.66   4.48            3.68            6.09    0.611443        0.97926        0.62   76.38      2.66        4.19     3.63    1.68   0.61   0.95    9.49     0.21     34.33
# BPMC    Blueprint Medicines Corp                          Healthcare, Biotechnology     5500.0  0.83  50.62       -1.30         4.85         -7.51        -25.55         0.56        -4.99     2.21    -2.83     -9.06      -17.95      17.87      -29.38      17.87           -31.46          560.20   3.99            3.08            5.16    0.762848        1.06000        0.72   86.09      0.33        0.39    83.44   10.81  18.37    NaN  -31.26     2.43    -41.67
# LB        Landbridge Company LLC             Energy, Oil & Gas Equipment & Services     5490.0   NaN  54.17       11.18         6.16         -9.30        -10.75        32.93          NaN     5.84     3.59     27.61      -14.71      31.68      -15.21     283.04           -15.21          283.04   5.38            4.83            8.97    0.331256        0.66449        0.50   71.82      2.63        0.77    32.59   49.94   3.83    NaN     NaN     0.87    -15.02
# VRNA       Verona Pharma Plc ADR                          Healthcare, Biotechnology     5480.0  0.24  59.60       39.49        11.11         -2.12         19.79        85.24       312.09     9.50     3.27     52.79       -7.98      37.23       -7.98     468.74            -7.98         3122.89   3.81            4.56            7.29    1.459492        1.37000        1.06   64.78      2.32         NaN   112.66  130.53  26.80    NaN  -76.51     0.60   -368.92
#
# [1160 rows x 36 columns]

# %%
# Save to pickle file
# new_df.to_pickle(dest_path)

# Using PyArrow (default, recommended for most cases)
new_df.to_parquet(dest_path, engine='pyarrow', compression='zstd')
print(f'save new_df to {dest_path}')

# # To load it later:
# loaded_df = pd.read_pickle('df_finviz.pkl')
# Out:
# save new_df to ..\data\2025-04-24_df_finviz.parquet
