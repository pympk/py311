# %% [markdown]
# #### Read the adjusted OHLCV data for the ticker csv files in Yloader directory, write the OHLCV data to a multilevel index dataframe, save the dataframe in data directory

# %%
# --- SCRIPT CONFIGURATION ---
# Define the directory where YOUR CSV files are located
data_dir = 'C:/Users/ping/Desktop/yloader' # <--- SET YOUR ACTUAL DATA DIRECTORY HERE
# For testing with a different directory, you can modify the line above, or temporarily use a line like:
# data_dir = 'C:/Users/ping/Desktop/test' # <--- SET YOUR TEST DATA DIRECTORY HERE

# Define the destination path for the output Parquet file
DEST_PATH = 'C:/Users/ping/Files_win10/python/py311/stocks/data/df_OHLCV_stocks_etfs.parquet'

# %%
import pandas as pd
import os
# import numpy as np # Only needed if you were to use np.nan explicitly somewhere

# Define the canonical column names for the data columns in your CSV files.
# It is assumed that:
# 1. CSV files do NOT have a header row.
# 2. The FIRST column in each CSV is 'Date'.
# 3. The columns FOLLOWING 'Date' correspond, in order, to the names in this list.
CANONICAL_COLUMN_NAMES = ['Adj Open', 'Adj High', 'Adj Low', 'Adj Close', 'Volume']

# --- CORE LOGIC ---
def process_csv_files(data_dir_path, canonical_data_column_names):
    """
    Processes multiple CSV files from a specified directory, combining them into a single DataFrame.

    Each CSV file is expected to:
    - Not have a header row.
    - Have its first column containing dates (named 'Date' internally).
    - Have subsequent columns matching the `canonical_data_column_names` in order and count.

    The function extracts a ticker symbol from each filename (e.g., "TICKER.csv" -> "TICKER").
    It then concatenates all data into a pandas DataFrame with a MultiIndex ('Ticker', 'Date').
    The final DataFrame is sorted primarily by 'Ticker' (alphabetically ascending, A-Z),
    and then, for each ticker, by 'Date' (newest first).

    Args:
        data_dir_path (str): The path to the directory containing the CSV files.
        canonical_data_column_names (list of str): A list of column names for the data
                                                   fields, appearing after the 'Date' column.

    Returns:
        pandas.DataFrame or None: A MultiIndex DataFrame containing all processed data,
                                  sorted as described. Returns None if no data is
                                  processed or a critical error occurs (e.g., directory not found).
    """
    all_dataframes = []
    tickers_list = []

    # Check if the directory exists
    if not os.path.isdir(data_dir_path):
        print(f"Error: Directory not found: {data_dir_path}")
        return None

    # Get all CSV files in the directory
    csv_files = [f for f in os.listdir(data_dir_path) 
                 if f.endswith('.csv') and os.path.isfile(os.path.join(data_dir_path, f))]

    if not csv_files:
        print(f"No CSV files found in directory: {data_dir_path}")
        return None
    
    print(f"Found CSV files: {csv_files}")

    # Define the complete list of column names expected in the CSV files.
    # The first column is 'Date', followed by the canonical data columns.
    expected_csv_column_names = ['Date'] + canonical_data_column_names

    for filename in csv_files:
        ticker = filename.replace('.csv', '') # Extract ticker from filename
        file_path = os.path.join(data_dir_path, filename)
        
        try:
            # Read the CSV file:
            df_temp = pd.read_csv(
                file_path,
                header=None,
                names=expected_csv_column_names,
                parse_dates=['Date'] 
            )
            
            df_temp.set_index('Date', inplace=True)
            
            if not isinstance(df_temp.index, pd.DatetimeIndex):
                print(f"Warning: 'Date' column in {filename} could not be parsed as dates. Skipping {ticker}.")
                continue

            if list(df_temp.columns) != canonical_data_column_names:
                print(f"Warning: Columns in {filename} ({list(df_temp.columns)}) "
                      f"do not perfectly match or align with CANONICAL_COLUMN_NAMES ({canonical_data_column_names}) "
                      f"after initial load. Reindexing to conform.")
                df_temp = df_temp.reindex(columns=canonical_data_column_names)

            all_dataframes.append(df_temp)
            tickers_list.append(ticker)
            print(f"Successfully processed: {filename}")
            
        except pd.errors.EmptyDataError:
            print(f"Warning: File {filename} is empty or contains no data. Skipping.")
        except pd.errors.ParserError as pe:
            print(f"Error parsing file {filename}: {pe}. "
                  f"Ensure it has exactly {len(expected_csv_column_names)} columns and valid data. Skipping.")
        except Exception as e:
            print(f"An unexpected error occurred while processing file {filename}: {e}. Skipping.")

    if not all_dataframes:
        print("No dataframes were successfully loaded or concatenated.")
        return None

    multi_index_df = pd.concat(all_dataframes, keys=tickers_list, names=['Ticker', 'Date'])
    
    # Sort the final DataFrame.
    # Primary sort key: 'Ticker' (alphabetical ascending, A-Z).
    # Secondary sort key: 'Date' (descending, newest dates first for each ticker).
    # This matches the indexing pattern shown in the example:
    # ('MDT', Timestamp('YYYY-MM-DD')) to ('SNAP', Timestamp('YYYY-MM-DD'))
    multi_index_df.sort_index(level=['Ticker', 'Date'], ascending=[True, False], inplace=True)
    
    if multi_index_df.columns.has_duplicates:
        print("\nWarning: Duplicate columns detected in the final DataFrame. Merging them using 'max' strategy...")
        multi_index_df = multi_index_df.groupby(level=0, axis=1).max()
        print("Duplicate columns merged.")
        
    return multi_index_df

# %%
print("Starting CSV processing...")
final_df = process_csv_files(data_dir, CANONICAL_COLUMN_NAMES)

if final_df is not None:
    print("\n--- MultiIndex DataFrame (First 5 Rows) ---")
    print(final_df.head()) 

    print("\n--- DataFrame Info ---")
    final_df.info() 

    if not final_df.empty:
        example_ticker_to_show = 'NVDA' 
        available_tickers = final_df.index.get_level_values('Ticker').unique()
        
        if example_ticker_to_show not in available_tickers:
            if len(available_tickers) > 0:
                example_ticker_to_show = available_tickers[0]
            else:
                example_ticker_to_show = None 
        
        if example_ticker_to_show:
            print(f"\n--- First 5 rows of '{example_ticker_to_show}' data (sorted by Date descending within Ticker) ---")
            print(final_df.loc[example_ticker_to_show].head())
        else:
            print("\nNo ticker data available in the final DataFrame to display as an example.")
else:
    print("CSV processing finished, but no data was loaded into the final DataFrame.")
# Out:
# Starting CSV processing...
# Found CSV files: ['A.csv', 'AA.csv', 'AAL.csv', 'AAON.csv', 'AAPL.csv', 'ABBV.csv', 'ABEV.csv', 'ABNB.csv', 'ABT.csv', 'ACGL.csv', 'ACI.csv', 'ACIW.csv', 'ACM.csv', 'ACN.csv', 'ACWI.csv', 'ACWV.csv', 'ACWX.csv', 'ADBE.csv', 'ADC.csv', 'ADI.csv', 'ADM.csv', 'ADMA.csv', 'ADP.csv', 'ADSK.csv', 'ADT.csv', 'AEE.csv', 'AEG.csv', 'AEM.csv', 'AEP.csv', 'AER.csv', 'AES.csv', 'AFG.csv', 'AFL.csv', 'AFRM.csv', 'AGCO.csv', 'AGG.csv', 'AGI.csv', 'AGNC.csv', 'AIG.csv', 'AIRR.csv', 'AIT.csv', 'AIZ.csv', 'AJG.csv', 'AKAM.csv', 'AL.csv', 'ALAB.csv', 'ALB.csv', 'ALC.csv', 'ALGN.csv', 'ALK.csv', 'ALL.csv', 'ALLE.csv', 'ALLY.csv', 'ALNY.csv', 'ALSN.csv', 'ALV.csv', 'AM.csv', 'AMAT.csv', 'AMCR.csv', 'AMD.csv', 'AME.csv', 'AMGN.csv', 'AMH.csv', 'AMLP.csv', 'AMP.csv', 'AMT.csv', 'AMX.csv', 'AMZN.csv', 'AN.csv', 'ANET.csv', 'ANSS.csv', 'AON.csv', 'AOS.csv', 'APA.csv', 'APD.csv', 'APG.csv', 'APH.csv', 'APO.csv', 'APP.csv', 'APPF.csv', 'APTV.csv', 'AR.csv', 'ARCC.csv', 'ARE.csv', 'ARES.csv', 'ARGX.csv', 'ARKB.csv', 'ARKK.csv', 'ARM.csv', 'ARMK.csv', 'ARW.csv', 'AS.csv', 'ASML.csv', 'ASND.csv', 'ASR.csv', 'ASTS.csv', 'ASX.csv', 'ATI.csv', 'ATO.csv', 'ATR.csv', 'AU.csv', 'AUR.csv', 'AVB.csv', 'AVDE.csv', 'AVDV.csv', 'AVEM.csv', 'AVGO.csv', 'AVLV.csv', 'AVTR.csv', 'AVUS.csv', 'AVUV.csv', 'AVY.csv', 'AWI.csv', 'AWK.csv', 'AXON.csv', 'AXP.csv', 'AXS.csv', 'AXTA.csv', 'AYI.csv', 'AZEK.csv', 'AZN.csv', 'AZO.csv', 'BA.csv', 'BABA.csv', 'BAC.csv', 'BAH.csv', 'BALL.csv', 'BAM.csv', 'BAP.csv', 'BAX.csv', 'BBAX.csv', 'BBCA.csv', 'BBD.csv', 'BBEU.csv', 'BBIN.csv', 'BBIO.csv', 'BBJP.csv', 'BBUS.csv', 'BBVA.csv', 'BBWI.csv', 'BBY.csv', 'BCE.csv', 'BCH.csv', 'BCS.csv', 'BDX.csv', 'BECN.csv', 'BEKE.csv', 'BEN.csv', 'BEP.csv', 'BERY.csv', 'BF-A.csv', 'BF-B.csv', 'BFAM.csv', 'BG.csv', 'BHP.csv', 'BIDU.csv', 'BIIB.csv', 'BIL.csv', 'BILI.csv', 'BILS.csv', 'BINC.csv', 'BIO.csv', 'BIP.csv', 'BIRK.csv', 'BITB.csv', 'BIV.csv', 'BJ.csv', 'BK.csv', 'BKLN.csv', 'BKNG.csv', 'BKR.csv', 'BLD.csv', 'BLDR.csv', 'BLK.csv', 'BLV.csv', 'BMI.csv', 'BMO.csv', 'BMRN.csv', 'BMY.csv', 'BN.csv', 'BND.csv', 'BNDX.csv', 'BNS.csv', 'BNT.csv', 'BNTX.csv', 'BOKF.csv', 'BOND.csv', 'BOXX.csv', 'BP.csv', 'BPMC.csv', 'BPOP.csv', 'BR.csv', 'BRBR.csv', 'BRFS.csv', 'BRK-A.csv', 'BRK-B.csv', 'BRKR.csv', 'BRO.csv', 'BROS.csv', 'BRX.csv', 'BSAC.csv', 'BSBR.csv', 'BSCP.csv', 'BSCQ.csv', 'BSCR.csv', 'BSV.csv', 'BSX.csv', 'BSY.csv', 'BTC.csv', 'BTI.csv', 'BUD.csv', 'BUFR.csv', 'BULL.csv', 'BURL.csv', 'BWA.csv', 'BWXT.csv', 'BX.csv', 'BXP.csv', 'BXSL.csv', 'BYD.csv', 'BZ.csv', 'C.csv', 'CACC.csv', 'CACI.csv', 'CAE.csv', 'CAG.csv', 'CAH.csv', 'CALF.csv', 'CARR.csv', 'CART.csv', 'CASY.csv', 'CAT.csv', 'CAVA.csv', 'CB.csv', 'CBOE.csv', 'CBRE.csv', 'CBSH.csv', 'CCCS.csv', 'CCEP.csv', 'CCI.csv', 'CCJ.csv', 'CCK.csv', 'CCL.csv', 'CDNS.csv', 'CDP.csv', 'CDW.csv', 'CEF.csv', 'CEG.csv', 'CELH.csv', 'CF.csv', 'CFG.csv', 'CFLT.csv', 'CFR.csv', 'CG.csv', 'CGCP.csv', 'CGDV.csv', 'CGGO.csv', 'CGGR.csv', 'CGUS.csv', 'CGXU.csv', 'CHD.csv', 'CHDN.csv', 'CHE.csv', 'CHH.csv', 'CHKP.csv', 'CHRW.csv', 'CHT.csv', 'CHTR.csv', 'CHWY.csv', 'CI.csv', 'CIBR.csv', 'CIEN.csv', 'CIGI.csv', 'CINF.csv', 'CL.csv', 'CLH.csv', 'CLS.csv', 'CLX.csv', 'CM.csv', 'CMA.csv', 'CMCSA.csv', 'CME.csv', 'CMF.csv', 'CMG.csv', 'CMI.csv', 'CMS.csv', 'CNA.csv', 'CNC.csv', 'CNH.csv', 'CNI.csv', 'CNM.csv', 'CNP.csv', 'CNQ.csv', 'COF.csv', 'COHR.csv', 'COIN.csv', 'COKE.csv', 'COO.csv', 'COOP.csv', 'COP.csv', 'COR.csv', 'CORT.csv', 'COST.csv', 'COWZ.csv', 'CP.csv', 'CPAY.csv', 'CPB.csv', 'CPNG.csv', 'CPRT.csv', 'CPT.csv', 'CQP.csv', 'CR.csv', 'CRBG.csv', 'CRDO.csv', 'CRH.csv', 'CRK.csv', 'CRL.csv', 'CRM.csv', 'CROX.csv', 'CRS.csv', 'CRVL.csv', 'CRWD.csv', 'CRWV.csv', 'CSCO.csv', 'CSGP.csv', 'CSL.csv', 'CSX.csv', 'CTAS.csv', 'CTRA.csv', 'CTRE.csv', 'CTSH.csv', 'CTVA.csv', 'CUBE.csv', 'CVE.csv', 'CVLT.csv', 'CVNA.csv', 'CVS.csv', 'CVX.csv', 'CW.csv', 'CWAN.csv', 'CWB.csv', 'CWEN-A.csv', 'CWEN.csv', 'CWST.csv', 'CX.csv', 'CYBR.csv', 'CZR.csv', 'D.csv', 'DAL.csv', 'DAS ...
# Successfully processed: A.csv
# Successfully processed: AA.csv
# Successfully processed: AAL.csv
# Successfully processed: AAON.csv
# Successfully processed: AAPL.csv
# Successfully processed: ABBV.csv
# Successfully processed: ABEV.csv
# Successfully processed: ABNB.csv
# Successfully processed: ABT.csv
# Successfully processed: ACGL.csv
# Successfully processed: ACI.csv
# Successfully processed: ACIW.csv
# Successfully processed: ACM.csv
# Successfully processed: ACN.csv
# Successfully processed: ACWI.csv
# Successfully processed: ACWV.csv
# Successfully processed: ACWX.csv
# Successfully processed: ADBE.csv
# Successfully processed: ADC.csv
# Successfully processed: ADI.csv
# Successfully processed: ADM.csv
# Successfully processed: ADMA.csv
# Successfully processed: ADP.csv
# Successfully processed: ADSK.csv
# Successfully processed: ADT.csv
# Successfully processed: AEE.csv
# Successfully processed: AEG.csv
# Successfully processed: AEM.csv
# Successfully processed: AEP.csv
# Successfully processed: AER.csv
# Successfully processed: AES.csv
# Successfully processed: AFG.csv
# Successfully processed: AFL.csv
# Successfully processed: AFRM.csv
# Successfully processed: AGCO.csv
# Successfully processed: AGG.csv
# Successfully processed: AGI.csv
# Successfully processed: AGNC.csv
# Successfully processed: AIG.csv
# Successfully processed: AIRR.csv
# Successfully processed: AIT.csv
# Successfully processed: AIZ.csv
# Successfully processed: AJG.csv
# Successfully processed: AKAM.csv
# Successfully processed: AL.csv
# Successfully processed: ALAB.csv
# Successfully processed: ALB.csv
# Successfully processed: ALC.csv
# Successfully processed: ALGN.csv
# Successfully processed: ALK.csv
# Successfully processed: ALL.csv
# Successfully processed: ALLE.csv
# Successfully processed: ALLY.csv
# Successfully processed: ALNY.csv
# Successfully processed: ALSN.csv
# Successfully processed: ALV.csv
# Successfully processed: AM.csv
# Successfully processed: AMAT.csv
# Successfully processed: AMCR.csv
# Successfully processed: AMD.csv
# Successfully processed: AME.csv
# Successfully processed: AMGN.csv
# Successfully processed: AMH.csv
# Successfully processed: AMLP.csv
# Successfully processed: AMP.csv
# Successfully processed: AMT.csv
# Successfully processed: AMX.csv
# Successfully processed: AMZN.csv
# Successfully processed: AN.csv
# Successfully processed: ANET.csv
# Successfully processed: ANSS.csv
# Successfully processed: AON.csv
# Successfully processed: AOS.csv
# Successfully processed: APA.csv
# Successfully processed: APD.csv
# Successfully processed: APG.csv
# Successfully processed: APH.csv
# Successfully processed: APO.csv
# Successfully processed: APP.csv
# Successfully processed: APPF.csv
# Successfully processed: APTV.csv
# Successfully processed: AR.csv
# Successfully processed: ARCC.csv
# Successfully processed: ARE.csv
# Successfully processed: ARES.csv
# Successfully processed: ARGX.csv
# Successfully processed: ARKB.csv
# Successfully processed: ARKK.csv
# Successfully processed: ARM.csv
# Successfully processed: ARMK.csv
# Successfully processed: ARW.csv
# Successfully processed: AS.csv
# Successfully processed: ASML.csv
# Successfully processed: ASND.csv
# Successfully processed: ASR.csv
# Successfully processed: ASTS.csv
# Successfully processed: ASX.csv
# Successfully processed: ATI.csv
# Successfully processed: ATO.csv
# Successfully processed: ATR.csv
# Successfully processed: AU.csv
# Successfully processed: AUR.csv
# Successfully processed: AVB.csv
# Successfully processed: AVDE.csv
# Successfully processed: AVDV.csv
# Successfully processed: AVEM.csv
# Successfully processed: AVGO.csv
# Successfully processed: AVLV.csv
# Successfully processed: AVTR.csv
# Successfully processed: AVUS.csv
# Successfully processed: AVUV.csv
# Successfully processed: AVY.csv
# Successfully processed: AWI.csv
# Successfully processed: AWK.csv
# Successfully processed: AXON.csv
# Successfully processed: AXP.csv
# Successfully processed: AXS.csv
# Successfully processed: AXTA.csv
# Successfully processed: AYI.csv
# Successfully processed: AZEK.csv
# Successfully processed: AZN.csv
# Successfully processed: AZO.csv
# Successfully processed: BA.csv
# Successfully processed: BABA.csv
# Successfully processed: BAC.csv
# Successfully processed: BAH.csv
# Successfully processed: BALL.csv
# Successfully processed: BAM.csv
# Successfully processed: BAP.csv
# Successfully processed: BAX.csv
# Successfully processed: BBAX.csv
# Successfully processed: BBCA.csv
# Successfully processed: BBD.csv
# Successfully processed: BBEU.csv
# Successfully processed: BBIN.csv
# Successfully processed: BBIO.csv
# Successfully processed: BBJP.csv
# Successfully processed: BBUS.csv
# Successfully processed: BBVA.csv
# Successfully processed: BBWI.csv
# Successfully processed: BBY.csv
# Successfully processed: BCE.csv
# Successfully processed: BCH.csv
# Successfully processed: BCS.csv
# Successfully processed: BDX.csv
# Successfully processed: BECN.csv
# Successfully processed: BEKE.csv
# Successfully processed: BEN.csv
# Successfully processed: BEP.csv
# Successfully processed: BERY.csv
# Successfully processed: BF-A.csv
# Successfully processed: BF-B.csv
# Successfully processed: BFAM.csv
# Successfully processed: BG.csv
# Successfully processed: BHP.csv
# Successfully processed: BIDU.csv
# Successfully processed: BIIB.csv
# Successfully processed: BIL.csv
# Successfully processed: BILI.csv
# Successfully processed: BILS.csv
# Successfully processed: BINC.csv
# Successfully processed: BIO.csv
# Successfully processed: BIP.csv
# Successfully processed: BIRK.csv
# Successfully processed: BITB.csv
# Successfully processed: BIV.csv
# Successfully processed: BJ.csv
# Successfully processed: BK.csv
# Successfully processed: BKLN.csv
# Successfully processed: BKNG.csv
# Successfully processed: BKR.csv
# Successfully processed: BLD.csv
# Successfully processed: BLDR.csv
# Successfully processed: BLK.csv
# Successfully processed: BLV.csv
# Successfully processed: BMI.csv
# Successfully processed: BMO.csv
# Successfully processed: BMRN.csv
# Successfully processed: BMY.csv
# Successfully processed: BN.csv
# Successfully processed: BND.csv
# Successfully processed: BNDX.csv
# Successfully processed: BNS.csv
# Successfully processed: BNT.csv
# Successfully processed: BNTX.csv
# Successfully processed: BOKF.csv
# Successfully processed: BOND.csv
# Successfully processed: BOXX.csv
# Successfully processed: BP.csv
# Successfully processed: BPMC.csv
# Successfully processed: BPOP.csv
# Successfully processed: BR.csv
# Successfully processed: BRBR.csv
# Successfully processed: BRFS.csv
# Successfully processed: BRK-A.csv
# Successfully processed: BRK-B.csv
# Successfully processed: BRKR.csv
# Successfully processed: BRO.csv
# Successfully processed: BROS.csv
# Successfully processed: BRX.csv
# Successfully processed: BSAC.csv
# Successfully processed: BSBR.csv
# Successfully processed: BSCP.csv
# Successfully processed: BSCQ.csv
# Successfully processed: BSCR.csv
# Successfully processed: BSV.csv
# Successfully processed: BSX.csv
# Successfully processed: BSY.csv
# Successfully processed: BTC.csv
# Successfully processed: BTI.csv
# Successfully processed: BUD.csv
# Successfully processed: BUFR.csv
# Successfully processed: BULL.csv
# Successfully processed: BURL.csv
# Successfully processed: BWA.csv
# Successfully processed: BWXT.csv
# Successfully processed: BX.csv
# Successfully processed: BXP.csv
# Successfully processed: BXSL.csv
# Successfully processed: BYD.csv
# Successfully processed: BZ.csv
# Successfully processed: C.csv
# Successfully processed: CACC.csv
# Successfully processed: CACI.csv
# Successfully processed: CAE.csv
# Successfully processed: CAG.csv
# Successfully processed: CAH.csv
# Successfully processed: CALF.csv
# Successfully processed: CARR.csv
# Successfully processed: CART.csv
# Successfully processed: CASY.csv
# Successfully processed: CAT.csv
# Successfully processed: CAVA.csv
# Successfully processed: CB.csv
# Successfully processed: CBOE.csv
# Successfully processed: CBRE.csv
# Successfully processed: CBSH.csv
# Successfully processed: CCCS.csv
# Successfully processed: CCEP.csv
# Successfully processed: CCI.csv
# Successfully processed: CCJ.csv
# Successfully processed: CCK.csv
# Successfully processed: CCL.csv
# Successfully processed: CDNS.csv
# Successfully processed: CDP.csv
# Successfully processed: CDW.csv
# Successfully processed: CEF.csv
# Successfully processed: CEG.csv
# Successfully processed: CELH.csv
# Successfully processed: CF.csv
# Successfully processed: CFG.csv
# Successfully processed: CFLT.csv
# Successfully processed: CFR.csv
# Successfully processed: CG.csv
# Successfully processed: CGCP.csv
# Successfully processed: CGDV.csv
# Successfully processed: CGGO.csv
# Successfully processed: CGGR.csv
# Successfully processed: CGUS.csv
# Successfully processed: CGXU.csv
# Successfully processed: CHD.csv
# Successfully processed: CHDN.csv
# Successfully processed: CHE.csv
# Successfully processed: CHH.csv
# Successfully processed: CHKP.csv
# Successfully processed: CHRW.csv
# Successfully processed: CHT.csv
# Successfully processed: CHTR.csv
# Successfully processed: CHWY.csv
# Successfully processed: CI.csv
# Successfully processed: CIBR.csv
# Successfully processed: CIEN.csv
# Successfully processed: CIGI.csv
# Successfully processed: CINF.csv
# Successfully processed: CL.csv
# Successfully processed: CLH.csv
# Successfully processed: CLS.csv
# Successfully processed: CLX.csv
# Successfully processed: CM.csv
# Successfully processed: CMA.csv
# Successfully processed: CMCSA.csv
# Successfully processed: CME.csv
# Successfully processed: CMF.csv
# Successfully processed: CMG.csv
# Successfully processed: CMI.csv
# Successfully processed: CMS.csv
# Successfully processed: CNA.csv
# Successfully processed: CNC.csv
# Successfully processed: CNH.csv
# Successfully processed: CNI.csv
# Successfully processed: CNM.csv
# Successfully processed: CNP.csv
# Successfully processed: CNQ.csv
# Successfully processed: COF.csv
# Successfully processed: COHR.csv
# Successfully processed: COIN.csv
# Successfully processed: COKE.csv
# Successfully processed: COO.csv
# Successfully processed: COOP.csv
# Successfully processed: COP.csv
# Successfully processed: COR.csv
# Successfully processed: CORT.csv
# Successfully processed: COST.csv
# Successfully processed: COWZ.csv
# Successfully processed: CP.csv
# Successfully processed: CPAY.csv
# Successfully processed: CPB.csv
# Successfully processed: CPNG.csv
# Successfully processed: CPRT.csv
# Successfully processed: CPT.csv
# Successfully processed: CQP.csv
# Successfully processed: CR.csv
# Successfully processed: CRBG.csv
# Successfully processed: CRDO.csv
# Successfully processed: CRH.csv
# Successfully processed: CRK.csv
# Successfully processed: CRL.csv
# Successfully processed: CRM.csv
# Successfully processed: CROX.csv
# Successfully processed: CRS.csv
# Successfully processed: CRVL.csv
# Successfully processed: CRWD.csv
# Successfully processed: CRWV.csv
# Successfully processed: CSCO.csv
# Successfully processed: CSGP.csv
# Successfully processed: CSL.csv
# Successfully processed: CSX.csv
# Successfully processed: CTAS.csv
# Successfully processed: CTRA.csv
# Successfully processed: CTRE.csv
# Successfully processed: CTSH.csv
# Successfully processed: CTVA.csv
# Successfully processed: CUBE.csv
# Successfully processed: CVE.csv
# Successfully processed: CVLT.csv
# Successfully processed: CVNA.csv
# Successfully processed: CVS.csv
# Successfully processed: CVX.csv
# Successfully processed: CW.csv
# Successfully processed: CWAN.csv
# Successfully processed: CWB.csv
# Successfully processed: CWEN-A.csv
# Successfully processed: CWEN.csv
# Successfully processed: CWST.csv
# Successfully processed: CX.csv
# Successfully processed: CYBR.csv
# Successfully processed: CZR.csv
# Successfully processed: D.csv
# Successfully processed: DAL.csv
# Successfully processed: DASH.csv
# Successfully processed: DAY.csv
# Successfully processed: DB.csv
# Successfully processed: DBEF.csv
# Successfully processed: DBX.csv
# Successfully processed: DCI.csv
# Successfully processed: DD.csv
# Successfully processed: DDOG.csv
# Successfully processed: DDS.csv
# Successfully processed: DE.csv
# Successfully processed: DECK.csv
# Successfully processed: DELL.csv
# Successfully processed: DEO.csv
# Successfully processed: DFAC.csv
# Successfully processed: DFAE.csv
# Successfully processed: DFAI.csv
# Successfully processed: DFAS.csv
# Successfully processed: DFAT.csv
# Successfully processed: DFAU.csv
# Successfully processed: DFAX.csv
# Successfully processed: DFCF.csv
# Successfully processed: DFEM.csv
# Successfully processed: DFIC.csv
# Successfully processed: DFIV.csv
# Successfully processed: DFLV.csv
# Successfully processed: DFS.csv
# Successfully processed: DFSD.csv
# Successfully processed: DFSV.csv
# Successfully processed: DFUS.csv
# Successfully processed: DFUV.csv
# Successfully processed: DG.csv
# Successfully processed: DGRO.csv
# Successfully processed: DGRW.csv
# Successfully processed: DGX.csv
# Successfully processed: DHI.csv
# Successfully processed: DHR.csv
# Successfully processed: DIA.csv
# Successfully processed: DIHP.csv
# Successfully processed: DINO.csv
# Successfully processed: DIS.csv
# Successfully processed: DIVO.csv
# Successfully processed: DKNG.csv
# Successfully processed: DKS.csv
# Successfully processed: DLB.csv
# Successfully processed: DLN.csv
# Successfully processed: DLR.csv
# Successfully processed: DLTR.csv
# Successfully processed: DOC.csv
# Successfully processed: DOCS.csv
# Successfully processed: DOCU.csv
# Successfully processed: DON.csv
# Successfully processed: DOV.csv
# Successfully processed: DOW.csv
# Successfully processed: DOX.csv
# Successfully processed: DPZ.csv
# Successfully processed: DRI.csv
# Successfully processed: DRS.csv
# Successfully processed: DSGX.csv
# Successfully processed: DSI.csv
# Successfully processed: DT.csv
# Successfully processed: DTE.csv
# Successfully processed: DTM.csv
# Successfully processed: DUHP.csv
# Successfully processed: DUK.csv
# Successfully processed: DUOL.csv
# Successfully processed: DVA.csv
# Successfully processed: DVN.csv
# Successfully processed: DVY.csv
# Successfully processed: DXCM.csv
# Successfully processed: DXJ.csv
# Successfully processed: DYNF.csv
# Successfully processed: E.csv
# Successfully processed: EA.csv
# Successfully processed: EAGG.csv
# Successfully processed: EAT.csv
# Successfully processed: EBAY.csv
# Successfully processed: EBR.csv
# Successfully processed: EC.csv
# Successfully processed: ECL.csv
# Successfully processed: ED.csv
# Successfully processed: EDU.csv
# Successfully processed: EDV.csv
# Successfully processed: EEM.csv
# Successfully processed: EEMV.csv
# Successfully processed: EFA.csv
# Successfully processed: EFAV.csv
# Successfully processed: EFG.csv
# Successfully processed: EFV.csv
# Successfully processed: EFX.csv
# Successfully processed: EG.csv
# Successfully processed: EGP.csv
# Successfully processed: EHC.csv
# Successfully processed: EIX.csv
# Successfully processed: EL.csv
# Successfully processed: ELAN.csv
# Successfully processed: ELS.csv
# Successfully processed: ELV.csv
# Successfully processed: EMB.csv
# Successfully processed: EME.csv
# Successfully processed: EMLP.csv
# Successfully processed: EMN.csv
# Successfully processed: EMR.csv
# Successfully processed: EMXC.csv
# Successfully processed: ENB.csv
# Successfully processed: ENPH.csv
# Successfully processed: ENSG.csv
# Successfully processed: ENTG.csv
# Successfully processed: EOG.csv
# Successfully processed: EPAM.csv
# Successfully processed: EPD.csv
# Successfully processed: EPRT.csv
# Successfully processed: EQH.csv
# Successfully processed: EQIX.csv
# Successfully processed: EQNR.csv
# Successfully processed: EQR.csv
# Successfully processed: EQT.csv
# Successfully processed: ERIC.csv
# Successfully processed: ERIE.csv
# Successfully processed: ERJ.csv
# Successfully processed: ES.csv
# Successfully processed: ESAB.csv
# Successfully processed: ESGD.csv
# Successfully processed: ESGE.csv
# Successfully processed: ESGU.csv
# Successfully processed: ESGV.csv
# Successfully processed: ESLT.csv
# Successfully processed: ESNT.csv
# Successfully processed: ESS.csv
# Successfully processed: ESTC.csv
# Successfully processed: ET.csv
# Successfully processed: ETN.csv
# Successfully processed: ETR.csv
# Successfully processed: EUFN.csv
# Successfully processed: EVR.csv
# Successfully processed: EVRG.csv
# Successfully processed: EW.csv
# Successfully processed: EWBC.csv
# Successfully processed: EWJ.csv
# Successfully processed: EWT.csv
# Successfully processed: EWU.csv
# Successfully processed: EWZ.csv
# Successfully processed: EXAS.csv
# Successfully processed: EXC.csv
# Successfully processed: EXE.csv
# Successfully processed: EXEL.csv
# Successfully processed: EXLS.csv
# Successfully processed: EXP.csv
# Successfully processed: EXPD.csv
# Successfully processed: EXPE.csv
# Successfully processed: EXR.csv
# Successfully processed: EZU.csv
# Successfully processed: F.csv
# Successfully processed: FAF.csv
# Successfully processed: FANG.csv
# Successfully processed: FAST.csv
# Successfully processed: FBCG.csv
# Successfully processed: FBIN.csv
# Successfully processed: FBND.csv
# Successfully processed: FBTC.csv
# Successfully processed: FCFS.csv
# Successfully processed: FCN.csv
# Successfully processed: FCNCA.csv
# Successfully processed: FCX.csv
# Successfully processed: FDL.csv
# Successfully processed: FDN.csv
# Successfully processed: FDS.csv
# Successfully processed: FDVV.csv
# Successfully processed: FDX.csv
# Successfully processed: FE.csv
# Successfully processed: FELC.csv
# Successfully processed: FELG.csv
# Successfully processed: FER.csv
# Successfully processed: FERG.csv
# Successfully processed: FEZ.csv
# Successfully processed: FFIV.csv
# Successfully processed: FHN.csv
# Successfully processed: FI.csv
# Successfully processed: FICO.csv
# Successfully processed: FIS.csv
# Successfully processed: FITB.csv
# Successfully processed: FIX.csv
# Successfully processed: FIXD.csv
# Successfully processed: FLEX.csv
# Successfully processed: FLOT.csv
# Successfully processed: FLR.csv
# Successfully processed: FLS.csv
# Successfully processed: FLUT.csv
# Successfully processed: FMS.csv
# Successfully processed: FMX.csv
# Successfully processed: FN.csv
# Successfully processed: FND.csv
# Successfully processed: FNDA.csv
# Successfully processed: FNDE.csv
# Successfully processed: FNDF.csv
# Successfully processed: FNDX.csv
# Successfully processed: FNF.csv
# Successfully processed: FNGA.csv
# Successfully processed: FNV.csv
# Successfully processed: FOUR.csv
# Successfully processed: FOX.csv
# Successfully processed: FOXA.csv
# Successfully processed: FPE.csv
# Successfully processed: FR.csv
# Successfully processed: FRHC.csv
# Successfully processed: FRT.csv
# Successfully processed: FSEC.csv
# Successfully processed: FSLR.csv
# Successfully processed: FSV.csv
# Successfully processed: FTAI.csv
# Successfully processed: FTCS.csv
# Successfully processed: FTEC.csv
# Successfully processed: FTI.csv
# Successfully processed: FTNT.csv
# Successfully processed: FTS.csv
# Successfully processed: FTSM.csv
# Successfully processed: FTV.csv
# Successfully processed: FUTU.csv
# Successfully processed: FV.csv
# Successfully processed: FVD.csv
# Successfully processed: FWONA.csv
# Successfully processed: FWONK.csv
# Successfully processed: FXI.csv
# Successfully processed: FYBR.csv
# Successfully processed: G.csv
# Successfully processed: GAP.csv
# Successfully processed: GBIL.csv
# Successfully processed: GBTC.csv
# Successfully processed: GD.csv
# Successfully processed: GDDY.csv
# Successfully processed: GDX.csv
# Successfully processed: GDXJ.csv
# Successfully processed: GE.csv
# Successfully processed: GEHC.csv
# Successfully processed: GEN.csv
# Successfully processed: GEV.csv
# Successfully processed: GFI.csv
# Successfully processed: GFL.csv
# Successfully processed: GFS.csv
# Successfully processed: GGAL.csv
# Successfully processed: GGG.csv
# Successfully processed: GIB.csv
# Successfully processed: GIL.csv
# Successfully processed: GILD.csv
# Successfully processed: GIS.csv
# Successfully processed: GL.csv
# Successfully processed: GLBE.csv
# Successfully processed: GLD.csv
# Successfully processed: GLDM.csv
# Successfully processed: GLOB.csv
# Successfully processed: GLPI.csv
# Successfully processed: GLW.csv
# Successfully processed: GM.csv
# Successfully processed: GMAB.csv
# Successfully processed: GME.csv
# Successfully processed: GMED.csv
# Successfully processed: GNRC.csv
# Successfully processed: GOLD.csv
# Successfully processed: GOOG.csv
# Successfully processed: GOOGL.csv
# Successfully processed: GOVT.csv
# Successfully processed: GPC.csv
# Successfully processed: GPK.csv
# Successfully processed: GPN.csv
# Successfully processed: GRAB.csv
# Successfully processed: GRMN.csv
# Successfully processed: GS.csv
# Successfully processed: GSIE.csv
# Successfully processed: GSK.csv
# Successfully processed: GSLC.csv
# Successfully processed: GTLB.csv
# Successfully processed: GTLS.csv
# Successfully processed: GUNR.csv
# Successfully processed: GVI.csv
# Successfully processed: GWRE.csv
# Successfully processed: GWW.csv
# Successfully processed: H.csv
# Successfully processed: HAL.csv
# Successfully processed: HALO.csv
# Successfully processed: HAS.csv
# Successfully processed: HBAN.csv
# Successfully processed: HCA.csv
# Successfully processed: HD.csv
# Successfully processed: HDB.csv
# Successfully processed: HDV.csv
# Successfully processed: HEFA.csv
# Successfully processed: HEI-A.csv
# Successfully processed: HEI.csv
# Successfully processed: HES.csv
# Successfully processed: HESM.csv
# Successfully processed: HIG.csv
# Successfully processed: HII.csv
# Successfully processed: HIMS.csv
# Successfully processed: HLI.csv
# Successfully processed: HLN.csv
# Successfully processed: HLNE.csv
# Successfully processed: HLT.csv
# Successfully processed: HMC.csv
# Successfully processed: HMY.csv
# Successfully processed: HOLX.csv
# Successfully processed: HOMB.csv
# Successfully processed: HON.csv
# Successfully processed: HOOD.csv
# Successfully processed: HPE.csv
# Successfully processed: HPQ.csv
# Successfully processed: HQY.csv
# Successfully processed: HRB.csv
# Successfully processed: HRL.csv
# Successfully processed: HSBC.csv
# Successfully processed: HSIC.csv
# Successfully processed: HST.csv
# Successfully processed: HSY.csv
# Successfully processed: HTHT.csv
# Successfully processed: HUBB.csv
# Successfully processed: HUBS.csv
# Successfully processed: HUM.csv
# Successfully processed: HWM.csv
# Successfully processed: HYD.csv
# Successfully processed: HYG.csv
# Successfully processed: HYLB.csv
# Successfully processed: IAGG.csv
# Successfully processed: IAU.csv
# Successfully processed: IBB.csv
# Successfully processed: IBDR.csv
# Successfully processed: IBIT.csv
# Successfully processed: IBKR.csv
# Successfully processed: IBM.csv
# Successfully processed: IBN.csv
# Successfully processed: ICE.csv
# Successfully processed: ICL.csv
# Successfully processed: ICLR.csv
# Successfully processed: ICSH.csv
# Successfully processed: IDA.csv
# Successfully processed: IDEV.csv
# Successfully processed: IDV.csv
# Successfully processed: IDXX.csv
# Successfully processed: IEF.csv
# Successfully processed: IEFA.csv
# Successfully processed: IEI.csv
# Successfully processed: IEMG.csv
# Successfully processed: IEUR.csv
# Successfully processed: IEX.csv
# Successfully processed: IFF.csv
# Successfully processed: IGF.csv
# Successfully processed: IGIB.csv
# Successfully processed: IGM.csv
# Successfully processed: IGSB.csv
# Successfully processed: IGV.csv
# Successfully processed: IHG.csv
# Successfully processed: IHI.csv
# Successfully processed: IJH.csv
# Successfully processed: IJJ.csv
# Successfully processed: IJK.csv
# Successfully processed: IJR.csv
# Successfully processed: IJS.csv
# Successfully processed: IJT.csv
# Successfully processed: ILMN.csv
# Successfully processed: IMO.csv
# Successfully processed: INCY.csv
# Successfully processed: INDA.csv
# Successfully processed: INFA.csv
# Successfully processed: INFY.csv
# Successfully processed: ING.csv
# Successfully processed: INGR.csv
# Successfully processed: INSM.csv
# Successfully processed: INTC.csv
# Successfully processed: INTU.csv
# Successfully processed: INVH.csv
# Successfully processed: IONQ.csv
# Successfully processed: IOO.csv
# Successfully processed: IOT.csv
# Successfully processed: IP.csv
# Successfully processed: IPG.csv
# Successfully processed: IQLT.csv
# Successfully processed: IQV.csv
# Successfully processed: IR.csv
# Successfully processed: IRM.csv
# Successfully processed: ISRG.csv
# Successfully processed: ISTB.csv
# Successfully processed: IT.csv
# Successfully processed: ITA.csv
# Successfully processed: ITOT.csv
# Successfully processed: ITT.csv
# Successfully processed: ITUB.csv
# Successfully processed: ITW.csv
# Successfully processed: IUSB.csv
# Successfully processed: IUSG.csv
# Successfully processed: IUSV.csv
# Successfully processed: IVE.csv
# Successfully processed: IVV.csv
# Successfully processed: IVW.csv
# Successfully processed: IVZ.csv
# Successfully processed: IWB.csv
# Successfully processed: IWD.csv
# Successfully processed: IWF.csv
# Successfully processed: IWM.csv
# Successfully processed: IWN.csv
# Successfully processed: IWO.csv
# Successfully processed: IWP.csv
# Successfully processed: IWR.csv
# Successfully processed: IWS.csv
# Successfully processed: IWV.csv
# Successfully processed: IWY.csv
# Successfully processed: IX.csv
# Successfully processed: IXJ.csv
# Successfully processed: IXN.csv
# Successfully processed: IXUS.csv
# Successfully processed: IYF.csv
# Successfully processed: IYR.csv
# Successfully processed: IYW.csv
# Successfully processed: J.csv
# Successfully processed: JAAA.csv
# Successfully processed: JAVA.csv
# Successfully processed: JAZZ.csv
# Successfully processed: JBHT.csv
# Successfully processed: JBL.csv
# Successfully processed: JBTM.csv
# Successfully processed: JCI.csv
# Successfully processed: JCPB.csv
# Successfully processed: JD.csv
# Successfully processed: JEF.csv
# Successfully processed: JEPI.csv
# Successfully processed: JEPQ.csv
# Successfully processed: JGLO.csv
# Successfully processed: JGRO.csv
# Successfully processed: JHG.csv
# Successfully processed: JHMM.csv
# Successfully processed: JHX.csv
# Successfully processed: JIRE.csv
# Successfully processed: JKHY.csv
# Successfully processed: JLL.csv
# Successfully processed: JMBS.csv
# Successfully processed: JMST.csv
# Successfully processed: JNJ.csv
# Successfully processed: JNK.csv
# Successfully processed: JNPR.csv
# Successfully processed: JPIE.csv
# Successfully processed: JPM.csv
# Successfully processed: JPST.csv
# Successfully processed: JQUA.csv
# Successfully processed: JXN.csv
# Successfully processed: K.csv
# Successfully processed: KB.csv
# Successfully processed: KBR.csv
# Successfully processed: KBWB.csv
# Successfully processed: KD.csv
# Successfully processed: KDP.csv
# Successfully processed: KEP.csv
# Successfully processed: KEX.csv
# Successfully processed: KEY.csv
# Successfully processed: KEYS.csv
# Successfully processed: KGC.csv
# Successfully processed: KHC.csv
# Successfully processed: KIM.csv
# Successfully processed: KKR.csv
# Successfully processed: KLAC.csv
# Successfully processed: KMB.csv
# Successfully processed: KMI.csv
# Successfully processed: KMX.csv
# Successfully processed: KNG.csv
# Successfully processed: KNSL.csv
# Successfully processed: KNTK.csv
# Successfully processed: KNX.csv
# Successfully processed: KO.csv
# Successfully processed: KR.csv
# Successfully processed: KRC.csv
# Successfully processed: KRE.csv
# Successfully processed: KSPI.csv
# Successfully processed: KT.csv
# Successfully processed: KVUE.csv
# Successfully processed: KVYO.csv
# Successfully processed: KWEB.csv
# Successfully processed: L.csv
# Successfully processed: LAD.csv
# Successfully processed: LAMR.csv
# Successfully processed: LB.csv
# Successfully processed: LBRDA.csv
# Successfully processed: LBRDK.csv
# Successfully processed: LCID.csv
# Successfully processed: LDOS.csv
# Successfully processed: LECO.csv
# Successfully processed: LEGN.csv
# Successfully processed: LEN.csv
# Successfully processed: LEVI.csv
# Successfully processed: LH.csv
# Successfully processed: LHX.csv
# Successfully processed: LI.csv
# Successfully processed: LII.csv
# Successfully processed: LIN.csv
# Successfully processed: LINE.csv
# Successfully processed: LKQ.csv
# Successfully processed: LLY.csv
# Successfully processed: LLYVA.csv
# Successfully processed: LLYVK.csv
# Successfully processed: LMBS.csv
# Successfully processed: LMT.csv
# Successfully processed: LNC.csv
# Successfully processed: LNG.csv
# Successfully processed: LNT.csv
# Successfully processed: LNW.csv
# Successfully processed: LOAR.csv
# Successfully processed: LOGI.csv
# Successfully processed: LOW.csv
# Successfully processed: LPLA.csv
# Successfully processed: LPX.csv
# Successfully processed: LQD.csv
# Successfully processed: LRCX.csv
# Successfully processed: LRN.csv
# Successfully processed: LSCC.csv
# Successfully processed: LTH.csv
# Successfully processed: LTM.csv
# Successfully processed: LULU.csv
# Successfully processed: LUV.csv
# Successfully processed: LVS.csv
# Successfully processed: LW.csv
# Successfully processed: LYB.csv
# Successfully processed: LYG.csv
# Successfully processed: LYV.csv
# Successfully processed: MA.csv
# Successfully processed: MAA.csv
# Successfully processed: MANH.csv
# Successfully processed: MAR.csv
# Successfully processed: MAS.csv
# Successfully processed: MASI.csv
# Successfully processed: MAT.csv
# Successfully processed: MBB.csv
# Successfully processed: MBLY.csv
# Successfully processed: MCD.csv
# Successfully processed: MCHI.csv
# Successfully processed: MCHP.csv
# Successfully processed: MCK.csv
# Successfully processed: MCO.csv
# Successfully processed: MDB.csv
# Successfully processed: MDGL.csv
# Successfully processed: MDLZ.csv
# Successfully processed: MDT.csv
# Successfully processed: MDY.csv
# Successfully processed: MEDP.csv
# Successfully processed: MELI.csv
# Successfully processed: MET.csv
# Successfully processed: META.csv
# Successfully processed: MFC.csv
# Successfully processed: MFG.csv
# Successfully processed: MGA.csv
# Successfully processed: MGC.csv
# Successfully processed: MGK.csv
# Successfully processed: MGM.csv
# Successfully processed: MGV.csv
# Successfully processed: MHK.csv
# Successfully processed: MIDD.csv
# Successfully processed: MINT.csv
# Successfully processed: MKC.csv
# Successfully processed: MKL.csv
# Successfully processed: MKTX.csv
# Successfully processed: MLI.csv
# Successfully processed: MLM.csv
# Successfully processed: MMC.csv
# Successfully processed: MMM.csv
# Successfully processed: MMSI.csv
# Successfully processed: MMYT.csv
# Successfully processed: MNDY.csv
# Successfully processed: MNSO.csv
# Successfully processed: MNST.csv
# Successfully processed: MO.csv
# Successfully processed: MOAT.csv
# Successfully processed: MOG-A.csv
# Successfully processed: MOH.csv
# Successfully processed: MORN.csv
# Successfully processed: MOS.csv
# Successfully processed: MPC.csv
# Successfully processed: MPLX.csv
# Successfully processed: MPWR.csv
# Successfully processed: MRK.csv
# Successfully processed: MRNA.csv
# Successfully processed: MRVL.csv
# Successfully processed: MS.csv
# Successfully processed: MSA.csv
# Successfully processed: MSCI.csv
# Successfully processed: MSFT.csv
# Successfully processed: MSI.csv
# Successfully processed: MSTR.csv
# Successfully processed: MSTY.csv
# Successfully processed: MT.csv
# Successfully processed: MTB.csv
# Successfully processed: MTCH.csv
# Successfully processed: MTD.csv
# Successfully processed: MTG.csv
# Successfully processed: MTSI.csv
# Successfully processed: MTUM.csv
# Successfully processed: MTZ.csv
# Successfully processed: MU.csv
# Successfully processed: MUB.csv
# Successfully processed: MUFG.csv
# Successfully processed: MUSA.csv
# Successfully processed: NBIS.csv
# Successfully processed: NBIX.csv
# Successfully processed: NCLH.csv
# Successfully processed: NDAQ.csv
# Successfully processed: NDSN.csv
# Successfully processed: NEAR.csv
# Successfully processed: NEE.csv
# Successfully processed: NEM.csv
# Successfully processed: NET.csv
# Successfully processed: NEU.csv
# Successfully processed: NFG.csv
# Successfully processed: NFLX.csv
# Successfully processed: NGG.csv
# Successfully processed: NI.csv
# Successfully processed: NICE.csv
# Successfully processed: NIO.csv
# Successfully processed: NKE.csv
# Successfully processed: NLY.csv
# Successfully processed: NMR.csv
# Successfully processed: NNN.csv
# Successfully processed: NOBL.csv
# Successfully processed: NOC.csv
# Successfully processed: NOK.csv
# Successfully processed: NOW.csv
# Successfully processed: NRG.csv
# Successfully processed: NSC.csv
# Successfully processed: NTAP.csv
# Successfully processed: NTES.csv
# Successfully processed: NTNX.csv
# Successfully processed: NTR.csv
# Successfully processed: NTRA.csv
# Successfully processed: NTRS.csv
# Successfully processed: NU.csv
# Successfully processed: NUE.csv
# Successfully processed: NVDA.csv
# Successfully processed: NVDL.csv
# Successfully processed: NVMI.csv
# Successfully processed: NVO.csv
# Successfully processed: NVR.csv
# Successfully processed: NVS.csv
# Successfully processed: NVT.csv
# Successfully processed: NWG.csv
# Successfully processed: NWS.csv
# Successfully processed: NWSA.csv
# Successfully processed: NXPI.csv
# Successfully processed: NXT.csv
# Successfully processed: NYT.csv
# Successfully processed: O.csv
# Successfully processed: OBDC.csv
# Successfully processed: OC.csv
# Successfully processed: ODFL.csv
# Successfully processed: OEF.csv
# Successfully processed: OGE.csv
# Successfully processed: OHI.csv
# Successfully processed: OKE.csv
# Successfully processed: OKTA.csv
# Successfully processed: OLED.csv
# Successfully processed: OLLI.csv
# Successfully processed: OMC.csv
# Successfully processed: OMF.csv
# Successfully processed: OMFL.csv
# Successfully processed: ON.csv
# Successfully processed: ONB.csv
# Successfully processed: ONC.csv
# Successfully processed: ONEQ.csv
# Successfully processed: ONON.csv
# Successfully processed: ONTO.csv
# Successfully processed: ORCL.csv
# Successfully processed: ORI.csv
# Successfully processed: ORLY.csv
# Successfully processed: OS.csv
# Successfully processed: OSK.csv
# Successfully processed: OTEX.csv
# Successfully processed: OTIS.csv
# Successfully processed: OVV.csv
# Successfully processed: OWL.csv
# Successfully processed: OXY.csv
# Successfully processed: PAA.csv
# Successfully processed: PAAA.csv
# Successfully processed: PAAS.csv
# Successfully processed: PAC.csv
# Successfully processed: PAG.csv
# Successfully processed: PAGP.csv
# Successfully processed: PANW.csv
# Successfully processed: PARA.csv
# Successfully processed: PATH.csv
# Successfully processed: PAVE.csv
# Successfully processed: PAYC.csv
# Successfully processed: PAYX.csv
# Successfully processed: PB.csv
# Successfully processed: PBA.csv
# Successfully processed: PBR-A.csv
# Successfully processed: PBR.csv
# Successfully processed: PBUS.csv
# Successfully processed: PCAR.csv
# Successfully processed: PCOR.csv
# Successfully processed: PCTY.csv
# Successfully processed: PDBC.csv
# Successfully processed: PDD.csv
# Successfully processed: PDI.csv
# Successfully processed: PEG.csv
# Successfully processed: PEGA.csv
# Successfully processed: PEN.csv
# Successfully processed: PEP.csv
# Successfully processed: PFE.csv
# Successfully processed: PFF.csv
# Successfully processed: PFG.csv
# Successfully processed: PFGC.csv
# Successfully processed: PG.csv
# Successfully processed: PGR.csv
# Successfully processed: PGX.csv
# Successfully processed: PH.csv
# Successfully processed: PHG.csv
# Successfully processed: PHM.csv
# Successfully processed: PHYS.csv
# Successfully processed: PINS.csv
# Successfully processed: PKG.csv
# Successfully processed: PKX.csv
# Successfully processed: PLD.csv
# Successfully processed: PLNT.csv
# Successfully processed: PLTR.csv
# Successfully processed: PM.csv
# Successfully processed: PNC.csv
# Successfully processed: PNFP.csv
# Successfully processed: PNR.csv
# Successfully processed: PNW.csv
# Successfully processed: PODD.csv
# Successfully processed: POOL.csv
# Successfully processed: POST.csv
# Successfully processed: PPA.csv
# Successfully processed: PPC.csv
# Successfully processed: PPG.csv
# Successfully processed: PPL.csv
# Successfully processed: PR.csv
# Successfully processed: PRF.csv
# Successfully processed: PRI.csv
# Successfully processed: PRMB.csv
# Successfully processed: PRU.csv
# Successfully processed: PSA.csv
# Successfully processed: PSLV.csv
# Successfully processed: PSN.csv
# Successfully processed: PSO.csv
# Successfully processed: PSTG.csv
# Successfully processed: PSX.csv
# Successfully processed: PTC.csv
# Successfully processed: PTLC.csv
# Successfully processed: PUK.csv
# Successfully processed: PULS.csv
# Successfully processed: PWR.csv
# Successfully processed: PYLD.csv
# Successfully processed: PYPL.csv
# Successfully processed: QCOM.csv
# Successfully processed: QGEN.csv
# Successfully processed: QLD.csv
# Successfully processed: QQQ.csv
# Successfully processed: QQQM.csv
# Successfully processed: QRVO.csv
# Successfully processed: QSR.csv
# Successfully processed: QUAL.csv
# Successfully processed: QXO.csv
# Successfully processed: QYLD.csv
# Successfully processed: R.csv
# Successfully processed: RACE.csv
# Successfully processed: RBA.csv
# Successfully processed: RBC.csv
# Successfully processed: RBLX.csv
# Successfully processed: RBRK.csv
# Successfully processed: RCI.csv
# Successfully processed: RCL.csv
# Successfully processed: RDDT.csv
# Successfully processed: RDVY.csv
# Successfully processed: RDY.csv
# Successfully processed: REET.csv
# Successfully processed: REG.csv
# Successfully processed: REGN.csv
# Successfully processed: RELX.csv
# Successfully processed: REXR.csv
# Successfully processed: RF.csv
# Successfully processed: RGA.csv
# Successfully processed: RGEN.csv
# Successfully processed: RGLD.csv
# Successfully processed: RHP.csv
# Successfully processed: RIO.csv
# Successfully processed: RITM.csv
# Successfully processed: RIVN.csv
# Successfully processed: RJF.csv
# Successfully processed: RKLB.csv
# Successfully processed: RKT.csv
# Successfully processed: RL.csv
# Successfully processed: RLI.csv
# Successfully processed: RMD.csv
# Successfully processed: RNR.csv
# Successfully processed: ROIV.csv
# Successfully processed: ROK.csv
# Successfully processed: ROKU.csv
# Successfully processed: ROL.csv
# Successfully processed: ROP.csv
# Successfully processed: ROST.csv
# Successfully processed: RPM.csv
# Successfully processed: RPRX.csv
# Successfully processed: RRC.csv
# Successfully processed: RRX.csv
# Successfully processed: RS.csv
# Successfully processed: RSG.csv
# Successfully processed: RSP.csv
# Successfully processed: RSPT.csv
# Successfully processed: RTO.csv
# Successfully processed: RTX.csv
# Successfully processed: RVMD.csv
# Successfully processed: RVTY.csv
# Successfully processed: RWL.csv
# Successfully processed: RY.csv
# Successfully processed: RYAAY.csv
# Successfully processed: RYAN.csv
# Successfully processed: S.csv
# Successfully processed: SAIA.csv
# Successfully processed: SAIC.csv
# Successfully processed: SAIL.csv
# Successfully processed: SAN.csv
# Successfully processed: SAP.csv
# Successfully processed: SARO.csv
# Successfully processed: SATS.csv
# Successfully processed: SBAC.csv
# Successfully processed: SBS.csv
# Successfully processed: SBUX.csv
# Successfully processed: SCCO.csv
# Successfully processed: SCHA.csv
# Successfully processed: SCHB.csv
# Successfully processed: SCHC.csv
# Successfully processed: SCHD.csv
# Successfully processed: SCHE.csv
# Successfully processed: SCHF.csv
# Successfully processed: SCHG.csv
# Successfully processed: SCHH.csv
# Successfully processed: SCHI.csv
# Successfully processed: SCHK.csv
# Successfully processed: SCHM.csv
# Successfully processed: SCHO.csv
# Successfully processed: SCHP.csv
# Successfully processed: SCHR.csv
# Successfully processed: SCHV.csv
# Successfully processed: SCHW.csv
# Successfully processed: SCHX.csv
# Successfully processed: SCHZ.csv
# Successfully processed: SCI.csv
# Successfully processed: SCZ.csv
# Successfully processed: SDVY.csv
# Successfully processed: SDY.csv
# Successfully processed: SE.csv
# Successfully processed: SEIC.csv
# Successfully processed: SF.csv
# Successfully processed: SFD.csv
# Successfully processed: SFM.csv
# Successfully processed: SGI.csv
# Successfully processed: SGOL.csv
# Successfully processed: SGOV.csv
# Successfully processed: SHEL.csv
# Successfully processed: SHG.csv
# Successfully processed: SHM.csv
# Successfully processed: SHOP.csv
# Successfully processed: SHV.csv
# Successfully processed: SHW.csv
# Successfully processed: SHY.csv
# Successfully processed: SHYG.csv
# Successfully processed: SIRI.csv
# Successfully processed: SJM.csv
# Successfully processed: SJNK.csv
# Successfully processed: SKM.csv
# Successfully processed: SKX.csv
# Successfully processed: SLB.csv
# Successfully processed: SLF.csv
# Successfully processed: SLGN.csv
# Successfully processed: SLM.csv
# Successfully processed: SLV.csv
# Successfully processed: SLYV.csv
# Successfully processed: SMBS.csv
# Successfully processed: SMCI.csv
# Successfully processed: SMFG.csv
# Successfully processed: SMH.csv
# Successfully processed: SMMT.csv
# Successfully processed: SN.csv
# Successfully processed: SNA.csv
# Successfully processed: SNAP.csv
# Successfully processed: SNN.csv
# Successfully processed: SNOW.csv
# Successfully processed: SNPS.csv
# Successfully processed: SNV.csv
# Successfully processed: SNX.csv
# Successfully processed: SNY.csv
# Successfully processed: SO.csv
# Successfully processed: SOFI.csv
# Successfully processed: SOLV.csv
# Successfully processed: SONY.csv
# Successfully processed: SOXL.csv
# Successfully processed: SOXX.csv
# Successfully processed: SPAB.csv
# Successfully processed: SPDW.csv
# Successfully processed: SPEM.csv
# Successfully processed: SPG.csv
# Successfully processed: SPGI.csv
# Successfully processed: SPHD.csv
# Successfully processed: SPHQ.csv
# Successfully processed: SPHY.csv
# Successfully processed: SPIB.csv
# Successfully processed: SPLG.csv
# Successfully processed: SPLV.csv
# Successfully processed: SPMB.csv
# Successfully processed: SPMD.csv
# Successfully processed: SPMO.csv
# Successfully processed: SPOT.csv
# Successfully processed: SPSB.csv
# Successfully processed: SPSM.csv
# Successfully processed: SPTI.csv
# Successfully processed: SPTL.csv
# Successfully processed: SPTM.csv
# Successfully processed: SPTS.csv
# Successfully processed: SPXC.csv
# Successfully processed: SPXL.csv
# Successfully processed: SPY.csv
# Successfully processed: SPYD.csv
# Successfully processed: SPYG.csv
# Successfully processed: SPYI.csv
# Successfully processed: SPYV.csv
# Successfully processed: SQQQ.csv
# Successfully processed: SRAD.csv
# Successfully processed: SRE.csv
# Successfully processed: SRLN.csv
# Successfully processed: SSB.csv
# Successfully processed: SSD.csv
# Successfully processed: SSNC.csv
# Successfully processed: SSO.csv
# Successfully processed: STAG.csv
# Successfully processed: STE.csv
# Successfully processed: STEP.csv
# Successfully processed: STIP.csv
# Successfully processed: STLA.csv
# Successfully processed: STLD.csv
# Successfully processed: STM.csv
# Successfully processed: STN.csv
# Successfully processed: STT.csv
# Successfully processed: STVN.csv
# Successfully processed: STWD.csv
# Successfully processed: STX.csv
# Successfully processed: STZ.csv
# Successfully processed: SU.csv
# Successfully processed: SUB.csv
# Successfully processed: SUI.csv
# Successfully processed: SUN.csv
# Successfully processed: SUSA.csv
# Successfully processed: SUZ.csv
# Successfully processed: SW.csv
# Successfully processed: SWK.csv
# Successfully processed: SWKS.csv
# Successfully processed: SYF.csv
# Successfully processed: SYK.csv
# Successfully processed: SYM.csv
# Successfully processed: SYY.csv
# Successfully processed: T.csv
# Successfully processed: TAK.csv
# Successfully processed: TAP.csv
# Successfully processed: TBIL.csv
# Successfully processed: TCAF.csv
# Successfully processed: TCOM.csv
# Successfully processed: TD.csv
# Successfully processed: TDG.csv
# Successfully processed: TDY.csv
# Successfully processed: TEAM.csv
# Successfully processed: TECH.csv
# Successfully processed: TECK.csv
# Successfully processed: TEF.csv
# Successfully processed: TEL.csv
# Successfully processed: TEM.csv
# Successfully processed: TER.csv
# Successfully processed: TEVA.csv
# Successfully processed: TFC.csv
# Successfully processed: TFI.csv
# Successfully processed: TFII.csv
# Successfully processed: TFLO.csv
# Successfully processed: TGT.csv
# Successfully processed: THC.csv
# Successfully processed: THG.csv
# Successfully processed: TIGO.csv
# Successfully processed: TIMB.csv
# Successfully processed: TIP.csv
# Successfully processed: TJX.csv
# Successfully processed: TKO.csv
# Successfully processed: TLH.csv
# Successfully processed: TLK.csv
# Successfully processed: TLN.csv
# Successfully processed: TLT.csv
# Successfully processed: TLX.csv
# Successfully processed: TM.csv
# Successfully processed: TME.csv
# Successfully processed: TMF.csv
# Successfully processed: TMHC.csv
# Successfully processed: TMO.csv
# Successfully processed: TMUS.csv
# Successfully processed: TOL.csv
# Successfully processed: TOST.csv
# Successfully processed: TOTL.csv
# Successfully processed: TPG.csv
# Successfully processed: TPL.csv
# Successfully processed: TPR.csv
# Successfully processed: TQQQ.csv
# Successfully processed: TREX.csv
# Successfully processed: TRGP.csv
# Successfully processed: TRI.csv
# Successfully processed: TRMB.csv
# Successfully processed: TRNO.csv
# Successfully processed: TROW.csv
# Successfully processed: TRP.csv
# Successfully processed: TRU.csv
# Successfully processed: TRV.csv
# Successfully processed: TS.csv
# Successfully processed: TSCO.csv
# Successfully processed: TSLA.csv
# Successfully processed: TSLL.csv
# Successfully processed: TSM.csv
# Successfully processed: TSN.csv
# Successfully processed: TT.csv
# Successfully processed: TTAN.csv
# Successfully processed: TTC.csv
# Successfully processed: TTD.csv
# Successfully processed: TTE.csv
# Successfully processed: TTEK.csv
# Successfully processed: TTWO.csv
# Successfully processed: TU.csv
# Successfully processed: TW.csv
# Successfully processed: TWLO.csv
# Successfully processed: TX.csv
# Successfully processed: TXN.csv
# Successfully processed: TXRH.csv
# Successfully processed: TXT.csv
# Successfully processed: TYL.csv
# Successfully processed: U.csv
# Successfully processed: UAL.csv
# Successfully processed: UBER.csv
# Successfully processed: UBS.csv
# Successfully processed: UCON.csv
# Successfully processed: UDR.csv
# Successfully processed: UFPI.csv
# Successfully processed: UGI.csv
# Successfully processed: UHAL-B.csv
# Successfully processed: UHAL.csv
# Successfully processed: UHS.csv
# Successfully processed: UI.csv
# Successfully processed: UL.csv
# Successfully processed: ULS.csv
# Successfully processed: ULTA.csv
# Successfully processed: UMBF.csv
# Successfully processed: UMC.csv
# Successfully processed: UNH.csv
# Successfully processed: UNM.csv
# Successfully processed: UNP.csv
# Successfully processed: UPRO.csv
# Successfully processed: UPS.csv
# Successfully processed: URI.csv
# Successfully processed: URTH.csv
# Successfully processed: USB.csv
# Successfully processed: USFD.csv
# Successfully processed: USFR.csv
# Successfully processed: USHY.csv
# Successfully processed: USIG.csv
# Successfully processed: USMV.csv
# Successfully processed: UTHR.csv
# Successfully processed: UWMC.csv
# Successfully processed: V.csv
# Successfully processed: VALE.csv
# Successfully processed: VB.csv
# Successfully processed: VBK.csv
# Successfully processed: VBR.csv
# Successfully processed: VCIT.csv
# Successfully processed: VCLT.csv
# Successfully processed: VCR.csv
# Successfully processed: VCSH.csv
# Successfully processed: VDC.csv
# Successfully processed: VDE.csv
# Successfully processed: VEA.csv
# Successfully processed: VEEV.csv
# Successfully processed: VERX.csv
# Successfully processed: VEU.csv
# Successfully processed: VFH.csv
# Successfully processed: VFLO.csv
# Successfully processed: VFS.csv
# Successfully processed: VG.csv
# Successfully processed: VGIT.csv
# Successfully processed: VGK.csv
# Successfully processed: VGLT.csv
# Successfully processed: VGSH.csv
# Successfully processed: VGT.csv
# Successfully processed: VHT.csv
# Successfully processed: VICI.csv
# Successfully processed: VIG.csv
# Successfully processed: VIGI.csv
# Successfully processed: VIK.csv
# Successfully processed: VIPS.csv
# Successfully processed: VIRT.csv
# Successfully processed: VIS.csv
# Successfully processed: VIV.csv
# Successfully processed: VLO.csv
# Successfully processed: VLTO.csv
# Successfully processed: VLUE.csv
# Successfully processed: VMBS.csv
# Successfully processed: VMC.csv
# Successfully processed: VMI.csv
# Successfully processed: VNO.csv
# Successfully processed: VNOM.csv
# Successfully processed: VNQ.csv
# Successfully processed: VNQI.csv
# Successfully processed: VO.csv
# Successfully processed: VOD.csv
# Successfully processed: VOE.csv
# Successfully processed: VONE.csv
# Successfully processed: VONG.csv
# Successfully processed: VONV.csv
# Successfully processed: VOO.csv
# Successfully processed: VOOG.csv
# Successfully processed: VOOV.csv
# Successfully processed: VOT.csv
# Successfully processed: VOX.csv
# Successfully processed: VOYA.csv
# Successfully processed: VPL.csv
# Successfully processed: VPU.csv
# Successfully processed: VRNA.csv
# Successfully processed: VRSK.csv
# Successfully processed: VRSN.csv
# Successfully processed: VRT.csv
# Successfully processed: VRTX.csv
# Successfully processed: VSGX.csv
# Successfully processed: VSS.csv
# Successfully processed: VST.csv
# Successfully processed: VT.csv
# Successfully processed: VTEB.csv
# Successfully processed: VTI.csv
# Successfully processed: VTIP.csv
# Successfully processed: VTR.csv
# Successfully processed: VTRS.csv
# Successfully processed: VTV.csv
# Successfully processed: VTWO.csv
# Successfully processed: VUG.csv
# Successfully processed: VUSB.csv
# Successfully processed: VV.csv
# Successfully processed: VWO.csv
# Successfully processed: VWOB.csv
# Successfully processed: VXF.csv
# Successfully processed: VXUS.csv
# Successfully processed: VYM.csv
# Successfully processed: VYMI.csv
# Successfully processed: VZ.csv
# Successfully processed: WAB.csv
# Successfully processed: WAL.csv
# Successfully processed: WAT.csv
# Successfully processed: WAY.csv
# Successfully processed: WBA.csv
# Successfully processed: WBD.csv
# Successfully processed: WBS.csv
# Successfully processed: WCC.csv
# Successfully processed: WCN.csv
# Successfully processed: WDAY.csv
# Successfully processed: WDC.csv
# Successfully processed: WDS.csv
# Successfully processed: WEC.csv
# Successfully processed: WELL.csv
# Successfully processed: WES.csv
# Successfully processed: WF.csv
# Successfully processed: WFC.csv
# Successfully processed: WFG.csv
# Successfully processed: WH.csv
# Successfully processed: WING.csv
# Successfully processed: WIT.csv
# Successfully processed: WIX.csv
# Successfully processed: WLK.csv
# Successfully processed: WM.csv
# Successfully processed: WMB.csv
# Successfully processed: WMG.csv
# Successfully processed: WMS.csv
# Successfully processed: WMT.csv
# Successfully processed: WPC.csv
# Successfully processed: WPM.csv
# Successfully processed: WPP.csv
# Successfully processed: WRB.csv
# Successfully processed: WSM.csv
# Successfully processed: WSO.csv
# Successfully processed: WST.csv
# Successfully processed: WTFC.csv
# Successfully processed: WTRG.csv
# Successfully processed: WTS.csv
# Successfully processed: WTW.csv
# Successfully processed: WWD.csv
# Successfully processed: WY.csv
# Successfully processed: WYNN.csv
# Successfully processed: X.csv
# Successfully processed: XBI.csv
# Successfully processed: XEL.csv
# Successfully processed: XLB.csv
# Successfully processed: XLC.csv
# Successfully processed: XLE.csv
# Successfully processed: XLF.csv
# Successfully processed: XLG.csv
# Successfully processed: XLI.csv
# Successfully processed: XLK.csv
# Successfully processed: XLP.csv
# Successfully processed: XLRE.csv
# Successfully processed: XLU.csv
# Successfully processed: XLV.csv
# Successfully processed: XLY.csv
# Successfully processed: XMHQ.csv
# Successfully processed: XMMO.csv
# Successfully processed: XOM.csv
# Successfully processed: XP.csv
# Successfully processed: XPEV.csv
# Successfully processed: XPO.csv
# Successfully processed: XYL.csv
# Successfully processed: XYZ.csv
# Successfully processed: YMM.csv
# Successfully processed: YPF.csv
# Successfully processed: YUM.csv
# Successfully processed: YUMC.csv
# Successfully processed: Z.csv
# Successfully processed: ZBH.csv
# Successfully processed: ZBRA.csv
# Successfully processed: ZG.csv
# Successfully processed: ZION.csv
# Successfully processed: ZK.csv
# Successfully processed: ZM.csv
# Successfully processed: ZS.csv
# Successfully processed: ZTO.csv
# Successfully processed: ZTS.csv
# Successfully processed: ZWS.csv
#
# --- MultiIndex DataFrame (First 5 Rows) ---
#                    Adj Open  Adj High  Adj Low  Adj Close   Volume
# Ticker Date
# A      2025-05-08    108.00    110.65   106.55     108.70  2093340
#        2025-05-07    106.69    107.60   104.79     107.52  2143700
#        2025-05-06    107.25    108.21   104.36     105.24  1960600
#        2025-05-05    108.10    109.25   107.46     108.37  1385500
#        2025-05-02    109.24    110.33   107.45     108.63  1213100
#
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 428529 entries, ('A', Timestamp('2025-05-08 00:00:00')) to ('ZWS', Timestamp('2024-05-07 00:00:00'))
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Adj Open   428529 non-null  float64
#  1   Adj High   428529 non-null  float64
#  2   Adj Low    428529 non-null  float64
#  3   Adj Close  428529 non-null  float64
#  4   Volume     428529 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 18.0+ MB
#
# --- First 5 rows of 'NVDA' data (sorted by Date descending within Ticker) ---
#             Adj Open  Adj High  Adj Low  Adj Close     Volume
# Date
# 2025-05-08    118.48    118.68   115.85     117.37  195705150
# 2025-05-07    113.05    117.68   112.28     117.06  207827800
# 2025-05-06    111.48    114.74   110.82     113.54  158525600
# 2025-05-05    112.91    114.67   112.66     113.82  133163200
# 2025-05-02    114.18    115.40   113.37     114.50  190194800

# %%
print(f'ticker to show: {example_ticker_to_show}')
final_df.loc[example_ticker_to_show]
# Out:
# ticker to show: NVDA
#             Adj Open  Adj High   Adj Low  Adj Close     Volume
# Date
# 2025-05-08  118.4800  118.6800  115.8500   117.3700  195705150
# 2025-05-07  113.0500  117.6800  112.2800   117.0600  207827800
# 2025-05-06  111.4800  114.7400  110.8200   113.5400  158525600
# 2025-05-05  112.9100  114.6700  112.6600   113.8200  133163200
# 2025-05-02  114.1800  115.4000  113.3700   114.5000  190194800
# ...              ...       ...       ...        ...        ...
# 2024-01-08   49.4934   52.2554   49.4604    52.2334  642751375
# 2024-01-05   48.4438   49.5284   48.2879    49.0786  415194877
# 2024-01-04   47.7491   48.4818   47.4902    47.9800  306650106
# 2024-01-03   47.4672   48.1659   47.3022    47.5511  321016529
# 2024-01-02   49.2255   49.2765   47.5771    48.1499  411408437
#
# [339 rows x 5 columns]

# %%
final_df.to_parquet(DEST_PATH, engine='pyarrow', compression='zstd', index=True)
print(f"OHLCV data saved to: {DEST_PATH}")
# Out:
# OHLCV data saved to: C:/Users/ping/Files_win10/python/py311/stocks/data/df_OHLCV_stocks_etfs.parquet

# %%
# _df = pd.read_parquet(DEST_PATH)
# print(_df.head())
