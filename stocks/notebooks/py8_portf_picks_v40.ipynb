# %%
import sys
from pathlib import Path

# Notebook cell
# %load_ext autoreload
# %autoreload 2

# Get root directory (assuming notebook is in root/notebooks/)
NOTEBOOK_DIR = Path.cwd()
ROOT_DIR = NOTEBOOK_DIR.parent if NOTEBOOK_DIR.name == 'notebooks' else NOTEBOOK_DIR

# Add src directory to Python path
sys.path.append(str(ROOT_DIR / 'src'))

# Verify path
print(f"Python will look in these locations:\n{sys.path}")


# --- Execute the processor ---
import utils
# from config import date_str, DOWNLOAD_DIR, DEST_DIR

# print(f'date_str: {date_str}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Python will look in these locations:
# ['C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.11.9\\python311.zip', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.11.9\\DLLs', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.11.9\\Lib', 'C:\\Users\\ping\\.pyenv\\pyenv-win\\versions\\3.11.9', 'c:\\Users\\ping\\Files_win10\\python\\py311\\.venv', '', 'c:\\Users\\ping\\Files_win10\\python\\py311\\.venv\\Lib\\site-packages', 'c:\\Users\\ping\\Files_win10\\python\\py311\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\ping\\Files_win10\\python\\py311\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\ping\\Files_win10\\python\\py311\\.venv\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py311\\.venv\\Lib\\site-packages\\setuptools\\_vendor', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src', 'c:\\Users\\ping\\Files_win10\\python\\py311\\stocks\\src']

# %%
date_str = '2025-04-09'

# %%
import pandas as pd
# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
pd.set_option('display.width', 1000)        # Let the display adjust to the window
# pd.set_option('display.max_colwidth', None) # Show full content of each cell
pd.set_option('display.max_rows', 200)
# pd.set_option('display.width', 120)
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
zscore_df = pd.read_parquet(f'..\data\{date_str}_zscore_df.parquet', engine='pyarrow')
cluster_stats_df = pd.read_parquet(f'..\data\{date_str}_cluster_stats_df.parquet', engine='pyarrow')
detailed_clusters_df = pd.read_parquet(f'..\data\{date_str}_detailed_clusters_df.parquet', engine='pyarrow')
# df_data = pd.read_parquet(f'..\data\{date_str}_df_finviz_merged.parquet', engine='pyarrow')

# %%
detailed_clusters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1180 entries, 1117 to 386
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Cluster_ID      1180 non-null   int32
#  1   Ticker          1180 non-null   object
#  2   Raw_Score       1180 non-null   float64
#  3   Risk_Adj_Score  1180 non-null   float64
#  4   Volatility      1180 non-null   float64
#  5   Price           1180 non-null   float64
#  6   MktCap AUM, M   1180 non-null   float64
# dtypes: float64(5), int32(1), object(1)
# memory usage: 69.1+ KB

# %%
import pandas as pd # Assuming pandas is used

def select_stocks_from_clusters(cluster_stats_df, detailed_clusters_df,
                                num_clusters=3, max_selection_per_cluster=5,
                                min_cluster_size=5, penalty_IntraCluster_Corr=0.3,
                                date_str=date_str,
                                min_raw_score=None, # <-- Added argument
                                min_risk_adj_score=None): # <-- Added argument
    """
    Pipeline to select stocks from better performing clusters, with optional score thresholds.

    Parameters:
    - cluster_stats_df: DataFrame with cluster statistics.
    - detailed_clusters_df: DataFrame with detailed cluster information including
                            'Ticker', 'Cluster_ID', 'Raw_Score', 'Risk_Adj_Score', etc.
    - num_clusters: int, Number of top clusters to select (default=3).
    - max_selection_per_cluster: int, Max number of stocks to select from each cluster (default=5).
    - min_cluster_size: int, Minimum size for a cluster to be considered (default=5).
    - penalty_IntraCluster_Corr: float, Penalty weight for intra-cluster correlation in
                                     composite score (default=0.3).
    - date_str: str, Date string for tracking/parameter storage.
    - min_raw_score: float, optional (default=None)
        Minimum Raw_Score required for a stock to be considered for selection.
        If None, no threshold is applied based on Raw_Score.
    - min_risk_adj_score: float, optional (default=None)
        Minimum Risk_Adj_Score required for a stock to be considered for selection.
        If None, no threshold is applied based on Risk_Adj_Score.

    Returns:
    - dict: A dictionary containing:
        - 'selected_stocks': DataFrame of selected stocks.
        - 'cluster_performance': DataFrame of selected cluster metrics.
        - 'parameters': Dictionary of the input parameters used.
    """

    # Store input parameters
    parameters = {
        'date_str': date_str,
        'num_clusters': num_clusters,
        'max_selection_per_cluster': max_selection_per_cluster,
        'min_cluster_size': min_cluster_size,
        'min_raw_score': min_raw_score,         # <-- Stored parameter
        'min_risk_adj_score': min_risk_adj_score, # <-- Stored parameter
        'penalty_IntraCluster_Corr': penalty_IntraCluster_Corr,
    }

    # ===== 1. Filter and Rank Clusters =====
    qualified_clusters = cluster_stats_df[cluster_stats_df['Size'] >= min_cluster_size].copy()
    if qualified_clusters.empty:
        print(f"Warning: No clusters met the minimum size criteria ({min_cluster_size}).")
        return {
            'selected_stocks': pd.DataFrame(),
            'cluster_performance': pd.DataFrame(),
            'parameters': parameters
        }

    qualified_clusters['Composite_Cluster_Score'] = (
        (1 - penalty_IntraCluster_Corr) * qualified_clusters['Avg_Raw_Score'] +
        penalty_IntraCluster_Corr * (1 - qualified_clusters['Avg_IntraCluster_Corr'])
    )
    ranked_clusters = qualified_clusters.sort_values('Composite_Cluster_Score', ascending=False)
    selected_clusters = ranked_clusters.head(num_clusters)
    cluster_ids = selected_clusters['Cluster_ID'].tolist()

    if not cluster_ids:
        print("Warning: No clusters were selected based on ranking.")
        return {
            'selected_stocks': pd.DataFrame(),
            'cluster_performance': selected_clusters, # Return empty selected clusters df
            'parameters': parameters
        }


    # ===== 2. Select Stocks from Each Cluster =====
    selected_stocks_list = []
    for cluster_id in cluster_ids:
        # Get all stocks for the current cluster
        cluster_stocks = detailed_clusters_df[detailed_clusters_df['Cluster_ID'] == cluster_id].copy()

        # ===> Apply Threshold Filters <===
        if min_raw_score is not None:
            cluster_stocks = cluster_stocks[cluster_stocks['Raw_Score'] >= min_raw_score]
        if min_risk_adj_score is not None:
            cluster_stocks = cluster_stocks[cluster_stocks['Risk_Adj_Score'] >= min_risk_adj_score]
        # ===> End of Added Filters <===

        # Proceed only if stocks remain after filtering
        if len(cluster_stocks) > 0:
            # Sort remaining stocks by Risk_Adj_Score and select top N
            top_stocks = cluster_stocks.sort_values('Risk_Adj_Score', ascending=False).head(max_selection_per_cluster)

            # Add cluster-level metrics to the selected stock rows
            cluster_metrics = selected_clusters[selected_clusters['Cluster_ID'] == cluster_id].iloc[0]
            for col in ['Composite_Cluster_Score', 'Avg_IntraCluster_Corr', 'Avg_Volatility',
                      'Avg_Raw_Score', 'Avg_Risk_Adj_Score', 'Size']: # Added Size for context
                # Use .get() for safety if a column might be missing
                top_stocks[f'Cluster_{col}'] = cluster_metrics.get(col, None)
            selected_stocks_list.append(top_stocks)

    # Consolidate selected stocks
    if selected_stocks_list:
        selected_stocks = pd.concat(selected_stocks_list)
        # Recalculate weights based on the final selection
        if selected_stocks['Risk_Adj_Score'].sum() != 0:
             selected_stocks['Weight'] = (selected_stocks['Risk_Adj_Score'] /
                                          selected_stocks['Risk_Adj_Score'].sum())
        else:
             # Handle case where all selected scores are zero (unlikely but possible)
             selected_stocks['Weight'] = 1 / len(selected_stocks) if len(selected_stocks) > 0 else 0

        selected_stocks = selected_stocks.sort_values(['Cluster_ID', 'Risk_Adj_Score'],
                                                    ascending=[True, False])
    else:
        selected_stocks = pd.DataFrame()
        print("Warning: No stocks met selection criteria (including score thresholds if applied).")


    # ===== 3. Prepare Enhanced Output Reports =====
    cluster_performance = selected_clusters.copy()
    # Calculate how many stocks were actually selected per cluster after filtering
    cluster_performance['Stocks_Selected'] = cluster_performance['Cluster_ID'].apply(
        lambda x: len(selected_stocks[selected_stocks['Cluster_ID'] == x]) if not selected_stocks.empty else 0)

    if not selected_stocks.empty:
         # Ensure Avg_IntraCluster_Corr exists before calculating diversification
        if 'Avg_IntraCluster_Corr' in cluster_performance.columns:
             cluster_performance['Intra_Cluster_Diversification'] = 1 - cluster_performance['Avg_IntraCluster_Corr']
        else:
             cluster_performance['Intra_Cluster_Diversification'] = pd.NA # Or None
    else:
      # Handle case where selected_stocks is empty
        cluster_performance['Intra_Cluster_Diversification'] = pd.NA # Or None

    # ===> Package results and parameters
    results_bundle = {
        'selected_stocks': selected_stocks,
        'cluster_performance': cluster_performance,
        'parameters': parameters
    }

    return results_bundle

# %%
import pandas as pd
from typing import Dict, Any

def print_stock_selection_report(output: Dict[str, Any]) -> None:
    """
    Prints a detailed report summarizing the results of the stock selection process,
    extracting all necessary information from the output dictionary.

    Args:
        output (Dict[str, Any]): The dictionary returned by the
                                 select_stocks_from_clusters function, containing:
                                 - 'selected_stocks': DataFrame of selected stocks.
                                 - 'cluster_performance': DataFrame of selected cluster metrics.
                                #  - 'parameters': Dictionary of the input parameters used.
                                #  - 'input_cluster_stats_df': Original cluster stats DataFrame.
                                #  - 'input_detailed_clusters_df': Original detailed clusters DataFrame.
    Returns:
        None: This function prints output to the console.
    """
    # Extract data from the output dictionary using .get() for safety
    selected_stocks = output.get('selected_stocks', pd.DataFrame())
    cluster_performance = output.get('cluster_performance', pd.DataFrame())
    used_params = output.get('parameters', {})
    # Extract the input DataFrames needed for the report
    cluster_stats_df = output.get('input_cluster_stats_df') # Might be None
    detailed_clusters_df = output.get('input_detailed_clusters_df') # Might be None

    # --- Start of Original Code Block (adapted) ---

    print("\n=== CLUSTER SELECTION CRITERIA ===")
    print("* Using Composite_Cluster_Score (balancing Raw Score and diversification) for cluster ranking.")
    print("* Using Risk_Adj_Score for stock selection within clusters.")

    num_selected_clusters = len(cluster_performance) if not cluster_performance.empty else 0
    # Use the extracted cluster_stats_df
    total_clusters = len(cluster_stats_df) if cluster_stats_df is not None and not cluster_stats_df.empty else 'N/A'

    print(f"* Selected top {num_selected_clusters} clusters from {total_clusters} total initial clusters.") # Adjusted wording slightly
    print(f"* Selection Criteria:")
    if used_params:
        for key, value in used_params.items():
            # Avoid printing the large input dataframes stored in parameters if they were added there too
            if not isinstance(value, pd.DataFrame):
                 print(f"    {key}: {value}")
    else:
        print("    Parameters not available.")


    if not cluster_performance.empty:
        print("\n=== SELECTED CLUSTERS (RANKED BY COMPOSITE SCORE) ===")
        display_cols_exist = [col for col in [
                                'Cluster_ID', 'Size', 'Avg_Raw_Score', 'Avg_Risk_Adj_Score',
                                'Avg_IntraCluster_Corr', 'Avg_Volatility', 'Composite_Cluster_Score',
                                'Stocks_Selected', 'Intra_Cluster_Diversification']
                              if col in cluster_performance.columns]
        print(cluster_performance[display_cols_exist].sort_values('Composite_Cluster_Score', ascending=False).to_string(index=False))

        # Print top 8 stocks by Raw_Score for each selected cluster
        # Check if detailed_clusters_df was successfully extracted
        if detailed_clusters_df is not None and not detailed_clusters_df.empty:
            print("\n=== TOP STOCKS BY RAW SCORE PER SELECTED CLUSTER ===")
            print("""* Volatility is the standard deviation of daily returns over the past 250 trading days (example context).
* Note: The stocks below are shown ranked by Raw_Score for analysis,
*       but actual selection within the cluster was based on Risk_Adj_Score.""")

            for cluster_id in cluster_performance['Cluster_ID']:
                 cluster_stocks = detailed_clusters_df[detailed_clusters_df['Cluster_ID'] == cluster_id]
                 if not cluster_stocks.empty:
                    required_cols = ['Ticker', 'Raw_Score', 'Risk_Adj_Score', 'Volatility']
                    if all(col in cluster_stocks.columns for col in required_cols):
                        top_raw = cluster_stocks.nlargest(8, 'Raw_Score')[required_cols]

                        print(f"\nCluster {cluster_id} - Top 8 by Raw Score:")
                        print(top_raw.to_string(index=False))
                        cluster_avg_raw = cluster_performance.loc[cluster_performance['Cluster_ID'] == cluster_id, 'Avg_Raw_Score'].values
                        cluster_avg_risk = cluster_performance.loc[cluster_performance['Cluster_ID'] == cluster_id, 'Avg_Risk_Adj_Score'].values
                        if len(cluster_avg_raw) > 0: print(f"Cluster Avg Raw Score: {cluster_avg_raw[0]:.2f}")
                        if len(cluster_avg_risk) > 0: print(f"Cluster Avg Risk Adj Score: {cluster_avg_risk[0]:.2f}")
                    else:
                        print(f"\nCluster {cluster_id} - Missing required columns in detailed_clusters_df to show top stocks.")
                 else:
                     print(f"\nCluster {cluster_id} - No stocks found in detailed_clusters_df for this cluster.")
        else:
            print("\n=== TOP STOCKS BY RAW SCORE PER SELECTED CLUSTER ===")
            print("Skipping - Detailed cluster information ('input_detailed_clusters_df') not found in the output dictionary.")

    else:
        print("\n=== SELECTED CLUSTERS ===")
        print("No clusters were selected based on the criteria.")


    print(f"\n=== FINAL SELECTED STOCKS (FILTERED & WEIGHTED) ===")
    if not selected_stocks.empty:
        print("* Stocks actually selected based on Risk_Adj_Score (and optional thresholds) within each cluster.")
        print("* Position weights assigned based on Risk_Adj_Score within the final selected portfolio.")

        desired_cols = ['Cluster_ID', 'Ticker', 'Raw_Score', 'Risk_Adj_Score',
                        'Volatility', 'Weight',
                        'Cluster_Avg_Raw_Score', 'Cluster_Avg_Risk_Adj_Score']
        available_cols = [col for col in desired_cols if col in selected_stocks.columns]
        print(selected_stocks[available_cols].sort_values(['Cluster_ID', 'Risk_Adj_Score'],
                                                        ascending=[True, False]).to_string(index=False))

        print("\n=== PORTFOLIO SUMMARY ===")
        print(f"Total Stocks Selected: {len(selected_stocks)}")
        print(f"Average Raw Score: {selected_stocks.get('Raw_Score', pd.Series(dtype=float)).mean():.2f}")
        print(f"Average Risk-Adjusted Score: {selected_stocks.get('Risk_Adj_Score', pd.Series(dtype=float)).mean():.2f}")
        print(f"Average Volatility: {selected_stocks.get('Volatility', pd.Series(dtype=float)).mean():.2f}")
        print(f"Total Weight (should be close to 1.0): {selected_stocks.get('Weight', pd.Series(dtype=float)).sum():.4f}")
        print("\nCluster Distribution:")
        print(selected_stocks['Cluster_ID'].value_counts().to_string())
    else:
        print("No stocks were selected after applying all filters and criteria.")

# %%
import pandas as pd
import numpy as np # Useful for generating the range with floats

# --- Iteration Setup ---
# Generate the factors using numpy.arange for float steps
# Add a small epsilon to the end value to ensure 1.0 is included due to float precision
raw_score_factors = np.arange(0.5, 1.2 + 0.01, 0.1)
risk_adj_score_factors = np.arange(0.5, 1.2 + 0.01, 0.1)

# Store results
all_portfolios = {} # Dictionary to store portfolios by name

# --- Fixed Parameters ---
num_clusters = 60
max_selection_per_cluster = 2
min_cluster_size = 3  # prevent extreme high risk adj scores
penalty_IntraCluster_Corr = 0
# You might want to get the date dynamically
portf_date_base = date_str # Example date, adjust as needed

# --- Iteration Loop ---
print("Starting portfolio generation loop...")
for raw_scale in raw_score_factors:
    for risk_adj_scale in risk_adj_score_factors:

        # --- Calculate dynamic parameters based on current factors ---
        # Round factors slightly to avoid potential floating point representation issues in calculations/names
        raw_scale = round(raw_scale, 1)
        risk_adj_scale = round(risk_adj_scale, 1)

        min_raw_score = 2.0 * raw_scale
        min_risk_adj_score = 100.0 * risk_adj_scale

        print(f"\nRunning with: raw_score_scale_factor={raw_scale:.1f}, risk_adj_score_scale_factor={risk_adj_scale:.1f}")
        print(f"Resulting thresholds: min_raw_score={min_raw_score:.2f}, min_risk_adj_score={min_risk_adj_score:.1f}")

        # --- Run the selection pipeline ---
        try:
            output = select_stocks_from_clusters(
                cluster_stats_df=cluster_stats_df,
                detailed_clusters_df=detailed_clusters_df,
                num_clusters=num_clusters,
                max_selection_per_cluster=max_selection_per_cluster,
                min_cluster_size=min_cluster_size,
                penalty_IntraCluster_Corr=penalty_IntraCluster_Corr,
                min_raw_score=min_raw_score,
                min_risk_adj_score=min_risk_adj_score,
                date_str=portf_date_base # Pass the date
            )

            # --- Process and Store Results ---
            portf_date = output['parameters']['date_str']
            portf_raw_score_val = output['parameters']['min_raw_score'] # Use the value returned by the function
            portf_risk_adj_score_val = output['parameters']['min_risk_adj_score'] # Use the value returned by the function
            _selected_stocks = output['selected_stocks']

            if _selected_stocks is not None and not _selected_stocks.empty:
                portf_selected_stocks = _selected_stocks.set_index('Ticker')[['Weight']] # Select only Weight column after setting index

                # Format the name using the factors or the resulting thresholds
                # Using factors for potentially cleaner names:
                # portf_name = f'{portf_date}_portf_rawFactor_{raw_scale:.1f}_riskAdjFactor_{risk_adj_scale:.1f}'
                # Using resulting thresholds (closer to original example, formatting):
                portf_name = f'{portf_date}_portf_rawscore_{portf_raw_score_val:.2f}_riskadjscore_{portf_risk_adj_score_val:.1f}'

                print(f'Generated Portfolio:')
                # print(f'portf_date: {portf_date}') # redundant if in name
                # print(f'portf_raw_score: {portf_raw_score_val:.2f}') # redundant if in name
                # print(f'portf_risk_adj_score: {portf_risk_adj_score_val:.1f}') # redundant if in name
                print(f'portf_name: {portf_name}')
                print(f'Number of stocks: {len(portf_selected_stocks)}')
                # print(f'port_selected_stocks:\n{portf_selected_stocks}') # Can be verbose, print if needed

                # Store the results - using the portfolio name as the key
                all_portfolios[portf_name] = {
                    'parameters': {
                        'raw_score_scale_factor': raw_scale,
                        'risk_adj_score_scale_factor': risk_adj_scale,
                        'min_raw_score': portf_raw_score_val,
                        'min_risk_adj_score': portf_risk_adj_score_val,
                        'num_clusters': num_clusters,
                        'max_selection_per_cluster': max_selection_per_cluster,
                        'min_cluster_size': min_cluster_size,
                        'penalty_IntraCluster_Corr': penalty_IntraCluster_Corr,
                        'date': portf_date
                    },
                    'selected_stocks': portf_selected_stocks
                }
            else:
                 print(f"No stocks selected for raw_scale={raw_scale:.1f}, risk_adj_scale={risk_adj_scale:.1f}")

        except Exception as e:
            print(f"ERROR processing combination raw_scale={raw_scale:.1f}, risk_adj_scale={risk_adj_scale:.1f}: {e}")
            # Decide if you want to continue or stop on error

print(f"\n--- Portfolio Generation Complete ---")
print(f"Generated {len(all_portfolios)} portfolios.")
# Out:
# Starting portfolio generation loop...
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_50.0
# Number of stocks: 12
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_60.0
# Number of stocks: 10
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_70.0
# Number of stocks: 7
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_80.0
# Number of stocks: 5
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_90.0
# Number of stocks: 3
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_100.0
# Number of stocks: 3
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.5, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=1.00, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.00_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_50.0
# Number of stocks: 8
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_60.0
# Number of stocks: 7
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_70.0
# Number of stocks: 4
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_80.0
# Number of stocks: 4
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_90.0
# Number of stocks: 3
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_100.0
# Number of stocks: 3
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.6, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=1.20, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.20_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_50.0
# Number of stocks: 6
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_60.0
# Number of stocks: 6
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_70.0
# Number of stocks: 4
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_80.0
# Number of stocks: 4
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_90.0
# Number of stocks: 3
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_100.0
# Number of stocks: 3
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.7, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=1.40, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.40_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_50.0
# Number of stocks: 2
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_60.0
# Number of stocks: 2
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_70.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_80.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_90.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_100.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.8, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=1.60, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.60_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_50.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_60.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_70.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_80.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_90.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_100.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=0.9, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=1.80, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_1.80_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_50.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_60.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_70.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_80.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_90.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_100.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.0, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=2.00, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.00_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_50.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_60.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_70.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_80.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_90.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_100.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.1, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=2.20, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.20_riskadjscore_120.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=0.5
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=50.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_50.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=0.6
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=60.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_60.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=0.7
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=70.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_70.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=0.8
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=80.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_80.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=0.9
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=90.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_90.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=1.0
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=100.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_100.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=1.1
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=110.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_110.0
# Number of stocks: 1
#
# Running with: raw_score_scale_factor=1.2, risk_adj_score_scale_factor=1.2
# Resulting thresholds: min_raw_score=2.40, min_risk_adj_score=120.0
# Generated Portfolio:
# portf_name: 2025-04-09_portf_rawscore_2.40_riskadjscore_120.0
# Number of stocks: 1
#
# --- Portfolio Generation Complete ---
# Generated 64 portfolios.

# %%
# --- Example: Accessing a specific portfolio ---
# # (Choose a valid name generated above)
# example_name = '2023-10-27_portf_rawscore_1.40_riskadjscore_80.0'
# if example_name in all_portfolios:
#     print(f"\nAccessing example portfolio: {example_name}")
#     print(all_portfolios[example_name]['selected_stocks'].head())
# else:
#     print(f"\nExample portfolio name '{example_name}' not found in results.")

# You can now iterate through `all_portfolios` dictionary
for portf_name, portf_data in all_portfolios.items():
    print(f"\nPortfolio: {portf_name}")
    print("Parameters:", portf_data['parameters'])
    print(f"Selected Stocks (head), count: {len(portf_data['selected_stocks'])}:")
    print(portf_data['selected_stocks'].head(20))
# Out:
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 12:
#         Weight
# Symbol
# SGOL    0.1067
# GLDM    0.1066
# TJX     0.0679
# IBN     0.0794
# HDB     0.0721
# CPRT    0.0649
# NOC     0.0561
# CNP     0.0877
# HRB     0.0819
# UNH     0.1499
# CVS     0.0691
# CNC     0.0578
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 10:
#         Weight
# Symbol
# SGOL    0.1204
# GLDM    0.1203
# TJX     0.0766
# IBN     0.0896
# HDB     0.0814
# CPRT    0.0732
# CNP     0.0990
# HRB     0.0924
# UNH     0.1692
# CVS     0.0779
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 7:
#         Weight
# Symbol
# SGOL    0.1559
# GLDM    0.1558
# IBN     0.1160
# HDB     0.1054
# CNP     0.1282
# HRB     0.1196
# UNH     0.2191
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 5:
#         Weight
# Symbol
# SGOL    0.2003
# GLDM    0.2001
# CNP     0.1646
# HRB     0.1536
# UNH     0.2814
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 3:
#         Weight
# Symbol
# SGOL    0.2938
# GLDM    0.2935
# UNH     0.4127
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 3:
#         Weight
# Symbol
# SGOL    0.2938
# GLDM    0.2935
# UNH     0.4127
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.00_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(0.5), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(1.0), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 8:
#         Weight
# Symbol
# SGOL    0.1518
# GLDM    0.1517
# TJX     0.0966
# CPRT    0.0923
# NOC     0.0797
# HRB     0.1165
# UNH     0.2133
# CVS     0.0982
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 7:
#         Weight
# Symbol
# SGOL    0.1650
# GLDM    0.1648
# TJX     0.1049
# CPRT    0.1003
# HRB     0.1265
# UNH     0.2317
# CVS     0.1067
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 4:
#         Weight
# Symbol
# SGOL    0.2397
# GLDM    0.2395
# HRB     0.1839
# UNH     0.3368
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 4:
#         Weight
# Symbol
# SGOL    0.2397
# GLDM    0.2395
# HRB     0.1839
# UNH     0.3368
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 3:
#         Weight
# Symbol
# SGOL    0.2938
# GLDM    0.2935
# UNH     0.4127
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 3:
#         Weight
# Symbol
# SGOL    0.2938
# GLDM    0.2935
# UNH     0.4127
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.20_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(0.6), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(1.2), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 6:
#         Weight
# Symbol
# SGOL    0.1843
# GLDM    0.1841
# CPRT    0.1120
# HRB     0.1414
# UNH     0.2589
# CVS     0.1193
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 6:
#         Weight
# Symbol
# SGOL    0.1843
# GLDM    0.1841
# CPRT    0.1120
# HRB     0.1414
# UNH     0.2589
# CVS     0.1193
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 4:
#         Weight
# Symbol
# SGOL    0.2397
# GLDM    0.2395
# HRB     0.1839
# UNH     0.3368
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 4:
#         Weight
# Symbol
# SGOL    0.2397
# GLDM    0.2395
# HRB     0.1839
# UNH     0.3368
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 3:
#         Weight
# Symbol
# SGOL    0.2938
# GLDM    0.2935
# UNH     0.4127
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 3:
#         Weight
# Symbol
# SGOL    0.2938
# GLDM    0.2935
# UNH     0.4127
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.40_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(0.7), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(1.4), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 2:
#         Weight
# Symbol
# UNH     0.6846
# CVS     0.3154
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 2:
#         Weight
# Symbol
# UNH     0.6846
# CVS     0.3154
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.60_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(0.8), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(1.6), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_1.80_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(0.9), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(1.8), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.00_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(1.0), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(2.0), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.20_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(1.1), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(2.2), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_50.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(0.5), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(50.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_60.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(0.6), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(60.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_70.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(0.7), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(70.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_80.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(0.8), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(80.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_90.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(0.9), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(90.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_100.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(1.0), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(100.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_110.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(1.1), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(110.00000000000001), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000
#
# Portfolio: 2025-04-09_portf_rawscore_2.40_riskadjscore_120.0
# Parameters: {'raw_score_scale_factor': np.float64(1.2), 'risk_adj_score_scale_factor': np.float64(1.2), 'min_raw_score': np.float64(2.4), 'min_risk_adj_score': np.float64(120.0), 'num_clusters': 60, 'max_selection_per_cluster': 2, 'min_cluster_size': 3, 'penalty_IntraCluster_Corr': 0, 'date': '2025-04-09'}
# Selected Stocks (head), count: 1:
#         Weight
# Symbol
# UNH     1.0000

# %%
# df_data = pd.read_parquet(f'..\data\{date_str}_df_finviz_merged.parquet', engine='pyarrow')
df_data = pd.read_parquet(r'..\data\2025-04-11_df_OHLCV_clean.parquet', engine='pyarrow')
df_data
# Out:
#                      Open    High     Low   Close  Adj Close   Volume  Adj Open  Adj High  Adj Low
# Symbol Date
# SSB    2025-04-11 80.4700 82.5200 78.5000 81.4500    81.4500   626776   80.4700   82.5200  78.5000
#        2025-04-10 84.4400 85.3900 78.3100 81.5500    81.5500  1000000   84.4400   85.3900  78.3100
#        2025-04-09 79.4900 88.7900 78.8700 87.3200    87.3200  1463500   79.4900   88.7900  78.8700
#        2025-04-08 85.3200 85.9100 79.5100 80.5900    80.5900  1105300   85.3200   85.9100  79.5100
#        2025-04-07 79.3400 85.4900 77.7400 82.0600    82.0600  1256100   79.3400   85.4900  77.7400
# ...                   ...     ...     ...     ...        ...      ...       ...       ...      ...
# SLGN   2024-04-18 46.8300 46.9300 46.4300 46.8400    46.1400   336200   46.1301   46.2287  45.7361
#        2024-04-17 47.1900 47.5200 46.7500 46.7900    46.0900   415600   46.4840   46.8091  46.0506
#        2024-04-16 47.1400 47.2700 46.5500 47.0500    46.3500   493900   46.4387   46.5667  45.8574
#        2024-04-15 47.8700 48.1000 46.9200 47.2500    46.5500   452900   47.1608   47.3874  46.2249
#        2024-04-12 48.4100 48.5100 47.3700 47.4700    46.7600   461900   47.6859   47.7844  46.6615
#
# [386289 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import traceback # Import traceback for detailed error printing

# --- Assume these are available ---
# all_portfolios: The dictionary generated previously.
#                 *** IMPORTANT: Check if the index name in selected_stocks_df is 'Ticker' or 'Symbol'. ***
#                 *** It MUST match the level name used in df_data ('Symbol' in this case). ***
# df_data: Your DataFrame with stock price data.
#          EXPECTED TO HAVE a MultiIndex named ['Symbol', 'Date'].

# Example placeholders (replace with your actual data loading)
# Dummy data for demonstration if you don't have it loaded
# try:
#     # Assume df_data might be loaded here, e.g.:
#     # df_data = pd.read_pickle('your_stock_data.pkl')

#     # Create dummy df_data if it doesn't exist for testing (using 'Symbol')
#     if 'df_data' not in locals():
#         print("Creating dummy df_data for demonstration (using 'Symbol')...")
#         dates = pd.date_range('2025-04-01', '2025-04-15', freq='B') # Business days
#         symbols = ['AAPL', 'MSFT', 'GOOG', 'SPY']
#         # Use 'Symbol' and 'Date' as index names
#         index = pd.MultiIndex.from_product([symbols, dates], names=['Symbol', 'Date'])
#         data = np.random.rand(len(index), 6) * 100 + 50
#         df_data = pd.DataFrame(data, index=index, columns=['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
#         # Add other adjusted columns if needed
#         df_data[['Adj Open', 'Adj High', 'Adj Low']] = df_data[['Open', 'High', 'Low']] # Simplistic adjustment
#         # Add some NaNs to test handling
#         df_data.iloc[5:7, df_data.columns.get_loc('Adj Close')] = np.nan # Make MSFT data missing for 2 days
#         df_data.loc[('GOOG', dates[3]), 'Adj Close'] = np.nan # Make GOOG missing on one day
#         print("Dummy df_data created with MultiIndex ['Symbol', 'Date'].")
#         print(df_data.head())

#     # Create dummy all_portfolios if it doesn't exist (using 'Symbol' in selected_stocks)
#     if 'all_portfolios' not in locals():
#          print("\nCreating dummy all_portfolios for demonstration (using 'Symbol')...")
#          all_portfolios = {}
#          for i, raw_f in enumerate([1.4, 1.6, 1.8, 2.0]):
#              for j, risk_f in enumerate([70.0, 80.0, 90.0, 100.0]):
#                  portf_date = '2025-04-08'
#                  portf_name = f"{portf_date}_portf_rawscore_{raw_f:.2f}_riskadjscore_{risk_f:.1f}"
#                  # Select different stocks for variety, including one that might have issues
#                  if (i + j) % 3 == 0:
#                      stocks = ['AAPL', 'MSFT'] # MSFT has NaNs
#                      weights = [0.6, 0.4]
#                  elif (i + j) % 3 == 1:
#                      stocks = ['GOOG', 'SPY'] # GOOG has a NaN
#                      weights = [0.5, 0.5]
#                  else:
#                      stocks = ['AAPL', 'SPY', 'FAKE'] # FAKE won't be in df_data
#                      weights = [0.4, 0.4, 0.2]

#                  # *** Make sure the index name here is 'Symbol' ***
#                  selected_df = pd.DataFrame({'Weight': weights}, index=pd.Index(stocks, name='Symbol')) # Use 'Symbol'
#                  all_portfolios[portf_name] = {
#                      'parameters': {'date': portf_date, 'raw_score_scale_factor': raw_f, 'risk_adj_score_scale_factor': risk_f},
#                      'selected_stocks': selected_df
#                  }
#          print(f"Dummy all_portfolios created with {len(all_portfolios)} portfolios (index='Symbol').")


# except Exception as e:
#     print(f"Error setting up dummy data: {e}")
#     traceback.print_exc()


# <<< --- FIX: ADAPT TO EXISTING INDEX NAMES --- >>>
print("\nChecking df_data index structure...")

# Define variables for the actual index level names discovered
ticker_level_name = None
date_level_name = None

try:
    if isinstance(df_data.index, pd.MultiIndex) and len(df_data.index.levels) >= 2:
        actual_names = list(df_data.index.names)
        print(f"Detected MultiIndex with names: {actual_names}")

        # Assign discovered names (assuming Ticker/Symbol is first, Date is second)
        # Handle unnamed levels (None) if necessary
        ticker_level_name = actual_names[0] if actual_names[0] is not None else 0 # Use name or position 0
        date_level_name = actual_names[1] if actual_names[1] is not None else 1   # Use name or position 1

        # Verify the discovered names seem reasonable (optional check)
        if isinstance(ticker_level_name, int) or isinstance(date_level_name, int):
             print(f"Warning: Using positional index levels ({ticker_level_name}, {date_level_name}) as names were missing.")
        elif 'Date' not in date_level_name: # Simple check if date level name looks plausible
             print(f"Warning: Second index level name '{date_level_name}' doesn't contain 'Date'. Ensure this is correct.")

        print(f"Using '{ticker_level_name}' for ticker/symbol level and '{date_level_name}' for date level.")

        # Sort index if necessary for performance
        if not df_data.index.is_monotonic_increasing:
             print("Sorting index...")
             df_data = df_data.sort_index()

    else:
        # If it's not a MultiIndex, check if 'Symbol'/'Ticker' and 'Date' are columns
        print("Index is not a MultiIndex. Checking columns...")
        # *** Adjust these column names if your actual columns are different ***
        potential_ticker_col = 'Symbol' # Check for 'Symbol' first
        if potential_ticker_col not in df_data.columns:
            potential_ticker_col = 'Ticker' # Fallback to 'Ticker'
        potential_date_col = 'Date'

        required_cols = []
        if potential_ticker_col in df_data.columns:
             required_cols.append(potential_ticker_col)
        if potential_date_col in df_data.columns:
             required_cols.append(potential_date_col)

        if len(required_cols) == 2:
            print(f"Attempting to set index using columns: {required_cols}...")
            df_data = df_data.set_index(required_cols)
            ticker_level_name = required_cols[0] # Set names based on columns used
            date_level_name = required_cols[1]
            print(f"MultiIndex set. Using '{ticker_level_name}' and '{date_level_name}'.")
             # Sort index after setting
            if not df_data.index.is_monotonic_increasing:
                 print("Sorting index...")
                 df_data = df_data.sort_index()
        else:
            missing = [col for col in [potential_ticker_col, potential_date_col] if col not in df_data.columns and col not in (df_data.index.names if isinstance(df_data.index, pd.MultiIndex) else [])]
            print(f"ERROR: Cannot set index. Required columns not found: {missing}")
            print("df_data columns:", df_data.columns)
            print("df_data index names:", df_data.index.names)
            import sys
            sys.exit("Exiting due to incorrect df_data structure.")


except Exception as e:
    print(f"ERROR: An unexpected error occurred during index check/setup: {e}")
    traceback.print_exc()
    import sys
    sys.exit("Exiting due to index setup error.")

# --- Recalculate trading_dates based on the potentially fixed df_data index ---
try:
    # Use the discovered date_level_name
    all_dates_in_data = df_data.index.get_level_values(date_level_name).unique()
    trading_dates = pd.DatetimeIndex(all_dates_in_data).sort_values()
    if not trading_dates.empty:
         print(f"\nTrading dates extracted using level '{date_level_name}'. Found {len(trading_dates)} unique dates.")
    else:
         print("WARNING: No dates found in the index. Trading date logic will fail.")

except (KeyError, IndexError) as e:
    print(f"ERROR: Could not find or access level '{date_level_name}' to extract trading dates: {e}")
    trading_dates = pd.DatetimeIndex([]) # Ensure it exists but is empty
    import sys
    sys.exit("Exiting - Cannot determine trading dates.")
except Exception as e:
    print(f"ERROR: An unexpected error occurred extracting trading dates: {e}")
    trading_dates = pd.DatetimeIndex([]) # Ensure it exists but is empty
    import sys
    sys.exit("Exiting - Cannot determine trading dates.")


# --- Helper Function to find next trading date (same as before) ---
def get_next_trading_date(current_date, trading_dates):
    """Finds the first trading date strictly after current_date."""
    if trading_dates.empty: # Handle empty trading dates
        return None
    current_date = pd.Timestamp(current_date)
    try:
        # Ensure trading_dates is sorted (should be already, but double-check)
        if not trading_dates.is_monotonic_increasing:
             trading_dates = trading_dates.sort_values()
        loc = trading_dates.searchsorted(current_date, side='right')
        if loc < len(trading_dates):
            return trading_dates[loc]
        else:
            return None # No trading date found after current_date
    except Exception as e:
        print(f"Error in get_next_trading_date for {current_date}: {e}")
        return None

# --- Calculate Returns for Each Portfolio ---
portfolio_returns_data = []

print("\nCalculating portfolio returns (handling missing tickers)...")
for portf_name, portf_data in all_portfolios.items():
    try:
        # Extract portfolio generation date and parameters
        params = portf_data['parameters']
        portf_date_str = params['date']
        portf_date = pd.Timestamp(portf_date_str)
        raw_factor = params['raw_score_scale_factor']
        risk_adj_factor = params['risk_adj_score_scale_factor']
        selected_stocks_df = portf_data['selected_stocks'] # Index=Symbol, Cols=[Weight]

        # *** Check if selected_stocks_df index name matches ticker_level_name ***
        if not isinstance(selected_stocks_df.index, pd.Index) or selected_stocks_df.index.name != ticker_level_name:
             print(f"Warning for {portf_name}: Index name of selected_stocks ('{selected_stocks_df.index.name}') does not match df_data ticker level ('{ticker_level_name}'). Attempting to rename.")
             try:
                 selected_stocks_df.index.name = ticker_level_name
                 print(f"Renamed selected_stocks index to '{ticker_level_name}'.")
             except Exception as rename_e:
                 print(f"Failed to rename selected_stocks index: {rename_e}. Skipping portfolio.")
                 continue # Skip if renaming fails

        if selected_stocks_df.empty:
            continue

        original_portfolio_tickers = selected_stocks_df.index.tolist()

        # Find Buy Date
        buy_date = get_next_trading_date(portf_date, trading_dates)
        if buy_date is None:
            print(f"Skipping {portf_name}: No trading date found after generation date {portf_date.date()}")
            continue

        # Find Sell Date
        sell_date = get_next_trading_date(buy_date, trading_dates)
        if sell_date is None:
            print(f"Skipping {portf_name}: No trading date found after buy date {buy_date.date()}")
            continue

        required_dates = [buy_date, sell_date]

        # --- MODIFIED PRICE FETCHING AND TICKER VALIDATION ---
        # 1. Filter df_data using the discovered level names
        potential_data = df_data.loc[
            (df_data.index.get_level_values(ticker_level_name).isin(original_portfolio_tickers)) &
            (df_data.index.get_level_values(date_level_name).isin(required_dates))
        ]

        # 2. Check which tickers *actually* have data for BOTH required dates
        ticker_date_counts = potential_data.index.get_level_values(ticker_level_name).value_counts()
        available_tickers = ticker_date_counts[ticker_date_counts >= len(required_dates)].index.tolist() # Use >= for robustness? Or == 2

        # 3. Check if any tickers remain
        if not available_tickers:
             print(f"Skipping {portf_name}: No stocks from portfolio found with data for BOTH Buy({buy_date.date()}) and Sell({sell_date.date()}) dates in df_data index.")
             continue

        # Report dropped tickers
        dropped_tickers = set(original_portfolio_tickers) - set(available_tickers)
        if dropped_tickers:
             expected_but_dropped = [t for t in dropped_tickers if t in df_data.index.get_level_values(ticker_level_name).unique()]
             # unexpected_tickers = [t for t in dropped_tickers if t not in df_data.index.get_level_values(ticker_level_name).unique()] # Tickers in portfolio but never in data
             if expected_but_dropped:
                  print(f"Warning for {portf_name}: Dropping tickers with missing data on {buy_date.date()}/{sell_date.date()}: {', '.join(expected_but_dropped)}")

        # 4. Fetch 'Adj Close' *only* for available tickers and required dates
        try:
            # Use .loc with precise index slicing (using discovered names)
            idx_slice = pd.IndexSlice[available_tickers, required_dates]
            # Ensure 'Adj Close' is the correct column name
            adj_close_col = 'Adj Close'
            if adj_close_col not in potential_data.columns:
                print(f"ERROR for {portf_name}: Column '{adj_close_col}' not found in potential_data. Available: {potential_data.columns}")
                continue
            prices = potential_data.loc[idx_slice, adj_close_col]

            # Unstack using the discovered date level name
            prices_unstacked = prices.unstack(level=date_level_name)

            # Rename columns for clarity and robustness
            prices_unstacked = prices_unstacked.rename(columns={buy_date: 'Buy Price', sell_date: 'Sell Price'})

            # 5. Drop any rows (tickers) that *still* have NaN after unstacking
            prices_unstacked = prices_unstacked.dropna()

            if prices_unstacked.empty:
                print(f"Skipping {portf_name}: All remaining stocks had NaN prices on required dates after unstacking.")
                continue

            final_available_tickers = prices_unstacked.index.tolist()

        except KeyError as e:
             print(f"KeyError during final price processing for {portf_name}: {e}. Check slicing logic or column name '{adj_close_col}'.")
             traceback.print_exc()
             continue
        except Exception as e:
             print(f"Error during final price processing for {portf_name} (Buy: {buy_date.date()}, Sell: {sell_date.date()}): {e}")
             traceback.print_exc()
             continue

        # --- Calculate Returns using only available tickers ---

        # 6. Select weights ONLY for the final available tickers
        # selected_stocks_df index should now match ticker_level_name due to check/rename above
        aligned_weights = selected_stocks_df.loc[final_available_tickers, 'Weight']

        # 7. Normalize weights for the stocks actually used
        weight_sum = aligned_weights.sum()
        if weight_sum <= 1e-9: # Use tolerance
             print(f"Skipping {portf_name}: Sum of weights for available stocks is too close to zero ({weight_sum:.4f}).")
             continue
        normalized_weights = aligned_weights / weight_sum

        # Get prices for calculation
        buy_prices = prices_unstacked.loc[final_available_tickers, 'Buy Price']
        sell_prices = prices_unstacked.loc[final_available_tickers, 'Sell Price']

        # Check for zero prices
        if (buy_prices.abs() < 1e-9).any():
            zero_price_mask = (buy_prices.abs() >= 1e-9)
            num_zero = (~zero_price_mask).sum()
            print(f"Warning: Found {num_zero} stock(s) with near-zero buy price in {portf_name} on {buy_date.date()}. Excluding them.")

            if not zero_price_mask.all():
                buy_prices = buy_prices[zero_price_mask]
                sell_prices = sell_prices[zero_price_mask]
                normalized_weights = normalized_weights.loc[zero_price_mask]

                if buy_prices.empty:
                     print(f"Skipping {portf_name}: No stocks remaining after zero price check.")
                     continue

                weight_sum = normalized_weights.sum()
                if weight_sum <= 1e-9:
                    print(f"Skipping {portf_name}: Sum of weights became near-zero after removing zero-price stocks.")
                    continue
                normalized_weights = normalized_weights / weight_sum

        # Calculate individual stock returns
        individual_returns = (sell_prices / buy_prices) - 1

        # Calculate weighted portfolio return
        portfolio_return = (individual_returns * normalized_weights).sum()

        # Store the result
        portfolio_returns_data.append({
            'portfolio_name': portf_name,
            'generation_date': portf_date,
            'buy_date': buy_date,
            'sell_date': sell_date,
            'raw_factor': raw_factor,
            'risk_adj_factor': risk_adj_factor,
            'portfolio_return': portfolio_return,
            'num_stocks_initial': len(original_portfolio_tickers),
            'num_stocks_calc': len(final_available_tickers)
        })

    except Exception as e:
        print(f"FATAL Error processing portfolio {portf_name}: {e}")
        traceback.print_exc()

# --- Convert results to DataFrame ---
if portfolio_returns_data:
    returns_df = pd.DataFrame(portfolio_returns_data)
    returns_df = returns_df.sort_values(by=['generation_date', 'raw_factor', 'risk_adj_factor'])

    print("\n--- Portfolio Return Calculation Complete ---")
    print(returns_df.head())
    print(f"\nCalculated returns for {len(returns_df)} portfolio instances.")

    # --- Analyze Results ---
    print("\n--- Performance Analysis by Factor Combination ---")
    performance_summary = returns_df.groupby(['raw_factor', 'risk_adj_factor'])['portfolio_return'].agg(
        mean='mean',
        median='median',
        std=lambda x: x.std(ddof=0) if len(x) > 1 else 0.0, # Handle stddev calc
        count='count'
    )
    performance_summary = performance_summary.sort_values(by='mean', ascending=False)

    # # <<< --- ADD THIS CORRECTION --- >>>
    # # Set std to NaN where count is 1, as std dev isn't meaningful for a single point
    # mask_single_count = performance_summary['count'] == 1
    # if mask_single_count.any():
    #     performance_summary.loc[mask_single_count, 'std'] = np.nan
    # # <<< --- END CORRECTION --- >>>

    print("\nPerformance per Factor Combination (sorted by mean return):")
    with pd.option_context('display.float_format', '{:.4f}'.format):
        print(performance_summary)

    stock_count_summary = returns_df.groupby(['raw_factor', 'risk_adj_factor'])['num_stocks_calc'].agg(['mean', 'min', 'max'])
    print("\nAverage/Min/Max Stocks Used in Calculation per Factor Combination:")
    with pd.option_context('display.float_format', '{:.2f}'.format):
        print(stock_count_summary)

else:
    print("\nNo portfolio returns were calculated.")

# Optional: Save results
if 'returns_df' in locals() and not returns_df.empty:
    returns_df.to_csv('portfolio_daily_returns_handled.csv', index=False)
    print("\nReturns saved to portfolio_daily_returns_handled.csv")
if 'performance_summary' in locals() and not performance_summary.empty:
    performance_summary.to_csv('portfolio_factor_performance_handled.csv')
    print("Performance summary saved to portfolio_factor_performance_handled.csv")
# Out:
# Checking df_data index structure...
# Detected MultiIndex with names: ['Symbol', 'Date']
# Using 'Symbol' for ticker/symbol level and 'Date' for date level.
#
# Trading dates extracted using level 'Date'. Found 251 unique dates.
#
# Calculating portfolio returns (handling missing tickers)...
#
# --- Portfolio Return Calculation Complete ---
#                                      portfolio_name generation_date   buy_date  sell_date  raw_factor  risk_adj_factor  portfolio_return  num_stocks_initial  num_stocks_calc
# 0  2025-04-09_portf_rawscore_1.00_riskadjscore_50.0      2025-04-09 2025-04-10 2025-04-11      0.5000           0.5000            0.0187                  12               12
# 1  2025-04-09_portf_rawscore_1.00_riskadjscore_60.0      2025-04-09 2025-04-10 2025-04-11      0.5000           0.6000            0.0174                  10               10
# 2  2025-04-09_portf_rawscore_1.00_riskadjscore_70.0      2025-04-09 2025-04-10 2025-04-11      0.5000           0.7000            0.0193                   7                7
# 3  2025-04-09_portf_rawscore_1.00_riskadjscore_80.0      2025-04-09 2025-04-10 2025-04-11      0.5000           0.8000            0.0171                   5                5
# 4  2025-04-09_portf_rawscore_1.00_riskadjscore_90.0      2025-04-09 2025-04-10 2025-04-11      0.5000           0.9000            0.0146                   3                3
#
# Calculated returns for 64 portfolio instances.
#
# --- Performance Analysis by Factor Combination ---
#
# Performance per Factor Combination (sorted by mean return):
#                              mean  median    std  count
# raw_factor risk_adj_factor
# 0.5000     0.7000          0.0193  0.0193 0.0000      1
#            0.5000          0.0187  0.0187 0.0000      1
# 0.7000     0.8000          0.0184  0.0184 0.0000      1
#            0.7000          0.0184  0.0184 0.0000      1
# 0.6000     0.7000          0.0184  0.0184 0.0000      1
#            0.8000          0.0184  0.0184 0.0000      1
#            0.5000          0.0176  0.0176 0.0000      1
# 0.5000     0.6000          0.0174  0.0174 0.0000      1
# 0.7000     0.5000          0.0173  0.0173 0.0000      1
#            0.6000          0.0173  0.0173 0.0000      1
# 0.5000     0.8000          0.0171  0.0171 0.0000      1
# 0.6000     0.6000          0.0161  0.0161 0.0000      1
# 0.7000     1.0000          0.0146  0.0146 0.0000      1
#            0.9000          0.0146  0.0146 0.0000      1
# 0.6000     1.0000          0.0146  0.0146 0.0000      1
#            0.9000          0.0146  0.0146 0.0000      1
# 0.5000     1.0000          0.0146  0.0146 0.0000      1
#            0.9000          0.0146  0.0146 0.0000      1
# 1.2000     0.9000          0.0085  0.0085 0.0000      1
# 1.1000     0.8000          0.0085  0.0085 0.0000      1
# 1.0000     0.8000          0.0085  0.0085 0.0000      1
#            0.9000          0.0085  0.0085 0.0000      1
#            1.0000          0.0085  0.0085 0.0000      1
#            1.1000          0.0085  0.0085 0.0000      1
#            1.2000          0.0085  0.0085 0.0000      1
# 1.1000     0.5000          0.0085  0.0085 0.0000      1
#            0.6000          0.0085  0.0085 0.0000      1
#            0.7000          0.0085  0.0085 0.0000      1
#            1.0000          0.0085  0.0085 0.0000      1
#            0.9000          0.0085  0.0085 0.0000      1
# 1.2000     0.8000          0.0085  0.0085 0.0000      1
# 1.1000     1.1000          0.0085  0.0085 0.0000      1
#            1.2000          0.0085  0.0085 0.0000      1
# 1.2000     0.5000          0.0085  0.0085 0.0000      1
#            0.6000          0.0085  0.0085 0.0000      1
#            0.7000          0.0085  0.0085 0.0000      1
# 1.0000     0.6000          0.0085  0.0085 0.0000      1
# 1.2000     1.1000          0.0085  0.0085 0.0000      1
#            1.0000          0.0085  0.0085 0.0000      1
# 1.0000     0.7000          0.0085  0.0085 0.0000      1
# 0.9000     0.5000          0.0085  0.0085 0.0000      1
# 1.0000     0.5000          0.0085  0.0085 0.0000      1
# 0.9000     1.2000          0.0085  0.0085 0.0000      1
# 0.5000     1.1000          0.0085  0.0085 0.0000      1
#            1.2000          0.0085  0.0085 0.0000      1
# 0.6000     1.1000          0.0085  0.0085 0.0000      1
#            1.2000          0.0085  0.0085 0.0000      1
# 0.7000     1.1000          0.0085  0.0085 0.0000      1
#            1.2000          0.0085  0.0085 0.0000      1
# 0.8000     0.7000          0.0085  0.0085 0.0000      1
#            0.8000          0.0085  0.0085 0.0000      1
#            0.9000          0.0085  0.0085 0.0000      1
#            1.0000          0.0085  0.0085 0.0000      1
#            1.1000          0.0085  0.0085 0.0000      1
#            1.2000          0.0085  0.0085 0.0000      1
# 0.9000     0.6000          0.0085  0.0085 0.0000      1
#            0.7000          0.0085  0.0085 0.0000      1
#            0.8000          0.0085  0.0085 0.0000      1
#            0.9000          0.0085  0.0085 0.0000      1
#            1.0000          0.0085  0.0085 0.0000      1
#            1.1000          0.0085  0.0085 0.0000      1
# 1.2000     1.2000          0.0085  0.0085 0.0000      1
# 0.8000     0.6000          0.0083  0.0083 0.0000      1
#            0.5000          0.0083  0.0083 0.0000      1
#
# Average/Min/Max Stocks Used in Calculation per Factor Combination:
#                             mean  min  max
# raw_factor risk_adj_factor
# 0.50       0.50            12.00   12   12
#            0.60            10.00   10   10
#            0.70             7.00    7    7
#            0.80             5.00    5    5
#            0.90             3.00    3    3
#            1.00             3.00    3    3
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 0.60       0.50             8.00    8    8
#            0.60             7.00    7    7
#            0.70             4.00    4    4
#            0.80             4.00    4    4
#            0.90             3.00    3    3
#            1.00             3.00    3    3
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 0.70       0.50             6.00    6    6
#            0.60             6.00    6    6
#            0.70             4.00    4    4
#            0.80             4.00    4    4
#            0.90             3.00    3    3
#            1.00             3.00    3    3
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 0.80       0.50             2.00    2    2
#            0.60             2.00    2    2
#            0.70             1.00    1    1
#            0.80             1.00    1    1
#            0.90             1.00    1    1
#            1.00             1.00    1    1
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 0.90       0.50             1.00    1    1
#            0.60             1.00    1    1
#            0.70             1.00    1    1
#            0.80             1.00    1    1
#            0.90             1.00    1    1
#            1.00             1.00    1    1
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 1.00       0.50             1.00    1    1
#            0.60             1.00    1    1
#            0.70             1.00    1    1
#            0.80             1.00    1    1
#            0.90             1.00    1    1
#            1.00             1.00    1    1
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 1.10       0.50             1.00    1    1
#            0.60             1.00    1    1
#            0.70             1.00    1    1
#            0.80             1.00    1    1
#            0.90             1.00    1    1
#            1.00             1.00    1    1
#            1.10             1.00    1    1
#            1.20             1.00    1    1
# 1.20       0.50             1.00    1    1
#            0.60             1.00    1    1
#            0.70             1.00    1    1
#            0.80             1.00    1    1
#            0.90             1.00    1    1
#            1.00             1.00    1    1
#            1.10             1.00    1    1
#            1.20             1.00    1    1
#
# Returns saved to portfolio_daily_returns_handled.csv
# Performance summary saved to portfolio_factor_performance_handled.csv

# %%
# # Default values
# num_clusters = 3
# max_selection_per_cluster = 5
# min_cluster_size = 5
# penalty_IntraCluster_Corr = 0.3
# min_raw_score = None      
# min_risk_adj_score = None  

raw_score_scale_factor = 0.8
risk_adj_score_scale_factor = 0.8

num_clusters = 60
max_selection_per_cluster = 2
min_cluster_size = 3  # prevent extreme high risk adj scores 
min_raw_score = 2.0 * raw_score_scale_factor    
min_risk_adj_score = 100.0  * risk_adj_score_scale_factor
penalty_IntraCluster_Corr = 0

# Run the selection pipeline
output = select_stocks_from_clusters(
    cluster_stats_df=cluster_stats_df,
    detailed_clusters_df=detailed_clusters_df,
    num_clusters=num_clusters,
    max_selection_per_cluster=max_selection_per_cluster,
    min_cluster_size=min_cluster_size,
    penalty_IntraCluster_Corr=penalty_IntraCluster_Corr,
    min_raw_score=min_raw_score,      # Example threshold
    min_risk_adj_score=min_risk_adj_score  # Example threshold    
)

portf_date = output['parameters']['date_str']
portf_raw_score = output['parameters']['min_raw_score']
portf_risk_adj_score = output['parameters']['min_risk_adj_score']
_selected_stocks = output['selected_stocks']
portf_selected_stocks = _selected_stocks[['Ticker', 'Weight']].set_index('Ticker')
portf_name = f'{portf_date}_portf_rawscore_{portf_raw_score}_riskadjscore_{portf_risk_adj_score}'

# new_df = portf_selected_stocks[['Ticker', 'Weight']].set_index('Ticker')

print(f'portf_date: {portf_date}')
print(f'portf_raw_score: {portf_raw_score}')
print(f'portf_risk_adj_score: {portf_risk_adj_score}')
print(f'port_selected_stocks:\n{portf_selected_stocks}')
print(f'\nportf_name: {portf_name}')
# Out:
# portf_date: 2025-04-09
# portf_raw_score: 1.6
# portf_risk_adj_score: 80.0
# port_selected_stocks:
#         Weight
# Ticker
# UNH     1.0000
#
# portf_name: 2025-04-09_portf_rawscore_1.6_riskadjscore_80.0

# %%
portf_date = output['parameters']['date_str']
portf_raw_score = output['parameters']['min_raw_score']
portf_risk_adj_score = output['parameters']['min_risk_adj_score']
# portf_selected_stocks = output['selected_stocks']
portf_selected_stocks = output['selected_stocks'][['Ticker', 'Weight']].set_index('Ticker')
portf_name = f'{portf_date}_portf_rawscore_{portf_raw_score}_riskadjscore_{portf_risk_adj_score}'

# new_df = portf_selected_stocks[['Ticker', 'Weight']].set_index('Ticker')

print(f'portf_date: {portf_date}')
print(f'portf_raw_score: {portf_raw_score}')
print(f'portf_risk_adj_score: {portf_risk_adj_score}')
print(f'port_selected_stocks:\n{portf_selected_stocks}')
print(f'\nportf_name: {portf_name}')
# Out:
# portf_date: 2025-04-09
# portf_raw_score: 1.6
# portf_risk_adj_score: 80.0
# port_selected_stocks:
#         Weight
# Ticker
# UNH     1.0000
#
# portf_name: 2025-04-09_portf_rawscore_1.6_riskadjscore_80.0
