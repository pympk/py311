# %%
# import sys
# from pathlib import Path

# # Notebook cell
# %load_ext autoreload
# %autoreload 2

# # Get root directory (assuming notebook is in root/notebooks/)
# NOTEBOOK_DIR = Path.cwd()
# ROOT_DIR = NOTEBOOK_DIR.parent if NOTEBOOK_DIR.name == 'notebooks' else NOTEBOOK_DIR

# # Add src directory to Python path
# sys.path.append(str(ROOT_DIR / 'src'))

# # Verify path
# print(f"Python will look in these locations:\n{sys.path}")


# # --- Execute the processor ---
# import utils


# OHLCV_PATH, DEST_PATH = utils.main_processor(
#     data_dir='..\data',  # search project ..\data
#     downloads_dir='',  # None searchs Downloads dir, '' omits search
#     downloads_limit=0,  # search the first 10 files
#     clean_name_override='df_finviz_n_ratios.pkl',  # override filename
#     start_file_pattern='df_OHLCV_', # search for files starting with 'df_'
# )

# SOURCE_PATH = DEST_PATH
# TICKERS_PATH = '..\data\df_common_tickers.pkl'

# %%
# print(f'OHLCV_PATH:   {OHLCV_PATH}')
# print(f'SOURCE_PATH:  {SOURCE_PATH}')
# print(f'DEST_PATH:    {DEST_PATH}')
# print(f'TICKERS_PATH: {TICKERS_PATH}')

# %%
# df_OHLCV_2025-03-14_clean.pkl

# %%
# process_files.py
from config import date_str, DOWNLOAD_DIR, DEST_DIR
from pathlib import Path  # Better path handling

print(f"date_str: {date_str}")
print(f"DOWNLOAD_DIR: {DOWNLOAD_DIR}")
print(f"DEST_DIR: {DEST_DIR}\n")

# Build paths
ohlcv_path = Path(DEST_DIR) / f'df_OHLCV_{date_str}_clean.parquet'
source_path = Path(DEST_DIR) / f'df_finviz_n_ratios.parquet'
dest_path = Path(DEST_DIR) / f'df_finviz_n_ratios_merged.parquet'
tickers_path = Path(DEST_DIR) / f'df_common_tickers.parquet'

print(f"ohlcv_path: {ohlcv_path}")
print(f"source_path: {source_path}")
print(f"dest_path: {dest_path}")
print(f"tickers_path: {tickers_path}")
# Out:
# date_str: 2025-04-01
# DOWNLOAD_DIR: C:\Users\ping\Downloads
# DEST_DIR: ..\data
#
# ohlcv_path: ..\data\df_OHLCV_2025-04-01_clean.parquet
# source_path: ..\data\df_finviz_n_ratios.parquet
# dest_path: ..\data\df_finviz_n_ratios_merged.parquet
# tickers_path: ..\data\df_common_tickers.parquet

# %%
import pandas as pd

# Set pandas display options to show more columns and rows
pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', 10)       # Limit to 10 rows for readability
# pd.set_option('display.width', None)        # Let the display adjust to the window
# pd.set_option('display.max_colwidth', None) # Show full content of each cell
pd.options.display.float_format = '{:.2f}'.format

# %%
# Load the parquet file into a DataFrame
df_finviz = pd.read_parquet(source_path)

# Display basic information about the DataFrame
print(f"df_finviz.shape: {df_finviz.shape}")
print("\nFirst few rows:")
df_finviz.head()
# Out:
# df_finviz.shape: (1538, 53)
#
# First few rows:
#                       Company  \
# Ticker
# AAPL                Apple Inc
# MSFT    Microsoft Corporation
# NVDA              NVIDIA Corp
# AMZN           Amazon.com Inc
# GOOG             Alphabet Inc
#
#                                                      Info  MktCap AUM, M  \
# Ticker
# AAPL                     Technology, Consumer Electronics     3352780.00
# MSFT                Technology, Software - Infrastructure     2841190.00
# NVDA                           Technology, Semiconductors     2687660.00
# AMZN                   Consumer Cyclical, Internet Retail     2036570.00
# GOOG    Communication Services, Internet Content & Inf...     1925920.00
#
#         Beta   RSI  Perf YTD %  Perf Week %  Perf Month %  Perf Quart %  \
# Ticker
# AAPL    1.26 48.10      -10.87        -0.25         -6.23        -12.68
# MSFT    1.00 42.27       -9.33        -3.28         -1.62        -11.23
# NVDA    1.96 40.62      -17.98        -8.73         -3.43        -19.60
# AMZN    1.39 38.08      -12.41        -6.58         -6.27        -14.11
# GOOG    1.04 37.16      -16.57        -8.05         -5.80        -18.12
#
#         Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  50D High %  \
# Ticker
# AAPL          -2.02        30.16     0.85    -3.01     -2.60      -10.72
# MSFT         -10.71        -9.16    -1.32    -5.38     -9.42      -14.76
# NVDA          -9.27        21.91    -3.95   -11.08    -13.61      -26.06
# AMZN           2.23         6.54    -2.75   -10.79     -4.03      -20.76
# GOOG          -3.88         4.35    -4.63   -11.80     -9.89      -23.87
#
#         50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %  \
# Ticker
# AAPL         7.09      -14.19      36.03           -14.19       350739.37
# MSFT         4.07      -18.40       4.07           -18.40       479564.32
# NVDA         6.27      -28.07      45.69           -28.07       330349.99
# AMZN         4.21      -20.76      26.75           -20.76       292730.49
# GOOG         4.38      -23.87       7.21           -23.87          553.52
#
#         ATR  Volatility W %  Volatility M %  Volume, M  Avg Volume, M  \
# Ticker
# AAPL   6.03            2.68            2.76      36.35          52.97
# MSFT   8.77            2.30            2.19      19.06          23.11
# NVDA   5.59            4.58            4.28     216.54         281.46
# AMZN   6.49            3.30            3.08      41.14          40.05
# GOOG   5.03            3.41            2.87      20.08          19.97
#
#         Rel Volume  Price  Change %  Dividend %  Sharpe 3d  Sortino 3d  \
# Ticker
# AAPL          0.69 223.19      0.48        0.47      18.30     6826.03
# MSFT          0.82 382.19      1.81        0.86       3.64       10.78
# NVDA          0.77 110.15      1.63        0.04       1.70        4.00
# AMZN          1.03 192.17      1.00         NaN      -1.50       -2.64
# GOOG          1.01 158.88      1.70        0.34      12.54     6826.03
#
#         Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  Sortino 10d  \
# Ticker
# AAPL      609.11       1.48        2.21      1.28        4.12         6.52
# MSFT        1.96      -3.95       -5.04      0.49       -1.86        -2.34
# NVDA        1.36      -7.75       -8.95      0.33       -4.43        -5.16
# AMZN        0.76      -7.73       -7.97      0.19       -1.31        -1.76
# GOOG      609.11      -6.97       -7.54      0.26       -3.21        -3.77
#
#         Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  \
# Ticker
# AAPL         1.85        1.89         2.62       1.34       -2.86
# MSFT         0.73       -0.28        -0.40       0.95       -2.88
# NVDA         0.47       -1.91        -2.61       0.73       -3.12
# AMZN         0.79       -1.84        -2.41       0.75       -4.48
# GOOG         0.59       -3.01        -3.58       0.63       -4.24
#
#         Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  Omega 60d  \
# Ticker
# AAPL          -3.31       0.63       -1.26        -1.59       0.81
# MSFT          -3.62       0.63       -1.67        -2.15       0.74
# NVDA          -3.71       0.61       -1.46        -1.78       0.78
# AMZN          -5.13       0.51       -2.30        -2.83       0.70
# GOOG          -4.79       0.53       -2.48        -2.92       0.67
#
#         Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  Sortino 250d  \
# Ticker
# AAPL          -0.14         -0.18        0.98         1.10          1.62
# MSFT          -0.74         -0.94        0.87        -0.48         -0.62
# NVDA          -0.54         -0.69        0.91         0.60          0.83
# AMZN           0.37          0.53        1.06         0.19          0.26
# GOOG          -0.24         -0.33        0.96         0.08          0.11
#
#         Omega 250d
# Ticker
# AAPL          1.21
# MSFT          0.92
# NVDA          1.10
# AMZN          1.03
# GOOG          1.01

# %%
df_common_tickers = pd.read_parquet(tickers_path)
tickers = df_common_tickers.index.to_list()

print(f'len(tickers): {len(tickers)}')
print(f'tickers[0:5]: {tickers[0:5]}')
# Out:
# len(tickers): 1538
# tickers[0:5]: ['AAPL', 'MSFT', 'NVDA', 'AMZN', 'GOOG']

# %%
import pandas as pd
import numpy as np  # Import numpy

# 1. Load Data
# path_data = '..\data\df_OHLCV_2025-03-14_clean.parquet'
df_OHLCV = pd.read_parquet(ohlcv_path)
print("df_OHLCV Info:")
display(df_OHLCV.info())


# 2. Prepare Adjusted Close Data
df_adj_close = df_OHLCV[['Adj Close']].unstack(level=0)
df_adj_close.columns = df_adj_close.columns.get_level_values(1)
df_adj_close = df_adj_close.sort_index(axis=0)

print(f'Before filter, len(df_adj_close.columns): {len(df_adj_close.columns)}\n')
df_adj_close = df_adj_close[tickers]
print(f'After filter, len(df_adj_close.columns): {len(df_adj_close.columns)}\n')
print("df_adj_close Info:")
print(df_adj_close.info())
print("df_adj_close Tail:")
display(df_adj_close.tail())


# 4. Calculate Returns
df_returns = df_adj_close.pct_change(periods=3) * 100
df_Perf_3D_pct = df_returns.tail(1)


# 5. Display Returns
pd.options.display.float_format = '{:.5f}'.format
print("df_Perf_3D_pct:")
display(df_Perf_3D_pct)
print("df_Perf_3D_pct Info:")
df_Perf_3D_pct.info()
print(df_Perf_3D_pct.info())  # Print is redundant, info is already displayed above
print("df_Perf_3D_pct Head:")
display(df_Perf_3D_pct.head(2))


# 6. Define Merge Function
def merge_dataframes(df, df_Perf_3D_pct):
    """
    Merges data from df_Perf_3D_pct into df, aligning based on tickers.
    Renames the added column to "Perf 3D %".

    Assumptions:
      - df_Perf_3D_pct has columns representing tickers.
      - df has an index representing tickers.
    """
    # Transpose df_Perf_3D_pct so that tickers become the index.
    df_Perf_3D_pct_transposed = df_Perf_3D_pct.T
    df_Perf_3D_pct_transposed.index.name = 'Ticker'

    # Ensure that the main dataframe's index also has a name if it doesn't
    if df.index.name is None:
        df.index.name = 'Ticker'

    # Merge the two dataframes based on the index (which represents the tickers)
    df_merged = df.merge(df_Perf_3D_pct_transposed, left_index=True, right_index=True, how='left')

    # Rename the added column, using the *last* column name
    if df_merged.shape[1] > df.shape[1]:  # Check if new columns were actually added
        last_col = df_merged.columns[-1]  # Get the last column name which is what we need to rename
        df_merged = df_merged.rename(columns={last_col: 'Perf 3D %'})

    return df_merged


# 7. Merge Dataframes
pd.options.display.float_format = '{:.2f}'.format
df_merged = merge_dataframes(df_finviz, df_Perf_3D_pct)
print("df_merged Head:")
display(df_merged.head())
# Out:
# df_OHLCV Info:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 386038 entries, ('TBIL', Timestamp('2025-04-01 00:00:00')) to ('IEI', Timestamp('2024-04-02 00:00:00'))
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Open       386038 non-null  float64
#  1   High       386038 non-null  float64
#  2   Low        386038 non-null  float64
#  3   Close      386038 non-null  float64
#  4   Adj Close  386038 non-null  float64
#  5   Volume     386038 non-null  Int64
#  6   Adj Open   386038 non-null  float64
#  7   Adj High   386038 non-null  float64
#  8   Adj Low    386038 non-null  float64
# dtypes: Int64(1), float64(8)
# memory usage: 28.4+ MB
# None
# Before filter, len(df_adj_close.columns): 1538
#
# After filter, len(df_adj_close.columns): 1538
#
# df_adj_close Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2024-04-02 to 2025-04-01
# Columns: 1538 entries, AAPL to FNDC
# dtypes: float64(1538)
# memory usage: 2.9 MB
# None
# df_adj_close Tail:
# Symbol       AAPL   MSFT   NVDA   AMZN   GOOG  GOOGL   META     BRK-A  BRK-B  \
# Date
# 2025-03-26 221.53 389.97 113.76 201.13 167.14 165.06 610.98 798963.00 533.21
# 2025-03-27 223.85 390.58 111.43 201.36 164.08 162.24 602.58 801950.00 534.52
# 2025-03-28 217.90 378.80 109.67 192.72 156.06 154.33 576.74 790250.00 526.31
# 2025-03-31 222.13 375.39 108.38 190.26 156.23 154.64 576.36 798442.00 532.58
# 2025-04-01 223.19 382.19 110.15 192.17 158.88 157.07 586.00 800300.00 532.99
#
# Symbol        TSM   TSLA   AVGO    LLY   WMT    JPM      V    VOO    IVV  \
# 2025-03-28 180.91 69.22 127.32 49.86 105.28 27.28 60.59 31.18 26.59 87.69
# 2025-03-31 180.97 68.56 126.43 49.90 104.58 26.73 59.50 31.69 26.49 88.00
# 2025-04-01 181.15 68.20 127.57 49.81 107.36 25.25 59.15 32.17 26.72 87.65
#
# Symbol       ICLR   REG   JKHY  PRMB  DFUS  RDVY   TER   PPC   ELS   MNDY  \
# Date
# 2025-03-26 178.78 72.83 179.39 34.06 61.67 59.41 88.01 52.59 66.65 264.47
# 2025-03-27 180.11 72.39 179.32 34.45 61.43 59.23 85.68 53.24 65.25 255.68
# 2025-03-28 179.07 72.87 178.59 35.30 60.18 58.03 82.78 53.39 66.43 247.01
# 2025-03-31 174.99 73.76 182.60 35.49 60.48 58.54 82.60 54.51 66.70 243.16
# 2025-04-01 166.56 73.57 184.02 35.21 60.73 58.79 82.61 56.26 66.56 262.18
#
# Symbol        IWS   MINT    CF  GLDM  SOLV   TXT    RGA  SOFI  ENTG  INSM  \
# Date
# 2025-03-26 127.62 100.60 76.64 59.78 74.24 75.17 201.61 13.07 92.44 76.57
# 2025-03-27 126.96 100.62 77.98 60.56 75.51 75.28 201.29 12.20 92.54 77.69
# ...
# 2025-04-01 -10.19144 -7.80856 1.08617 1.38466 -1.03093 -11.56401 1.80373
#
# Symbol         VIGI     BBCA      FR    ESAB     GGAL     ZION     BFAM  \
# Date
# 2025-04-01 -1.29731 -0.15191 0.20446 1.10386 -2.14463 -1.55193 -1.49636
#
# Symbol        AXTA      LSCC      TTC     NFG     SATS     RGEN      MHK  \
# Date
# 2025-04-01 0.81546 -10.53254 -2.53828 2.08520 -3.70795 -6.28646 -1.86023
#
# Symbol         UGI     CVLT     DFAU      ADT     MDGL    CWST      KNX  \
# Date
# 2025-04-01 1.70006 -1.41578 -1.12763 -0.85055 -3.94046 1.75185 -1.81737
#
# Symbol           BZ     CRDO       WH       FN     ROIV    OLLI     PDI  \
# Date
# 2025-04-01 -4.98504 -1.67334 -1.29081 -4.63698 -6.01145 1.30892 0.35497
#
# Symbol          VPL     AZEK      ALV    SPYD      ASTS     AGCO     HIMS  \
# Date
# 2025-04-01 -2.32746 -2.69130 -2.23946 0.59266 -15.31008 -6.10965 -2.72556
#
# Symbol        STAG      WTS      FAF     GIL      IVZ     VPU     TFLO  \
# Date
# 2025-04-01 2.57644 -1.52384 -0.01504 0.55791 -2.31511 2.12804 -0.29621
#
# Symbol          AAL     ONEQ     QRVO       PB    IAGG      BIO    LNTH  \
# Date
# 2025-04-01 -7.54039 -2.15376 -1.98127 -1.10551 0.44115 -2.89691 0.91715
#
# Symbol          ONB    CHRD     OTEX      EAT    STWD     GTLS     VIPS  \
# Date
# 2025-04-01 -2.05033 0.43695 -4.26576 -2.25403 1.63850 -4.88186 -6.96970
#
# Symbol         VLUE    DFCF     BOKF    POST    WING     OLED     JGLO  \
# Date
# 2025-04-01 -0.80082 0.98180 -2.07087 1.24471 3.10088 -7.24589 -1.21992
#
# Symbol         CWAN      SSD     JIRE     BBWI    TRNO     TFII     SRAD  \
# Date
# 2025-04-01 -3.07066 -1.27124 -1.60444 -3.98119 0.42796 -5.22315 -3.42222
#
# Symbol         TFX     VOYA    LEVI     FNDE     UFPI      FLS      KBR  \
# Date
# 2025-04-01 0.66729 -2.10375 2.50313 -1.27796 -3.16105 -2.05098 -2.44236
#
# Symbol         AAON     SHYG      SNV     JBTM      AN     BUFR   LLYVK  \
# Date
# 2025-04-01 -1.34596 -0.63365 -3.45992 -1.43776 0.52061 -0.70000 1.40458
#
# Symbol          IJS     BEP     MTDR    FTSM     QFIN    EPRT      PSN  \
# Date
# 2025-04-01 -1.88945 0.44643 -0.75728 0.11712 -7.95927 0.24730 -1.63501
#
# Symbol          LPX   LLYVA     IDA      LTH     BPOP     GBIL    CACC  \
# Date
# 2025-04-01 -2.47085 1.40701 2.52402 -4.79042 -2.24249 -0.26965 2.45812
#
# Symbol         MCHI      ITA     THG     BBIO     NXT     BILI     TREX  \
# Date
# 2025-04-01 -2.25766 -1.38134 0.19472 -9.28571 0.70175 -5.80357 -1.44976
#
# Symbol        DINO      BWA      VFC      MAT      FDN      RVMD     STEP  \
# Date
# 2025-04-01 0.00000 -1.00590 -2.24651 -1.22013 -3.04656 -11.75853 -0.12973
#
# Symbol         WEX      SLM       CE    CIGI     WFG    MMSI      CHH  \
# Date
# 2025-04-01 3.60546 -0.37000 -4.37919 0.05698 1.20623 2.11097 -0.58418
#
# Symbol         TMHC      AWI     SPXC     AVLV      JXN      LNC      MGC  \
# Date
# 2025-04-01 -1.09352 -1.82297 -0.87529 -0.83359 -1.46956 -2.09353 -1.17256
#
# Symbol            S     CDP     BRKR     CROX     INFA       R      FLR  \
# Date
# 2025-04-01 -3.82429 1.56833 -7.06559 -1.31115 -4.59459 1.59061 -2.17976
#
# Symbol      CWEN-A    JCPB     MTG     GLBE    CWEN      IOO     IGF     PSLV  \
# Date
# 2025-04-01 1.66431 0.59970 1.36931 -1.98802 1.33023 -1.48797 0.97444 -1.36986
#
# Symbol          OSK     PEGA     ONTO       TX      TAL      ALK     ESNT  \
# Date
# 2025-04-01 -3.22481 -2.68891 -4.16602 -2.73929 -3.01471 -6.59048 -0.46146
#
# Symbol         COLD      SRPT     SPTS     FSK    VIRT    ACIW     CRK  \
# Date
# 2025-04-01 -2.40296 -13.78638 -0.06856 1.28023 2.22753 2.77325 2.62229
#
# Symbol         CCCS    RITM    SPMB     AVDE      HR      USM     TGTX  \
# Date
# 2025-04-01 -0.11025 0.52770 1.05215 -1.55717 1.01432 -0.34310 -6.09453
#
# Symbol         MNSO      MTN     FCN      QLD     NOV      OMF    CRVL  \
# Date
# 2025-04-01 -1.89549 -1.90062 0.46523 -3.84533 0.85079 -2.81244 1.30415
#
# Symbol         QXO     PBUS      IJT      VMI      LEGN     PATH      FPE  \
# Date
# 2025-04-01 1.21342 -1.07338 -1.05597 -3.36661 -10.93529 -3.40386 -0.17016
#
# Symbol          KEX      MSA      DDS    BRFS     OPCH      IBB      CHX  \
# Date
# 2025-04-01 -1.24405 -3.17314 -1.63810 1.14286 -0.71023 -5.42636 -0.43118
#
# Symbol          SQM      JHG    BOXX     ACWX     ICSH      VCR    BOND  \
# Date
# 2025-04-01 -1.30606 -2.05018 0.06282 -1.52212 -0.25671 -2.12956 0.74155
#
# Symbol         JQUA     BLV     SPMO     FDL     XMHQ     IEUR     GDXJ  \
# Date
# 2025-04-01 -0.71867 1.87617 -1.30283 0.48894 -0.68655 -1.34272 -0.95719
#
# Symbol         TBIL     VONE      RWL     TMF     VOOV      IGM      VIS  \
# Date
# 2025-04-01 -0.30006 -1.00947 -0.62987 9.58971 -0.72339 -2.16880 -0.96972
#
# Symbol          XLB    JMBS     CALF     DFAE     ARKK      XBI     CGGO  \
# Date
# 2025-04-01 -0.39243 0.80285 -1.20419 -1.47560 -5.86845 -8.61686 -1.69374
#
# Symbol        VWOB     BBIN     VUSB     GUNR    LMBS    PDBC     SJNK  \
# Date
# 2025-04-01 0.14069 -1.83442 -0.28107 -0.40910 0.28554 1.03627 -0.67434
#
# Symbol         CGUS     FDVV    SGOL     JGRO     DFEM      DLN    CGCP  \
# Date
# 2025-04-01 -1.12127 -0.22133 1.95339 -1.75949 -1.55211 -0.13857 0.76131
#
# Symbol         EFAV     BBAX     FNGA      IHI     OMFL      SSO      PPA  \
# Date
# 2025-04-01 -0.16635 -0.40494 -7.39144 -0.43175 -0.44610 -2.24126 -1.37055
#
# Symbol          IXN     ESGE      FEZ    PYLD    DFSD      VOX      IDV  \
# Date
# 2025-04-01 -1.77560 -1.51558 -1.19392 0.00000 0.35865 -2.21262 -0.60645
#
# Symbol         FELC      EWT    BSCQ     BBUS    ISTB     URTH      DSI  \
# Date
# 2025-04-01 -1.01106 -2.03252 0.10272 -1.15167 0.12451 -1.27266 -1.13374
#
# Symbol          PGX     TSLL     DFSV     EEMV     VSGX     BBEU     DIVO  \
# Date
# 2025-04-01 -0.88028 -3.86064 -1.91371 -0.86646 -1.48309 -1.33801 -0.56166
#
# Symbol         SPXL    FIXD     EDV      IXJ     ARKB     SCHC     HYLB  \
# Date
# 2025-04-01 -3.46730 1.12721 3.62235 -1.29827 -2.36066 -1.72178 -0.33177
#
# Symbol         JHMM     TCAF      CWB    EAGG    REET     SCHK     CMF  \
# Date
# 2025-04-01 -0.77734 -1.21951 -1.31105 0.80748 0.66308 -1.06188 0.60790
#
# Symbol         SLYV     KBWB      IYF     KNG     GSIE    BSCP     BILS  \
# Date
# 2025-04-01 -1.92669 -1.79528 -0.83502 0.11905 -1.43409 0.09676 -0.27155
#
# Symbol         NVDL      DON    SPHD     IYR    JMST     FBCG     DIHP  \
# Date
# 2025-04-01 -2.64631 -0.30127 0.64412 0.98019 0.11806 -2.13127 -1.09850
#
# Symbol        TOTL       FV     XMMO    UCON     HYD      KRE     SUSA  \
# Date
# 2025-04-01 0.52539 -1.79875 -0.07817 0.24291 0.90569 -1.96351 -0.88572
#
# Symbol         SHM     QTEC     VFLO      DXJ     PTLC     ACWV     GVI  \
# Date
# 2025-04-01 0.31606 -3.06966 -0.86755 -4.17507 -0.52174 -0.00859 0.31271
#
# Symbol         TFI     SLYG     UPRO     CGXU      EWZ     JPIE    EMLP  \
# Date
# 2025-04-01 0.71413 -0.85796 -3.44203 -2.71975 -0.72161 -0.19569 1.39898
#
# Symbol         IBDR     DFLV    BSCR     NEAR      EWU     ANGL     JAVA  \
# Date
# 2025-04-01 -0.20678 -0.74845 0.20460 -0.17720 -0.58417 -0.34674 -0.56400
#
# Symbol          IYH     SPGP     IBDQ     BKLC     BITB     FNDC
# Date
# 2025-04-01 -1.35269 -0.89930 -0.19889 -1.34587 -2.34276 -1.78620
# df_merged Head:
#                       Company  \
# Ticker
# AAPL                Apple Inc
# MSFT    Microsoft Corporation
# NVDA              NVIDIA Corp
# AMZN           Amazon.com Inc
# GOOG             Alphabet Inc
#
#                                                      Info  MktCap AUM, M  \
# Ticker
# AAPL                     Technology, Consumer Electronics     3352780.00
# MSFT                Technology, Software - Infrastructure     2841190.00
# NVDA                           Technology, Semiconductors     2687660.00
# AMZN                   Consumer Cyclical, Internet Retail     2036570.00
# GOOG    Communication Services, Internet Content & Inf...     1925920.00
#
#         Beta   RSI  Perf YTD %  Perf Week %  Perf Month %  Perf Quart %  \
# Ticker
# AAPL    1.26 48.10      -10.87        -0.25         -6.23        -12.68
# MSFT    1.00 42.27       -9.33        -3.28         -1.62        -11.23
# NVDA    1.96 40.62      -17.98        -8.73         -3.43        -19.60
# AMZN    1.39 38.08      -12.41        -6.58         -6.27        -14.11
# GOOG    1.04 37.16      -16.57        -8.05         -5.80        -18.12
#
#         Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  50D High %  \
# Ticker
# AAPL          -2.02        30.16     0.85    -3.01     -2.60      -10.72
# MSFT         -10.71        -9.16    -1.32    -5.38     -9.42      -14.76
# NVDA          -9.27        21.91    -3.95   -11.08    -13.61      -26.06
# AMZN           2.23         6.54    -2.75   -10.79     -4.03      -20.76
# GOOG          -3.88         4.35    -4.63   -11.80     -9.89      -23.87
#
#         50D Low %  52W High %  52W Low %  All-Time High %  All-Time Low %  \
# Ticker
# AAPL         7.09      -14.19      36.03           -14.19       350739.37
# MSFT         4.07      -18.40       4.07           -18.40       479564.32
# NVDA         6.27      -28.07      45.69           -28.07       330349.99
# AMZN         4.21      -20.76      26.75           -20.76       292730.49
# GOOG         4.38      -23.87       7.21           -23.87          553.52
#
#         ATR  Volatility W %  Volatility M %  Volume, M  Avg Volume, M  \
# Ticker
# AAPL   6.03            2.68            2.76      36.35          52.97
# MSFT   8.77            2.30            2.19      19.06          23.11
# NVDA   5.59            4.58            4.28     216.54         281.46
# AMZN   6.49            3.30            3.08      41.14          40.05
# GOOG   5.03            3.41            2.87      20.08          19.97
#
#         Rel Volume  Price  Change %  Dividend %  Sharpe 3d  Sortino 3d  \
# Ticker
# AAPL          0.69 223.19      0.48        0.47      18.30     6826.03
# MSFT          0.82 382.19      1.81        0.86       3.64       10.78
# NVDA          0.77 110.15      1.63        0.04       1.70        4.00
# AMZN          1.03 192.17      1.00         NaN      -1.50       -2.64
# GOOG          1.01 158.88      1.70        0.34      12.54     6826.03
#
#         Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  Sortino 10d  \
# Ticker
# AAPL      609.11       1.48        2.21      1.28        4.12         6.52
# MSFT        1.96      -3.95       -5.04      0.49       -1.86        -2.34
# NVDA        1.36      -7.75       -8.95      0.33       -4.43        -5.16
# AMZN        0.76      -7.73       -7.97      0.19       -1.31        -1.76
# GOOG      609.11      -6.97       -7.54      0.26       -3.21        -3.77
#
#         Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  \
# Ticker
# AAPL         1.85        1.89         2.62       1.34       -2.86
# MSFT         0.73       -0.28        -0.40       0.95       -2.88
# NVDA         0.47       -1.91        -2.61       0.73       -3.12
# AMZN         0.79       -1.84        -2.41       0.75       -4.48
# GOOG         0.59       -3.01        -3.58       0.63       -4.24
#
#         Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  Omega 60d  \
# Ticker
# AAPL          -3.31       0.63       -1.26        -1.59       0.81
# MSFT          -3.62       0.63       -1.67        -2.15       0.74
# NVDA          -3.71       0.61       -1.46        -1.78       0.78
# AMZN          -5.13       0.51       -2.30        -2.83       0.70
# GOOG          -4.79       0.53       -2.48        -2.92       0.67
#
#         Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  Sortino 250d  \
# Ticker
# AAPL          -0.14         -0.18        0.98         1.10          1.62
# MSFT          -0.74         -0.94        0.87        -0.48         -0.62
# NVDA          -0.54         -0.69        0.91         0.60          0.83
# AMZN           0.37          0.53        1.06         0.19          0.26
# GOOG          -0.24         -0.33        0.96         0.08          0.11
#
#         Omega 250d  Perf 3D %
# Ticker
# AAPL          1.21      -0.29
# MSFT          0.92      -2.15
# NVDA          1.10      -1.15
# AMZN          1.03      -4.56
# GOOG          1.01      -3.17

# %%
import pandas as pd

def find_duplicate_columns(df):
  """
  Finds and returns a list of duplicate column names in a Pandas DataFrame.

  Args:
    df: The Pandas DataFrame to check.

  Returns:
    A list of column names that are duplicates (excluding the first occurrence).
    Returns an empty list if no duplicate columns are found.
  """

  duplicate_columns = []
  seen_columns = set()  # Keep track of columns we've already encountered

  for col in df.columns:
    if col in seen_columns:
      duplicate_columns.append(col)
    else:
      seen_columns.add(col)

  return duplicate_columns

# %%
# import pandas as pd

# def remove_duplicate_columns(df):
#   """Removes duplicate columns from a DataFrame, keeping the first occurrence.
#   Prints the names of the duplicate columns.

#   Args:
#     df: pandas DataFrame.

#   Returns:
#     pandas DataFrame with duplicate columns removed.
#   """
#   seen_columns = set()
#   cols_to_keep = []
#   duplicate_cols = []  # Keep track of duplicate column names
#   for col in df.columns:
#       if col not in seen_columns:
#           cols_to_keep.append(col)
#           seen_columns.add(col)
#       else:
#           duplicate_cols.append(col)  # Add the duplicate column to the list

#   if duplicate_cols:
#       print("Duplicate columns found and removed:", duplicate_cols)
#   else:
#       print("No duplicate columns found.")

#   return df.loc[:,~df.columns.duplicated()]

# # Remove duplicates
# df_merged = remove_duplicate_columns(df_merged)
# print("\nDataFrame after removing duplicate columns:")
# display(df_merged.info())

# %%
duplicate_cols = find_duplicate_columns(df_merged)

if duplicate_cols:
    print("Duplicate columns found:")
    for col in duplicate_cols:
        print(f"- {col}")
    raise ValueError("Duplicate columns found") # Raise the error
else:
    print("No duplicate columns found.")
# Out:
# No duplicate columns found.

# %%
new_column_order = ['Company', 'Info', 'MktCap AUM, M', 'Beta', 'RSI', 'Perf YTD %',
       'Perf 3D %', 'Perf Week %', 'Perf Month %', 'Perf Quart %', 'Perf Half %',
       'Perf Year %', 'SMA20 %', 'SMA50 %', 'SMA200 %', '50D High %',
       '50D Low %', '52W High %', '52W Low %', 'All-Time High %',
       'All-Time Low %', 'ATR', 'Volatility W %', 'Volatility M %',
       'Volume, M', 'Avg Volume, M', 'Rel Volume', 'Price', 'Change %',
       'Dividend %', 'Sharpe 3d', 'Sortino 3d', 'Omega 3d', 'Sharpe 5d',
       'Sortino 5d', 'Omega 5d', 'Sharpe 10d', 'Sortino 10d', 'Omega 10d',
       'Sharpe 15d', 'Sortino 15d', 'Omega 15d', 'Sharpe 30d', 'Sortino 30d',
       'Omega 30d', 'Sharpe 60d', 'Sortino 60d', 'Omega 60d', 'Sharpe 120d',
       'Sortino 120d', 'Omega 120d', 'Sharpe 250d', 'Sortino 250d',
       'Omega 250d']

# %%
# Reindex the DataFrame with the new column order
df_merged = df_merged.reindex(columns=new_column_order)

print("reindexed df_merged Head:")
display(df_merged.head(), df_merged.info())
# Out:
# reindexed df_merged Head:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1538 entries, AAPL to FNDC
# Data columns (total 54 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          
perf Quart %  Perf Half %  Perf Year %  SMA20 %  SMA50 %  SMA200 %  \
# Ticker
# AAPL          -12.68        -2.02        30.16     0.85    -3.01     -2.60
# MSFT          -11.23       -10.71        -9.16    -1.32    -5.38     -9.42
# NVDA          -19.60        -9.27        21.91    -3.95   -11.08    -13.61
# AMZN          -14.11         2.23         6.54    -2.75   -10.79     -4.03
# GOOG          -18.12        -3.88         4.35    -4.63   -11.80     -9.89
#
#         50D High %  50D Low %  52W High %  52W Low %  All-Time High %  \
# Ticker
# AAPL        -10.72       7.09      -14.19      36.03           -14.19
# MSFT        -14.76       4.07      -18.40       4.07           -18.40
# NVDA        -26.06       6.27      -28.07      45.69           -28.07
# AMZN        -20.76       4.21      -20.76      26.75           -20.76
# GOOG        -23.87       4.38      -23.87       7.21           -23.87
#
#         All-Time Low %  ATR  Volatility W %  Volatility M %  Volume, M  \
# Ticker
# AAPL         350739.37 6.03            2.68            2.76      36.35
# MSFT         479564.32 8.77            2.30            2.19      19.06
# NVDA         330349.99 5.59            4.58            4.28     216.54
# AMZN         292730.49 6.49            3.30            3.08      41.14
# GOOG            553.52 5.03            3.41            2.87      20.08
#
#         Avg Volume, M  Rel Volume  Price  Change %  Dividend %  Sharpe 3d  \
# Ticker
# AAPL            52.97        0.69 223.19      0.48        0.47      18.30
# MSFT            23.11        0.82 382.19      1.81        0.86       3.64
# NVDA           281.46        0.77 110.15      1.63        0.04       1.70
# AMZN            40.05        1.03 192.17      1.00         NaN      -1.50
# GOOG            19.97        1.01 158.88      1.70        0.34      12.54
#
#         Sortino 3d  Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  \
# Ticker
# AAPL       6826.03    609.11       1.48        2.21      1.28        4.12
# MSFT         10.78      1.96      -3.95       -5.04      0.49       -1.86
# NVDA          4.00      1.36      -7.75       -8.95      0.33       -4.43
# AMZN         -2.64      0.76      -7.73       -7.97      0.19       -1.31
# GOOG       6826.03    609.11      -6.97       -7.54      0.26       -3.21
#
#         Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  \
# Ticker
# AAPL           6.52       1.85        1.89         2.62       1.34
# MSFT          -2.34       0.73       -0.28        -0.40       0.95
# NVDA          -5.16       0.47       -1.91        -2.61       0.73
# AMZN          -1.76       0.79       -1.84        -2.41       0.75
# GOOG          -3.77       0.59       -3.01        -3.58       0.63
#
#         Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  \
# Ticker
# AAPL         -2.86        -3.31       0.63       -1.26        -1.59
# MSFT         -2.88        -3.62       0.63       -1.67        -2.15
# NVDA         -3.12        -3.71       0.61       -1.46        -1.78
# AMZN         -4.48        -5.13       0.51       -2.30        -2.83
# GOOG         -4.24        -4.79       0.53       -2.48        -2.92
#
#         Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  \
# Ticker
# AAPL         0.81        -0.14         -0.18        0.98         1.10
# MSFT         0.74        -0.74         -0.94        0.87        -0.48
# NVDA         0.78        -0.54         -0.69        0.91         0.60
# AMZN         0.70         0.37          0.53        1.06         0.19
# GOOG         0.67        -0.24         -0.33        0.96         0.08
#
#         Sortino 250d  Omega 250d
# Ticker
# AAPL            1.62        1.21
# MSFT           -0.62        0.92
# NVDA            0.83        1.10
# AMZN            0.26        1.03
# GOOG            0.11        1.01
# None

# %%
df_merged.to_parquet(dest_path)
print(f"Merged dataframe saved to {dest_path}")
# Out:
# Merged dataframe saved to ..\data\df_finviz_n_ratios_merged.parquet
