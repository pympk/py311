# %%
import ast
import sys
from contextlib import redirect_stdout
from pathlib import Path


class Tee:
    def __init__(self, *streams):
        self.streams = streams

    def write(self, data):
        for s in self.streams:
            s.write(data)

    def flush(self):
        for s in self.streams:
            s.flush()


base = Path(r"C:\Users\ping\Files_win10\python\py311\stocks\notebooks_RLVR_v2")

EXCLUDE_DIRS = {"archive", "output", "output_v19a", "data", "yee_files", "__pycache__"}
EXCLUDE_FILES = {
    "utils",
    "__init__",
}  # any file whose name contains one of these

output_path = base / "list_dir_class_def.txt"

with output_path.open("w", encoding="utf-8") as out_file, redirect_stdout(
    Tee(sys.stdout, out_file)
):
    for f in sorted(base.rglob("*")):
        if not f.is_file():
            continue
        rel = f.relative_to(base)
        if any(part in EXCLUDE_DIRS for part in rel.parts[:-1]):
            continue
        if any(pat in f.name for pat in EXCLUDE_FILES):
            continue

        print(rel)

        if f.suffix == ".py":
            try:
                tree = ast.parse(f.read_text(encoding="utf-8"))
            except (SyntaxError, UnicodeDecodeError):
                continue

            for node in tree.body:
                if isinstance(node, ast.ClassDef):
                    print(f"    class {node.name}")
                    for item in node.body:
                        if isinstance(item, (ast.FunctionDef, ast.AsyncFunctionDef)):
                            print(f"        def {item.name}")
                elif isinstance(node, (ast.FunctionDef, ast.AsyncFunctionDef)):
                    print(f"    def {node.name}")
# Out:
# 00_01_02_03.txt
# 00_RLVR_data_process_v7.ipynb
# 01_RLVR_Part1_AlphaCache_v5.ipynb
# 02_RLVR_Part2_Training_v19a.ipynb
# 03_RLVR_Part3_Analysis_v4.ipynb
# core\auditor.py
#     class SystemAuditor
#         def verify_math_integrity
#         def verify_ranking_integrity
#         def verify_vol_alignment_integrity
#         def verify_feature_engineering_integrity
#         def verify_macro_engine
#         def verify_analyzer_short
#         def verify_analyzer_long
#         def audit_feature_engineering_integrity
#         def audit_oos_results
# core\contracts.py
#     class MarketObservation
#     class FilterPack
#         def __repr__
#     class EngineInput
#     class EngineOutput
#     class SelectionResult
#     class DiscoveryResult
#     class MetricBlueprint
#         def __call__
# core\logic.py
#     class AlphaLogic
#         def calculate_veritable_reward
#         def slugify_columns
#     class SelectionLogic
#         def apply_action
# core\paths.py
# ...

# %%
import ast
from pathlib import Path

base = Path(r"C:\Users\ping\Files_win10\python\py311\stocks\notebooks_RLVR_v2")

EXCLUDE_DIRS = {"archive", "output", "output_v19a", "data", "yee_files", "__pycache__"}
EXCLUDE_FILES = {
    "utils",
    "__init__",
}  # any file whose name contains one of these

for f in sorted(base.rglob("*")):
    if not f.is_file():
        continue
    rel = f.relative_to(base)
    if any(part in EXCLUDE_DIRS for part in rel.parts[:-1]):
        continue
    if any(pat in f.name for pat in EXCLUDE_FILES):
        continue

    print(rel)

    if f.suffix == ".py":
        try:
            tree = ast.parse(f.read_text(encoding="utf-8"))
        except (SyntaxError, UnicodeDecodeError):
            continue

        for node in tree.body:
            if isinstance(node, ast.ClassDef):
                print(f"    class {node.name}")
                for item in node.body:
                    if isinstance(item, (ast.FunctionDef, ast.AsyncFunctionDef)):
                        print(f"        def {item.name}")
            elif isinstance(node, (ast.FunctionDef, ast.AsyncFunctionDef)):
                print(f"    def {node.name}")
# Out:
# 00_01_02_03.txt
# 00_RLVR_data_process_v7.ipynb
# 01_RLVR_Part1_AlphaCache_v5.ipynb
# 02_RLVR_Part2_Training_v19a.ipynb
# 03_RLVR_Part3_Analysis_v4.ipynb
# core\auditor.py
#     class SystemAuditor
#         def verify_math_integrity
#         def verify_ranking_integrity
#         def verify_vol_alignment_integrity
#         def verify_feature_engineering_integrity
#         def verify_macro_engine
#         def verify_analyzer_short
#         def verify_analyzer_long
#         def audit_feature_engineering_integrity
#         def audit_oos_results
# core\contracts.py
#     class MarketObservation
#     class FilterPack
#         def __repr__
#     class EngineInput
#     class EngineOutput
#     class SelectionResult
#     class DiscoveryResult
#     class MetricBlueprint
#         def __call__
# core\logic.py
#     class AlphaLogic
#         def calculate_veritable_reward
#         def slugify_columns
#     class SelectionLogic
#         def apply_action
# core\paths.py
# ...
