# %%
import pandas as pd

data_path = r"c:\Users\ping\Files_win10\python\py311\stocks\data\2025-12-28_df_finviz_stocks_etfs.parquet"

_df = pd.read_parquet(data_path, engine="pyarrow")

# %%
_df
# Out:
#          No.                                  Company    Index  \
# Ticker
# VOO        1                     Vanguard S&P 500 ETF        -
# IVV        2                 iShares Core S&P 500 ETF        -
# SPY        3                   SPDR S&P 500 ETF Trust        -
# VTI        4          Vanguard Total Stock Market ETF        -
# QQQ        5               Invesco QQQ Trust Series 1        -
# VUG        6                      Vanguard Growth ETF        -
# VEA        7      Vanguard FTSE Developed Markets ETF        -
# IEFA       8               iShares Core MSCI EAFE ETF        -
# VTV        9                       Vanguard Value ETF        -
# GLD       10                         SPDR Gold Shares        -
# BND       11           Vanguard Total Bond Market ETF        -
# AGG       12     iShares Core U.S. Aggregate Bond ETF        -
# IWF       13          iShares Russell 1000 Growth ETF        -
# IEMG      14   iShares Core MSCI Emerging Markets ETF        -
# ...

# %%
import pandas as pd

data_path = r"c:\Users\ping\Files_win10\python\py311\stocks\data\2025-12-26_df_finviz_stocks_etfs.parquet"

_df = pd.read_parquet(data_path, engine="pyarrow")

# %%
_df
# Out:
#         No.                                           Company  \
# Ticker
# NVDA      1                                       NVIDIA Corp
# AAPL      2                                         Apple Inc
# GOOGL     3                                      Alphabet Inc
# GOOG      4                                      Alphabet Inc
# MSFT      5                             Microsoft Corporation
# ...     ...                                               ...
# EVTR    397                 Eaton Vance Total Return Bond ETF
# EMLC    396     VanEck J.P. Morgan EM Local Currency Bond ETF
# SLYV    399  State Street SPDR S&P 600 TM Small Cap Value ETF
# MAGS    398                   Roundhill Magnificent Seven ETF
# TMF     400   Direxion Daily 20+ Year Treasury Bull 3X Shares
#
#                      Index                  Sector  \
# Ticker
# NVDA    DJIA, NDX, S&P 500              Technology
# AAPL    DJIA, NDX, S&P 500              Technology
# ...
