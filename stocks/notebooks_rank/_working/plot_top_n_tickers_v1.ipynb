# %%
import pandas as pd
from pathlib import Path

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 3000)

download_path = Path.home() / "Downloads"  
OHLCV_file_path = r'c:\Users\ping\Files_win10\python\py311\stocks\data\df_OHLCV_clean_stocks_etfs.parquet'

df_OHLCV = pd.read_parquet(OHLCV_file_path, engine='pyarrow')

# %%
df_OHLCV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 375500 entries, ('A', Timestamp('2024-09-24 00:00:00')) to ('ZWS', Timestamp('2025-09-23 00:00:00'))
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Adj Open   375500 non-null  float64
#  1   Adj High   375500 non-null  float64
#  2   Adj Low    375500 non-null  float64
#  3   Adj Close  375500 non-null  float64
#  4   Volume     375500 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 15.8+ MB

# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import pprint 

def plot_interactive_performers_widget(df_ohlcv, 
                                       default_metric='Price',
                                       default_period='1Y', 
                                       default_rank_start=1,
                                       default_rank_end=10):
    """
    Creates a robust interactive plot using ipywidgets for state management.
    Metrics include Price, Sharpe, and Return/ATR.
    (Final corrected version).
    """
    # --- 1. Data Preparation: Reshape & Calculate Intermediate Values ---
    print("Reshaping data and calculating intermediate metrics (ATR)...")
    
    if not isinstance(df_ohlcv.index, pd.MultiIndex):
        raise ValueError("The input DataFrame does not have the expected 'long' format with a (Ticker, Date) MultiIndex.")
    
    df_close = df_ohlcv['Adj Close'].unstack(level=0)
    df_high = df_ohlcv['Adj High'].unstack(level=0)
    df_low = df_ohlcv['Adj Low'].unstack(level=0)
    df_close.index = pd.to_datetime(df_close.index)
    df_high.index = pd.to_datetime(df_high.index)
    df_low.index = pd.to_datetime(df_low.index)

    high_low = df_high - df_low
    high_prev_close = abs(df_high - df_close.shift(1))
    low_prev_close = abs(df_low - df_close.shift(1))
    tr = np.maximum(high_low, np.maximum(high_prev_close, low_prev_close))
    df_atr = tr.ewm(alpha=1/14, adjust=False).mean()
    
    print("Data successfully reshaped and ATR calculated.")
    
    # --- 2. Pre-computation Phase ---
    print("Starting pre-computation for all metrics across all periods...")
    end_date = df_close.index.max()
    metrics = ['Price', 'Sharpe', 'Return/ATR']
    periods = {
        '1D': end_date - pd.DateOffset(days=1), '5D': end_date - pd.DateOffset(days=5),
        '3M': end_date - pd.DateOffset(months=3), '6M': end_date - pd.DateOffset(months=6),
        'YTD': datetime(end_date.year, 1, 1), '1Y': end_date - pd.DateOffset(years=1),
        '5Y': end_date - pd.DateOffset(years=5),
    }
    all_rankings = {metric: {} for metric in metrics}
    period_normalized_data = {}
    for label, start_date in periods.items():
        period_close = df_close.loc[start_date:end_date]
        period_atr = df_atr.loc[start_date:end_date]
        if period_close.empty or len(period_close) < 2: continue
        first_prices, last_prices = period_close.bfill().iloc[0], period_close.ffill().iloc[-1]
        all_rankings['Price'][label] = (last_prices / first_prices).dropna().sort_values(ascending=False).index.tolist()
        daily_returns = period_close.pct_change()
        mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
        sharpe_ratio = (mean_returns / std_returns).fillna(0)
        all_rankings['Sharpe'][label] = (sharpe_ratio * np.sqrt(252)).sort_values(ascending=False).index.tolist()
        mean_atr = period_atr.mean()
        return_on_atr = (mean_returns / mean_atr).fillna(0)
        all_rankings['Return/ATR'][label] = return_on_atr.sort_values(ascending=False).index.tolist()
        period_normalized_data[label] = period_close.div(first_prices)
    print("Pre-computation finished.")

    # --- 3. Create ipywidgets Controls & Data Holder ---
    rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
    max_traces = 50 
    metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
    period_dropdown = widgets.Dropdown(options=list(periods.keys()), value=default_period, description='Period:')
    rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
    rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
    update_button = widgets.Button(description="Update Chart", button_style='primary')
    ticker_list_output = widgets.Output()
    _currently_displayed_tickers = []

    # --- 4. Create a FigureWidget ---
    fig = go.FigureWidget()
    for i in range(max_traces):
        fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))

    # --- 5. Define the Update Logic ---
    def update_plot(button_click):
        metric, period, rank_start, rank_end = metric_dropdown.value, period_dropdown.value, rank_start_dropdown.value, rank_end_dropdown.value
        ticker_list_output.clear_output()
        if rank_start > rank_end:
            with ticker_list_output: print("Error: 'Rank Start' must be less than or equal to 'Rank End'.")
            return
        ranked_tickers = all_rankings[metric].get(period, [])
        tickers_to_display = ranked_tickers[rank_start-1:rank_end]
        norm_data = period_normalized_data.get(period)

        with fig.batch_update():
            for i in range(max_traces):
                trace = fig.data[i]
                
                # --- THIS IS THE CORRECTED LOGIC ---
                # First, check if there's a ticker available for this trace index
                if i < len(tickers_to_display) and norm_data is not None:
                    ticker = tickers_to_display[i]
                    # Second, check if that ticker actually has data in the norm_data frame
                    if ticker in norm_data.columns:
                        trace.x, trace.y, trace.name = norm_data[ticker].index, norm_data[ticker], ticker
                        trace.visible, trace.showlegend = True, True
                    else: # Handle cases where a ticker was ranked but has no data
                        trace.visible, trace.showlegend = False, False
                else: # If no ticker for this trace index, hide it
                    trace.visible, trace.showlegend = False, False

        _currently_displayed_tickers.clear()
        _currently_displayed_tickers.extend(tickers_to_display)
        with ticker_list_output:
            print("Currently Displayed Tickers:")
            pprint.pprint(tickers_to_display, width=120, compact=True) 
    
    # --- 6. Set up Initial View and Layout ---
    update_plot(None)
    fig.update_layout(title_text='Top Performing Tickers (Normalized to 1)', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers', height=700, margin=dict(t=50))
    fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
    update_button.on_click(update_plot)
    
    # --- 7. Display the UI ---
    controls = widgets.HBox([metric_dropdown, period_dropdown, rank_start_dropdown, rank_end_dropdown, update_button])
    ui_container = widgets.VBox([controls, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
    display(ui_container, fig)
    return _currently_displayed_tickers

# %% [markdown]
# ### **J. Welles Wilder Jr. definition ATR that captures overnight gaps.**
#
# Let's be precise:
#
# *   **We WILL calculate** the **True Range (TR)** for each day, which is the maximum of:
#     1.  `(Today's High - Today's Low)`
#     2.  `abs(Today's High - Yesterday's Close)`
#     3.  `abs(Today's Low - Yesterday's Close)`
# *   Then, we will typically calculate the **Average True Range (ATR)**, which is a **Exponential Moving Average** of this True Range value. This is the standard industry indicator for volatility that includes intraday and overnight movement.

# %% [markdown]
# ### **Return/ATR Calculation**
#
# You are correct that the ATR calculation should be tied to the `Period` dropdown, but here's how we'll do it in a standard, robust way:
#
# **Step 1: Pre-computation (Done once for all stocks)**
#
# First, for the entire historical dataset, we will calculate a standard **14-day Average True Range (ATR)**. This is the industry standard lookback period defined by Wilder. This step creates a new, continuous ATR data series for every single stock, just like we have an 'Adj Close' series.
#
# **Step 2: On-the-Fly Calculation (When you click "Update Chart")**
#
# This is where your interpretation comes in. When you make your selections in the dropdowns (e.g., `Metric: Return/ATR`, `Period: 3M`):
#
# 1.  We slice the **daily returns** data to get only the last **3 months**.
# 2.  We also slice the pre-computed **14-day ATR** data to get only the last **3 months**.
# 3.  We then calculate:
#     *   **Numerator:** The `mean()` of the daily returns over those 3 months.
#     *   **Denominator:** The `mean()` of the ATR values over those 3 months.
# 4.  The final score for the new metric is `Numerator / Denominator`.
#
# **In short: The `Period` dropdown defines the window of data we analyze, not the lookback period of the ATR indicator itself.**
#
# This is the best practice because it ensures we are always comparing apples to apples. We're using a consistent measure of volatility (14-day ATR) and seeing how it behaves over different analysis windows (1D, 3M, 1Y, etc.).

# %%
# --- NEW: Initialize the variable before the call ---
plotted_tickers = [] 

# Call the final function and capture the returned list
# The 'plotted_tickers' list will be updated in place every time you click the button.
plotted_tickers = plot_interactive_performers_widget(
    df_OHLCV, 
    default_metric='Sharpe', 
    default_period='1Y', 
    default_rank_start=20, 
    default_rank_end=40
)

# print("\n--- After the plot, the 'plotted_tickers' variable holds the last displayed list: ---")
# print(plotted_tickers)
# Out:
# Reshaping data and calculating intermediate metrics (ATR)...
# Data successfully reshaped and ATR calculated.
# Starting pre-computation for all metrics across all periods...
# Pre-computation finished.
# VBox(children=(HBox(children=(Dropdown(description='Metric:', index=1, options=('Price', 'Sharpe', 'Return/ATR…
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'name': 'ESLT',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '693b0c68-888c-4870-b29a-2125eef0d400',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99948651, 1.00705402, ..., 2.53099099, 2.58804552,
#                           2.58835673])},
#              {'mode': 'lines',
#               'name': 'SPSB',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '671c86c6-295a-4c81-a6ba-eb34212ab2ab',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99901097, 0.99835047, ..., 1.04746985, 1.04677823,
#                           1.04712404])},
#              {'mode': 'lines',
#               'name': 'SGHC',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'bd05b702-8c1b-4369-9264-6b2f3aa4587a',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.98351698, 0.95329717, ..., 3.33977053, 3.65216403,
#                           3.7260025 ])},
#              {'mode': 'lines',
#               'name': 'VRNA',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4ae0bbdd-ac7e-4811-a9f0-fee2ee0182aa',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.95279838, 0.93189481, ..., 3.57451113, 3.58226568,
#                           3.58226568])},
#              {'mode': 'lines',
#               'name': 'KTOS',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '67d8541d-bee6-4e86-9f74-253c5fb437d4',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99310939, 0.99870801, ..., 3.47846684, 3.47631352,
#                           3.61326443])},
#              {'mode': 'lines',
#               'name': 'OKLO',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1e0aefac-58da-4b56-8f45-d58110070ce9',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([ 1.        ,  0.99037304,  1.03249097, ..., 16.27316486, 16.88327316,
#                           17.16606498])},
#              {'mode': 'lines',
#               'name': 'SHLD',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '748d3ee5-b100-4941-9c49-179c31bb867d',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.9948893 , 0.99704018, ..., 1.80159462, 1.8197215 ,
#                           1.81593379])},
#              {'mode': 'lines',
#               'name': 'STIP',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f2c45729-30e3-439b-9166-fa0e83ab8b48',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.9982264 , 0.99714287, ..., 1.05478286, 1.05386548,
#                           1.05468093])},
#              {'mode': 'lines',
#               'name': 'IDCC',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a490a7cc-3d52-448e-a3b0-dafd34a34fb8',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.98530836, 0.99711557, ..., 2.43872415, 2.52380016,
#                           2.54375806])},
#              {'mode': 'lines',
#               'name': 'HOOD',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'cb5a3703-cf93-4f09-8e31-a4176ea2d750',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.98331137, 0.98506807, ..., 5.48001757, 5.48484848,
#                           5.54238032])},
#              {'mode': 'lines',
#               'name': 'VTIP',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'aedbcbfb-1971-4843-8ed6-da0bf44e556a',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99919032, 0.99757097, ..., 1.05507891, 1.05403819,
#                           1.05507891])},
#              {'mode': 'lines',
#               'name': 'JPIE',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '0f91bf91-ea34-44d5-b9a2-05d4d70ffe5e',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00064683, 1.        , ..., 1.06166818, 1.06189674,
#                           1.06258242])},
#              {'mode': 'lines',
#               'name': 'CLS',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3f11fd59-a786-4cb3-a2c9-04d16369627d',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.01460292, 1.0420084 , ..., 5.05961192, 5.09681936,
#                           5.15383077])},
#              {'mode': 'lines',
#               'name': 'PLTR',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '278495b3-854a-46a8-bd86-d1966a6acd1a',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00596206, 1.00542005, ..., 4.94281843, 4.8598916 ,
#                           4.94715447])},
#              {'mode': 'lines',
#               'name': 'RKLB',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd776be3a-0eec-4c38-9506-4a3a096116f4',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.13570487, 1.14492754, ..., 6.29644269, 6.56258235,
#                           6.97101449])},
#              {'mode': 'lines',
#               'name': 'SOFI',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '705303b3-5f14-4628-845a-eb1af7511060',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.98722861, 0.99106003, ..., 3.7688378 , 3.80715198,
#                           3.71519796])},
#              {'mode': 'lines',
#               'name': 'LLYVK',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '14295cf6-c06d-4a64-bed1-037549d9a2f6',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.03054903, 1.07690664, ..., 2.07049776, 2.08395642,
#                           2.08246101])},
#              {'mode': 'lines',
#               'name': 'FLOT',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ad86eed8-463a-446a-9c4e-b4f516abe9f1',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00019589, 1.        , ..., 1.05162228, 1.05182848,
#                           1.05203468])},
#              {'mode': 'lines',
#               'name': 'OR',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6e6e6a41-e8d6-4da4-ab21-3c5b35f7942a',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00377041, 1.02206829, ..., 2.02156847, 2.0161356 ,
#                           2.04275663])},
#              {'mode': 'lines',
#               'name': 'KGC',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '81fdea87-d35b-44f8-bdf0-a01727e3f787',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99897511, 1.00512857, ..., 2.4317752 , 2.50838284,
#                           2.53426381])},
#              {'mode': 'lines',
#               'name': 'SRAD',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3ee7c27c-7a88-4c3b-ace5-12066181bb23',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.03425775, 1.0228385 , ..., 2.45840131, 2.42495922,
#                           2.45350734])},
#              {'mode': 'lines',
#               'name': 'placeholder_21',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '13c96875-54ed-486c-b599-3cd23438d79c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_22',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '12b7d6b1-cb4f-449d-85f2-f1981dba9665',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_23',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e965ac5d-4c98-4724-ad90-cb6bbfc4a3ad',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_24',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a1aa2a0e-15d6-4013-ab57-c050cd127b0f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_25',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9998ef09-7243-4e0a-9065-4730916e4a57',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_26',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '65593d51-1f86-4d30-86b5-d8f75b1c11d5',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_27',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fc6b3e8e-4bf8-4368-ba0c-f1a46787ce80',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_28',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a6480116-8338-43a7-9e24-84910219e796',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_29',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '725a4a0b-2f81-4c8c-b4ce-373322588ce4',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_30',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '25db3e08-0ea8-4aa5-9f60-44a03510aad1',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_31',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '758a3f89-753c-42b9-aa13-247416b804f8',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_32',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd31b67f4-73bc-4fe5-a6c7-38ff79ee3161',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_33',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '51b99020-66a8-4ddc-ac34-33471b0955d2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_34',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '106385f0-6f19-481e-b6ba-9fafd95a61fd',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_35',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0499d9b7-3f83-499b-b09a-25cc2f606975',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_36',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ca7a8f08-de52-4ad1-844b-c8d4a6deb620',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_37',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b01842ae-d8e3-4776-98ed-8a8d8ef407aa',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_38',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e9845590-b239-40ed-a82c-d11f192fe09a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_39',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b5676603-db0f-477d-96cc-de108a8147dd',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_40',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '48bfa0cf-a96c-4f41-81df-15677e312f09',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_41',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b45c618e-c251-4ed6-9f7a-6eddf193d29d',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_42',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '511645ee-83b0-45be-83e8-a601736bb48e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_43',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fc244338-9d56-4ae2-88fa-f4e144f6be76',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_44',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0b944c05-b98d-4b38-af22-07176d7c5086',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_45',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '19b5bfc6-8c81-4583-b741-15f2a2a1f186',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_46',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a5bcbe35-9761-4931-8b27-dcd2a94e7e04',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_47',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9f88024e-3959-41cf-b5a7-2fc3b7ff39a3',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_48',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '42b8f82f-1473-4576-94df-859c36a7890f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_49',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1deed2c9-91b9-48cf-9bcd-8b252f1d74e9',
#               'visible': False,
#               'x': [None],
#               'y': [None]}],
#     'layout': {'height': 700,
#                'hovermode': 'x unified',
#                'legend': {'title': {'text': 'Tickers'}},
#                'margin': {'t': 50},
#                'shapes': [{'line': {'color': 'grey', 'dash': 'dash', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'x domain',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y'}],
#                'template': '...',
#                'title': {'text': 'Top Performing Tickers (Normalized to 1)'},
#                'xaxis': {'title': {'text': 'Date'}},
#                'yaxis': {'title': {'text': 'Normalized Price (Start = 1)'}}}
# })

# %%
print("\n--- After the plot, the 'plotted_tickers' variable holds the last displayed list: ---")
print(plotted_tickers)
# Out:
# --- After the plot, the 'plotted_tickers' variable holds the last displayed list: ---
# ['NIO', 'HL', 'UWMC', 'EQX', 'MFG', 'BBD', 'GRAB', 'QS', 'EBR', 'CDE', 'NMR', 'IAG', 'CX', 'AEG', 'SAN', 'LYG', 'WBD', 'SBSW', 'FPE', 'VALE']

# %% [markdown]
# ### Plot Tickers

# %%
# --- 2. Define the list of tickers you want to keep ---
tickers_to_plot = ['SPY', 'VGT', 'QQQ', 'NVDA', 'GOOG', 'META', 'ORCL', 'APP', 'U', 'B', 'NIO',
                   'HL', 'UWMC', 'EQX', 'MFG', 'BBD', 'GRAB', 'QS', 'EBR', 'CDE', 'NMR', 'IAG',
                    'CX', 'AEG', 'SAN', 'GLD', 'IAUM', 'IBIT', 'MSTR',
                   'LYG', 'WBD', 'SBSW', 'FPE', 'VALE']



# --- 3. The Efficient Filtering Code ---
# This single line performs a fast, index-based selection.
# The result preserves the original MultiIndex structure and format.
filtered_df = df_OHLCV.loc[tickers_to_plot]


# --- 4. Verification ---
print("Filtered DataFrame created. Shape:", filtered_df.shape)
print("Filtered DataFrame Index Levels:", filtered_df.index.names)

# Verify that only the desired tickers are present
remaining_tickers = filtered_df.index.get_level_values('Ticker').unique().tolist()
print("Tickers remaining in filtered_df:", remaining_tickers)
assert set(tickers_to_plot) == set(remaining_tickers)

print("\nAll checks passed. The format is preserved correctly.")
display(filtered_df.head())
# Out:
# Filtered DataFrame created. Shape: (8500, 5)
# Filtered DataFrame Index Levels: ['Ticker', 'Date']
# Tickers remaining in filtered_df: ['SPY', 'VGT', 'QQQ', 'NVDA', 'GOOG', 'META', 'ORCL', 'APP', 'U', 'B', 'NIO', 'HL', 'UWMC', 'EQX', 'MFG', 'BBD', 'GRAB', 'QS', 'EBR', 'CDE', 'NMR', 'IAG', 'CX', 'AEG', 'SAN', 'GLD', 'IAUM', 'IBIT', 'MSTR', 'LYG', 'WBD', 'SBSW', 'FPE', 'VALE']
#
# All checks passed. The format is preserved correctly.
#                    Adj Open  Adj High  Adj Low  Adj Close    Volume
# Ticker Date
# SPY    2024-09-24   563.628   564.497  560.782    564.438  47374742
#        2024-09-25   564.280   565.021  562.077    563.193  38895797
#        2024-09-26   567.481   567.807  563.055    565.426  48923643
#        2024-09-27   566.503   567.323  563.568    564.606  42612741
#        2024-09-30   563.568   567.481  561.257    566.868  64330101

# %%
# --- NEW: Initialize the variable before the call ---
plotted_tickers = [] 

# Call the final function and capture the returned list
# The 'plotted_tickers' list will be updated in place every time you click the button.
plotted_tickers = plot_interactive_performers_widget(
    filtered_df, 
    default_metric='Sharpe', 
    default_period='1Y', 
    default_rank_start=20, 
    default_rank_end=40
)

# print("\n--- After the plot, the 'plotted_tickers' variable holds the last displayed list: ---")
# print(plotted_tickers)
# Out:
# Reshaping data and calculating intermediate metrics (ATR)...
# Data successfully reshaped and ATR calculated.
# Starting pre-computation for all metrics across all periods...
# Pre-computation finished.
# VBox(children=(HBox(children=(Dropdown(description='Metric:', index=1, options=('Price', 'Sharpe', 'Return/ATR…
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'name': 'EQX',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f8290fad-8196-40d8-932a-75711ce5af70',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99530516, 1.01095462, ..., 1.69014085, 1.71205008,
#                           1.68231612])},
#              {'mode': 'lines',
#               'name': 'U',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e5752e8a-58ec-433f-aef4-9561d32f0be8',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.94394135, 0.96334627, ..., 1.98576973, 1.97973264,
#                           1.91979301])},
#              {'mode': 'lines',
#               'name': 'EBR',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'ba443fcc-b627-44c6-86e1-f7c0d38c5556',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.97945308, 1.00274007, ..., 1.36931698, 1.34350786,
#                           1.38078769])},
#              {'mode': 'lines',
#               'name': 'BBD',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7ed6741e-85ae-45e0-a4d2-0fea45245284',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00774794, 1.03488052, ..., 1.40910033, 1.4048688 ,
#                           1.43448953])},
#              {'mode': 'lines',
#               'name': 'CX',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '3af6e185-54d0-49a0-b409-8d2547b6f6b2',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.98145352, 0.99072598, ..., 1.41632222, 1.43974541,
#                           1.42725304])},
#              {'mode': 'lines',
#               'name': 'HL',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1f875bd5-45fd-4616-9ef2-d719bec5c0a3',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.        , 1.01555851, ..., 1.55727165, 1.59563509,
#                           1.58710988])},
#              {'mode': 'lines',
#               'name': 'VGT',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '68fb216a-1825-4132-889d-131042c1599c',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00066936, 1.01307833, ..., 1.27862665, 1.2992939 ,
#                           1.28594127])},
#              {'mode': 'lines',
#               'name': 'AEG',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '17225963-45ee-4678-894d-a8f1e9d3e024',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.98589334, 1.00940444, ..., 1.26212367, 1.27992285,
#                           1.29934014])},
#              {'mode': 'lines',
#               'name': 'NVDA',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f5b2312d-a683-4be3-b156-e442768ece2d',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.02184797, 1.02622585, ..., 1.46207639, 1.51951008,
#                           1.4766417 ])},
#              {'mode': 'lines',
#               'name': 'QQQ',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c43cfec5-a1dd-4600-a2e6-21696886f2bc',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00092592, 1.00844717, ..., 1.24005676, 1.2473978 ,
#                           1.2391122 ])},
#              {'mode': 'lines',
#               'name': 'META',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9311d1a5-d619-4e01-aed4-6d4274ae3cb2',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00884138, 1.00800621, ..., 1.38515824, 1.36255173,
#                           1.3451717 ])},
#              {'mode': 'lines',
#               'name': 'SPY',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'd3739ff7-6ab2-42f6-b672-c2b5a80e4f11',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.99779427, 1.00175041, ..., 1.17585988, 1.18142294,
#                           1.17499176])},
#              {'mode': 'lines',
#               'name': 'NIO',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7c3edbd3-3970-40e8-ac23-a5932b00639d',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.95117845, 0.97306397, ..., 1.24074074, 1.16329966,
#                           1.16666667])},
#              {'mode': 'lines',
#               'name': 'VALE',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b4221b4e-3f8b-4bbc-a0f5-1a18cff802a0',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00812817, 1.0659459 , ..., 1.06351725, 1.06351725,
#                           1.07233092])},
#              {'mode': 'lines',
#               'name': 'UWMC',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c6b191aa-0fd5-4cb9-a255-053dc35c85c2',
#               'visible': True,
#               'x': array([datetime.datetime(2024, 9, 24, 0, 0),
#                           datetime.datetime(2024, 9, 25, 0, 0),
#                           datetime.datetime(2024, 9, 26, 0, 0), ...,
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.97334746, 0.97103044, ..., 0.79940145, 0.78940893,
#                           0.79940145])},
#              {'mode': 'lines',
#               'name': 'placeholder_15',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0b705d30-7ae5-490a-8bf2-9fd357b80e3f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_16',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1047162c-edf9-4fbf-91d2-2a48d5a8fbb0',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_17',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '35a4609f-b71d-4e6c-9755-fc89af41e199',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_18',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '83fe062b-760f-402a-bcb7-34965afb3438',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_19',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b603f2d5-7049-48af-9d2c-aeeec05edd72',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_20',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8765332a-83d3-4d2b-8781-4de594900ecc',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_21',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '24c4afcb-ce35-40b2-995e-56c1afa5ddee',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_22',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '03fbe187-231a-4714-ac76-dbaa4562ff84',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_23',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'aef5cd6e-b055-426e-9d89-4ad744b99cc0',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_24',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '163ab696-9738-436c-81b0-5d73e3ac40c2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_25',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8101c4af-8528-407f-9bfc-1f820d3cbd82',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_26',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '206d2810-b09d-4e51-b120-32c4f124ef85',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_27',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8d5054ea-0e01-4c25-8d4a-f1abd694f2ff',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_28',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9741646d-6ff6-49f7-af98-69051160aa72',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_29',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '73e00bf8-8b90-4206-8ce4-cc2d049cd732',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_30',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '556541dd-59b0-4d3f-aa2e-1d7bbe326093',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_31',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'de1c44bf-1ddd-44ec-ae77-2b0428635cf2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_32',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '12b7f079-6ce0-4e5e-943a-65100e1b4e85',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_33',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ad8fd6d9-0f72-4a6f-aa7b-6335ec97d999',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_34',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f41f16e1-cd3c-4dd3-bdcb-d44f9b0568e5',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_35',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '209017f9-a006-44fd-9360-b6be46c4afef',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_36',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '72c983a0-c744-4a71-96d2-5d2391bf331f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_37',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e217cfbe-f34b-4361-9d05-f2de31aa6e5f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_38',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '72dd0576-f4da-4185-aac3-e315deb18d86',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_39',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '604f6fa1-7a43-44a6-85ba-63c6cb34b945',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_40',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '62eb8c77-85ec-4c19-a913-e0df85441d1d',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_41',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0ef46236-6147-4e98-91e0-a59f894c9bcb',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_42',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '900596fc-0150-4993-a206-f6113099024b',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_43',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f16b391f-6c6b-43e9-9327-634d5f0180b2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_44',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd160a628-43f8-4c5f-a250-bf1ff10354f4',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_45',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'dcbdf89d-12e8-4d78-956b-e2467e798879',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_46',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b056952b-ff2b-446e-a92d-d5f80839dcfe',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_47',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '64600cfb-3704-4910-81f8-5d3cc55939c8',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_48',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '43f9c765-604d-4a08-a7f2-6401af659086',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_49',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4182174a-7b6a-4d7b-ab7f-31bd6feecbc3',
#               'visible': False,
#               'x': [None],
#               'y': [None]}],
#     'layout': {'height': 700,
#                'hovermode': 'x unified',
#                'legend': {'title': {'text': 'Tickers'}},
#                'margin': {'t': 50},
#                'shapes': [{'line': {'color': 'grey', 'dash': 'dash', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'x domain',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y'}],
#                'template': '...',
#                'title': {'text': 'Top Performing Tickers (Normalized to 1)'},
#                'xaxis': {'title': {'text': 'Date'}},
#                'yaxis': {'title': {'text': 'Normalized Price (Start = 1)'}}}
# })

# %%
print(plotted_tickers)
# Out:
# ['BBD', 'LYG', 'SAN', 'SBSW', 'EBR', 'MFG', 'HL', 'CDE', 'EQX', 'AEG', 'IAG', 'QS', 'CX', 'NIO', 'NMR', 'GRAB', 'WBD', 'B', 'VALE', 'UWMC', 'FPE', 'IAUM', 'U', 'ORCL', 'IBIT', 'GLD', 'NVDA', 'GOOG', 'APP', 'QQQ', 'SPY', 'VGT', 'META', 'MSTR']

# %% [markdown]
# ### Load df_finviz

# %%
finviz_file_path = r'C:\Users\ping\Files_win10\python\py311\stocks\data\2025-09-23_df_finviz_merged_stocks_etfs.parquet'

# %%
finviz_file_path = r'C:\Users\ping\Files_win10\python\py311\stocks\data\2025-09-23_df_finviz_merged_stocks_etfs.parquet'
df_finviz = pd.read_parquet(finviz_file_path, engine='pyarrow')

print(f'df_finviz :\n{df_finviz }')
# Out:
# df_finviz :
#        No.                                        Company               Index                  Sector                        Industry Country Exchange                                               Info  MktCap AUM, M  Rank  Market Cap, M    P/E  Fwd P/E   PEG    P/S    P/B    P/C  P/FCF  Book/sh  Cash/sh  Dividend %  Dividend TTM Dividend Ex Date  Payout Ratio %    EPS  EPS next Q  EPS this Y %  EPS next Y %  EPS past 5Y %  EPS next 5Y %  Sales past 5Y %  Sales Q/Q %  EPS Q/Q %  EPS YoY TTM %  Sales YoY TTM %  Sales, M  Income, M  EPS Surprise %  Revenue Surprise %  Outstanding, M  Float, M  Float %  Insider Own %  Insider Trans %  Inst Own %  Inst Trans %  Short Float %  Short Ratio  Short Interest, M  ROA %   ROE %  ROIC %  Curr R  Quick R  LTDebt/Eq  Debt/Eq  Gross M %  Oper M %  Profit M %  Perf 3D %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  Perf YTD %  Beta   ATR  ATR/Price %  Volatility W %  Volatility M %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %        52W Range  All-Time High %  All-Time Low %    RSI  Earnings    IPO Date Optionable Shortable  Employees  Change from Open %  Gap %  Recom  Avg Volume, M  Rel Volume     Volume  Target Price  Prev Close    Open    High     Low   Price  Change %                            Single Category         Asset Type  Expense %  Holdings  AUM, M  Flows 1M, M  Flows% 1M  Flows 3M, M  Flows% 3M  Flows YTD, M  Flows% YTD  Return% 1Y  Return% 3Y  Return% 5Y                                               Tags  Sharpe 3d    Sortino 3d     Omega 3d  Sharpe 5d  Sortino 5d  Omega 5d  Sharpe 10d  Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# NVDA     1                                    NVIDIA Corp  DJIA, NDX, S&P 500              Technology                  Semiconductors     USA     NASD                         Technology, Semiconductors      4335850.0     1      4335850.0  50.78    27.96  1.45  26.24  43.39  76.35  60.20     4.11     2.34        0.02          0.04        9/11/2025            1.16   3.51        1.24           NaN           NaN            NaN            NaN              NaN        55.60      61.23          64.54            71.55  165220.0    86600.0            4.13                1.51         24350.0   23310.0    95.73           4.08            -0.95       67.97          1.74           0.84         1.12             196.70  76.65  109.42   78.42    4.21     3.60       0.10     0.11      69.85     58.09       52.41   1.242624         2.03          0.25         20.64        46.96        51.38       32.87  2.12  5.34     2.992770            3.21            2.60     1.75     1.26     26.26       -3.32      10.13       -3.32     105.99   86.62 - 184.55            -3.32       535189.95  53.68  Aug 27/a   1/22/1999        Yes       Yes    36000.0               -1.96  -0.88   1.33      175.89000        1.08  190712133        217.22      183.61  182.00  182.42  176.21  178.43     -2.82                                                                      NaN       NaN     NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   1.788306      4.254403     1.379012   6.021997   13.377352  2.685388    0.523666     0.887935   1.097172    2.271182     3.904146   1.461691   -0.716526    -1.012771   0.884367    1.814037     2.830641   1.347423     2.319134      4.057989    1.571838     0.961512      1.378887    1.189376
# MSFT     2                          Microsoft Corporation  DJIA, NDX, S&P 500              Technology       Software - Infrastructure     USA     NASD              Technology, Software - Infrastructure      3785190.0     2      3785190.0  37.33    27.83  2.24  13.44  11.02  40.03  52.86    46.20    12.72        0.69          3.32       11/20/2025           24.34  13.64        3.65           NaN           NaN            NaN            NaN              NaN        18.10      23.77          15.50            14.93  281720.0   101830.0            8.16                3.40          7430.0    7320.0    98.51           1.48            -0.26       73.28         -0.34           0.80         2.83              58.49  18.00   33.28   22.93    1.35     1.35       0.29     0.33      68.82     45.62       36.15   0.153407         0.04          0.39          3.90        29.55        16.08       20.81  1.02  7.68     1.508159            1.27            1.41     0.53    -0.54     13.36       -8.32       3.42       -8.32      47.69  344.79 - 555.45            -8.32       639004.80  50.39  Jul 30/a   3/13/1986        Yes       Yes   228000.0               -0.87  -0.15   1.20       20.66000        0.96   19772199        624.36      514.45  513.69  514.59  507.31  509.23     -1.01                                                                      NaN       NaN     NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  - -56.271420    -15.567793     0.000000  -0.591745   -1.198826  0.905283    2.560823     4.942880   1.507434    0.607505     0.860209   1.108345   -2.265225    -2.883677   0.689563    0.481714     0.774186   1.088460     2.314678      4.785886    1.630504     0.689868      1.070522    1.144069
# AAPL     3                                      Apple Inc  DJIA, NDX, S&P 500              Technology            Consumer Electronics     USA     NASD                   Technology, Consumer Electronics      3775840.0     3      3775840.0  38.68    31.78  4.26   9.24  57.42  68.19  39.26     4.43     3.73        0.40          1.02        8/11/2025           16.11   6.58        1.76           NaN           NaN            NaN            NaN              NaN         9.63      12.19           0.15             5.97  408620.0    99280.0            9.18                4.99         14860.0   14820.0    99.79           0.10            -2.09       64.53          1.20           0.77         1.99             113.58  29.94  149.81   66.96    0.87     0.83       1.25     1.54      46.68     31.87       24.30   6.957289         6.84         11.71         27.02        15.27        11.17        1.60  1.10  5.17     2.031993            2.07            1.81     7.29    12.71     14.71       -0.86      26.27       -2.18      50.36  169.21 - 260.10            -2.18       399846.50  72.28  Jul 31/a  12/12/1980        Yes       Yes   164000.0               -0.59  -0.05   2.04       56.99000        1.06   60202976        246.92      256.08  255.94  257.34  253.58  254.43     -0.64                                                                      NaN       NaN     NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   8.233085     61.777818     6.503605   9.943792   61.641486  6.559335   12.498562    74.760438  11.113765    3.894121     7.367128   1.969564    3.460851     6.709068   1.847470    3.622067     7.471808   1.948539     0.781162      1.243348    1.178108     0.401158      0.597866    1.082453
# GOOG     4                                   Alphabet Inc        NDX, S&P 500  Communication Services  Internet Content & Information     USA     NASD  Communication Services, Internet Content & Inf...      3049470.0     4      3049470.0  26.88    23.62  1.81   8.21   8.42  32.05  45.70    29.98     7.87        0.23          0.82         9/8/2025            7.46   9.39        2.32           NaN           NaN            NaN            NaN              NaN        14.06      22.28          34.52            13.19  371210.0   115570.0            5.82                2.54          5440.0    5040.0    92.67          58.32             0.01       26.82         -1.75           0.62         1.24              31.06  25.21   34.83   28.86    1.90     1.90       0.10     0.11      58.92     32.65       31.13   0.003963         0.37         22.07         50.44        48.50        54.58       32.50  1.01  5.34     2.116192            1.86            2.11     7.05    18.89     36.16       -1.70      39.64       -1.70      76.88  142.66 - 256.70            -1.70          937.96  79.89  Jul 23/a   3/27/2014        Yes       Yes   183323.0               -0.53   0.32   1.49       25.13000        0.69   17300658        240.41      252.88  253.69  254.77  251.09  252.34     -0.21                                                                      NaN       NaN     NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  - -18.467913    -13.565318     0.000000   3.771183    7.741512  1.807069    5.863000    23.346265   3.633173    7.279999    30.237621   4.534829    5.822675    28.320206   4.171869    5.734150    17.249650   3.334411     3.017409      5.387148    1.747348     1.426088      2.194911    1.283352
# GOOGL    5                                   Alphabet Inc        NDX, S&P 500  Communication Services  Internet Content & Information     USA     NASD  Communication Services, Internet Content & Inf...      3045470.0     5      3045470.0  26.81    23.55  1.81   8.20   8.39  32.01  45.64    29.98     7.86        0.21          0.82         9/8/2025            7.46   9.39        2.32           NaN           NaN            NaN            NaN              NaN        14.06      22.28          34.52            13.19  371210.0   115570.0            5.83                2.54          5820.0    5800.0    99.73          52.04             0.02       38.39         -1.74           0.96         1.44              55.47  25.21   34.83   28.86    1.90     1.90       0.10     0.11      58.92     32.65       31.13  -0.146808         0.20         22.11         50.90        50.08        55.21       32.94  1.01  5.37     2.133831            1.85            2.12     6.96    18.96     36.81       -1.70      40.06       -1.70      79.08  140.53 - 256.00            -1.70        10380.05  79.20  Jul 23/a   8/19/2004        Yes       Yes   183323.0               -0.55   0.21   1.49       38.63000        0.69   26575081        241.05      252.53  253.06  254.36  250.48  251.66     -0.34                                                                      NaN       NaN     NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  - -26.927241    -14.652370     0.000000   3.284164    6.717967  1.648403    5.529111    22.839029   3.416514    7.022525    29.939299   4.310287    5.752719    27.727649   4.061639    5.723078    17.406149   3.315833     3.041956      5.465891    1.746737     1.430254      2.204154    1.283779
# ...    ...                                            ...                 ...                     ...                             ...     ...      ...                                                ...            ...   ...            ...    ...      ...   ...    ...    ...    ...    ...      ...      ...         ...           ...              ...             ...    ...         ...           ...           ...            ...            ...              ...          ...        ...            ...              ...       ...        ...             ...                 ...             ...       ...      ...            ...              ...         ...           ...            ...          ...                ...    ...     ...     ...     ...      ...        ...      ...        ...       ...         ...        ...          ...           ...           ...          ...          ...         ...   ...   ...          ...             ...             ...      ...      ...       ...         ...        ...         ...        ...              ...              ...             ...    ...       ...         ...        ...       ...        ...                 ...    ...    ...            ...         ...        ...           ...         ...     ...     ...     ...     ...       ...                                        ...                ...        ...       ...     ...          ...        ...          ...        ...           ...         ...         ...         ...         ...                                                ...        ...           ...          ...        ...         ...       ...         ...          ...        ...         ...          ...        ...         ...          ...        ...         ...          ...        ...          ...           ...         ...          ...           ...         ...
# BILS   395           SPDR Bloomberg 3-12 Month T-Bill ETF                   -               Financial            Exchange Traded Fund     USA     NYSE  Financial, Exchange Traded Fund, Bonds - Treas...         3860.0  1555            NaN    NaN      NaN   NaN    NaN    NaN    NaN    NaN      NaN      NaN        4.31          4.29         9/2/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN       NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         0.11               0.05    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.060362         0.09          0.04          0.10         0.05         0.03        0.31  0.01  0.03     0.030163            0.01            0.01     0.10     0.13      0.17       -0.05       0.32       -0.14       0.47    98.99 - 99.60            -0.66            0.58  64.87         -   9/24/2020        Yes       Yes        NaN                0.01   0.00    NaN        0.43148        0.69     296980           NaN       99.45   99.45   99.46   99.45   99.46      0.01              Bonds - Treasury & Government              Bonds       0.14      25.0  3860.0        19.87       0.52       -39.84      -1.02        595.17       18.21        4.09        4.61         NaN              U.S., fixed-income, treasuries, bonds  -1.758701     -3.040953     0.729090   2.851186    6.679717  1.595077    1.417423     2.277013   1.242834    2.678552     5.841274   1.617917    2.512958     4.668119   1.514116    1.860218     4.034487   1.412313     1.134449      1.969716    1.213285     1.184811      1.987452    1.215904
# REET   396                        iShares Global REIT ETF                   -               Financial            Exchange Traded Fund     USA     NYSE  Financial, Exchange Traded Fund, Global or ExU...         3850.0  1556            NaN    NaN      NaN   NaN    NaN    NaN    NaN    NaN      NaN      NaN        3.73          0.95        9/16/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN       NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         1.55               2.13    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.196386        -0.04          0.31          1.76         4.81        -5.45        6.42  1.00  0.24     0.940808            0.89            0.81     0.06     1.52      3.89       -1.85       5.07       -6.16      21.71    20.96 - 27.18           -17.12           63.32  53.77         -   7/10/2014        Yes       Yes        NaN                0.28   0.28    NaN        1.37000        1.78    2451694           NaN       25.37   25.44   25.55   25.39   25.51      0.55  Global or ExUS Equities - Industry Sector  Equities (Stocks)       0.14     361.0  3850.0      -113.60      -2.87      -167.11      -4.16        -58.84       -1.51       -1.93        5.50        5.93                 Global, equity, real-estate, REITs  19.320188  21068.548290  1877.935460   2.637458    4.417427  1.556544    1.901899     4.355567   1.415403    3.825275     9.520448   1.969149    2.634179     4.428816   1.544469    1.179341     1.766843   1.209704     0.552866      0.788392    1.111631    -0.242539     -0.328981    0.957834
# IXJ    397                  iShares Global Healthcare ETF                   -               Financial            Exchange Traded Fund     USA     NYSE  Financial, Exchange Traded Fund, Global or ExU...         3830.0  1557            NaN    NaN      NaN   NaN    NaN    NaN    NaN    NaN      NaN      NaN        1.57          1.38        6/16/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN       NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         0.26               0.04    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN  -0.227661         0.10         -0.75          2.29        -4.90       -11.85        1.95  0.64  0.79     0.901312            0.71            0.83    -0.22     1.44     -0.17       -1.87       6.68      -11.30       8.64    80.68 - 98.82           -13.48          509.06  52.17         -  11/21/2001        Yes       Yes        NaN                0.10  -0.23    NaN        0.16013        0.94     151297           NaN       87.76   87.56   87.98   87.46   87.65     -0.13  Global or ExUS Equities - Industry Sector  Equities (Stocks)       0.40     137.0  3830.0          NaN       0.00          NaN       0.00        101.84        2.73      -10.75        4.53        5.09                         Global, equity, healthcare  -8.646609     -9.768517     0.129751  -0.880304   -1.534563  0.863190   -0.846177    -1.287692   0.847146   -0.269056    -0.391268   0.951433    2.987199     5.089568   1.696321    0.320662     0.456001   1.054813    -0.297658     -0.392097    0.949688    -0.793299     -1.045134    0.873339
# RECS   398            Columbia Research Enhanced Core ETF                   -               Financial            Exchange Traded Fund     USA     NYSE  Financial, Exchange Traded Fund, US Equities -...         3810.0  1558            NaN    NaN      NaN   NaN    NaN    NaN    NaN    NaN      NaN      NaN        0.94          0.38       12/18/2024             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN       NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         0.25               0.15    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.881612         1.44          2.51         11.03        17.52        18.67       15.68  0.95  0.32     0.799001            0.87            0.69     1.72     3.67     12.37       -0.45       8.68       -0.45      39.84    28.64 - 40.23            -0.45          210.21  67.72         -   9/25/2019         No       Yes        NaN               -0.40  -0.02    NaN        0.60043        1.03     620060           NaN       40.22   40.21   40.32   39.96   40.05     -0.42            US Equities - Factor & Thematic  Equities (Stocks)       0.15     375.0  3810.0       165.03       4.52       502.66      15.19       1770.00       86.21       21.25       21.68       17.33  U.S., equity, value, growth, mid-large-cap, Ru...   3.348351      9.543469     1.850200  10.530802   26.766980  4.372322    6.848381    17.969121   2.830836    5.896579    13.996697   2.531929    2.901928     5.630137   1.600993    3.394512     6.198438   1.718678     1.579209      2.472356    1.426267     0.854157      1.267281    1.192245
# EMLC   399  VanEck J.P. Morgan EM Local Currency Bond ETF                   -               Financial            Exchange Traded Fund     USA     NYSE  Financial, Exchange Traded Fund, Bonds - Treas...         3810.0  1559            NaN    NaN      NaN   NaN    NaN    NaN    NaN    NaN      NaN      NaN        5.40          1.38         9/2/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN       NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         1.29               3.32    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.156250        -0.19          0.94          2.27         7.46         1.96       10.95  0.38  0.11     0.429017            0.35            0.33     0.81     1.42      5.25       -0.60       3.18       -0.60      11.76    22.94 - 25.80           -54.15           15.21  63.66         -   7/23/2010        Yes       Yes        NaN               -0.04   0.04    NaN        2.57000        0.84    2167807           NaN       25.64   25.65   25.66   25.61   25.64      0.00              Bonds - Treasury & Government              Bonds       0.30     508.0  3810.0        73.42       1.97       403.33      11.84        929.08       32.26        7.99        8.83        1.17      Emerging, fixed-income, currency-bonds, bonds   8.182945     60.389561     6.379930  -4.213364   -4.943041  0.408813    6.080195    15.072944   2.940574    7.205240    20.562207   3.707698    2.466519     4.317215   1.485487    1.416219     2.154641   1.261683     2.499144      3.800063    1.555178     0.461076      0.673553    1.082314
#
# [1470 rows x 139 columns]

# %%
print(df_finviz.loc[plotted_tickers])
# Out:
#        No.                                          Company               Index                  Sector                          Industry         Country Exchange                                               Info  MktCap AUM, M  Rank  Market Cap, M     P/E  Fwd P/E    PEG     P/S     P/B      P/C   P/FCF  Book/sh  Cash/sh  Dividend %  Dividend TTM Dividend Ex Date  Payout Ratio %    EPS  EPS next Q  EPS this Y %  EPS next Y %  EPS past 5Y %  EPS next 5Y %  Sales past 5Y %  Sales Q/Q %  EPS Q/Q %  EPS YoY TTM %  Sales YoY TTM %   Sales, M  Income, M  EPS Surprise %  Revenue Surprise %  Outstanding, M  Float, M  Float %  Insider Own %  Insider Trans %  Inst Own %  Inst Trans %  Short Float %  Short Ratio  Short Interest, M  ROA %   ROE %  ROIC %  Curr R  Quick R  LTDebt/Eq  Debt/Eq  Gross M %  Oper M %  Profit M %  Perf 3D %  Perf Week %  Perf Month %  Perf Quart %  Perf Half %  Perf Year %  Perf YTD %  Beta    ATR  ATR/Price %  Volatility W %  Volatility M %  SMA20 %  SMA50 %  SMA200 %  50D High %  50D Low %  52W High %  52W Low %        52W Range  All-Time High %  All-Time Low %    RSI  Earnings    IPO Date Optionable Shortable  Employees  Change from Open %  Gap %  Recom  Avg Volume, M  Rel Volume     Volume  Target Price  Prev Close    Open    High     Low   Price  Change %                          Single Category            Asset Type  Expense %  Holdings    AUM, M  Flows 1M, M  Flows% 1M  Flows 3M, M  Flows% 3M  Flows YTD, M  Flows% YTD  Return% 1Y  Return% 3Y  Return% 5Y                                               Tags   Sharpe 3d    Sortino 3d     Omega 3d  Sharpe 5d    Sortino 5d     Omega 5d  Sharpe 10d  Sortino 10d  Omega 10d  Sharpe 15d  Sortino 15d  Omega 15d  Sharpe 30d  Sortino 30d  Omega 30d  Sharpe 60d  Sortino 60d  Omega 60d  Sharpe 120d  Sortino 120d  Omega 120d  Sharpe 250d  Sortino 250d  Omega 250d
# BBD    629                          Banco Bradesco S.A. ADR                   -               Financial                  Banks - Regional             USA     NYSE                        Financial, Banks - Regional        17980.0   754        17980.0    9.92     7.05   0.53    0.32    1.12      NaN    0.58     3.02      NaN        7.18          0.11        10/1/2025           10.40   0.34        0.11           NaN           NaN            NaN            NaN              NaN        12.12      35.48          39.03            -4.58   56950.00    3620.00            7.96                3.18         5300.00   5300.00   100.00           0.00              NaN       21.12           NaN           0.30         0.46              16.13   0.96   11.76    4.31    0.39      NaN       1.63     4.12        NaN      8.45        6.35   3.669725         5.61         13.76         11.88        55.90        29.83       86.69  0.77   0.08     2.359882            2.61            2.21     7.26    13.42     36.48        1.50      24.18        1.50      93.79      1.75 - 3.34           -41.44         2428.87  71.90  Jul 30/a  11/21/2001        Yes       Yes    84022.0                2.11   0.00   1.00       35.43000        2.95  104528142          4.10        3.32    3.32    3.41    3.32    3.39      2.11                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    8.278166     63.066357     6.618398   5.805629     14.883048     2.539134    9.969243    27.543458   4.304593    8.322953    24.524630   3.593023    3.344993     5.215068   1.753551    1.745422     2.670621   1.348521     2.427898      5.159211    1.675534     1.043418      1.743510    1.214364
# LYG    228                     Lloyds Banking Group plc ADR                   -               Financial                  Banks - Regional  United Kingdom     NYSE                        Financial, Banks - Regional        66560.0   259        66560.0     NaN     8.57    NaN    2.08    1.21      NaN     NaN     3.69      NaN        4.29          0.17         8/4/2025           48.42    NaN        0.12           NaN           NaN            NaN            NaN              NaN        10.63      27.96          -5.74             0.76   32050.00    5260.00            7.56               -1.12        14980.00  14890.00    99.38           0.00              NaN        4.50          0.00           0.04         0.68               6.11   0.44   10.06    2.88    2.76      NaN       2.30     3.30        NaN     24.93       16.42  -2.401747        -1.97         -2.83          6.18        17.32        44.19       64.34  1.06   0.07     1.565996            1.21            1.18     0.24     1.50     18.57       -3.46      10.37       -3.46      74.61      2.56 - 4.63           -83.99          282.05  50.52  Jul 24/b  11/27/2001        Yes       Yes    61228.0               -0.67   0.67   1.79        8.97000        0.42    3723023          5.00        4.47    4.50    4.52    4.45    4.47      0.00                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   10.432097    295.380728    27.314607  -5.750427     -6.211286     0.221767   -0.338949    -0.458640   0.936195    3.341369     5.142430   1.787448   -0.659698    -0.855514   0.894718    1.081211     1.522737   1.192608     1.382997      2.016050    1.283651     1.318634      1.959582    1.262334
# SAN     90                         Banco Santander S.A. ADR                   -               Financial               Banks - Diversified           Spain     NYSE                     Financial, Banks - Diversified       152420.0    98       152420.0   11.19     9.33   0.71    1.23    1.29      NaN     NaN     7.93      NaN        2.65          0.23        4/30/2025           20.18   0.92        0.26           NaN           NaN            NaN            NaN              NaN       -54.20      21.55          17.03           -14.74  123450.00   14530.00           -1.79               -2.21        14870.00  14870.00   100.00           0.00              NaN        2.85          1.53           0.06         1.70               8.83   0.70   12.85    2.36    1.90      NaN       4.22     4.22        NaN     16.53       11.77   1.485149         2.40          4.70         23.94        46.64       100.20      124.78  1.03   0.17     1.658537            1.22            1.26     4.21     9.67     41.81       -0.39      23.79       -0.39     131.38     4.43 - 10.29           -46.70          509.72  67.35  Jul 31/b   7/30/1987        Yes       Yes   206753.0                0.29   0.79   1.92        5.19000        0.82    4281515          9.86       10.14   10.22   10.33   10.20   10.25      1.08                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    0.416594      0.865302     1.077087   6.504821     13.826605     2.741989    5.151493     9.132272   2.102686    8.676088    19.671595   3.580455    3.589973     6.443536   1.760120    3.484170     5.903781   1.735329     2.634816      3.929716    1.610506     2.293723      3.525952    1.506730
# SBSW  1103                   Sibanye Stillwater Limited ADR                   -         Basic Materials    Other Precious Metals & Mining    South Africa     NYSE    Basic Materials, Other Precious Metals & Mining         7300.0  1369         7300.0     NaN    10.00    NaN    1.19    3.21     6.17     NaN     3.21     1.67        0.93           NaN        9/21/2023             NaN  -0.27        0.00           NaN           NaN            NaN            NaN              NaN         1.07      51.04          93.14             6.27    6150.00    -193.18          222.92                4.22          707.64    706.22    99.80           0.20             0.00       23.82         86.33           2.19         1.85              15.48  -2.49   -8.31   -4.15    2.89     1.53       1.05     1.06      13.55     10.31       -3.14  18.098511        19.61         23.77         49.20       138.11       143.74      212.42  0.72   0.43     4.170708            4.32            3.56    19.27    18.65     80.48        2.28      45.31        2.28     238.03     3.05 - 10.08           -50.15          524.99  70.39  Aug 28/b   2/11/2013        Yes       Yes    72423.0                0.39   1.99   3.14        8.37000        1.39   11602934          9.33       10.07   10.27   10.57   10.25   10.31      2.38                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   27.979380  21068.548290  1877.935460  22.796094  64246.067899  8095.243732    9.214122    39.650543   6.450559    5.213065    10.106807   2.354799    2.395951     3.898249   1.476598    2.794539     4.554062   1.593427     2.693437      4.409531    1.625464     1.546635      2.447195    1.300418
# EBR    608          Centrais Eletricas Brasileiras S.A. ADR                   -               Utilities             Utilities - Renewable          Brazil     NYSE                   Utilities, Utilities - Renewable        19030.0   729        19030.0   18.67    13.02   0.89    2.49    1.06     3.48    7.46     9.09     2.77        3.80          0.62        8/18/2025           32.73   0.52        0.09           NaN           NaN            NaN            NaN              NaN        11.75    -172.73          37.23             6.41    7630.00    1190.00          -21.48                5.24         1980.00       NaN      NaN            NaN              NaN        1.35          3.69            NaN         1.44               2.26   2.40    6.01    3.80    1.86     1.85       0.54     0.66      44.56     35.25       15.65   4.560261         6.29         22.68         31.38        33.56        25.55       68.36  0.61   0.22     2.284528            2.40            1.99    11.34    21.90     36.20        0.84      43.52        0.84      76.62      5.45 - 9.55           -47.79          761.13  77.47  Aug 06/a  10/17/2003         No       Yes     7710.0                2.45   0.32   1.00        1.56000        1.06    1663299         10.62        9.37    9.40    9.63    9.37    9.63      2.77                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    2.067511      5.068601     1.451547   7.222213     19.321618     3.434295   11.871012    35.316577   7.674206   11.095537    29.397231   5.947214    3.744062     5.888321   1.782265    3.203268     6.419393   1.774340     2.169686      3.749612    1.446875     1.081174      1.667718    1.198314
# MFG    176                 Mizuho Financial Group, Inc. ADR                   -               Financial                  Banks - Regional           Japan     NYSE                        Financial, Banks - Regional        84230.0   200        84230.0   14.26    10.79   1.23    1.51    1.15      NaN     NaN     5.84      NaN        2.93          0.09        3/31/2025           36.44   0.47        0.14           NaN           NaN            NaN            NaN              NaN        -5.59       9.49          24.37            -2.22   55710.00    5960.00           14.74                6.81        12500.00  12500.00   100.00           0.00              NaN        1.53          0.42           0.02         1.09               3.08   0.32    8.69    3.05    2.03      NaN       1.68     5.65        NaN     13.12       10.70   2.431611         2.59          2.12         20.36        14.04        66.42       37.83  0.38   0.12     1.780415            1.28            1.27     2.01     6.79     21.29       -0.74      23.78       -0.74      69.77      3.97 - 6.79           -56.09          244.76  61.26  Jul 31/a   11/8/2006        Yes       Yes    52554.0               -0.74   0.59   1.73        2.83000        0.46    1290211          6.99        6.75    6.79    6.81    6.73    6.74     -0.15                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    9.184681    101.061832    10.003304  13.509900    128.804934    17.227896    0.559920     0.844206   1.096201    4.693891     9.750924   2.132367    1.754120     2.930630   1.306870    3.073203     5.384417   1.708176     1.252257      1.669790    1.289011     1.610151      2.308118    1.344634
# HL    1078                                  Hecla Mining Co                 RUT         Basic Materials    Other Precious Metals & Mining             USA     NYSE    Basic Materials, Other Precious Metals & Mining         7480.0  1337         7480.0   71.37    24.28   1.29    7.06    3.21    25.24   81.89     3.48     0.44        0.18          0.03        8/22/2025           70.67   0.16        0.09           NaN           NaN            NaN            NaN              NaN        23.76     101.79         317.43            36.30    1060.00      99.71           40.85               17.03          663.07    620.30    93.55           7.42             0.00       63.57          2.53           3.47         0.85              21.51   3.21    4.67    3.51    2.67     1.99       0.23     0.25      26.47     22.90        9.41   3.714020        -1.59         41.57         92.59        90.29        67.22      127.49  1.30   0.48     4.297225            5.01            4.67    11.54    38.93     81.36       -6.13      98.75       -6.13     150.45     4.46 - 11.90           -57.74         2150.59  72.35  Aug 06/a    7/2/1962        Yes       Yes     1830.0               -0.53   0.00   2.11       25.27000        1.09   27491357          8.86       11.23   11.23   11.57   11.09   11.17     -0.53                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    7.104941     38.714638     4.448974   2.291349      4.146763     1.435367    1.253161     2.037964   1.213031    6.059600    18.249260   3.136740    6.358862    16.796606   3.350604    4.474533    10.346162   2.419434     2.498814      4.101566    1.608351     1.027682      1.564621    1.205956
# CDE    828                                 Coeur Mining Inc                 RUT         Basic Materials                              Gold             USA     NYSE                              Basic Materials, Gold        11590.0  1009        11590.0   46.23    20.68   0.54    7.94    4.10   103.79   46.55     4.40     0.17         NaN           NaN                -            0.00   0.39        0.21           NaN           NaN            NaN            NaN              NaN       133.39    2955.56         298.99            68.88    1460.00     190.67           12.36                4.52          642.70    631.53    98.26           1.74            -5.27       76.75          3.74           2.65         1.23              16.73   6.06    9.88    6.00    1.61     0.60       0.12     0.14      30.04     26.21       13.07  10.749386        10.82         49.38        102.13       188.02       160.93      215.21  1.22   0.73     4.048808            5.76            4.73    20.04    47.95    120.78       -1.53     110.51       -1.53     293.67     4.58 - 18.31           -94.99         1012.96  82.02  Aug 06/a   11/1/1982        Yes       Yes     2116.0               -0.06   0.95   1.11       13.62000        1.48   20197023         13.64       17.87   18.04   18.43   17.92   18.03      0.90                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   22.922665  21068.548290  1877.935460  17.762396  64246.067899  8095.243732    8.670004    24.190062   4.482200    8.594136    24.185940   4.305959    8.126013    18.514913   3.886039    5.899766    12.915622   2.890482     3.893017      8.577772    2.136306     1.630731      2.812444    1.335743
# EQX   1014                                Equinox Gold Corp                   -         Basic Materials                              Gold          Canada     AMEX                              Basic Materials, Gold         8400.0  1243         8400.0     NaN     9.96    NaN    4.41    1.54    19.52  285.86     6.97     0.55         NaN           NaN                -            0.00  -0.06        0.14           NaN           NaN            NaN            NaN              NaN        77.65     -92.17        -108.99            74.31    1910.00     -23.03          280.62               -1.65          759.01    732.36    96.49           6.32             0.00       54.52         36.14           2.82         1.31              20.65  -0.28   -0.54   -0.34    0.94     0.53       0.29     0.34      23.28     17.68       -1.21   3.365385         1.80         34.04         84.39        58.79        75.08      114.14  1.13   0.40     3.720930            3.89            4.02     8.99    34.13     59.79       -3.20      79.02       -3.20     117.17     4.95 - 11.10           -64.16          357.45  71.06  Aug 13/a   9/19/2013        Yes       Yes        NaN               -2.80   1.10   1.44       15.75000        0.90   14146117          9.88       10.94   11.06   11.15   10.68   10.75     -1.74                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   -1.747547     -3.024264     0.730577   5.640447     15.135577     2.889866    0.139671     0.214679   1.021189    5.322718    14.399363   2.594554    6.497389    19.092393   3.757506    5.602131    14.614497   3.059603     2.144935      3.597571    1.457677     1.177317      1.880979    1.222556
# AEG    791                                        Aegon Ltd                   -               Financial           Insurance - Diversified     Netherlands     NYSE                 Financial, Insurance - Diversified        12570.0   962        12570.0    8.86     7.74   0.20    0.52    1.16      NaN   15.54     6.90      NaN        5.90          0.44         9/4/2025           74.20   0.91         NaN           NaN           NaN            NaN            NaN              NaN       -32.54     -82.58        3071.48            -6.19   24370.00    1440.00          181.55                 NaN         1960.00   1570.00    79.76           0.00              NaN       12.67        -11.19           0.41         1.16               6.35   0.41   14.42    9.06    4.14      NaN       0.46     0.46        NaN      6.14        5.90   4.557292         4.42          0.88         16.38        20.21        27.87       36.33  0.98   0.13     1.618929            1.13            1.02     3.79     7.36     18.82       -0.86      17.40       -0.86      48.15      5.42 - 8.10           -87.16          592.43  65.89  Aug 21/b   6/28/1985        Yes       Yes    15582.0               -0.37   1.90   1.93        5.45000        0.80    4386647          8.12        7.91    8.06    8.15    8.00    8.03      1.52                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -  304.302920  21068.548290  1877.935460  18.780058    119.991649    16.117527    6.888896    11.513221   2.946853    2.279315     3.047212   1.462451    2.282422     4.709583   1.610231    1.704339     2.883274   1.359699     1.500152      2.238206    1.329613     0.911477      1.245958    1.184149
# IAG   1132                                     Iamgold Corp                   -         Basic Materials                              Gold          Canada     NYSE                              Basic Materials, Gold         6910.0  1403         6910.0    8.68     9.26   0.31    3.47    2.01    30.72     NaN     5.97     0.39         NaN           NaN         7/1/2013            0.00   1.38        0.27           NaN           NaN            NaN            NaN              NaN        48.42     -14.89         460.89            59.15    1990.00     806.10           -6.00                4.25          575.10    556.20    96.71           3.29             0.00       65.33          0.38           2.43         1.02              13.54  15.48   26.28   17.55    1.47     0.76       0.34     0.35      31.69     29.34       40.44   9.082652         9.08         36.94         65.66       102.19       126.18      132.75  1.23   0.43     3.580350            4.14            3.92    15.59    38.28     72.86       -0.50      79.52       -0.50     170.50     4.44 - 12.07           -49.71         1205.29  82.11  Aug 07/a   12/2/2002        Yes       Yes        NaN               -1.40   1.75   1.83       13.33000        1.38   18395909         10.83       11.97   12.18   12.32   11.98   12.01      0.33                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   12.593521  21068.548290  1877.935460  12.949346    347.851737    44.825200    6.948543    14.638844   3.623886    8.798079    28.021677   5.908496    8.504644    20.798556   4.446846    4.747978     8.600935   2.251703     2.514097      3.871017    1.549337     1.608537      2.463120    1.322399
# QS    1067                                QuantumScape Corp                   -       Consumer Cyclical                        Auto Parts             USA     NYSE                      Consumer Cyclical, Auto Parts         7660.0  1322         7660.0     NaN      NaN    NaN     NaN    7.46     9.60     NaN     1.81     1.41         NaN           NaN                -             NaN  -0.87       -0.20           NaN           NaN            NaN            NaN              NaN          NaN      16.79           9.21              NaN       0.00    -463.36            5.21                 NaN          522.08    407.34    78.02          28.04            -2.79       27.89          7.15          13.48         1.12              54.89 -36.13  -42.03  -41.94   16.40    16.40       0.08     0.09        NaN       NaN         NaN  11.541632        33.30         65.81        212.47       190.34       128.16      160.69  4.89   1.00     7.390983           12.14            8.80    41.04    38.09    121.99       -9.98      82.84       -9.98     297.94     3.40 - 15.03           -89.81          297.94  76.41  Jul 23/a   8/17/2020        Yes       Yes      800.0                0.52   0.15   3.50       48.81000        0.89   43335116          6.36       13.44   13.46   14.17   13.05   13.53      0.67                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   16.967057  21068.548290  1877.935460  13.555499  64246.067899  8095.243732   13.329096   132.440254  26.028855    8.040587    24.093329   4.795734    3.417009     7.813187   1.996529    3.046645     5.619402   1.699906     2.631020      5.268580    1.686060     1.300835      2.463102    1.293344
# CX     747                         Cemex S.A.B. De C.V. ADR                   -         Basic Materials                Building Materials          Mexico     NYSE                Basic Materials, Building Materials        13820.0   903        13820.0    8.90    12.60   1.74    0.88    0.99    11.86   30.00     9.22     0.77        1.27          0.09        9/17/2025           13.35   1.03        0.18           NaN           NaN            NaN            NaN              NaN        -6.12      40.86         795.20            -9.62   15720.00    1510.00           13.25               -2.04         1510.00   1510.00   100.00           0.00              NaN       33.52         16.58           1.25         1.60              18.92   3.15    7.12    9.34    0.86     0.61       0.21     0.23      31.04     10.12        9.60  -1.931330        -4.29          2.70         31.70        50.83        43.71       62.06  1.52   0.23     2.516411            2.80            2.41    -1.30     4.84     33.93       -4.94      26.24       -4.94      86.91      4.89 - 9.61           -67.42          489.68  51.86  Jul 24/b   9/15/1999        Yes       Yes    44494.0               -0.98   0.11   1.85       11.83000        0.74    8792490          9.93        9.22    9.23    9.41    9.11    9.14     -0.87                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    3.358294      9.583908     1.853802  -6.900292     -8.067983     0.343800   -0.399944    -0.650320   0.939847   -0.149747    -0.227935   0.978105    1.528962     2.322172   1.268752    4.566971     8.042395   2.043553     3.224845      5.037873    1.707500     1.039837      1.588355    1.202922
# NIO    754                                      NIO Inc ADR                   -       Consumer Cyclical                Auto Manufacturers           China     NYSE              Consumer Cyclical, Auto Manufacturers        13470.0   913        13470.0     NaN      NaN    NaN    1.40     NaN     3.57     NaN    -0.07     1.94         NaN           NaN                -             NaN  -1.60       -0.22           NaN           NaN            NaN            NaN              NaN         9.10       7.70          -5.91             9.60    9630.00   -3367.15           16.63                0.86         2100.00   1940.00    92.68           0.04             0.00        8.94        -11.21           9.85         2.47             191.37 -24.23 -329.46 -116.40    0.84     0.69        NaN      NaN      10.28    -33.62      -34.97  -5.970149        -1.28          9.31         98.00        58.22        28.33       58.94  1.28   0.42     6.060606            5.81            5.95     5.87    25.70     55.69       -8.82      75.00      -10.12     129.47      3.02 - 7.71           -89.66          482.35  60.41  Sep 02/b   9/12/2018        Yes       Yes    45635.0                0.87  -0.58   1.97       77.53000        1.01   78399791          7.22        6.91    6.87    7.17    6.77    6.93      0.29                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -  -10.284610    -10.734235     0.043718  -9.233741     -8.859263     0.037154    7.873256    16.706878   3.723616    2.450430     3.826546   1.475738    4.815459     9.575075   2.156028    4.180853     7.710282   1.950109     2.169921      3.794630    1.428558     0.505533      0.791404    1.087477
# NMR    548                         Nomura Holdings Inc. ADR                   -               Financial                   Capital Markets           Japan     NYSE                         Financial, Capital Markets        22060.0   649        22060.0    9.08     9.76  41.29    0.71    0.92     0.57     NaN     8.15    13.02        4.31          0.15        3/31/2025           53.60   0.82        0.17           NaN           NaN            NaN            NaN              NaN         2.42      64.18          80.88             4.19   31270.00    2520.00           -6.53               16.61         2950.00   2950.00   100.00           0.00              NaN        2.27          1.39           0.06         3.70               1.84   0.65   11.06    1.78    1.41     1.41       4.89     9.80      36.85     11.35        8.06  -1.190476        -1.06          1.36         19.52        12.33        35.33       29.02  0.77   0.11     1.472557            0.99            1.10     1.25     5.40     17.69       -1.58      20.29       -1.58      53.70      4.86 - 7.59           -69.26          156.70  58.16  Aug 07/b  12/17/2001        Yes       Yes    27242.0               -0.66   0.40   2.43        0.49787        0.94     469449          7.56        7.49    7.52    7.54    7.45    7.47     -0.27                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   -0.651364     -1.231278     0.890309  -1.408884     -2.041357     0.786016    0.036548     0.055377   1.005772    5.521977    13.952961   2.636777    1.418466     2.448713   1.251567    2.078360     3.633469   1.441887     1.189359      1.741705    1.259532     1.198031      1.812275    1.245219
# GRAB   490                            Grab Holdings Limited                   -              Technology            Software - Application       Singapore     NASD                 Technology, Software - Application        25760.0   577        25760.0  238.49    56.79    NaN    8.39    4.05     3.60   32.20     1.56     1.76         NaN           NaN                -             NaN   0.03        0.01           NaN           NaN            NaN            NaN              NaN        23.34     161.94         150.74            18.84    3070.00     112.00          -27.01                0.42         3950.00   2460.00    62.21          39.66             0.00       49.10          1.45           7.24         4.24             178.01   1.14    1.77    1.69    1.88     1.87       0.04     0.30      42.87      2.02        3.65  -0.472441         0.00         23.20         33.33        36.80        72.68       33.90  0.91   0.27     4.272152            5.06            4.30    13.52    19.42     29.73       -3.95      33.62       -3.95      88.10      3.36 - 6.58           -65.10          188.58  72.09  Sep 08/b   12/1/2020        Yes       Yes    11267.0               -2.32   0.31   1.54       41.99000        1.31   54990496          6.22        6.45    6.47    6.62    6.26    6.32     -2.02                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   -4.210718     -6.124143     0.454418   5.688071     14.020479     2.766414    8.945319    23.724223   4.279787   10.075175    26.825226   5.625299    5.555387    13.838116   2.849988    2.593961     4.263590   1.569671     1.471693      2.199590    1.305571     1.205998      1.806389    1.252718
# WBD    302                       Warner Bros. Discovery Inc        NDX, S&P 500  Communication Services                     Entertainment             USA     NASD              Communication Services, Entertainment        48430.0   348        48430.0   64.77      NaN   1.01    1.26    1.34     9.83   11.91    14.57     1.99         NaN           NaN        3/24/2010             NaN   0.30       -0.09           NaN           NaN            NaN            NaN              NaN         1.08     115.52         106.41            -3.79   38420.00     769.00          362.83                0.39         2480.00   2330.00    94.29           5.74            -0.45       71.28          3.67           4.02         1.32              93.78   0.73    2.18    1.09    1.04     1.04       0.95     0.96      26.59      3.04        2.00   4.598930         7.18         62.32         79.45        78.30       132.86       85.05  1.74   1.00     5.112474            5.56            6.34    30.33    45.58     78.87       -0.69      81.78       -0.69     169.79     7.25 - 19.69           -74.97          282.13  78.12  Aug 07/b    7/6/2005        Yes       Yes    35000.0               -0.41   0.15   2.11       71.11000        0.68   48066280         14.89       19.61   19.64   20.12   19.43   19.56     -0.25                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    7.655578     48.150269     5.289567  17.513859    247.505159    32.182719    8.129691    40.898598   7.229650    7.051889    35.238900   6.478042    5.098448    21.445402   3.842126    3.135664     7.987550   2.113608     2.003660      3.724366    1.561365     1.595660      2.841646    1.385033
# B      255                              Barrick Mining Corp                   -         Basic Materials                              Gold          Canada     NYSE                              Basic Materials, Gold        58920.0   291        58920.0   21.68    13.51   0.82    4.27    2.37    12.27   30.96    14.55     2.81        1.38          0.45        8/29/2025           33.10   1.59        0.59           NaN           NaN            NaN            NaN              NaN        16.20     124.19          84.96            16.79   13790.00    2760.00            2.20                0.55         1710.00   1700.00    99.78           0.22             0.00       66.36          3.02           0.91         0.98              15.43   5.91   11.41    9.37    3.21     2.53       0.19     0.19      40.40     39.41       20.05  14.865314        19.76         31.83         67.02        82.85        70.74      122.84  0.31   1.07     3.097858            5.79            2.96    18.66    36.70     71.59       -3.25      68.32       -3.25     128.59    15.11 - 35.70           -36.10         6442.59  83.39  Aug 11/b    2/1/1985        Yes       Yes    26800.0               -2.76   0.45   1.83       15.72000        2.27   35689585         33.12       35.36   35.52   36.10   34.34   34.54     -2.32                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    5.709043     23.235924     3.070021  12.198460     56.136599     8.072547    7.161030    31.594668   4.593689    8.525646    38.229731   6.423388    8.480772    33.176792   5.510076    6.350494    15.575273   3.229529     3.206448      5.398912    1.759571     1.619276      2.536833    1.315890
# VALE   309                                    Vale S.A. ADR                   -         Basic Materials  Other Industrial Metals & Mining          Brazil     NYSE  Basic Materials, Other Industrial Metals & Mining        46740.0   356        46740.0    9.11     6.35   1.29    1.28    1.19     8.21   22.98     9.19     1.33        7.22          0.72        8/13/2025           54.50   1.20        0.43           NaN           NaN            NaN            NaN              NaN       -11.44     -23.75         -46.86           -12.89   36620.00    5140.00           41.00               -0.97         4270.00   4270.00    99.99           0.01             0.00       16.43          1.82           1.36         1.51              58.23   5.81   13.49    9.14    1.22     0.85       0.43     0.45      34.27     26.29       14.04   1.014760         0.37          8.20         18.89        10.16         2.71       23.45  0.83   0.18     1.643836            1.43            1.42     3.90     7.53     13.78       -0.54      16.99       -8.25      35.94     8.06 - 11.93           -60.75          893.78  71.91  Jul 31/a   3/21/2002        Yes       Yes    64616.0                0.27   0.55   1.83       38.55000        0.86   33199922         12.41       10.86   10.92   11.06   10.90   10.95      0.83                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   10.794979    563.605232    51.209945   4.614669     12.036554     2.457441   11.009715    44.832787   6.911480   10.404822    26.688517   5.105903    4.632318     8.750272   2.234201    2.734944     4.577209   1.582209     0.802544      1.154222    1.153661     0.251577      0.362466    1.045397
# UWMC   886                         UWM Holdings Corporation                   -               Financial                  Mortgage Finance             USA     NYSE                        Financial, Mortgage Finance        10240.0  1084        10240.0     NaN    14.61    NaN    3.94    7.48    20.89     NaN     0.86     0.31        6.25          0.40        9/18/2025          309.36  -0.07        0.08           NaN           NaN            NaN            NaN              NaN        21.90     254.06         -21.43            12.27    2600.00      11.85          164.03               19.89          205.98    185.93    90.27          15.78            -9.98       59.93          1.13          18.68         4.04              34.73   0.09    8.18    0.19    0.20     0.20      34.53    63.80      85.72     18.58        0.46  -2.587519        -3.76          9.97         49.88        10.73       -24.79        9.03  1.84   0.28     4.375000            4.75            3.84     2.04    20.06     21.29      -10.36      60.80      -26.65      68.64      3.80 - 8.73           -55.49          125.35  59.29  Aug 07/b   3/24/2020        Yes       Yes     9100.0                0.00   1.27   2.44        8.59000        0.78    6687891          5.21        6.32    6.40    6.54    6.23    6.40      1.27                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -   -0.071046     -0.141197     0.987421  -8.418857     -8.982953     0.269361   -5.573980    -6.477711   0.457591    5.296510    15.117648   2.464899    4.128502    11.256100   2.043674    3.655988     8.054990   1.873064     0.736988      1.063656    1.138339    -0.288153     -0.408299    0.951962
# FPE    292  First Trust Preferred Securities and Income ETF                   -               Financial              Exchange Traded Fund             USA     NYSE  Financial, Exchange Traded Fund, Other Asset T...         6240.0  1452            NaN     NaN      NaN    NaN     NaN     NaN      NaN     NaN      NaN      NaN        5.60          1.03        8/21/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN        NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         0.74               0.93    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.000000         0.05          1.66          3.26         3.31         1.10        3.90  0.37   0.05     0.271887            0.25            0.24     0.88     1.78      3.61       -0.16       3.31       -0.16       9.66    16.77 - 18.42           -13.42           76.83  76.61         -   2/12/2013        Yes       Yes        NaN               -0.05   0.05    NaN        1.27000        0.69     870249           NaN       18.39   18.40   18.40   18.37   18.39      0.00  Other Asset Types - Multi-Asset / Other       Preferred Stock       0.85     256.0    6240.0        65.40       1.06       120.72       1.97         354.1        6.02        7.08        7.77        4.23  U.S., fixed-income, preferred-securities, inco...    4.675290     16.025205     2.427639  -0.690082     -0.997981     0.894854    9.695167    44.640708   7.099968   14.655637    94.702416  17.139880    6.484209    12.756890   3.051374    5.716509    10.715785   2.564000     1.704547      2.401134    1.445547     0.583786      0.808933    1.123136
# IAUM   369                         iShares Gold Trust Micro                   -               Financial              Exchange Traded Fund             USA     NYSE  Financial, Exchange Traded Fund, Commodities &...         4400.0  1529            NaN     NaN      NaN    NaN     NaN     NaN      NaN     NaN      NaN      NaN         NaN           NaN                -             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN        NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         2.29               6.09    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   3.217822         2.01         11.60         13.21        25.18        45.41       43.41  0.15   0.38     1.012523            1.04            0.84     4.59     9.06     19.77        0.39      15.19        0.39      47.09    25.51 - 37.38             0.39          132.15  78.87         -   6/29/2021         No       Yes        NaN               -0.53   0.94    NaN        2.66000        0.95    2530935           NaN       37.38   37.73   37.78   37.41   37.53      0.40     Commodities & Metals - Gold / Metals  Commodities & Metals       0.09       1.0    4400.0       644.88      17.18      1000.00      29.56        2170.0       97.63       46.93       31.03         NaN                          commodity, physical, gold   17.548082  21068.548290  1877.935460  11.898480     54.477003     7.863457    7.033658    18.286739   3.286085    7.969953    21.939210   3.668809    8.153831    23.291615   3.826394    3.954461     7.148834   1.877106     1.846343      2.990050    1.350819     1.866428      2.864138    1.358642
# U      613                               Unity Software Inc                   -              Technology            Software - Application             USA     NYSE                 Technology, Software - Application        18810.0   734        18810.0     NaN    50.16    NaN   10.57    5.87    11.12   53.00     7.58     4.00         NaN           NaN                -             NaN  -1.06        0.18           NaN           NaN            NaN            NaN              NaN        -1.85      18.54          48.10           -13.74    1780.00    -433.91           30.06                3.08          420.44    334.07    79.46          20.93            -3.95       67.12          7.17          11.69         2.88              39.06  -6.48  -13.62   -7.89    2.72     2.72       0.72     0.73      74.42    -25.56      -24.38  -2.046205        -3.05         13.69         85.19        95.86       119.42       98.13  2.35   2.04     4.582210            3.71            4.56     3.12    16.39     66.54       -5.16      55.23       -5.16     190.41    15.33 - 46.94           -78.80          220.40  60.73  Aug 06/b   9/18/2020        Yes       Yes     4987.0               -3.36   0.35   2.12       13.56000        0.91   12353782         36.40       45.91   46.07   46.15   44.37   44.52     -3.03                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -  -13.861704    -12.336816     0.000000  -5.140444     -6.039760     0.358054    2.196468     5.225296   1.590421    4.182587     9.209689   2.238882    3.224610     6.682329   1.851074    4.298638    10.235385   2.284086     2.530880      4.774622    1.604744     1.193867      2.068957    1.246042
# ORCL    13                                      Oracle Corp             S&P 500              Technology         Software - Infrastructure             USA     NYSE              Technology, Software - Infrastructure       891820.0    13       891820.0   72.65    38.87   3.10   15.11   36.91    81.04     NaN     8.50     3.87        0.58          1.80        10/9/2025           39.16   4.32        1.64           NaN           NaN            NaN            NaN              NaN        12.17      -2.06          11.23             9.67   59020.00   12440.00           -0.75               -0.75         2840.00   1660.00    58.49          41.52            -0.78       44.60          1.33           1.29         1.17              21.48   7.66   71.15   10.02    0.62     0.62       4.14     4.62      66.10     31.63       21.08   5.802036         2.34         32.77         45.78       102.64        87.26       88.33  1.57  15.87     5.056878            5.10            4.37    16.09    22.91     65.38       -9.22      43.44       -9.22     164.03  118.86 - 345.72            -9.22       782060.92  63.99  Sep 09/a   3/12/1986        Yes       Yes   162000.0               -2.28  -2.13   1.72       18.39000        1.87   34467533        341.33      328.15  321.16  325.00  310.05  313.83     -4.36                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    2.017029      4.917730     1.438106   3.504489      7.413723     1.727996   -1.531202    -2.152765   0.797708    4.419097    17.855656   3.069637    2.019041     6.096880   1.723973    2.147127     6.042636   1.797956     2.572450      6.438537    1.843673     1.337715      2.532521    1.339211
# ...
# NVDA     1                                      NVIDIA Corp  DJIA, NDX, S&P 500              Technology                    Semiconductors             USA     NASD                         Technology, Semiconductors      4335850.0     1      4335850.0   50.78    27.96   1.45   26.24   43.39    76.35   60.20     4.11     2.34        0.02          0.04        9/11/2025            1.16   3.51        1.24           NaN           NaN            NaN            NaN              NaN        55.60      61.23          64.54            71.55  165220.00   86600.00            4.13                1.51        24350.00  23310.00    95.73           4.08            -0.95       67.97          1.74           0.84         1.12             196.70  76.65  109.42   78.42    4.21     3.60       0.10     0.11      69.85     58.09       52.41   1.242624         2.03          0.25         20.64        46.96        51.38       32.87  2.12   5.34     2.992770            3.21            2.60     1.75     1.26     26.26       -3.32      10.13       -3.32     105.99   86.62 - 184.55            -3.32       535189.95  53.68  Aug 27/a   1/22/1999        Yes       Yes    36000.0               -1.96  -0.88   1.33      175.89000        1.08  190712133        217.22      183.61  182.00  182.42  176.21  178.43     -2.82                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    1.788306      4.254403     1.379012   6.021997     13.377352     2.685388    0.523666     0.887935   1.097172    2.271182     3.904146   1.461691   -0.716526    -1.012771   0.884367    1.814037     2.830641   1.347423     2.319134      4.057989    1.571838     0.961512      1.378887    1.189376
# GOOG     4                                     Alphabet Inc        NDX, S&P 500  Communication Services    Internet Content & Information             USA     NASD  Communication Services, Internet Content & Inf...      3049470.0     4      3049470.0   26.88    23.62   1.81    8.21    8.42    32.05   45.70    29.98     7.87        0.23          0.82         9/8/2025            7.46   9.39        2.32           NaN           NaN            NaN            NaN              NaN        14.06      22.28          34.52            13.19  371210.00  115570.00            5.82                2.54         5440.00   5040.00    92.67          58.32             0.01       26.82         -1.75           0.62         1.24              31.06  25.21   34.83   28.86    1.90     1.90       0.10     0.11      58.92     32.65       31.13   0.003963         0.37         22.07         50.44        48.50        54.58       32.50  1.01   5.34     2.116192            1.86            2.11     7.05    18.89     36.16       -1.70      39.64       -1.70      76.88  142.66 - 256.70            -1.70          937.96  79.89  Jul 23/a   3/27/2014        Yes       Yes   183323.0               -0.53   0.32   1.49       25.13000        0.69   17300658        240.41      252.88  253.69  254.77  251.09  252.34     -0.21                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -  -18.467913    -13.565318     0.000000   3.771183      7.741512     1.807069    5.863000    23.346265   3.633173    7.279999    30.237621   4.534829    5.822675    28.320206   4.171869    5.734150    17.249650   3.334411     3.017409      5.387148    1.747348     1.426088      2.194911    1.283352
# APP     53                                    Applovin Corp        NDX, S&P 500  Communication Services              Advertising Agencies             USA     NASD       Communication Services, Advertising Agencies       220260.0    58       220260.0   96.74    46.78   1.73   41.45  189.02   184.69   77.26     3.45     3.53         NaN           NaN                -            0.00   6.73        2.37           NaN           NaN            NaN            NaN              NaN        16.54     133.99         180.24            34.33    5310.00    2320.00           21.94                2.81          308.17    223.41    72.50          33.95            -2.02       59.82         -4.67           5.96         1.86              13.31  42.41  240.30   49.65    2.74     2.74       3.01     3.01      79.52     56.29       43.71   4.772171         7.85         47.43         86.33        91.68       425.15      101.09  2.49  24.70     3.793114            4.25            4.13    17.87    41.34     77.44       -0.89      90.34       -0.89     422.66  124.59 - 657.00            -0.89         7024.51  84.49  Aug 06/a   4/15/2021        Yes       Yes     1563.0                1.58  -0.38   1.66        7.15000        1.08    7749212        558.29      643.50  641.03  670.19  637.51  651.18      1.19                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -    1.181040      2.639831     1.235175  12.433266     59.595052     8.508271   16.297863    77.002845  15.552170   10.738921    57.691224  11.174358    5.826609    12.014283   2.830868    5.134470    10.746658   2.478430     2.704339      4.402148    1.593828     2.172567      3.753219    1.543543
# QQQ      5                       Invesco QQQ Trust Series 1                   -               Financial              Exchange Traded Fund             USA     NASD  Financial, Exchange Traded Fund, US Equities -...       386080.0    30            NaN     NaN      NaN    NaN     NaN     NaN      NaN     NaN      NaN      NaN        0.47          2.84        9/22/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN        NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         1.11              51.75    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.600204         1.19          4.59         10.82        21.92        23.76       17.01  1.16   5.82     0.972919            0.93            0.86     2.61     4.28     14.01       -0.77       8.46       -0.77      48.66  402.39 - 602.87            -0.77         2941.50  68.70         -   3/10/1999        Yes       Yes        NaN               -0.68   0.01    NaN       46.45000        1.38   63949256           NaN      602.20  602.29  602.57  596.98  598.20     -0.66        US Equities - Broad Market & Size     Equities (Stocks)       0.20     101.0  386080.0     -2470.00      -0.64      2700.00       0.70        9990.0        2.66       28.46       28.25       17.32                            U.S., equity, Nasdaq100   -0.929152     -1.716241     0.847105   8.109919     16.839359     3.121560    9.718541    21.732424   3.970879   11.601471    27.871659   5.752065    2.296396     3.545726   1.438084    2.826873     4.437997   1.581802     1.781945      2.983272    1.509488     0.868648      1.300666    1.189349
# SPY      3                           SPDR S&P 500 ETF Trust                   -               Financial              Exchange Traded Fund             USA     NYSE  Financial, Exchange Traded Fund, US Equities -...       664070.0    19            NaN     NaN      NaN    NaN     NaN     NaN      NaN     NaN      NaN      NaN        1.09          7.25        9/19/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN        NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         1.61             113.53    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   0.421090         0.49          2.77          9.30        15.53        16.15       13.16  1.01   5.01     0.755417            0.81            0.66     1.50     3.26     10.71       -0.61       7.31       -0.61      37.65  481.80 - 667.29            -0.61         1458.46  66.56         -   1/29/1993        Yes       Yes        NaN               -0.53  -0.02    NaN       70.57000        1.15   81344530           NaN      666.84  666.72  667.34  661.98  663.21     -0.54        US Equities - Broad Market & Size     Equities (Stocks)       0.09     504.0  664070.0    -17030.00      -2.50    -11900.00      -1.76      -43410.0       -6.14       20.26       21.27       16.06                                U.S., equity, SP500   -1.136319     -2.063724     0.816149   6.421015     11.726868     2.477447    7.239454    16.030244   3.010878    8.388274    19.225718   3.522747    3.200724     5.908799   1.653923    3.124714     5.292596   1.671490     1.423329      2.285515    1.405197     0.727737      1.094355    1.166095
# VGT     15              Vanguard Information Technology ETF                   -               Financial              Exchange Traded Fund             USA     NYSE  Financial, Exchange Traded Fund, US Equities -...       109110.0   148            NaN     NaN      NaN    NaN     NaN     NaN      NaN     NaN      NaN      NaN        0.42          3.13        6/26/2025             NaN    NaN         NaN           NaN           NaN            NaN            NaN              NaN          NaN        NaN            NaN              NaN        NaN        NaN             NaN                 NaN             NaN       NaN      NaN            NaN              NaN         NaN           NaN            NaN         0.79               0.38    NaN     NaN     NaN     NaN      NaN        NaN      NaN        NaN       NaN         NaN   1.511623         2.93          7.38         15.29        29.55        28.60       19.88  1.25   9.69     1.299956            1.41            1.12     4.32     6.47     18.93       -1.09      12.26       -1.09      65.28  451.00 - 753.59            -1.09         2483.74  70.05         -   1/30/2004        Yes       Yes        NaN               -0.92  -0.11    NaN        0.47727        1.55     738932           NaN      753.15  752.35  753.50  742.90  745.41     -1.03            US Equities - Industry Sector     Equities (Stocks)       0.09     318.0  109110.0       693.85       0.64      2510.00       2.35        5400.0        5.20       34.31       31.85       20.28                     U.S., equity, technology, I.T.    2.364392      5.990631     1.533688   9.970201     24.604268     4.099846    7.566670    18.485646   3.287628   10.143198    25.962488   5.007190    2.979223     4.801630   1.590706    3.154229     5.052743   1.637272     2.055934      3.429258    1.562995     0.908569      1.339332    1.191425
# META     7                               Meta Platforms Inc        NDX, S&P 500  Communication Services    Internet Content & Information             USA     NASD  Communication Services, Internet Content & Inf...      1897540.0     7      1897540.0   27.36    25.19   2.13   10.61    9.74    40.17   37.85    77.53    18.80        0.23          2.08        9/22/2025            8.38  27.61        6.66           NaN           NaN            NaN            NaN              NaN        21.61      38.30          40.62            19.38  178800.00   71510.00           21.36                6.01         2170.00   2160.00    99.59          13.85            -0.14       68.00         -0.51           1.13         2.08              24.37  27.24   40.65   29.47    1.97     1.97       0.24     0.25      81.95     44.08       39.99  -3.119565        -3.03          0.08          6.07        22.07        35.11       29.02  1.21  16.87     2.233254            2.48            1.88    -0.21     0.95     14.03       -5.13       9.29       -5.13      57.44  479.80 - 796.25            -5.13         4204.27  48.74  Jul 30/a   5/18/2012        Yes       Yes    74067.0               -1.79   0.53   1.44       11.70000        0.90   10494184        868.42      765.16  769.20  770.60  751.07  755.40     -1.28                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  -  -92.549556    -15.759021     0.000000 -10.345052     -9.885091     0.177816    0.671076     1.052055   1.113266    2.260541     3.616295   1.426085   -2.131580    -2.768840   0.712964    0.345161     0.687844   1.071937     1.389734      2.498588    1.325771     0.891911      1.437020    1.180367
# MSTR   158                                     Strategy Inc                 NDX              Technology            Software - Application             USA     NASD                 Technology, Software - Application        92940.0   177        92940.0   28.86      NaN    NaN  201.04    1.94  1782.91     NaN   168.98     0.18         NaN           NaN                -             NaN  11.36       -0.10           NaN           NaN            NaN            NaN              NaN         2.73    5776.79        1243.91            -3.81     462.32    4730.00        33263.78                0.84          283.55    263.35    92.88           7.13             0.08       49.76         10.46           8.61         1.94              22.68  13.34   18.01    8.08    0.68     0.68       0.16     0.16      70.10    -13.37     1023.69  -6.112511        -2.18         -8.47        -13.06        -2.37       126.59       13.18  3.85  15.13     4.615901            4.85            3.95    -2.08   -11.26     -7.31      -28.31       3.16      -39.64     126.03  145.01 - 543.00           -39.64        77942.86  41.87  Jul 31/a   6/11/1998        Yes       Yes     1534.0               -2.66   0.24   1.50       11.67000        0.80    9354926        562.69      335.93  336.75  339.00  327.77  327.78     -2.43                                                                       NaN       NaN       NaN          NaN        NaN          NaN        NaN           NaN         NaN         NaN         NaN         NaN                                                  - -425.681147    -15.868992     0.000000  -0.406822     -0.869371     0.934324    0.359595     0.695273   1.060953   -0.304426    -0.559771   0.951257   -3.353174    -4.345048   0.586215   -1.494866    -2.005499   0.782687     0.416900      0.662752    1.082150     1.241771      2.052357    1.248269

# %% [markdown]
# ### Verification Workflow Example

# %%
def inspect_ticker_data(df_ohlcv, ticker, period):
    """
    Provides a detailed, transparent breakdown of performance metric calculations for a single ticker over a specific period.
    
    Returns a pandas DataFrame containing the original OHLCV data plus all intermediate columns
    used to calculate Price, Sharpe, and Return/ATR metrics. This serves as a "calculation worksheet"
    for easy verification.
    """
    # 1. Initial Data Slicing and Validation
    if ticker not in df_ohlcv.index.get_level_values(0):
        print(f"Error: Ticker '{ticker}' not found in the DataFrame.")
        return
        
    ticker_df = df_ohlcv.loc[ticker].copy()
    ticker_df.index = pd.to_datetime(ticker_df.index)
    end_date = ticker_df.index.max()
    
    periods = {
        '1D': end_date - pd.DateOffset(days=1), '5D': end_date - pd.DateOffset(days=5),
        '3M': end_date - pd.DateOffset(months=3), '6M': end_date - pd.DateOffset(months=6),
        'YTD': datetime(end_date.year, 1, 1), '1Y': end_date - pd.DateOffset(years=1),
        '5Y': end_date - pd.DateOffset(years=5),
    }
    
    if period not in periods:
        print(f"Error: Period '{period}' is not a valid option.")
        return
        
    start_date = periods[period]
    period_df = ticker_df.loc[start_date:end_date].copy()
    
    if len(period_df) < 2:
        print(f"Not enough data for ticker '{ticker}' in period '{period}'.")
        return

    # 2. Add Calculation Columns to the DataFrame
    # --- Price Performance Columns ---
    start_price = period_df['Adj Close'].bfill().iloc[0]
    period_df['Normalized Price'] = period_df['Adj Close'] / start_price

    # --- Sharpe Ratio Columns ---
    period_df['Daily Return'] = period_df['Adj Close'].pct_change()

    # --- Return/ATR Columns (matches the main function's logic) ---
    period_df['Prev Close'] = period_df['Adj Close'].shift(1)
    period_df['High-Low'] = period_df['Adj High'] - period_df['Adj Low']
    period_df['High-PrevClose'] = abs(period_df['Adj High'] - period_df['Prev Close'])
    period_df['Low-PrevClose'] = abs(period_df['Adj Low'] - period_df['Prev Close'])
    period_df['True Range'] = period_df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis=1)
    # Use the same ewm parameters as the main plotting function for consistency
    period_df['ATR'] = period_df['True Range'].ewm(alpha=1/14, adjust=False).mean()

    # 3. Calculate Final Metrics for Summary Printout
    # Price
    end_price = period_df['Adj Close'].ffill().iloc[-1]
    normalized_price = end_price / start_price
    
    # Sharpe
    mean_daily_return = period_df['Daily Return'].mean()
    std_daily_return = period_df['Daily Return'].std()
    daily_sharpe = 0 if std_daily_return == 0 else mean_daily_return / std_daily_return
    annualized_sharpe = daily_sharpe * np.sqrt(252)

    # Return/ATR
    mean_atr = period_df['ATR'].mean()
    return_on_atr = 0 if mean_atr == 0 else mean_daily_return / mean_atr

    # 4. Display Summary and DataFrame
    display(Markdown(f"### Sanity Check for Ticker: `{ticker}` | Period: `{period}`"))
    
    display(Markdown("**1. Price Performance Calculation:**"))
    print(f"   - Start Date ({period_df.index.min().date()}): {start_price:,.2f}")
    print(f"   - End Date   ({period_df.index.max().date()}): {end_price:,.2f}")
    print(f"   - Final Normalized Price: ({end_price:,.2f} / {start_price:,.2f}) = {normalized_price:.4f}\n")

    display(Markdown("**2. Sharpe Ratio Calculation:**"))
    print(f"   - Number of Trading Days: {len(period_df)}")
    print(f"   - Mean of Daily Returns: {mean_daily_return:.6f}")
    print(f"   - Std Dev of Daily Returns: {std_daily_return:.6f}")
    print(f"   - Annualized Sharpe Ratio: {annualized_sharpe:.4f}\n")
    
    display(Markdown("**3. Return/ATR Calculation:**"))
    print(f"   - Mean of Daily Returns: {mean_daily_return:.6f}")
    print(f"   - Mean ATR (14-day EWM): {mean_atr:.6f}")
    print(f"   - Return / Mean ATR: {return_on_atr:.6f}\n")

    display(Markdown("**4. Underlying Data and Calculation Worksheet:**"))
    # Define a clean column order for the final display
    display_cols = [
        'Adj Open', 'Adj High', 'Adj Low', 'Adj Close', # Original Data
        'Normalized Price', 'Daily Return',             # Metric Columns
        'Prev Close', 'True Range', 'ATR'               # ATR Intermediates
    ]
    # Filter for columns that actually exist to avoid errors if some are missing
    display_cols = [col for col in display_cols if col in period_df.columns]
    with pd.option_context('display.max_rows', 15):
        display(period_df[display_cols])
    
    return period_df

# %%
# --- 1. Run the Main Plot to Get a Ranked List ---
# We'll use Sharpe over 1 Year and look at the top 10 performers.
_METRIC = 'Return/ATR'
_PERIOD = '3M'
_RANK_START = 1
_RANK_END = 10

print(f"--- Running main widget to get the Top {_RANK_END} tickers for '{_METRIC}' over '{_PERIOD}' ---")
# The UI will be displayed. Make sure to click "Update Chart" if defaults are different.
plotted_tickers = plot_interactive_performers_widget(
    df_OHLCV, 
    default_metric=_METRIC, 
    default_period=_PERIOD, 
    default_rank_start=_RANK_START, 
    default_rank_end=_RANK_END
)

# --- 2. Perform the Verification Check ---
print("\n" + "="*80)
print("--- STARTING VERIFICATION PROCESS ---")
print("="*80 + "\n")

# We need at least two tickers to compare. Let's check for the 1st and 5th.
if len(plotted_tickers) >= 5:
    ticker_to_check_1 = plotted_tickers[0]  # The #1 ranked ticker
    ticker_to_check_2 = plotted_tickers[4]  # The #5 ranked ticker

    print(f"\n--- Verifying Rank #1: {ticker_to_check_1} ---")
    inspection_df_1 = inspect_ticker_data(
        df_OHLCV, 
        ticker=ticker_to_check_1, 
        period=_PERIOD
    )

    print(f"\n--- Verifying Rank #5: {ticker_to_check_2} ---")
    inspection_df_2 = inspect_ticker_data(
        df_OHLCV, 
        ticker=ticker_to_check_2, 
        period=_PERIOD
    )
    
    # You can now manually compare the printed summaries above.
    # For Sharpe, look at the "Annualized Sharpe Ratio".
    # For Price, look at the "Final Normalized Price".
    # For Return/ATR, look at the "Return / Mean ATR".
    # The value for the first ticker should be greater than the value for the second.

else:
    print(f"Could not perform verification check: The plotter returned fewer than 5 tickers ({len(plotted_tickers)}).")

print("\n" + "="*80)
print("--- VERIFICATION PROCESS COMPLETE ---")
print("="*80)
# Out:
# --- Running main widget to get the Top 10 tickers for 'Return/ATR' over '3M' ---
# Reshaping data and calculating intermediate metrics (ATR)...
# Data successfully reshaped and ATR calculated.
# Starting pre-computation for all metrics across all periods...
# Pre-computation finished.
# VBox(children=(HBox(children=(Dropdown(description='Metric:', index=2, options=('Price', 'Sharpe', 'Return/ATR…
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'name': 'NIO',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6e7da9f9-1588-4b8e-ace8-99af94009760',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.02040816, 1.01166181, 0.99708455, 1.00874636, 1.        ,
#                           1.02332362, 1.01457726, 1.02332362, 0.9941691 , 1.02040816, 1.01457726,
#                           1.07580175, 1.13702624, 1.21574344, 1.23906706, 1.19825073, 1.28279883,
#                           1.27988338, 1.31778426, 1.4606414 , 1.43440233, 1.40816327, 1.43440233,
#                           1.40816327, 1.37317784, 1.3148688 , 1.41982507, 1.4606414 , 1.34110787,
#                           1.31195335, 1.34402332, 1.36443149, 1.41107872, 1.43148688, 1.303207  ,
#                           1.34693878, 1.29737609, 1.40233236, 1.41982507, 1.47813411, 1.47813411,
#                           1.61516035, 1.8483965 , 1.7755102 , 1.95335277, 1.8483965 , 1.89795918,
#                           1.86005831, 1.91836735, 1.8425656 , 1.78717201, 1.73469388, 1.79883382,
#                           1.83090379, 1.66763848, 1.7696793 , 1.81341108, 1.89212828, 2.04664723,
#                           2.17201166, 2.14868805, 2.14868805, 2.01457726, 2.02040816])},
#              {'mode': 'lines',
#               'name': 'HL',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1a9acc31-2e2e-428e-aa61-f952448892c6',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.9965635 , 1.00171911, 1.03092847, 1.0034365 , 1.02920937,
#                           1.02577287, 1.03608236, 1.04295535, 1.05842045, 0.96048114, 0.99140962,
#                           1.0120286 , 1.08591071, 1.05326484, 1.04982835, 1.03436497, 1.02233637,
#                           1.        , 1.04123796, 1.08419332, 1.07903771, 1.06185523, 1.05498395,
#                           1.02749198, 1.03436497, 1.00171911, 0.98625401, 0.97766363, 1.02577287,
#                           1.05498395, 1.04982835, 1.24054963, 1.30584308, 1.29725097, 1.31786996,
#                           1.33505244, 1.31615257, 1.31786996, 1.33161594, 1.2783511 , 1.30584308,
#                           1.32130645, 1.35637626, 1.35121893, 1.37528645, 1.38044377, 1.3873202 ,
#                           1.46296096, 1.53344439, 1.54375904, 1.52141063, 1.55063547, 1.73973735,
#                           1.750052  , 1.88586154, 1.91680548, 1.92712013, 2.02167108, 1.95118765,
#                           1.89617619, 1.85147938, 1.88414243, 1.93055835, 1.9202437 ])},
#              {'mode': 'lines',
#               'name': 'UWMC',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '818897b4-88df-43c8-92ad-3c47a85f0202',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.01425247, 0.98337251, 0.99524998, 0.97387247, 0.98337251,
#                           1.02137751, 1.0190025 , 1.01187746, 0.94774253, 0.98574753, 1.01187746,
#                           0.98574753, 0.98574753, 1.00475002, 0.99287497, 1.        , 0.99049996,
#                           1.00712503, 1.04513002, 1.10451252, 1.09026246, 1.04038   , 1.01425247,
#                           1.01187746, 0.99524998, 0.96199501, 0.95486998, 0.99049996, 1.01662749,
#                           1.03325497, 1.00237501, 1.06888495, 1.07363497, 1.07838499, 1.20190001,
#                           1.32779245, 1.30166251, 1.27790999, 1.27553498, 1.33016746, 1.31591498,
#                           1.27790999, 1.38242251, 1.35154496, 1.37054746, 1.35154496, 1.32541502,
#                           1.35391997, 1.32541502, 1.34916995, 1.40142501, 1.49881249, 1.53444248,
#                           1.52019   , 1.61520248, 1.64133001, 1.62707994, 1.60332501, 1.5795725 ,
#                           1.59619998, 1.58414409, 1.54315406, 1.52386464, 1.54315406])},
#              {'mode': 'lines',
#               'name': 'EQX',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f52ed16c-98be-4651-a5fc-8697a65e3e16',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 0.95261438, 0.96078431, 0.96568627, 0.92810458, 0.93954248,
#                           0.94444444, 0.95424837, 0.94771242, 0.96405229, 0.95915033, 0.98529412,
#                           0.99836601, 1.01797386, 1.02777778, 1.        , 1.0130719 , 1.02614379,
#                           1.02614379, 1.05392157, 1.0620915 , 1.04411765, 1.03921569, 1.04411765,
#                           1.02777778, 1.03594771, 1.        , 0.99673203, 0.99183007, 1.02941176,
#                           1.04575163, 1.07352941, 1.07026144, 1.05228758, 1.08660131, 1.1127451 ,
#                           1.10947712, 1.27777778, 1.30392157, 1.30228758, 1.23366013, 1.26633987,
#                           1.29084967, 1.31045752, 1.32026144, 1.34477124, 1.33986928, 1.35130719,
#                           1.43137255, 1.49346405, 1.48856209, 1.46568627, 1.59803922, 1.60620915,
#                           1.62581699, 1.75490196, 1.79248366, 1.73366013, 1.77287582, 1.7254902 ,
#                           1.69934641, 1.69934641, 1.76470588, 1.7875817 , 1.75653595])},
#              {'mode': 'lines',
#               'name': 'MFG',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c82899a3-33a9-424a-a8bc-3567f17606bb',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.03321033, 1.01660517, 1.03321033, 1.02583026, 1.02583026,
#                           1.03690037, 1.03136531, 1.03874539, 1.        , 1.00738007, 1.01476015,
#                           1.01845018, 1.01476015, 1.01291513, 1.01107011, 1.01845018, 1.03321033,
#                           1.02583026, 1.04059041, 1.05719557, 1.13099631, 1.14391144, 1.14206642,
#                           1.09594096, 1.08856089, 1.08671587, 1.08856089, 1.07749077, 1.09409594,
#                           1.10332103, 1.12177122, 1.13284133, 1.15498155, 1.15129151, 1.18634686,
#                           1.18081181, 1.19926199, 1.23247232, 1.22140221, 1.19372694, 1.20664207,
#                           1.19557196, 1.21771218, 1.2103321 , 1.21402214, 1.2103321 , 1.23062731,
#                           1.21771218, 1.20479705, 1.17712177, 1.20664207, 1.20110701, 1.23062731,
#                           1.22324723, 1.23800738, 1.22324723, 1.2195572 , 1.23431734, 1.21217712,
#                           1.2103321 , 1.21402214, 1.22509225, 1.24538745, 1.24354244])},
#              {'mode': 'lines',
#               'name': 'BBD',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'a8b3cbe0-fda7-49cc-999b-7582e5ecfa43',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.00331292, 0.99006798, 0.99669045, 1.00331292, 1.02318034,
#                           1.02318034, 1.0245278 , 1.04577982, 1.02553755, 1.03228497, 1.01541979,
#                           0.98505638, 0.97830896, 0.98168267, 0.98505638, 0.97156491, 0.97156491,
#                           0.94794892, 0.94794892, 0.94457521, 0.97156491, 0.95807006, 0.94457521,
#                           0.92770665, 0.93782779, 0.93445408, 0.93445408, 0.94794892, 0.94794892,
#                           0.95233914, 0.96247041, 0.97597876, 0.97935585, 0.97935585, 1.01988092,
#                           1.00974966, 0.99961839, 0.99961839, 1.01988092, 0.9658475 , 0.97260168,
#                           0.97597876, 1.00637257, 1.01312675, 1.00637257, 1.01988092, 1.05027473,
#                           1.05027473, 1.01988092, 1.01988092, 1.03676637, 1.07391435, 1.06378308,
#                           1.0570289 , 1.05365182, 1.06716017, 1.0570289 , 1.07391435, 1.08404562,
#                           1.11781651, 1.10430815, 1.12457069, 1.1211936 , 1.14483322])},
#              {'mode': 'lines',
#               'name': 'GRAB',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fdc277ab-cc86-477c-9163-2862b7ae708c',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.03947368, 1.00657895, 1.02412281, 1.07894737, 1.10307018,
#                           1.08114035, 1.0745614 , 1.06798246, 1.08991228, 1.05263158, 1.09429825,
#                           1.07894737, 1.09649123, 1.09868421, 1.10526316, 1.125     , 1.15131579,
#                           1.17105263, 1.17324561, 1.1995614 , 1.17763158, 1.17105263, 1.1754386 ,
#                           1.15789474, 1.16447368, 1.16008772, 1.07236842, 1.05263158, 1.0877193 ,
#                           1.08991228, 1.04605263, 1.08552632, 1.07017544, 1.05701754, 1.09429825,
#                           1.12280702, 1.125     , 1.125     , 1.11842105, 1.10745614, 1.10307018,
#                           1.09868421, 1.125     , 1.09868421, 1.09649123, 1.08552632, 1.08991228,
#                           1.09429825, 1.08114035, 1.07894737, 1.10745614, 1.13157895, 1.13815789,
#                           1.16008772, 1.1622807 , 1.2127193 , 1.31578947, 1.34649123, 1.38596491,
#                           1.3377193 , 1.39254386, 1.40131579, 1.41447368, 1.38596491])},
#              {'mode': 'lines',
#               'name': 'QS',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '60486a36-1e2d-499f-a7b6-542b1d71f38d',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
#                           datetime.datetime(2025, 9, 16, 0, 0),
#                           datetime.datetime(2025, 9, 17, 0, 0),
#                           datetime.datetime(2025, 9, 18, 0, 0),
#                           datetime.datetime(2025, 9, 19, 0, 0),
#                           datetime.datetime(2025, 9, 22, 0, 0),
#                           datetime.datetime(2025, 9, 23, 0, 0)], dtype=object),
#               'y': array([1.        , 1.02122642, 1.33726415, 1.80424528, 1.56132075, 1.58490566,
#                           1.5       , 1.60377358, 1.65566038, 1.65330189, 1.92924528, 1.97169811,
#                           2.14386792, 2.17688679, 2.37028302, 2.55896226, 2.67688679, 3.20754717,
#                           3.45283019, 2.95283019, 3.25471698, 3.0259434 , 2.97877358, 2.82311321,
#                           2.58962264, 2.18867925, 2.07075472, 2.02830189, 1.94811321, 1.95754717,
#                           2.0495283 , 1.95283019, 2.17924528, 2.06603774, 2.14150943, 2.20518868,
#                           2.22641509, 2.14386792, 2.12971698, 2.0754717 , 1.86556604, 1.86556604,
#                           1.85613208, 1.9245283 , 1.89858491, 1.96462264, 1.89622642, 1.91037736,
#                           1.87028302, 1.82311321, 1.83490566, 1.80424528, 1.8490566 , 2.23820755,
#                           2.01179245, 1.96933962, 2.08726415, 2.34669811, 2.44339623, 2.39386792,
#                           2.41981132, 2.86084906, 3.16509434, 3.16981132, 3.19103774])},
#              {'mode': 'lines',
#               'name': 'EBR',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '643f4b25-4212-4e4e-8ce5-7abb2e1cfb52',
#               'visible': True,
#               'x': array([datetime.datetime(2025, 6, 23, 0, 0),
#                           datetime.datetime(2025, 6, 24, 0, 0),
#                           datetime.datetime(2025, 6, 25, 0, 0),
#                           datetime.datetime(2025, 6, 26, 0, 0),
#                           datetime.datetime(2025, 6, 27, 0, 0),
#                           datetime.datetime(2025, 6, 30, 0, 0),
#                           datetime.datetime(2025, 7, 1, 0, 0),
#                           datetime.datetime(2025, 7, 2, 0, 0),
#                           datetime.datetime(2025, 7, 3, 0, 0),
#                           datetime.datetime(2025, 7, 7, 0, 0),
#                           datetime.datetime(2025, 7, 8, 0, 0),
#                           datetime.datetime(2025, 7, 9, 0, 0),
#                           datetime.datetime(2025, 7, 10, 0, 0),
#                           datetime.datetime(2025, 7, 11, 0, 0),
#                           datetime.datetime(2025, 7, 14, 0, 0),
#                           datetime.datetime(2025, 7, 15, 0, 0),
#                           datetime.datetime(2025, 7, 16, 0, 0),
#                           datetime.datetime(2025, 7, 17, 0, 0),
#                           datetime.datetime(2025, 7, 18, 0, 0),
#                           datetime.datetime(2025, 7, 21, 0, 0),
#                           datetime.datetime(2025, 7, 22, 0, 0),
#                           datetime.datetime(2025, 7, 23, 0, 0),
#                           datetime.datetime(2025, 7, 24, 0, 0),
#                           datetime.datetime(2025, 7, 25, 0, 0),
#                           datetime.datetime(2025, 7, 28, 0, 0),
#                           datetime.datetime(2025, 7, 29, 0, 0),
#                           datetime.datetime(2025, 7, 30, 0, 0),
#                           datetime.datetime(2025, 7, 31, 0, 0),
#                           datetime.datetime(2025, 8, 1, 0, 0),
#                           datetime.datetime(2025, 8, 4, 0, 0),
#                           datetime.datetime(2025, 8, 5, 0, 0),
#                           datetime.datetime(2025, 8, 6, 0, 0),
#                           datetime.datetime(2025, 8, 7, 0, 0),
#                           datetime.datetime(2025, 8, 8, 0, 0),
#                           datetime.datetime(2025, 8, 11, 0, 0),
#                           datetime.datetime(2025, 8, 12, 0, 0),
#                           datetime.datetime(2025, 8, 13, 0, 0),
#                           datetime.datetime(2025, 8, 14, 0, 0),
#                           datetime.datetime(2025, 8, 15, 0, 0),
#                           datetime.datetime(2025, 8, 18, 0, 0),
#                           datetime.datetime(2025, 8, 19, 0, 0),
#                           datetime.datetime(2025, 8, 20, 0, 0),
#                           datetime.datetime(2025, 8, 21, 0, 0),
#                           datetime.datetime(2025, 8, 22, 0, 0),
#                           datetime.datetime(2025, 8, 25, 0, 0),
#                           datetime.datetime(2025, 8, 26, 0, 0),
#                           datetime.datetime(2025, 8, 27, 0, 0),
#                           datetime.datetime(2025, 8, 28, 0, 0),
#                           datetime.datetime(2025, 8, 29, 0, 0),
#                           datetime.datetime(2025, 9, 2, 0, 0),
#                           datetime.datetime(2025, 9, 3, 0, 0),
#                           datetime.datetime(2025, 9, 4, 0, 0),
#                           datetime.datetime(2025, 9, 5, 0, 0),
#                           datetime.datetime(2025, 9, 8, 0, 0),
#                           datetime.datetime(2025, 9, 9, 0, 0),
#                           datetime.datetime(2025, 9, 10, 0, 0),
#                           datetime.datetime(2025, 9, 11, 0, 0),
#                           datetime.datetime(2025, 9, 12, 0, 0),
#                           datetime.datetime(2025, 9, 15, 0, 0),
# ...
#               'type': 'scatter',
#               'uid': 'cbf30e8d-c1cf-4886-ab34-b699c8c8acfc',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_14',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b229da33-bf92-4618-8cb8-de3a065eef4e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_15',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '09350803-b02e-4fde-ac8f-2d96faa24504',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_16',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f77398bb-9ca0-410a-80ca-549a9c0f3552',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_17',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9ef6250c-09fb-4505-869b-d126753463ce',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_18',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fb0dee4e-12fa-4b13-a8d0-fb244342aa1b',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_19',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0ffbca4e-a8fe-4373-ba4c-b65827c7cd8c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_20',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b8059db4-5d2d-491b-a3f6-2bc3bf2f8aea',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_21',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3f9811d1-ffec-4c7e-9f36-f8eb2292d189',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_22',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd2ff36dc-615e-4e28-a3c4-cbd0548df613',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_23',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6b24ba26-0882-4ff9-a729-8859016e7571',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_24',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ec03ca63-e070-4f87-9c4b-06afb295092c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_25',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bc4b9131-ba03-4b80-a756-de2f7061e90c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_26',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cd6bd875-0a7e-4a24-a5ba-6fb72b6c2fef',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_27',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '836ff5c9-f5d6-4614-81f4-bd9b3d7628bb',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_28',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '94d63abe-18c8-44f7-a269-e7f9cfe81887',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_29',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0a22bb58-cf39-4090-a925-a159e4c8c4a7',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_30',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0e401dc9-e4a1-42f1-8e31-8057b88232a9',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_31',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'afc8cc6b-c55e-4533-8cfe-23ae771ae185',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_32',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '02f68903-7a79-4d46-8bae-937c3c855345',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_33',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8d871e71-80e6-4e87-95fc-63750b8eecb7',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_34',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3c27f562-5ed9-4a34-b03d-7e0c459895d9',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_35',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4226ac4f-58f4-49de-a6c5-a43794acac92',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_36',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2cdc47c1-e446-4cb9-bc65-dcb9d7553dd8',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_37',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8e088efa-1b39-4096-af02-172ddfacf88a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_38',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0297c782-1a07-4f2b-b05a-3091ce84726f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_39',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fbb02bb6-6b71-427f-9b5c-da6cd8fc4622',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_40',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1450760e-f25f-4050-930c-1bedbf4d8af6',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_41',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f91b528b-8d6e-41e9-9232-696ac2a19679',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_42',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd6bab674-2a58-480f-8060-30a243b4b251',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_43',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4714b0a8-e58f-47bb-8d7b-ebb2d801db3b',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_44',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '22bc4b44-124f-47d6-9509-38995a4aa776',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_45',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bfd9c9a0-76c5-48ba-a2ce-c280afcc7c95',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_46',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e5814029-ed9d-43a4-9f31-2b41f32f30a9',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_47',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e498ee5d-be8c-45b4-9aba-21a5f403cb9c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_48',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ff453121-a449-4679-abde-ca959c9161db',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_49',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ddf7b1b6-d73f-4e7f-85cc-e0198eccf507',
#               'visible': False,
#               'x': [None],
#               'y': [None]}],
#     'layout': {'height': 700,
#                'hovermode': 'x unified',
#                'legend': {'title': {'text': 'Tickers'}},
#                'margin': {'t': 50},
#                'shapes': [{'line': {'color': 'grey', 'dash': 'dash', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'x domain',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y'}],
#                'template': '...',
#                'title': {'text': 'Top Performing Tickers (Normalized to 1)'},
#                'xaxis': {'title': {'text': 'Date'}},
#                'yaxis': {'title': {'text': 'Normalized Price (Start = 1)'}}}
# })
# ================================================================================
# --- STARTING VERIFICATION PROCESS ---
# ================================================================================
#
#
# --- Verifying Rank #1: NIO ---
# ### Sanity Check for Ticker: `NIO` | Period: `3M`
# **1. Price Performance Calculation:**
#    - Start Date (2025-06-23): 3.43
#    - End Date   (2025-09-23): 6.93
#    - Final Normalized Price: (6.93 / 3.43) = 2.0204
# **2. Sharpe Ratio Calculation:**
#    - Number of Trading Days: 65
#    - Mean of Daily Returns: 0.012151
#    - Std Dev of Daily Returns: 0.047697
#    - Annualized Sharpe Ratio: 4.0441
# **3. Return/ATR Calculation:**
#    - Mean of Daily Returns: 0.012151
#    - Mean ATR (14-day EWM): 0.258025
#    - Return / Mean ATR: 0.047093
# **4. Underlying Data and Calculation Worksheet:**
#             Adj Open  Adj High  Adj Low  Adj Close  Normalized Price  Daily Return  Prev Close  True Range       ATR
# Date
# 2025-06-23      3.40      3.45     3.34       3.43          1.000000           NaN         NaN        0.11  0.110000
# 2025-06-24      3.46      3.57     3.41       3.50          1.020408      0.020408        3.43        0.16  0.113571
# 2025-06-25      3.57      3.57     3.44       3.47          1.011662     -0.008571        3.50        0.13  0.114745
# 2025-06-26      3.46      3.48     3.40       3.42          0.997085     -0.014409        3.47        0.08  0.112263
# 2025-06-27      3.42      3.55     3.40       3.46          1.008746      0.011696        3.42        0.15  0.114959
# ...              ...       ...      ...        ...               ...           ...         ...         ...       ...
# 2025-09-17      7.23      7.45     7.06       7.45          2.172012      0.061254        7.02        0.43  0.420248
# 2025-09-18      7.23      7.50     7.20       7.37          2.148688     -0.010738        7.45        0.30  0.411659
# 2025-09-19      7.59      7.60     7.28       7.37          2.148688      0.000000        7.37        0.32  0.405112
# 2025-09-22      7.37      7.41     6.80       6.91          2.014577     -0.062415        7.37        0.61  0.419747
# 2025-09-23      6.90      7.17     6.77       6.93          2.020408      0.002894        6.91        0.40  0.418336
#
# [65 rows x 9 columns]
# --- Verifying Rank #5: MFG ---
# ### Sanity Check for Ticker: `MFG` | Period: `3M`
# **1. Price Performance Calculation:**
#    - Start Date (2025-06-23): 5.42
#    - End Date   (2025-09-23): 6.74
#    - Final Normalized Price: (6.74 / 5.42) = 1.2435
# **2. Sharpe Ratio Calculation:**
#    - Number of Trading Days: 65
#    - Mean of Daily Returns: 0.003550
#    - Std Dev of Daily Returns: 0.016836
#    - Annualized Sharpe Ratio: 3.3470
# **3. Return/ATR Calculation:**
#    - Mean of Daily Returns: 0.003550
#    - Mean ATR (14-day EWM): 0.108315
#    - Return / Mean ATR: 0.032773
# **4. Underlying Data and Calculation Worksheet:**
#             Adj Open  Adj High  Adj Low  Adj Close  Normalized Price  Daily Return  Prev Close  True Range       ATR
# Date
# 2025-06-23      5.35      5.43     5.35       5.42          1.000000           NaN         NaN        0.08  0.080000
# 2025-06-24      5.57      5.62     5.57       5.60          1.033210      0.033210        5.42        0.20  0.088571
# 2025-06-25      5.49      5.53     5.49       5.51          1.016605     -0.016071        5.60        0.11  0.090102
# 2025-06-26      5.57      5.62     5.57       5.60          1.033210      0.016334        5.51        0.11  0.091523
# 2025-06-27      5.57      5.58     5.53       5.56          1.025830     -0.007143        5.60        0.07  0.089986
# ...              ...       ...      ...        ...               ...           ...         ...         ...       ...
# 2025-09-17      6.56      6.63     6.53       6.56          1.210332     -0.001522        6.57        0.10  0.124442
# 2025-09-18      6.50      6.60     6.50       6.58          1.214022      0.003049        6.56        0.10  0.122696
# 2025-09-19      6.64      6.65     6.60       6.64          1.225092      0.009119        6.58        0.07  0.118932
# 2025-09-22      6.67      6.77     6.67       6.75          1.245387      0.016566        6.64        0.13  0.119722
# 2025-09-23      6.79      6.81     6.73       6.74          1.243542     -0.001481        6.75        0.08  0.116885
#
# [65 rows x 9 columns]
# ================================================================================
# --- VERIFICATION PROCESS COMPLETE ---
# ================================================================================

# %%
import os
# safe, platform-independent way
inspection_df_1.to_csv(os.path.join(download_path, f'{ticker_to_check_1}.csv'))
inspection_df_2.to_csv(os.path.join(download_path, f'{ticker_to_check_2}.csv'))

# %%
cutoff = pd.Timestamp('today') - pd.DateOffset(months=3)
last_3m = df_OHLCV.loc[df_OHLCV.index >= cutoff].copy()
last_3m

# %%
df_OHLCV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 375500 entries, ('A', Timestamp('2024-09-24 00:00:00')) to ('ZWS', Timestamp('2025-09-23 00:00:00'))
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Adj Open   375500 non-null  float64
#  1   Adj High   375500 non-null  float64
#  2   Adj Low    375500 non-null  float64
#  3   Adj Close  375500 non-null  float64
#  4   Volume     375500 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 23.9+ MB

# %%
df_OHLCV.sort_index(inplace=True)
df_OHLCV.loc[(ticker_to_check_1, slice('2025-06-23', '2025-09-23')), :]
# Out:
#                    Adj Open  Adj High  Adj Low  Adj Close     Volume
# Ticker Date
# NIO    2025-06-23      3.40      3.45     3.34       3.43   28943200
#        2025-06-24      3.46      3.57     3.41       3.50   33481300
#        2025-06-25      3.57      3.57     3.44       3.47   21509500
#        2025-06-26      3.46      3.48     3.40       3.42   31146400
#        2025-06-27      3.42      3.55     3.40       3.46   63720200
#        2025-06-30      3.49      3.49     3.41       3.43   24598900
#        2025-07-01      3.47      3.57     3.45       3.51   46064800
#        2025-07-02      3.50      3.54     3.47       3.48   22912600
#        2025-07-03      3.50      3.55     3.47       3.51   15645500
#        2025-07-07      3.44      3.47     3.39       3.41   31339200
#        2025-07-08      3.43      3.52     3.38       3.50   43515600
#        2025-07-09      3.52      3.59     3.46       3.48   26907300
#        2025-07-10      3.55      3.70     3.49       3.69   74015200
#        2025-07-11      3.75      4.05     3.70       3.90  141527800
#        2025-07-14      4.11      4.22     4.02       4.17  122870700
#        2025-07-15      4.25      4.28     4.13       4.25   66259200
#        2025-07-16      4.19      4.19     3.96       4.11   69862800
#        2025-07-17      4.13      4.49     4.11       4.40  116140100
#        2025-07-18      4.38      4.57     4.28       4.39   78373600
#        2025-07-21      4.47      4.67     4.46       4.52   58884000
#        2025-07-22      4.64      5.09     4.64       5.01  133091900
#        2025-07-23      5.19      5.21     4.87       4.92  108246500
#        2025-07-24      4.92      4.95     4.70       4.83   63260400
#        2025-07-25      4.84      5.09     4.79       4.92   60712300
#        2025-07-28      4.99      5.01     4.82       4.83   42322400
#        2025-07-29      4.82      4.84     4.68       4.71   38397400
#        2025-07-30      4.60      4.61     4.51       4.51   40824100
#        2025-07-31      4.68      4.98     4.46       4.87  131207100
#        2025-08-01      4.74      5.06     4.73       5.01   81680900
#        2025-08-04      4.89      4.90     4.58       4.60   92178900
#        2025-08-05      4.66      4.67     4.46       4.50   55676400
#        2025-08-06      4.59      4.67     4.52       4.61   55025100
#        2025-08-07      4.62      4.72     4.59       4.68   27399000
#        2025-08-08      4.73      4.87     4.71       4.84   36036300
#        2025-08-11      4.96      5.01     4.85       4.91   36250500
#        2025-08-12      4.74      4.74     4.45       4.47  106157200
#        2025-08-13      4.61      4.62     4.54       4.62   35804200
#        2025-08-14      4.50      4.51     4.37       4.45   43446300
#        2025-08-15      4.56      4.82     4.55       4.81   69021000
#        2025-08-18      4.91      4.97     4.81       4.87   47355300
#        2025-08-19      4.94      5.23     4.93       5.07   90447700
#        2025-08-20      5.01      5.14     4.97       5.07   46063500
#        2025-08-21      5.24      5.68     5.24       5.54  147125700
#        2025-08-22      5.87      6.58     5.78       6.34  234464700
#        2025-08-25      6.70      6.73     6.07       6.09  156581500
#        2025-08-26      6.39      6.83     6.38       6.70  146133100
#        2025-08-27      6.50      6.62     6.31       6.34   89801700
#        2025-08-28      6.53      6.54     6.26       6.51   74896800
#        2025-08-29      6.44      6.51     6.26       6.38   57629700
#        2025-09-02      6.24      6.64     6.06       6.58  123577100
#        2025-09-03      6.38      6.40     6.04       6.32   89712400
#        2025-09-04      6.07      6.19     5.97       6.13   72831200
#        2025-09-05      6.18      6.23     5.92       5.95   59299500
#        2025-09-08      6.05      6.23     5.95       6.17   81801400
#        2025-09-09      6.06      6.32     6.05       6.28   54499200
#        2025-09-10      5.74      5.78     5.60       5.72  237836500
#        2025-09-11      5.83      6.13     5.77       6.07   95275100
#        2025-09-12      6.03      6.29     5.94       6.22   75071300
#        2025-09-15      6.46      6.83     6.42       6.49   68234900
#        2025-09-16      6.55      7.09     6.48       7.02  130662500
#        2025-09-17      7.23      7.45     7.06       7.45  122761800
#        2025-09-18      7.23      7.50     7.20       7.37   76975000
#        2025-09-19      7.59      7.60     7.28       7.37   79099400
#        2025-09-22      7.37      7.41     6.80       6.91  128795300
#        2025-09-23      6.90      7.17     6.77       6.93   78265316

# %%
# --- Example Usage after running the main plotting cell ---

# Let's say the main plot is showing tickers for 'Return/ATR' over '6M'
_period = '3M' 

# Pick the top-ranked ticker from the list returned by the main function
if plotted_tickers:
    _ticker = plotted_tickers[0] 

    # Call the new inspection function
    inspection_df = inspect_ticker_data(
        df_OHLCV, # Use the same dataframe you passed to the plot
        ticker=_ticker, 
        period=_period
    )
else:
    print("Run the main plotting widget first to populate the 'plotted_tickers' list.")
# Out:
# ### Sanity Check for Ticker: `NIO` | Period: `3M`
# **1. Price Performance Calculation:**
#    - Start Date (2025-06-23): 3.43
#    - End Date   (2025-09-23): 6.93
#    - Final Normalized Price: (6.93 / 3.43) = 2.0204
# **2. Sharpe Ratio Calculation:**
#    - Number of Trading Days: 65
#    - Mean of Daily Returns: 0.012151
#    - Std Dev of Daily Returns: 0.047697
#    - Annualized Sharpe Ratio: 4.0441
# **3. Return/ATR Calculation:**
#    - Mean of Daily Returns: 0.012151
#    - Mean ATR (14-day EWM): 0.258025
#    - Return / Mean ATR: 0.047093
# **4. Underlying Data and Calculation Worksheet:**
#             Adj Open  Adj High  Adj Low  Adj Close  Normalized Price  Daily Return  Prev Close  True Range       ATR
# Date
# 2025-06-23      3.40      3.45     3.34       3.43          1.000000           NaN         NaN        0.11  0.110000
# 2025-06-24      3.46      3.57     3.41       3.50          1.020408      0.020408        3.43        0.16  0.113571
# 2025-06-25      3.57      3.57     3.44       3.47          1.011662     -0.008571        3.50        0.13  0.114745
# 2025-06-26      3.46      3.48     3.40       3.42          0.997085     -0.014409        3.47        0.08  0.112263
# 2025-06-27      3.42      3.55     3.40       3.46          1.008746      0.011696        3.42        0.15  0.114959
# ...              ...       ...      ...        ...               ...           ...         ...         ...       ...
# 2025-09-17      7.23      7.45     7.06       7.45          2.172012      0.061254        7.02        0.43  0.420248
# 2025-09-18      7.23      7.50     7.20       7.37          2.148688     -0.010738        7.45        0.30  0.411659
# 2025-09-19      7.59      7.60     7.28       7.37          2.148688      0.000000        7.37        0.32  0.405112
# 2025-09-22      7.37      7.41     6.80       6.91          2.014577     -0.062415        7.37        0.61  0.419747
# 2025-09-23      6.90      7.17     6.77       6.93          2.020408      0.002894        6.91        0.40  0.418336
#
# [65 rows x 9 columns]

# %%
_ticker = 'IREN'
_period = '3M'
_period_df = inspect_ticker_data(df_OHLCV, ticker=_ticker, period=_period)
# Out:
# ### Sanity Check for Ticker: `IREN` | Period: `3M`
# **1. Price Performance Calculation:**
#    - Start Date (2025-06-23): 10.66
#    - End Date   (2025-09-23): 41.77
#    - Final Normalized Price: (41.77 / 10.66) = 3.9184
# **2. Sharpe Ratio Calculation:**
#    - Number of Trading Days: 65
#    - Mean of Daily Returns: 0.022925
#    - Std Dev of Daily Returns: 0.053319
#    - Daily Sharpe Ratio: (0.022925 / 0.053319) = 0.4300
#    - Annualized Sharpe Ratio: (0.4300 * sqrt(252)) = 6.8255
# **3. Underlying Data Sample:**
#             Adj Close  Daily Return
# Date
# 2025-06-23      10.66           NaN
# 2025-06-24      11.54      0.082552
# 2025-06-25      11.87      0.028596
# 2025-06-26      13.11      0.104465
# 2025-06-27      14.00      0.067887
#    ...
#             Adj Close  Daily Return
# Date
# 2025-09-17      37.90      0.039781
# 2025-09-18      36.32     -0.041689
# 2025-09-19      38.64      0.063877
# 2025-09-22      41.90      0.084369
# 2025-09-23      41.77     -0.003103

# %%
_ticker = 'IREN'
_period = '3M'
_period_df = inspect_ticker_data(df_OHLCV, ticker=_ticker, period=_period)
# Out:
# ### Sanity Check for Ticker: `IREN` | Period: `3M`
# **1. Price Performance Calculation:**
#    - Start Date (2025-06-23): 10.66
#    - End Date   (2025-09-23): 41.77
#    - Final Normalized Price: (41.77 / 10.66) = 3.9184
# **2. Sharpe Ratio Calculation:**
#    - Number of Trading Days: 65
#    - Mean of Daily Returns: 0.022925
#    - Std Dev of Daily Returns: 0.053319
#    - Annualized Sharpe Ratio: 6.8255
# **3. Return/ATR Calculation:**
#    - Mean of Daily Returns: 0.022925
#    - Mean ATR (14-day EWM): 1.623931
#    - Return / Mean ATR: 0.014117
# **4. Underlying Data and Calculation Worksheet:**
#             Adj Open  Adj High  Adj Low  Adj Close  Normalized Price  Daily Return  Prev Close  True Range       ATR
# Date
# 2025-06-23    10.720    10.820    9.825      10.66          1.000000           NaN         NaN       0.995  0.995000
# 2025-06-24    11.070    11.620   10.920      11.54          1.082552      0.082552       10.66       0.960  0.992500
# 2025-06-25    11.980    12.235   11.750      11.87          1.113508      0.028596       11.54       0.695  0.971250
# 2025-06-26    11.890    13.295   11.600      13.11          1.229831      0.104465       11.87       1.695  1.022946
# 2025-06-27    13.390    14.290   13.090      14.00          1.313321      0.067887       13.11       1.200  1.035593
# ...              ...       ...      ...        ...               ...           ...         ...         ...       ...
# 2025-09-17    35.755    38.475   34.620      37.90          3.555347      0.039781       36.45       3.855  2.462469
# 2025-09-18    38.380    38.500   36.030      36.32          3.407129     -0.041689       37.90       2.470  2.463007
# 2025-09-19    36.710    39.870   36.630      38.64          3.624765      0.063877       36.32       3.550  2.540649
# 2025-09-22    41.385    42.930   39.645      41.90          3.930582      0.084369       38.64       4.290  2.665603
# 2025-09-23    43.005    44.250   40.580      41.77          3.918386     -0.003103       41.90       3.670  2.737345
#
# [65 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

def inspect_ticker_data(df_ohlcv, ticker, period):
    """
    Performs a detailed calculation sanity check for a single ticker over a given period.

    Args:
        df_ohlcv (pd.DataFrame): The original 'long' format DataFrame with a 
                                 (Ticker, Date) MultiIndex.
        ticker (str): The ticker symbol to inspect (e.g., 'NVDA').
        period (str): The period to analyze (e.g., '1Y', '3M', '5D').
    """
    # --- 1. Data Preparation ---
    
    # Check if the ticker exists
    if ticker not in df_ohlcv.index.get_level_values(0):
        print(f"Error: Ticker '{ticker}' not found in the DataFrame.")
        return

    # Select all data for the specified ticker and create a clean DataFrame
    ticker_df = df_ohlcv.loc[ticker].copy()
    ticker_df.index = pd.to_datetime(ticker_df.index)
    
    # Define the start date based on the period
    end_date = ticker_df.index.max()
    periods = {
        '1D': end_date - pd.DateOffset(days=1), '5D': end_date - pd.DateOffset(days=5),
        '3M': end_date - pd.DateOffset(months=3), '6M': end_date - pd.DateOffset(months=6),
        'YTD': datetime(end_date.year, 1, 1), '1Y': end_date - pd.DateOffset(years=1),
        '5Y': end_date - pd.DateOffset(years=5),
    }
    
    if period not in periods:
        print(f"Error: Period '{period}' is not a valid option. Choose from {list(periods.keys())}")
        return
        
    start_date = periods[period]
    
    # Slice the DataFrame for the requested period
    period_df = ticker_df.loc[start_date:end_date].copy()

    if len(period_df) < 2:
        print(f"Not enough data for ticker '{ticker}' in period '{period}' to perform calculations.")
        return

    # --- 2. Perform and Display Calculations ---

    display(Markdown(f"### Sanity Check for Ticker: `{ticker}` | Period: `{period}`"))

    # Price Performance
    start_price = period_df['Adj Close'].bfill().iloc[0]
    end_price = period_df['Adj Close'].ffill().iloc[-1]
    normalized_price = end_price / start_price
    
    display(Markdown("**1. Price Performance Calculation:**"))
    print(f"   - Start Date ({period_df.index.min().date()}): {start_price:,.2f}")
    print(f"   - End Date   ({period_df.index.max().date()}): {end_price:,.2f}")
    print(f"   - Final Normalized Price: ({end_price:,.2f} / {start_price:,.2f}) = {normalized_price:.4f}\n")

    # Sharpe Ratio
    period_df['Daily Return'] = period_df['Adj Close'].pct_change()
    mean_daily_return = period_df['Daily Return'].mean()
    std_daily_return = period_df['Daily Return'].std()
    
    # Handle case where standard deviation is zero (flat price)
    daily_sharpe = 0 if std_daily_return == 0 else mean_daily_return / std_daily_return
    annualized_sharpe = daily_sharpe * np.sqrt(252)

    display(Markdown("**2. Sharpe Ratio Calculation:**"))
    print(f"   - Number of Trading Days: {len(period_df)}")
    print(f"   - Mean of Daily Returns: {mean_daily_return:.6f}")
    print(f"   - Std Dev of Daily Returns: {std_daily_return:.6f}")
    print(f"   - Daily Sharpe Ratio: ({mean_daily_return:.6f} / {std_daily_return:.6f}) = {daily_sharpe:.4f}")
    print(f"   - Annualized Sharpe Ratio: ({daily_sharpe:.4f} * sqrt(252)) = {annualized_sharpe:.4f}\n")
    
    # --- 3. Display Underlying Data ---
    display(Markdown("**3. Underlying Data Sample:**"))
    display(period_df[['Adj Close', 'Daily Return']].head())
    if len(period_df) > 10:
        print("   ...")
        display(period_df[['Adj Close', 'Daily Return']].tail())
        
    return period_df[['Adj Close', 'Daily Return']]

# %%
_ticker = 'IREN'
_period = '3M'
_period_df = inspect_ticker_data(df_OHLCV, ticker=_ticker, period=_period)
# Out:
# ### Sanity Check for Ticker: `IREN` | Period: `3M`
# **1. Price Performance Calculation:**
#    - Start Date (2025-06-23): 10.66
#    - End Date   (2025-09-23): 41.77
#    - Final Normalized Price: (41.77 / 10.66) = 3.9184
# **2. Sharpe Ratio Calculation:**
#    - Number of Trading Days: 65
#    - Mean of Daily Returns: 0.022925
#    - Std Dev of Daily Returns: 0.053319
#    - Daily Sharpe Ratio: (0.022925 / 0.053319) = 0.4300
#    - Annualized Sharpe Ratio: (0.4300 * sqrt(252)) = 6.8255
# **3. Underlying Data Sample:**
#             Adj Close  Daily Return
# Date
# 2025-06-23      10.66           NaN
# 2025-06-24      11.54      0.082552
# 2025-06-25      11.87      0.028596
# 2025-06-26      13.11      0.104465
# 2025-06-27      14.00      0.067887
#    ...
#             Adj Close  Daily Return
# Date
# 2025-09-17      37.90      0.039781
# 2025-09-18      36.32     -0.041689
# 2025-09-19      38.64      0.063877
# 2025-09-22      41.90      0.084369
# 2025-09-23      41.77     -0.003103

# %%
_ticker_df = df_OHLCV.loc[_ticker].copy()

# %% [markdown]
# ##################

# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import pprint # Import the pretty-print library

def plot_interactive_performers_widget(df_ohlcv, 
                                       default_metric='Price',
                                       default_period='1Y', 
                                       default_rank_start=1,
                                       default_rank_end=10):
    """
    Creates a robust interactive plot using ipywidgets for state management.
    Allows for selecting tickers by a slice of their rank (e.g., 10th to 20th).
    Returns a list that is updated with the currently displayed tickers.
    """
    # --- [Section 1 & 2: Data Prep & Pre-computation] ---
    print("Reshaping and pre-computing all performance data...")
    if not isinstance(df_ohlcv.index, pd.MultiIndex) or 'Adj Close' not in df_ohlcv.columns:
        raise ValueError("Expected 'long' format with (Ticker, Date) MultiIndex and 'Adj Close' column.")
    df_close = df_ohlcv['Adj Close'].unstack(level=0)
    df_close.index = pd.to_datetime(df_close.index)
    end_date = df_close.index.max()
    metrics = ['Price', 'Sharpe']
    periods = {
        '1D': end_date - pd.DateOffset(days=1), '5D': end_date - pd.DateOffset(days=5),
        '3M': end_date - pd.DateOffset(months=3), '6M': end_date - pd.DateOffset(months=6),
        'YTD': datetime(end_date.year, 1, 1), '1Y': end_date - pd.DateOffset(years=1),
        '5Y': end_date - pd.DateOffset(years=5),
    }
    all_rankings = {metric: {} for metric in metrics}
    period_normalized_data = {}
    for label, start_date in periods.items():
        period_df = df_close.loc[start_date:end_date]
        if period_df.empty or len(period_df) < 2: continue
        first_prices, last_prices = period_df.bfill().iloc[0], period_df.ffill().iloc[-1]
        all_rankings['Price'][label] = (last_prices / first_prices).dropna().sort_values(ascending=False).index.tolist()
        daily_returns = period_df.pct_change()
        mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
        sharpe_ratio = (mean_returns / std_returns).fillna(0)
        all_rankings['Sharpe'][label] = (sharpe_ratio * np.sqrt(252)).sort_values(ascending=False).index.tolist()
        period_normalized_data[label] = period_df.div(first_prices)
    print("Pre-computation finished.")

    # --- 3. Create ipywidgets Controls & Data Holder ---
    rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
    max_traces = 50 
    metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
    period_dropdown = widgets.Dropdown(options=list(periods.keys()), value=default_period, description='Period:')
    rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
    rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
    update_button = widgets.Button(description="Update Chart", button_style='primary')
    ticker_list_output = widgets.Output()
    
    _currently_displayed_tickers = []

    # --- 4. Create a FigureWidget ---
    fig = go.FigureWidget()
    for i in range(max_traces):
        fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))

    # --- 5. Define the Update Logic ---
    def update_plot(button_click):
        metric, period, rank_start, rank_end = metric_dropdown.value, period_dropdown.value, rank_start_dropdown.value, rank_end_dropdown.value
        
        ticker_list_output.clear_output()
        
        if rank_start > rank_end:
            with ticker_list_output: print("Error: 'Rank Start' must be less than or equal to 'Rank End'.")
            return
        
        ranked_tickers = all_rankings[metric].get(period, [])
        tickers_to_display = ranked_tickers[rank_start-1:rank_end]
        norm_data = period_normalized_data.get(period)

        with fig.batch_update():
            for i in range(max_traces):
                trace = fig.data[i]
                if i < len(tickers_to_display) and norm_data is not None:
                    ticker = tickers_to_display[i]
                    trace.x, trace.y, trace.name = norm_data[ticker].index, norm_data[ticker], ticker
                    trace.visible, trace.showlegend = True, True
                else:
                    trace.visible, trace.showlegend = False, False
        
        _currently_displayed_tickers.clear()
        _currently_displayed_tickers.extend(tickers_to_display)
        
        with ticker_list_output:
            print("Currently Displayed Tickers:")
            # --- NEW: Use compact=True to force a more horizontal layout ---
            pprint.pprint(tickers_to_display, width=120, compact=True) 

    # --- 6. Set up Initial View and Layout ---
    update_plot(None)
    fig.update_layout(
        title_text='Top Performing Tickers (Normalized to 1)',
        xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)',
        hovermode='x unified', legend_title_text='Tickers',
        height=700, margin=dict(t=50)
    )
    fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
    update_button.on_click(update_plot)
    
    # --- 7. Display the UI ---
    controls = widgets.HBox([metric_dropdown, period_dropdown, rank_start_dropdown, rank_end_dropdown, update_button])
    ui_container = widgets.VBox([controls, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
    
    display(ui_container, fig)
    
    return _currently_displayed_tickers

# %%
# --- NEW: Initialize the variable before the call ---
plotted_tickers = [] 

# Call the final function and capture the returned list
# The 'plotted_tickers' list will be updated in place every time you click the button.
plotted_tickers = plot_interactive_performers_widget(
    df_ohlcv=df_OHLCV, 
    default_metric='Sharpe', 
    default_period='1Y', 
    default_rank_start=20, 
    default_rank_end=40
)

print("\n--- After the plot, the 'plotted_tickers' variable holds the last displayed list: ---")
print(plotted_tickers)

# %%
print("\n--- After the plot, the 'plotted_tickers' variable holds the last displayed list: ---")
print(plotted_tickers)
