# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import ipywidgets as widgets
import pprint 
from pathlib import Path
from datetime import datetime, date
from IPython.display import display, Markdown

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 3000)

download_path = Path.home() / "Downloads"  
# OHLCV_file_path = r'c:\Users\ping\Files_win10\python\py311\stocks\data\df_OHLCV_clean_stocks_etfs.parquet'
OHLCV_file_path = r'c:\Users\ping\Files_win10\python\py311\stocks\data\df_OHLCV_stocks_etfs.parquet'

df_OHLCV = pd.read_parquet(OHLCV_file_path, engine='pyarrow')

# %%
df_OHLCV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1094338 entries, ('AA', Timestamp('2025-09-25 00:00:00')) to ('ZWS', Timestamp('2023-01-03 00:00:00'))
# Data columns (total 5 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   Adj Open   1094338 non-null  float64
#  1   Adj High   1094338 non-null  float64
#  2   Adj Low    1094338 non-null  float64
#  3   Adj Close  1094338 non-null  float64
#  4   Volume     1094338 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 46.0+ MB

# %%
df_OHLCV.loc['AA']
# Out:
#             Adj Open  Adj High  Adj Low  Adj Close   Volume
# Date
# 2025-09-25   31.2100   31.8450  30.8100    31.4500  5318714
# 2025-09-24   31.7600   32.0300  31.1050    31.2300  7167700
# 2025-09-23   32.6700   32.9700  31.0300    31.5300  7983300
# 2025-09-22   32.0000   32.6400  31.7900    32.6300  4758300
# 2025-09-19   32.7700   32.9900  32.2800    32.4600  6383100
# ...              ...       ...      ...        ...      ...
# 2023-01-09   46.0172   48.9760  45.9205    48.6086  6386678
# 2023-01-06   44.9825   46.1622  44.1703    44.8278  4803970
# 2023-01-05   43.8028   44.4700  42.6812    43.9866  3966801
# 2023-01-04   43.2904   44.3830  42.9045    43.6385  3643827
# 2023-01-03   44.2573   45.1276  42.9713    43.1066  2978436
#
# [685 rows x 5 columns]

# %% [markdown]
# ### The New "Walk-Forward" Analyzer Function
#
# Here is the complete code. You can add this new function to your project; it does not replace or interfere with our previous functions.

# %%
# import pandas as pd
# import plotly.graph_objects as go
# from datetime import datetime, date
# import numpy as np
# import ipywidgets as widgets
# from IPython.display import display, Markdown
# import pprint 

# def plot_walk_forward_analyzer(df_ohlcv, 
#                                default_start_date=None,
#                                default_calc_period='3M', 
#                                default_fwd_period='1M',
#                                default_metric='Sharpe (ATR)',
#                                default_rank_start=1,
#                                default_rank_end=10):
#     """
#     Creates a robust, interactive walk-forward analysis plot.
#     Returns a container whose first element is updated with a results DataFrame
#     that includes both calculation gain ('CalcGain') and forward-looking gain ('FwdGain').
#     """
#     print("Initializing Walk-Forward Analyzer...")
#     if not isinstance(df_ohlcv.index, pd.MultiIndex):
#         raise ValueError("Input DataFrame must have a (Ticker, Date) MultiIndex.")
#     df_ohlcv = df_ohlcv.sort_index()
#     print("Pre-processing data (unstacking)...")
#     df_close_full = df_ohlcv['Adj Close'].unstack(level=0)
#     df_high_full = df_ohlcv['Adj High'].unstack(level=0)
#     df_low_full = df_ohlcv['Adj Low'].unstack(level=0)
#     df_close_full.index = pd.to_datetime(df_close_full.index)
#     df_high_full.index = pd.to_datetime(df_high_full.index)
#     df_low_full.index = pd.to_datetime(df_low_full.index)
    
#     if isinstance(default_start_date, str):
#         default_start_date = pd.to_datetime(default_start_date).date()
    
#     min_date_available = df_close_full.index.min()
#     max_date_available = df_close_full.index.max()
#     if default_start_date is None:
#         default_start_date = max_date_available.date() - pd.DateOffset(years=1)
        
#     start_date_picker = widgets.DatePicker(description='Start Date:', value=default_start_date, disabled=False)
#     # ... (rest of widget definitions are unchanged) ...
#     calc_period_options = {'1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1)}
#     fwd_period_options = {'0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2), '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3)}
#     calc_period_dropdown = widgets.Dropdown(options=calc_period_options.keys(), value=default_calc_period, description='Calc Period:')
#     fwd_period_dropdown = widgets.Dropdown(options=fwd_period_options.keys(), value=default_fwd_period, description='Fwd Period:')
#     metrics = ['Price', 'Sharpe', 'Sharpe (ATR)']
#     metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
#     rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
#     rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
#     rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
#     update_button = widgets.Button(description="Update Chart", button_style='primary')
#     ticker_list_output = widgets.Output()
#     results_container = [None]
#     fig = go.FigureWidget()
#     max_traces = 50
#     for i in range(max_traces):
#         fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))


#     def update_plot(button_click):
#         ticker_list_output.clear_output()
#         start_date = pd.to_datetime(start_date_picker.value)
#         calc_period = calc_period_options[calc_period_dropdown.value]
#         fwd_period = fwd_period_options[fwd_period_dropdown.value]
#         metric = metric_dropdown.value
#         rank_start, rank_end = rank_start_dropdown.value, rank_end_dropdown.value
#         if rank_start > rank_end:
#             with ticker_list_output: print("Error: 'Rank Start' must be <= 'Rank End'.")
#             return
#         calc_end_date_theoretical = start_date + calc_period
#         viz_end_date_theoretical = calc_end_date_theoretical + fwd_period
#         safe_start_date = max(start_date, min_date_available)
#         safe_calc_end_date = min(calc_end_date_theoretical, max_date_available)
#         safe_viz_end_date = min(viz_end_date_theoretical, max_date_available)
#         if safe_start_date >= safe_calc_end_date:
#             with ticker_list_output: print(f"Error: Invalid date range. The calculation period has no data.")
#             return
            
#         calc_close_raw = df_close_full.loc[safe_start_date:safe_calc_end_date]
        
#         # --- DEFINITIVE FIX: Drop columns (tickers) that have NO data in the period ---
#         calc_close = calc_close_raw.dropna(axis=1, how='all')
        
#         if calc_close.shape[1] == 0 or len(calc_close) < 2:
#             with ticker_list_output: print("Error: Not enough data in the calculation period to rank.")
#             return

#         metric_values = {}
#         first_prices = calc_close.bfill().iloc[0]
#         last_prices = calc_close.ffill().iloc[-1]
#         metric_values['Price'] = (last_prices / first_prices).dropna()
        
#         # This will now be called on a clean DataFrame with no all-NaN columns
#         daily_returns = calc_close.bfill().ffill().pct_change()
        
#         mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
#         metric_values['Sharpe'] = (mean_returns / std_returns * np.sqrt(252)).fillna(0)
        
#         # Ensure High/Low DFs only contain the valid tickers
#         valid_tickers = calc_close.columns
#         calc_high = df_high_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         calc_low = df_low_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]

#         high_low = calc_high - calc_low
#         high_prev_close = abs(calc_high - df_close_full[valid_tickers].shift(1).loc[safe_start_date:safe_calc_end_date])
#         low_prev_close = abs(calc_low - df_close_full[valid_tickers].shift(1).loc[safe_start_date:safe_calc_end_date])
#         tr = np.maximum(high_low, np.maximum(high_prev_close, low_prev_close))
#         atr = tr.ewm(alpha=1/14, adjust=False).mean()
#         atrp = (atr / calc_close).mean()
#         metric_values['Sharpe (ATR)'] = (mean_returns / atrp).fillna(0)
        
#         sorted_tickers = metric_values[metric].sort_values(ascending=False)
#         # ... (rest of the function is unchanged and will work correctly) ...
#         tickers_to_display = sorted_tickers.index[rank_start-1:rank_end].tolist()
#         normalized_plot_data = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date]
#         normalized_plot_data = normalized_plot_data.div(normalized_plot_data.bfill().iloc[0])
#         actual_calc_end_ts = calc_close.index.max()
#         actual_viz_start_date = normalized_plot_data.index.min().date()
#         actual_viz_end_date = normalized_plot_data.index.max().date()
#         actual_calc_end_date = actual_calc_end_ts.date()
#         with fig.batch_update():
#             fig.layout.shapes = []
#             fig.add_shape(type="line", x0=actual_calc_end_ts, y0=0, x1=actual_calc_end_ts, y1=1, xref='x', yref='paper', line=dict(color="grey", width=2, dash="dash"))
#             for i in range(max_traces):
#                 trace = fig.data[i]
#                 if i < len(tickers_to_display):
#                     ticker = tickers_to_display[i]
#                     trace.x, trace.y, trace.name = normalized_plot_data.index, normalized_plot_data[ticker], ticker
#                     trace.visible, trace.showlegend = True, True
#                 else:
#                     trace.visible, trace.showlegend = False, False
        
#         calc_start_prices = calc_close.bfill().iloc[0]
#         calc_end_prices = calc_close.ffill().iloc[-1]
        
#         fwd_close_slice = df_close_full.loc[actual_calc_end_ts:safe_viz_end_date]
        
#         if fwd_close_slice.empty or len(fwd_close_slice) < 2:
#             viz_end_prices = calc_end_prices
#         else:
#             viz_end_prices = fwd_close_slice.ffill().iloc[-1]

#         calc_gains = (calc_end_prices / calc_start_prices) - 1
#         fwd_gains = (viz_end_prices / calc_end_prices) - 1
#         results_df = pd.DataFrame({'Rank': range(rank_start, rank_start + len(tickers_to_display)), 'Metric': metric, 'MetricValue': sorted_tickers.loc[tickers_to_display].values, 'CalcPrice': calc_end_prices.loc[tickers_to_display], 'CalcGain': calc_gains.loc[tickers_to_display], 'CalcPeriod': calc_period_dropdown.value, 'FwdPeriod': fwd_period_dropdown.value, 'FwdGain': fwd_gains.loc[tickers_to_display]}, index=pd.Index(tickers_to_display, name='Ticker'))
#         results_df = results_df[['Rank', 'Metric', 'MetricValue', 'CalcPrice', 'CalcGain', 'CalcPeriod', 'FwdPeriod', 'FwdGain']]
#         results_container[0] = results_df
#         with ticker_list_output:
#              print(f"Analyzing from {actual_viz_start_date} to {actual_viz_end_date}.")
#              print(f"  - Ranking based on performance from {actual_viz_start_date} to {actual_calc_end_date}.")
#              pprint.pprint(tickers_to_display, width=120, compact=True)

#     fig.update_layout(title_text='Walk-Forward Performance Analysis', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers (Ranked)', height=700, margin=dict(t=50))
#     fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
#     update_button.on_click(update_plot)
#     controls_row1 = widgets.HBox([start_date_picker, calc_period_dropdown, fwd_period_dropdown])
#     controls_row2 = widgets.HBox([metric_dropdown, rank_start_dropdown, rank_end_dropdown, update_button])
#     ui_container = widgets.VBox([controls_row1, controls_row2, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
#     display(ui_container, fig)
#     update_plot(None)
#     return results_container

# %%
# # All imports remain the same
# import pandas as pd
# import plotly.graph_objects as go
# from datetime import datetime, date
# import numpy as np
# import ipywidgets as widgets
# from IPython.display import display, Markdown
# import pprint 

# # --- Function 1: The Advanced Walk-Forward Analyzer (UPDATED) ---
# def plot_walk_forward_analyzer(df_ohlcv, 
#                                default_start_date=None,
#                                default_calc_period='3M', 
#                                default_fwd_period='1M',
#                                default_metric='Sharpe (ATR)',
#                                default_rank_start=1,
#                                default_rank_end=10,
#                                default_benchmark_ticker='VOO'): # New parameter for default benchmark
#     """
#     Creates a robust, interactive walk-forward analysis plot with benchmark and portfolio analysis.
#     Returns a container whose first element is updated with a results DataFrame
#     that includes both calculation gain ('CalcGain') and forward-looking gain ('FwdGain').
#     """
#     print("Initializing Walk-Forward Analyzer...")
#     if not isinstance(df_ohlcv.index, pd.MultiIndex):
#         raise ValueError("Input DataFrame must have a (Ticker, Date) MultiIndex.")
#     df_ohlcv = df_ohlcv.sort_index()
#     print("Pre-processing data (unstacking)...")
#     # Using 'Adj Close' for all calculations to ensure consistency
#     df_close_full = df_ohlcv['Adj Close'].unstack(level=0)
#     df_high_full = df_ohlcv['Adj High'].unstack(level=0)
#     df_low_full = df_ohlcv['Adj Low'].unstack(level=0)
#     df_close_full.index = pd.to_datetime(df_close_full.index)
#     df_high_full.index = pd.to_datetime(df_high_full.index)
#     df_low_full.index = pd.to_datetime(df_low_full.index)
    
#     if isinstance(default_start_date, str):
#         default_start_date = pd.to_datetime(default_start_date).date()
    
#     min_date_available = df_close_full.index.min()
#     max_date_available = df_close_full.index.max()
#     if default_start_date is None:
#         default_start_date = max_date_available.date() - pd.DateOffset(years=1)
        
#     # --- WIDGET DEFINITIONS (with new Benchmark Text Box) ---
#     start_date_picker = widgets.DatePicker(description='Start Date:', value=default_start_date, disabled=False)
#     calc_period_options = {'1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1)}
#     fwd_period_options = {'0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2), '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3)}
#     calc_period_dropdown = widgets.Dropdown(options=calc_period_options.keys(), value=default_calc_period, description='Calc Period:')
#     fwd_period_dropdown = widgets.Dropdown(options=fwd_period_options.keys(), value=default_fwd_period, description='Fwd Period:')
#     metrics = ['Price', 'Sharpe', 'Sharpe (ATR)']
#     metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
#     rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
#     rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
#     rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
#     benchmark_ticker_input = widgets.Text(value=default_benchmark_ticker, description='Benchmark:', placeholder='Enter Ticker') # <-- NEW WIDGET
#     update_button = widgets.Button(description="Update Chart", button_style='primary')
#     ticker_list_output = widgets.Output()
#     results_container = [None]

#     # --- FIGURE INITIALIZATION (with new placeholder traces) ---
#     fig = go.FigureWidget()
#     max_traces = 50
#     # Placeholder traces for individual ranked tickers
#     for i in range(max_traces):
#         fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))
    
#     # NEW: Add dedicated trace for the Benchmark
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Benchmark', visible=True, showlegend=True,
#                            line=dict(color='black', width=3, dash='dash')))
    
#     # NEW: Add dedicated trace for the Group Portfolio
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Group Portfolio', visible=True, showlegend=True,
#                            line=dict(color='green', width=3)))

#     def update_plot(button_click):
#         ticker_list_output.clear_output()
#         # --- Get values from widgets ---
#         start_date = pd.to_datetime(start_date_picker.value)
#         calc_period = calc_period_options[calc_period_dropdown.value]
#         fwd_period = fwd_period_options[fwd_period_dropdown.value]
#         metric = metric_dropdown.value
#         rank_start, rank_end = rank_start_dropdown.value, rank_end_dropdown.value
#         benchmark_ticker = benchmark_ticker_input.value.strip().upper() # <-- NEW: Get benchmark ticker

#         # --- Date and data slicing logic (unchanged) ---
#         if rank_start > rank_end:
#             with ticker_list_output: print("Error: 'Rank Start' must be <= 'Rank End'.")
#             return
#         calc_end_date_theoretical = start_date + calc_period
#         viz_end_date_theoretical = calc_end_date_theoretical + fwd_period
#         safe_start_date = max(start_date, min_date_available)
#         safe_calc_end_date = min(calc_end_date_theoretical, max_date_available)
#         safe_viz_end_date = min(viz_end_date_theoretical, max_date_available)
#         if safe_start_date >= safe_calc_end_date:
#             with ticker_list_output: print(f"Error: Invalid date range. The calculation period has no data.")
#             return
            
#         calc_close_raw = df_close_full.loc[safe_start_date:safe_calc_end_date]
#         calc_close = calc_close_raw.dropna(axis=1, how='all')
        
#         if calc_close.shape[1] == 0 or len(calc_close) < 2:
#             with ticker_list_output: print("Error: Not enough data in the calculation period to rank.")
#             return

#         # --- Metric calculation logic (unchanged) ---
#         metric_values = {}
#         first_prices = calc_close.bfill().iloc[0]
#         last_prices = calc_close.ffill().iloc[-1]
#         metric_values['Price'] = (last_prices / first_prices).dropna()
#         daily_returns = calc_close.bfill().ffill().pct_change()
#         mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
#         metric_values['Sharpe'] = (mean_returns / std_returns * np.sqrt(252)).fillna(0)
#         valid_tickers = calc_close.columns
#         calc_high = df_high_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         calc_low = df_low_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         high_low = calc_high - calc_low
#         high_prev_close = abs(calc_high - df_close_full[valid_tickers].shift(1).loc[safe_start_date:safe_calc_end_date])
#         low_prev_close = abs(calc_low - df_close_full[valid_tickers].shift(1).loc[safe_start_date:safe_calc_end_date])
#         tr = np.maximum(high_low, np.maximum(high_prev_close, low_prev_close))
#         atr = tr.ewm(alpha=1/14, adjust=False).mean()
#         atrp = (atr / calc_close).mean()
#         metric_values['Sharpe (ATR)'] = (mean_returns / atrp).fillna(0)
        
#         # --- Ticker selection and plotting data normalization (unchanged) ---
#         sorted_tickers = metric_values[metric].sort_values(ascending=False)
#         tickers_to_display = sorted_tickers.index[rank_start-1:rank_end].tolist()
#         if not tickers_to_display:
#             with ticker_list_output: print("Error: No tickers found for the selected rank range.")
#             return
            
#         normalized_plot_data = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date]
#         normalized_plot_data = normalized_plot_data.div(normalized_plot_data.bfill().iloc[0])

#         actual_calc_end_ts = calc_close.index.max()
#         actual_viz_start_date = normalized_plot_data.index.min().date()
#         actual_viz_end_date = normalized_plot_data.index.max().date()
#         actual_calc_end_date = actual_calc_end_ts.date()

#         # --- BATCH FIGURE UPDATE (Now includes Benchmark and Portfolio) ---
#         with fig.batch_update():
#             # Update individual ticker traces
#             for i in range(max_traces):
#                 trace = fig.data[i]
#                 if i < len(tickers_to_display):
#                     ticker = tickers_to_display[i]
#                     trace.x, trace.y, trace.name = normalized_plot_data.index, normalized_plot_data[ticker], ticker
#                     trace.visible, trace.showlegend = True, True
#                 else:
#                     trace.visible, trace.showlegend = False, False

#             # NEW: Update Benchmark Trace
#             benchmark_trace = fig.data[max_traces]
#             if benchmark_ticker and benchmark_ticker in df_close_full.columns:
#                 benchmark_series = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date]
#                 if not benchmark_series.dropna().empty:
#                     normalized_benchmark = benchmark_series / benchmark_series.bfill().iloc[0]
#                     benchmark_trace.x, benchmark_trace.y = normalized_benchmark.index, normalized_benchmark
#                     benchmark_trace.name = f"Benchmark ({benchmark_ticker})"
#                     benchmark_trace.visible = True
#                 else:
#                     benchmark_trace.visible = False # Hide if no data in period
#             else:
#                 benchmark_trace.visible = False # Hide if ticker invalid or not provided

#             # NEW: Update Group Portfolio Trace
#             portfolio_trace = fig.data[max_traces + 1]
#             portfolio_series = normalized_plot_data.mean(axis=1)
#             portfolio_trace.x, portfolio_trace.y = portfolio_series.index, portfolio_series
#             portfolio_trace.name = 'Group Portfolio'
#             portfolio_trace.visible = True

#             # Update layout (unchanged)
#             fig.layout.shapes = []
#             fig.add_shape(type="line", x0=actual_calc_end_ts, y0=0, x1=actual_calc_end_ts, y1=1, xref='x', yref='paper', line=dict(color="grey", width=2, dash="dash"))
        
#         # --- Results DataFrame creation (unchanged) ---
#         calc_start_prices = calc_close.bfill().iloc[0]
#         calc_end_prices = calc_close.ffill().iloc[-1]
#         fwd_close_slice = df_close_full.loc[actual_calc_end_ts:safe_viz_end_date]
#         if fwd_close_slice.empty or len(fwd_close_slice) < 2:
#             viz_end_prices = calc_end_prices
#         else:
#             viz_end_prices = fwd_close_slice.ffill().iloc[-1]
#         calc_gains = (calc_end_prices / calc_start_prices) - 1
#         fwd_gains = (viz_end_prices / calc_end_prices) - 1
#         results_df = pd.DataFrame({'Rank': range(rank_start, rank_start + len(tickers_to_display)), 'Metric': metric, 'MetricValue': sorted_tickers.loc[tickers_to_display].values, 'CalcPrice': calc_end_prices.loc[tickers_to_display], 'CalcGain': calc_gains.loc[tickers_to_display], 'CalcPeriod': calc_period_dropdown.value, 'FwdPeriod': fwd_period_dropdown.value, 'FwdGain': fwd_gains.loc[tickers_to_display]}, index=pd.Index(tickers_to_display, name='Ticker'))
#         results_df = results_df[['Rank', 'Metric', 'MetricValue', 'CalcPrice', 'CalcGain', 'CalcPeriod', 'FwdPeriod', 'FwdGain']]
#         results_container[0] = results_df

#         # --- TEXT OUTPUT (Now includes Sharpe comparisons) ---
#         with ticker_list_output:
#              print(f"Analyzing from {actual_viz_start_date} to {actual_viz_end_date}.")
#              print(f"  - Ranking based on performance from {actual_viz_start_date} to {actual_calc_end_date}.")
#              pprint.pprint(tickers_to_display, width=120, compact=True)

#              # NEW: Sharpe Ratio Analysis for the full visualized period
#              print("\n--- Full Period Performance ---")
             
#              # Portfolio Sharpe
#              full_period_raw_portfolio = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date].mean(axis=1)
#              portfolio_returns = full_period_raw_portfolio.pct_change()
#              if portfolio_returns.std() > 0:
#                  portfolio_sharpe = (portfolio_returns.mean() / portfolio_returns.std()) * np.sqrt(252)
#                  print(f"  - Group Portfolio Sharpe: {portfolio_sharpe:.2f}")
#              else:
#                  print("  - Group Portfolio Sharpe: N/A (no volatility)")

#              # Benchmark Sharpe
#              if benchmark_trace.visible:
#                  full_period_raw_benchmark = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date]
#                  benchmark_returns = full_period_raw_benchmark.pct_change()
#                  if benchmark_returns.std() > 0:
#                      benchmark_sharpe = (benchmark_returns.mean() / benchmark_returns.std()) * np.sqrt(252)
#                      print(f"  - Benchmark ({benchmark_ticker}) Sharpe: {benchmark_sharpe:.2f}")
#                  else:
#                      print(f"  - Benchmark ({benchmark_ticker}) Sharpe: N/A (no volatility)")
#              else:
#                  if not benchmark_ticker:
#                      print("  - Benchmark Sharpe: No benchmark ticker entered.")
#                  else:
#                      print(f"  - Benchmark Sharpe: Ticker '{benchmark_ticker}' not found or has no data in this period.")


#     # --- FINAL UI LAYOUT ---
#     fig.update_layout(title_text='Walk-Forward Performance Analysis', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers (Ranked)', height=700, margin=dict(t=50))
#     fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
#     update_button.on_click(update_plot)
#     controls_row1 = widgets.HBox([start_date_picker, calc_period_dropdown, fwd_period_dropdown])
#     # Add new benchmark widget to the controls
#     controls_row2 = widgets.HBox([metric_dropdown, rank_start_dropdown, rank_end_dropdown, benchmark_ticker_input, update_button])
#     ui_container = widgets.VBox([controls_row1, controls_row2, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
    
#     display(ui_container, fig)
#     update_plot(None) # Initial plot draw
#     return results_container

# %%
# # All imports remain the same
# import pandas as pd
# import plotly.graph_objects as go
# from datetime import datetime, date
# import numpy as np
# import ipywidgets as widgets
# from IPython.display import display, Markdown
# import pprint 

# # --- Function 1: The Advanced Walk-Forward Analyzer (UPDATED) ---
# def plot_walk_forward_analyzer(df_ohlcv, 
#                                default_start_date=None,
#                                default_calc_period='3M', 
#                                default_fwd_period='1M',
#                                default_metric='Sharpe (ATR)',
#                                default_rank_start=1,
#                                default_rank_end=10,
#                                default_benchmark_ticker='VOO'):
#     """
#     Creates a robust, interactive walk-forward analysis plot with benchmark and portfolio analysis.
#     Returns a container whose first element is updated with a results DataFrame
#     that includes both calculation gain ('CalcGain') and forward-looking gain ('FwdGain').
#     """
#     print("Initializing Walk-Forward Analyzer...")
#     if not isinstance(df_ohlcv.index, pd.MultiIndex):
#         raise ValueError("Input DataFrame must have a (Ticker, Date) MultiIndex.")
#     df_ohlcv = df_ohlcv.sort_index()
#     print("Pre-processing data (unstacking)...")
#     df_close_full = df_ohlcv['Adj Close'].unstack(level=0)
#     df_high_full = df_ohlcv['Adj High'].unstack(level=0)
#     df_low_full = df_ohlcv['Adj Low'].unstack(level=0)
#     df_close_full.index = pd.to_datetime(df_close_full.index)
#     df_high_full.index = pd.to_datetime(df_high_full.index)
#     df_low_full.index = pd.to_datetime(df_low_full.index)
    
#     if isinstance(default_start_date, str):
#         default_start_date = pd.to_datetime(default_start_date).date()
    
#     min_date_available = df_close_full.index.min()
#     max_date_available = df_close_full.index.max()
#     if default_start_date is None:
#         default_start_date = max_date_available.date() - pd.DateOffset(years=1)
        
#     start_date_picker = widgets.DatePicker(description='Start Date:', value=default_start_date, disabled=False)
#     calc_period_options = {'1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1)}
#     fwd_period_options = {'0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2), '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3)}
#     calc_period_dropdown = widgets.Dropdown(options=calc_period_options.keys(), value=default_calc_period, description='Calc Period:')
#     fwd_period_dropdown = widgets.Dropdown(options=fwd_period_options.keys(), value=default_fwd_period, description='Fwd Period:')
#     metrics = ['Price', 'Sharpe', 'Sharpe (ATR)']
#     metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
#     rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
#     rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
#     rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
#     benchmark_ticker_input = widgets.Text(value=default_benchmark_ticker, description='Benchmark:', placeholder='Enter Ticker')
#     update_button = widgets.Button(description="Update Chart", button_style='primary')
#     ticker_list_output = widgets.Output()
#     results_container = [None]

#     fig = go.FigureWidget()
#     max_traces = 50
#     for i in range(max_traces):
#         fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Benchmark', visible=True, showlegend=True, line=dict(color='black', width=3, dash='dash')))
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Group Portfolio', visible=True, showlegend=True, line=dict(color='green', width=3)))

#     def calculate_performance_metrics(price_series: pd.Series):
#         """Helper function to compute gain and Sharpe for a given price series."""
#         if price_series.dropna().shape[0] < 2:
#             return {'gain': np.nan, 'sharpe': np.nan}
        
#         gain = (price_series.ffill().iloc[-1] / price_series.bfill().iloc[0]) - 1
        
#         returns = price_series.pct_change()
#         std_dev = returns.std()
        
#         if std_dev > 0:
#             sharpe = (returns.mean() / std_dev) * np.sqrt(252)
#         else:
#             sharpe = np.nan # Or 0, but NaN is more explicit for no volatility
            
#         return {'gain': gain, 'sharpe': sharpe}

#     def update_plot(button_click):
#         ticker_list_output.clear_output()
#         # --- Get values from widgets (unchanged) ---
#         start_date = pd.to_datetime(start_date_picker.value)
#         calc_period = calc_period_options[calc_period_dropdown.value]
#         fwd_period = fwd_period_options[fwd_period_dropdown.value]
#         metric = metric_dropdown.value
#         rank_start, rank_end = rank_start_dropdown.value, rank_end_dropdown.value
#         benchmark_ticker = benchmark_ticker_input.value.strip().upper()
        
#         # --- Date and data slicing logic (unchanged) ---
#         if rank_start > rank_end:
#             with ticker_list_output: print("Error: 'Rank Start' must be <= 'Rank End'.")
#             return
#         calc_end_date_theoretical = start_date + calc_period
#         viz_end_date_theoretical = calc_end_date_theoretical + fwd_period
#         safe_start_date = max(start_date, min_date_available)
#         safe_calc_end_date = min(calc_end_date_theoretical, max_date_available)
#         safe_viz_end_date = min(viz_end_date_theoretical, max_date_available)
#         if safe_start_date >= safe_calc_end_date:
#             with ticker_list_output: print(f"Error: Invalid date range. The calculation period has no data.")
#             return
#         calc_close_raw = df_close_full.loc[safe_start_date:safe_calc_end_date]
#         calc_close = calc_close_raw.dropna(axis=1, how='all')
#         if calc_close.shape[1] == 0 or len(calc_close) < 2:
#             with ticker_list_output: print("Error: Not enough data in the calculation period to rank.")
#             return
        
#         # --- Metric calculation and ranking (unchanged) ---
#         metric_values = {}
#         first_prices = calc_close.bfill().iloc[0]; last_prices = calc_close.ffill().iloc[-1]
#         metric_values['Price'] = (last_prices / first_prices).dropna()
#         daily_returns = calc_close.bfill().ffill().pct_change()
#         mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
#         metric_values['Sharpe'] = (mean_returns / std_returns * np.sqrt(252)).fillna(0)
#         valid_tickers = calc_close.columns
#         calc_high = df_high_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         calc_low = df_low_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         tr = np.maximum(calc_high - calc_low, abs(calc_high - df_close_full[valid_tickers].shift(1)), abs(calc_low - df_close_full[valid_tickers].shift(1)))
#         atr = tr.ewm(alpha=1/14, adjust=False).mean()
#         atrp = (atr / calc_close).mean()
#         metric_values['Sharpe (ATR)'] = (mean_returns / atrp).fillna(0)
#         sorted_tickers = metric_values[metric].sort_values(ascending=False)
#         tickers_to_display = sorted_tickers.index[rank_start-1:rank_end].tolist()
#         if not tickers_to_display:
#             with ticker_list_output: print("Error: No tickers found for the selected rank range.")
#             return
            
#         # --- Plotting data preparation (unchanged) ---
#         normalized_plot_data = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date]
#         normalized_plot_data = normalized_plot_data.div(normalized_plot_data.bfill().iloc[0])
#         actual_calc_end_ts = calc_close.index.max()
#         actual_viz_start_date = normalized_plot_data.index.min().date()
#         actual_viz_end_date = normalized_plot_data.index.max().date()

#         # --- Plot updates (unchanged) ---
#         with fig.batch_update():
#             for i in range(max_traces):
#                 trace = fig.data[i]
#                 if i < len(tickers_to_display):
#                     ticker = tickers_to_display[i]
#                     trace.x, trace.y, trace.name = normalized_plot_data.index, normalized_plot_data[ticker], ticker
#                     trace.visible, trace.showlegend = True, True
#                 else: trace.visible, trace.showlegend = False, False
#             benchmark_trace = fig.data[max_traces]
#             if benchmark_ticker and benchmark_ticker in df_close_full.columns:
#                 benchmark_series = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date]
#                 if not benchmark_series.dropna().empty:
#                     normalized_benchmark = benchmark_series / benchmark_series.bfill().iloc[0]
#                     benchmark_trace.x, benchmark_trace.y = normalized_benchmark.index, normalized_benchmark
#                     benchmark_trace.name = f"Benchmark ({benchmark_ticker})"; benchmark_trace.visible = True
#                 else: benchmark_trace.visible = False
#             else: benchmark_trace.visible = False
#             portfolio_trace = fig.data[max_traces + 1]
#             portfolio_series = normalized_plot_data.mean(axis=1)
#             portfolio_trace.x, portfolio_trace.y = portfolio_series.index, portfolio_series
#             portfolio_trace.name = 'Group Portfolio'; portfolio_trace.visible = True
#             fig.layout.shapes = []
#             fig.add_shape(type="line", x0=actual_calc_end_ts, y0=0, x1=actual_calc_end_ts, y1=1, xref='x', yref='paper', line=dict(color="grey", width=2, dash="dash"))
        
#         # --- Results DataFrame creation (unchanged) ---
#         # (This part can be kept as is, it populates the returned object)
#         calc_start_prices = calc_close.bfill().iloc[0]
#         calc_end_prices = calc_close.ffill().iloc[-1]
#         fwd_close_slice = df_close_full.loc[actual_calc_end_ts:safe_viz_end_date]
#         if fwd_close_slice.empty or len(fwd_close_slice) < 2:
#             viz_end_prices = calc_end_prices
#         else:
#             viz_end_prices = fwd_close_slice.ffill().iloc[-1]
#         calc_gains = (calc_end_prices / calc_start_prices) - 1
#         fwd_gains = (viz_end_prices / calc_end_prices) - 1
#         results_df = pd.DataFrame({'Rank': range(rank_start, rank_start + len(tickers_to_display)), 'Metric': metric, 'MetricValue': sorted_tickers.loc[tickers_to_display].values, 'CalcPrice': calc_end_prices.loc[tickers_to_display], 'CalcGain': calc_gains.loc[tickers_to_display], 'CalcPeriod': calc_period_dropdown.value, 'FwdPeriod': fwd_period_dropdown.value, 'FwdGain': fwd_gains.loc[tickers_to_display]}, index=pd.Index(tickers_to_display, name='Ticker'))
#         results_container[0] = results_df
        
#         # --- NEW: DETAILED PERFORMANCE ANALYSIS AND OUTPUT ---
#         with ticker_list_output:
#             print(f"Analyzing from {actual_viz_start_date} to {actual_viz_end_date}.")
#             print(f"  - Ranking based on performance from {actual_viz_start_date} to {actual_calc_end_ts.date()}.")
#             pprint.pprint(tickers_to_display, width=120, compact=True)
            
#             # Prepare raw price series for the portfolio and benchmark
#             portfolio_raw = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date].mean(axis=1)
#             benchmark_raw = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date] if benchmark_trace.visible else pd.Series(dtype='float64')

#             # --- Slicing for each period ---
#             calc_p = portfolio_raw.loc[:actual_calc_end_ts]
#             calc_b = benchmark_raw.loc[:actual_calc_end_ts]
#             fwd_p = portfolio_raw.loc[actual_calc_end_ts:]
#             fwd_b = benchmark_raw.loc[actual_calc_end_ts:]
            
#             # --- Calculate performance for each period ---
#             perf_calc = {'port': calculate_performance_metrics(calc_p), 'bench': calculate_performance_metrics(calc_b)}
#             perf_fwd = {'port': calculate_performance_metrics(fwd_p), 'bench': calculate_performance_metrics(fwd_b)}
#             perf_full = {'port': calculate_performance_metrics(portfolio_raw), 'bench': calculate_performance_metrics(benchmark_raw)}
            
#             # --- Formatted Printing ---
#             def print_period_stats(title, period_perf):
#                 pg, ps = period_perf['port']['gain'], period_perf['port']['sharpe']
#                 bg, bs = period_perf['bench']['gain'], period_perf['bench']['sharpe']
                
#                 print(f"\n--- {title} ---")
#                 # Gain
#                 print(f"  - Group Portfolio Gain:  {pg: >8.2%}")
#                 if not np.isnan(bg):
#                     print(f"  - Benchmark ({benchmark_ticker}) Gain:   {bg: >8.2%}")
#                     print(f"  - Gain Delta (vs Bm):   {pg - bg: >+8.2%}")
#                 # Sharpe
#                 print(f"  - Group Portfolio Sharpe:  {ps: >7.2f}")
#                 if not np.isnan(bs):
#                     print(f"  - Benchmark ({benchmark_ticker}) Sharpe:  {bs: >7.2f}")
#                     print(f"  - Sharpe Delta (vs Bm):   {ps - bs: >+7.2f}")

#             print_period_stats("Calculation Period Performance (In-Sample)", perf_calc)
#             print_period_stats("Forward Period Performance (The Moment of Truth)", perf_fwd)
#             print_period_stats("Full Period Performance (Total)", perf_full)

#     # --- FINAL UI LAYOUT (unchanged) ---
#     fig.update_layout(title_text='Walk-Forward Performance Analysis', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers (Ranked)', height=700, margin=dict(t=50))
#     fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
#     update_button.on_click(update_plot)
#     controls_row1 = widgets.HBox([start_date_picker, calc_period_dropdown, fwd_period_dropdown])
#     controls_row2 = widgets.HBox([metric_dropdown, rank_start_dropdown, rank_end_dropdown, benchmark_ticker_input, update_button])
#     ui_container = widgets.VBox([controls_row1, controls_row2, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
    
#     display(ui_container, fig)
#     update_plot(None)
#     return results_container

# %%
# # All imports remain the same
# import pandas as pd
# import plotly.graph_objects as go
# from datetime import datetime, date
# import numpy as np
# import ipywidgets as widgets
# from IPython.display import display, Markdown
# import pprint 

# # --- Function 1: The Advanced Walk-Forward Analyzer (UPDATED) ---
# def plot_walk_forward_analyzer(df_ohlcv, 
#                                default_start_date=None,
#                                default_calc_period='3M', 
#                                default_fwd_period='1M',
#                                default_metric='Sharpe (ATR)',
#                                default_rank_start=1,
#                                default_rank_end=10,
#                                default_benchmark_ticker='VOO'):
#     """
#     Creates a robust, interactive walk-forward analysis plot with benchmark and portfolio analysis.
#     The text output is now a compact, styled table for easy comparison.
#     """
#     print("Initializing Walk-Forward Analyzer...")
#     if not isinstance(df_ohlcv.index, pd.MultiIndex):
#         raise ValueError("Input DataFrame must have a (Ticker, Date) MultiIndex.")
#     df_ohlcv = df_ohlcv.sort_index()
#     print("Pre-processing data (unstacking)...")
#     df_close_full = df_ohlcv['Adj Close'].unstack(level=0)
#     df_high_full = df_ohlcv['Adj High'].unstack(level=0)
#     df_low_full = df_ohlcv['Adj Low'].unstack(level=0)
#     df_close_full.index = pd.to_datetime(df_close_full.index)
#     df_high_full.index = pd.to_datetime(df_high_full.index)
#     df_low_full.index = pd.to_datetime(df_low_full.index)
    
#     if isinstance(default_start_date, str):
#         default_start_date = pd.to_datetime(default_start_date).date()
    
#     min_date_available = df_close_full.index.min()
#     max_date_available = df_close_full.index.max()
#     if default_start_date is None:
#         default_start_date = max_date_available.date() - pd.DateOffset(years=1)
        
#     start_date_picker = widgets.DatePicker(description='Start Date:', value=default_start_date, disabled=False)
#     calc_period_options = {'1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1)}
#     fwd_period_options = {'0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2), '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3)}
#     calc_period_dropdown = widgets.Dropdown(options=calc_period_options.keys(), value=default_calc_period, description='Calc Period:')
#     fwd_period_dropdown = widgets.Dropdown(options=fwd_period_options.keys(), value=default_fwd_period, description='Fwd Period:')
#     metrics = ['Price', 'Sharpe', 'Sharpe (ATR)']
#     metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
#     rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
#     rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
#     rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
#     benchmark_ticker_input = widgets.Text(value=default_benchmark_ticker, description='Benchmark:', placeholder='Enter Ticker')
#     update_button = widgets.Button(description="Update Chart", button_style='primary')
#     ticker_list_output = widgets.Output()
#     results_container = [None]

#     fig = go.FigureWidget()
#     max_traces = 50
#     for i in range(max_traces):
#         fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Benchmark', visible=True, showlegend=True, line=dict(color='black', width=3, dash='dash')))
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Group Portfolio', visible=True, showlegend=True, line=dict(color='green', width=3)))

#     def calculate_performance_metrics(price_series: pd.Series):
#         """Helper function to compute gain and Sharpe for a given price series."""
#         if price_series.dropna().shape[0] < 2:
#             return {'gain': np.nan, 'sharpe': np.nan}
#         gain = (price_series.ffill().iloc[-1] / price_series.bfill().iloc[0]) - 1
#         returns = price_series.pct_change()
#         std_dev = returns.std()
#         if std_dev > 0:
#             sharpe = (returns.mean() / std_dev) * np.sqrt(252)
#         else:
#             sharpe = np.nan
#         return {'gain': gain, 'sharpe': sharpe}

#     def update_plot(button_click):
#         ticker_list_output.clear_output()
#         start_date = pd.to_datetime(start_date_picker.value)
#         calc_period = calc_period_options[calc_period_dropdown.value]
#         fwd_period = fwd_period_options[fwd_period_dropdown.value]
#         metric = metric_dropdown.value
#         rank_start, rank_end = rank_start_dropdown.value, rank_end_dropdown.value
#         benchmark_ticker = benchmark_ticker_input.value.strip().upper()
        
#         if rank_start > rank_end:
#             with ticker_list_output: print("Error: 'Rank Start' must be <= 'Rank End'.")
#             return
#         calc_end_date_theoretical = start_date + calc_period
#         viz_end_date_theoretical = calc_end_date_theoretical + fwd_period
#         safe_start_date = max(start_date, min_date_available)
#         safe_calc_end_date = min(calc_end_date_theoretical, max_date_available)
#         safe_viz_end_date = min(viz_end_date_theoretical, max_date_available)
#         if safe_start_date >= safe_calc_end_date:
#             with ticker_list_output: print(f"Error: Invalid date range. The calculation period has no data.")
#             return
#         calc_close_raw = df_close_full.loc[safe_start_date:safe_calc_end_date]
#         calc_close = calc_close_raw.dropna(axis=1, how='all')
#         if calc_close.shape[1] == 0 or len(calc_close) < 2:
#             with ticker_list_output: print("Error: Not enough data in the calculation period to rank.")
#             return
        
#         # --- Metric calculation and plotting logic (unchanged) ---
#         metric_values = {}
#         first_prices = calc_close.bfill().iloc[0]; last_prices = calc_close.ffill().iloc[-1]
#         metric_values['Price'] = (last_prices / first_prices).dropna()
#         daily_returns = calc_close.bfill().ffill().pct_change()
#         mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
#         metric_values['Sharpe'] = (mean_returns / std_returns * np.sqrt(252)).fillna(0)
#         valid_tickers = calc_close.columns
#         calc_high = df_high_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         calc_low = df_low_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         tr = np.maximum(calc_high - calc_low, abs(calc_high - df_close_full[valid_tickers].shift(1)), abs(calc_low - df_close_full[valid_tickers].shift(1)))
#         atr = tr.ewm(alpha=1/14, adjust=False).mean()
#         atrp = (atr / calc_close).mean()
#         metric_values['Sharpe (ATR)'] = (mean_returns / atrp).fillna(0)
#         sorted_tickers = metric_values[metric].sort_values(ascending=False)
#         tickers_to_display = sorted_tickers.index[rank_start-1:rank_end].tolist()
#         if not tickers_to_display:
#             with ticker_list_output: print("Error: No tickers found for the selected rank range.")
#             return
#         normalized_plot_data = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date]
#         normalized_plot_data = normalized_plot_data.div(normalized_plot_data.bfill().iloc[0])
#         actual_calc_end_ts = calc_close.index.max()
#         actual_viz_start_date = normalized_plot_data.index.min().date()
#         actual_viz_end_date = normalized_plot_data.index.max().date()
#         with fig.batch_update():
#             # (Plotting logic is unchanged)
#             for i in range(max_traces):
#                 trace = fig.data[i]
#                 if i < len(tickers_to_display):
#                     ticker = tickers_to_display[i]
#                     trace.x, trace.y, trace.name = normalized_plot_data.index, normalized_plot_data[ticker], ticker
#                     trace.visible, trace.showlegend = True, True
#                 else: trace.visible, trace.showlegend = False, False
#             benchmark_trace = fig.data[max_traces]
#             if benchmark_ticker and benchmark_ticker in df_close_full.columns:
#                 benchmark_series = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date]
#                 if not benchmark_series.dropna().empty:
#                     normalized_benchmark = benchmark_series / benchmark_series.bfill().iloc[0]
#                     benchmark_trace.x, benchmark_trace.y = normalized_benchmark.index, normalized_benchmark
#                     benchmark_trace.name = f"Benchmark ({benchmark_ticker})"; benchmark_trace.visible = True
#                 else: benchmark_trace.visible = False
#             else: benchmark_trace.visible = False
#             portfolio_trace = fig.data[max_traces + 1]
#             portfolio_series = normalized_plot_data.mean(axis=1)
#             portfolio_trace.x, portfolio_trace.y = portfolio_series.index, portfolio_series
#             portfolio_trace.name = 'Group Portfolio'; portfolio_trace.visible = True
#             fig.layout.shapes = []
#             fig.add_shape(type="line", x0=actual_calc_end_ts, y0=0, x1=actual_calc_end_ts, y1=1, xref='x', yref='paper', line=dict(color="grey", width=2, dash="dash"))
        
#         # --- Results DataFrame (unchanged) ---
#         calc_start_prices = calc_close.bfill().iloc[0]; calc_end_prices = calc_close.ffill().iloc[-1]
#         fwd_close_slice = df_close_full.loc[actual_calc_end_ts:safe_viz_end_date]
#         viz_end_prices = fwd_close_slice.ffill().iloc[-1] if not fwd_close_slice.empty and len(fwd_close_slice) >= 2 else calc_end_prices
#         calc_gains = (calc_end_prices / calc_start_prices) - 1
#         fwd_gains = (viz_end_prices / calc_end_prices) - 1
#         results_df = pd.DataFrame({'Rank': range(rank_start, rank_start + len(tickers_to_display)), 'Metric': metric, 'MetricValue': sorted_tickers.loc[tickers_to_display].values, 'CalcPrice': calc_end_prices.loc[tickers_to_display], 'CalcGain': calc_gains.loc[tickers_to_display], 'CalcPeriod': calc_period_dropdown.value, 'FwdPeriod': fwd_period_dropdown.value, 'FwdGain': fwd_gains.loc[tickers_to_display]}, index=pd.Index(tickers_to_display, name='Ticker'))
#         results_container[0] = results_df
        
#         # --- NEW: TABULAR PERFORMANCE ANALYSIS AND OUTPUT ---
#         with ticker_list_output:
#             print(f"Analyzing from {actual_viz_start_date} to {actual_viz_end_date}.")
#             print(f"  - Ranking based on performance from {actual_viz_start_date} to {actual_calc_end_ts.date()}.")
#             pprint.pprint(tickers_to_display, width=120, compact=True)
            
#             # Prepare raw price series
#             portfolio_raw = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date].mean(axis=1)
#             benchmark_raw = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date] if benchmark_trace.visible else pd.Series(dtype='float64')

#             # Calculate performance for each period
#             perf_calc = {'port': calculate_performance_metrics(portfolio_raw.loc[:actual_calc_end_ts]), 'bench': calculate_performance_metrics(benchmark_raw.loc[:actual_calc_end_ts])}
#             perf_fwd = {'port': calculate_performance_metrics(portfolio_raw.loc[actual_calc_end_ts:]), 'bench': calculate_performance_metrics(benchmark_raw.loc[actual_calc_end_ts:])}
#             perf_full = {'port': calculate_performance_metrics(portfolio_raw), 'bench': calculate_performance_metrics(benchmark_raw)}
            
#             # Build DataFrame rows
#             rows = []
#             rows.append({'Metric': 'Group Portfolio Gain', 'Full': perf_full['port']['gain'], 'Calc': perf_calc['port']['gain'], 'Fwd': perf_fwd['port']['gain']})
#             if benchmark_trace.visible:
#                 rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Gain', 'Full': perf_full['bench']['gain'], 'Calc': perf_calc['bench']['gain'], 'Fwd': perf_fwd['bench']['gain']})
#                 rows.append({'Metric': 'Gain Delta (vs Bm)', 'Full': perf_full['port']['gain'] - perf_full['bench']['gain'], 'Calc': perf_calc['port']['gain'] - perf_calc['bench']['gain'], 'Fwd': perf_fwd['port']['gain'] - perf_fwd['bench']['gain']})

#             rows.append({'Metric': 'Group Portfolio Sharpe', 'Full': perf_full['port']['sharpe'], 'Calc': perf_calc['port']['sharpe'], 'Fwd': perf_fwd['port']['sharpe']})
#             if benchmark_trace.visible:
#                 rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Sharpe', 'Full': perf_full['bench']['sharpe'], 'Calc': perf_calc['bench']['sharpe'], 'Fwd': perf_fwd['bench']['sharpe']})
#                 rows.append({'Metric': 'Sharpe Delta (vs Bm)', 'Full': perf_full['port']['sharpe'] - perf_full['bench']['sharpe'], 'Calc': perf_calc['port']['sharpe'] - perf_calc['bench']['sharpe'], 'Fwd': perf_fwd['port']['sharpe'] - perf_fwd['bench']['sharpe']})

#             # Create and style the DataFrame
#             report_df = pd.DataFrame(rows).set_index('Metric')
            
#             # Define rows for specific formatting
#             gain_rows = [row for row in report_df.index if 'Gain' in row or 'Delta' in row]
#             sharpe_rows = [row for row in report_df.index if 'Sharpe' in row]

#             # Apply styling
#             styled_df = report_df.style \
#                 .format('{:+.2%}', na_rep='N/A', subset=(gain_rows, report_df.columns)) \
#                 .format('{:+.2f}', na_rep='N/A', subset=(sharpe_rows, report_df.columns)) \
#                 .set_properties(**{'text-align': 'right', 'width': '100px'}) \
#                 .set_properties(subset=pd.IndexSlice[['Metric']], **{'text-align': 'left'}) \
#                 .set_table_styles([dict(selector='th', props=[('text-align', 'right')])])
            
#             print("\n--- Strategy Performance Summary ---")
#             display(styled_df)


#     # --- FINAL UI LAYOUT (unchanged) ---
#     fig.update_layout(title_text='Walk-Forward Performance Analysis', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers (Ranked)', height=700, margin=dict(t=50))
#     fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
#     update_button.on_click(update_plot)
#     controls_row1 = widgets.HBox([start_date_picker, calc_period_dropdown, fwd_period_dropdown])
#     controls_row2 = widgets.HBox([metric_dropdown, rank_start_dropdown, rank_end_dropdown, benchmark_ticker_input, update_button])
#     ui_container = widgets.VBox([controls_row1, controls_row2, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
    
#     display(ui_container, fig)
#     update_plot(None)
#     return results_container

# %%
# # All imports remain the same
# import pandas as pd
# import plotly.graph_objects as go
# from datetime import datetime, date
# import numpy as np
# import ipywidgets as widgets
# from IPython.display import display, Markdown
# import pprint 

# # --- Function 1: The Advanced Walk-Forward Analyzer (FIXED) ---
# def plot_walk_forward_analyzer(df_ohlcv, 
#                                default_start_date=None,
#                                default_calc_period='3M', 
#                                default_fwd_period='1M',
#                                default_metric='Sharpe (ATR)',
#                                default_rank_start=1,
#                                default_rank_end=10,
#                                default_benchmark_ticker='VOO'):
#     """
#     Creates a robust, interactive walk-forward analysis plot with benchmark and portfolio analysis.
#     The text output is now a compact, styled table for easy comparison.
#     """
#     print("Initializing Walk-Forward Analyzer...")
#     if not isinstance(df_ohlcv.index, pd.MultiIndex):
#         raise ValueError("Input DataFrame must have a (Ticker, Date) MultiIndex.")
#     df_ohlcv = df_ohlcv.sort_index()
#     print("Pre-processing data (unstacking)...")
#     df_close_full = df_ohlcv['Adj Close'].unstack(level=0)
#     df_high_full = df_ohlcv['Adj High'].unstack(level=0)
#     df_low_full = df_ohlcv['Adj Low'].unstack(level=0)
#     df_close_full.index = pd.to_datetime(df_close_full.index)
#     df_high_full.index = pd.to_datetime(df_high_full.index)
#     df_low_full.index = pd.to_datetime(df_low_full.index)
    
#     # --- Widgets and Figure Setup (unchanged) ---
#     if isinstance(default_start_date, str):
#         default_start_date = pd.to_datetime(default_start_date).date()
#     min_date_available = df_close_full.index.min()
#     max_date_available = df_close_full.index.max()
#     if default_start_date is None:
#         default_start_date = max_date_available.date() - pd.DateOffset(years=1)
#     start_date_picker = widgets.DatePicker(description='Start Date:', value=default_start_date, disabled=False)
#     calc_period_options = {'1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1)}
#     fwd_period_options = {'0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2), '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3)}
#     calc_period_dropdown = widgets.Dropdown(options=calc_period_options.keys(), value=default_calc_period, description='Calc Period:')
#     fwd_period_dropdown = widgets.Dropdown(options=fwd_period_options.keys(), value=default_fwd_period, description='Fwd Period:')
#     metrics = ['Price', 'Sharpe', 'Sharpe (ATR)']
#     metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
#     rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
#     rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
#     rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
#     benchmark_ticker_input = widgets.Text(value=default_benchmark_ticker, description='Benchmark:', placeholder='Enter Ticker')
#     update_button = widgets.Button(description="Update Chart", button_style='primary')
#     ticker_list_output = widgets.Output()
#     results_container = [None]
#     fig = go.FigureWidget()
#     max_traces = 50
#     for i in range(max_traces):
#         fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Benchmark', visible=True, showlegend=True, line=dict(color='black', width=3, dash='dash')))
#     fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Group Portfolio', visible=True, showlegend=True, line=dict(color='green', width=3)))

#     def calculate_performance_metrics(price_series: pd.Series):
#         if price_series.dropna().shape[0] < 2:
#             return {'gain': np.nan, 'sharpe': np.nan}
#         gain = (price_series.ffill().iloc[-1] / price_series.bfill().iloc[0]) - 1
#         returns = price_series.pct_change()
#         std_dev = returns.std()
#         if std_dev > 0:
#             sharpe = (returns.mean() / std_dev) * np.sqrt(252)
#         else:
#             sharpe = np.nan
#         return {'gain': gain, 'sharpe': sharpe}

#     def update_plot(button_click):
#         # --- All calculation and plotting logic is unchanged... ---
#         ticker_list_output.clear_output()
#         start_date = pd.to_datetime(start_date_picker.value)
#         calc_period = calc_period_options[calc_period_dropdown.value]
#         fwd_period = fwd_period_options[fwd_period_dropdown.value]
#         metric = metric_dropdown.value
#         rank_start, rank_end = rank_start_dropdown.value, rank_end_dropdown.value
#         benchmark_ticker = benchmark_ticker_input.value.strip().upper()
#         if rank_start > rank_end:
#             with ticker_list_output: print("Error: 'Rank Start' must be <= 'Rank End'.")
#             return
#         calc_end_date_theoretical = start_date + calc_period
#         viz_end_date_theoretical = calc_end_date_theoretical + fwd_period
#         safe_start_date = max(start_date, min_date_available)
#         safe_calc_end_date = min(calc_end_date_theoretical, max_date_available)
#         safe_viz_end_date = min(viz_end_date_theoretical, max_date_available)
#         if safe_start_date >= safe_calc_end_date:
#             with ticker_list_output: print(f"Error: Invalid date range. The calculation period has no data.")
#             return
#         calc_close_raw = df_close_full.loc[safe_start_date:safe_calc_end_date]
#         calc_close = calc_close_raw.dropna(axis=1, how='all')
#         if calc_close.shape[1] == 0 or len(calc_close) < 2:
#             with ticker_list_output: print("Error: Not enough data in the calculation period to rank.")
#             return
#         metric_values = {}
#         first_prices = calc_close.bfill().iloc[0]; last_prices = calc_close.ffill().iloc[-1]
#         metric_values['Price'] = (last_prices / first_prices).dropna()
#         daily_returns = calc_close.bfill().ffill().pct_change()
#         mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
#         metric_values['Sharpe'] = (mean_returns / std_returns * np.sqrt(252)).fillna(0)
#         valid_tickers = calc_close.columns
#         calc_high = df_high_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         calc_low = df_low_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
#         tr = np.maximum(calc_high - calc_low, abs(calc_high - df_close_full[valid_tickers].shift(1)), abs(calc_low - df_close_full[valid_tickers].shift(1)))
#         atr = tr.ewm(alpha=1/14, adjust=False).mean()
#         atrp = (atr / calc_close).mean()
#         metric_values['Sharpe (ATR)'] = (mean_returns / atrp).fillna(0)
#         sorted_tickers = metric_values[metric].sort_values(ascending=False)
#         tickers_to_display = sorted_tickers.index[rank_start-1:rank_end].tolist()
#         if not tickers_to_display:
#             with ticker_list_output: print("Error: No tickers found for the selected rank range.")
#             return
#         normalized_plot_data = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date]
#         normalized_plot_data = normalized_plot_data.div(normalized_plot_data.bfill().iloc[0])
#         actual_calc_end_ts = calc_close.index.max()
#         actual_viz_start_date = normalized_plot_data.index.min().date()
#         actual_viz_end_date = normalized_plot_data.index.max().date()
#         with fig.batch_update():
#             for i in range(max_traces):
#                 trace = fig.data[i]
#                 if i < len(tickers_to_display):
#                     ticker = tickers_to_display[i]
#                     trace.x, trace.y, trace.name = normalized_plot_data.index, normalized_plot_data[ticker], ticker
#                     trace.visible, trace.showlegend = True, True
#                 else: trace.visible, trace.showlegend = False, False
#             benchmark_trace = fig.data[max_traces]
#             if benchmark_ticker and benchmark_ticker in df_close_full.columns:
#                 benchmark_series = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date]
#                 if not benchmark_series.dropna().empty:
#                     normalized_benchmark = benchmark_series / benchmark_series.bfill().iloc[0]
#                     benchmark_trace.x, benchmark_trace.y = normalized_benchmark.index, normalized_benchmark
#                     benchmark_trace.name = f"Benchmark ({benchmark_ticker})"; benchmark_trace.visible = True
#                 else: benchmark_trace.visible = False
#             else: benchmark_trace.visible = False
#             portfolio_trace = fig.data[max_traces + 1]
#             portfolio_series = normalized_plot_data.mean(axis=1)
#             portfolio_trace.x, portfolio_trace.y = portfolio_series.index, portfolio_series
#             portfolio_trace.name = 'Group Portfolio'; portfolio_trace.visible = True
#             fig.layout.shapes = []
#             fig.add_shape(type="line", x0=actual_calc_end_ts, y0=0, x1=actual_calc_end_ts, y1=1, xref='x', yref='paper', line=dict(color="grey", width=2, dash="dash"))
#         calc_start_prices = calc_close.bfill().iloc[0]; calc_end_prices = calc_close.ffill().iloc[-1]
#         fwd_close_slice = df_close_full.loc[actual_calc_end_ts:safe_viz_end_date]
#         viz_end_prices = fwd_close_slice.ffill().iloc[-1] if not fwd_close_slice.empty and len(fwd_close_slice) >= 2 else calc_end_prices
#         calc_gains = (calc_end_prices / calc_start_prices) - 1
#         fwd_gains = (viz_end_prices / calc_end_prices) - 1
#         results_df = pd.DataFrame({'Rank': range(rank_start, rank_start + len(tickers_to_display)), 'Metric': metric, 'MetricValue': sorted_tickers.loc[tickers_to_display].values, 'CalcPrice': calc_end_prices.loc[tickers_to_display], 'CalcGain': calc_gains.loc[tickers_to_display], 'CalcPeriod': calc_period_dropdown.value, 'FwdPeriod': fwd_period_dropdown.value, 'FwdGain': fwd_gains.loc[tickers_to_display]}, index=pd.Index(tickers_to_display, name='Ticker'))
#         results_container[0] = results_df
        
#         # --- TABULAR PERFORMANCE OUTPUT ---
#         with ticker_list_output:
#             print(f"Analyzing from {actual_viz_start_date} to {actual_viz_end_date}.")
#             print(f"  - Ranking based on performance from {actual_viz_start_date} to {actual_calc_end_ts.date()}.")
#             pprint.pprint(tickers_to_display, width=120, compact=True)
            
#             portfolio_raw = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date].mean(axis=1)
#             benchmark_raw = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date] if benchmark_trace.visible else pd.Series(dtype='float64')
#             perf_calc = {'port': calculate_performance_metrics(portfolio_raw.loc[:actual_calc_end_ts]), 'bench': calculate_performance_metrics(benchmark_raw.loc[:actual_calc_end_ts])}
#             perf_fwd = {'port': calculate_performance_metrics(portfolio_raw.loc[actual_calc_end_ts:]), 'bench': calculate_performance_metrics(benchmark_raw.loc[actual_calc_end_ts:])}
#             perf_full = {'port': calculate_performance_metrics(portfolio_raw), 'bench': calculate_performance_metrics(benchmark_raw)}
#             rows = []
#             rows.append({'Metric': 'Group Portfolio Gain', 'Full': perf_full['port']['gain'], 'Calc': perf_calc['port']['gain'], 'Fwd': perf_fwd['port']['gain']})
#             if benchmark_trace.visible:
#                 rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Gain', 'Full': perf_full['bench']['gain'], 'Calc': perf_calc['bench']['gain'], 'Fwd': perf_fwd['bench']['gain']})
#                 rows.append({'Metric': 'Gain Delta (vs Bm)', 'Full': perf_full['port']['gain'] - perf_full['bench']['gain'], 'Calc': perf_calc['port']['gain'] - perf_calc['bench']['gain'], 'Fwd': perf_fwd['port']['gain'] - perf_fwd['bench']['gain']})
#             rows.append({'Metric': 'Group Portfolio Sharpe', 'Full': perf_full['port']['sharpe'], 'Calc': perf_calc['port']['sharpe'], 'Fwd': perf_fwd['port']['sharpe']})
#             if benchmark_trace.visible:
#                 rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Sharpe', 'Full': perf_full['bench']['sharpe'], 'Calc': perf_calc['bench']['sharpe'], 'Fwd': perf_fwd['bench']['sharpe']})
#                 rows.append({'Metric': 'Sharpe Delta (vs Bm)', 'Full': perf_full['port']['sharpe'] - perf_full['bench']['sharpe'], 'Calc': perf_calc['port']['sharpe'] - perf_calc['bench']['sharpe'], 'Fwd': perf_fwd['port']['sharpe'] - perf_fwd['bench']['sharpe']})
#             report_df = pd.DataFrame(rows).set_index('Metric')
            
#             # --- !!! THIS IS THE FIXED STYLING BLOCK !!! ---
#             gain_rows = [row for row in report_df.index if 'Gain' in row or 'Delta' in row]
#             sharpe_rows = [row for row in report_df.index if 'Sharpe' in row]
#             styled_df = report_df.style \
#                 .format('{:+.2%}', na_rep='N/A', subset=(gain_rows, report_df.columns)) \
#                 .format('{:+.2f}', na_rep='N/A', subset=(sharpe_rows, report_df.columns)) \
#                 .set_properties(**{'text-align': 'right', 'width': '100px'}) \
#                 .set_table_styles([
#                     {'selector': 'th.col_heading', 'props': [('text-align', 'right')]},
#                     {'selector': 'th.row_heading', 'props': [('text-align', 'left')]}
#                 ])
#             # --- !!! END OF FIX !!! ---
            
#             print("\n--- Strategy Performance Summary ---")
#             display(styled_df)

#     # --- FINAL UI LAYOUT (unchanged) ---
#     fig.update_layout(title_text='Walk-Forward Performance Analysis', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers (Ranked)', height=700, margin=dict(t=50))
#     fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
#     update_button.on_click(update_plot)
#     controls_row1 = widgets.HBox([start_date_picker, calc_period_dropdown, fwd_period_dropdown])
#     controls_row2 = widgets.HBox([metric_dropdown, rank_start_dropdown, rank_end_dropdown, benchmark_ticker_input, update_button])
#     ui_container = widgets.VBox([controls_row1, controls_row2, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
#     display(ui_container, fig)
#     update_plot(None)
#     return results_container

# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime, date
import numpy as np
import ipywidgets as widgets
from IPython.display import display, Markdown
import pprint 

def plot_walk_forward_analyzer(df_ohlcv, 
                               default_start_date=None,
                               default_calc_period='3M', 
                               default_fwd_period='1M',
                               default_metric='Sharpe (ATR)',
                               default_rank_start=1,
                               default_rank_end=10,
                               default_benchmark_ticker='VOO'):
    """
    Creates a robust, interactive walk-forward analysis plot with benchmark and portfolio analysis.
    The returned results DataFrame now includes a row for the benchmark's performance.
    """
    print("Initializing Walk-Forward Analyzer...")
    if not isinstance(df_ohlcv.index, pd.MultiIndex):
        raise ValueError("Input DataFrame must have a (Ticker, Date) MultiIndex.")
    df_ohlcv = df_ohlcv.sort_index()
    print("Pre-processing data (unstacking)...")
    df_close_full = df_ohlcv['Adj Close'].unstack(level=0)
    df_high_full = df_ohlcv['Adj High'].unstack(level=0)
    df_low_full = df_ohlcv['Adj Low'].unstack(level=0)
    df_close_full.index = pd.to_datetime(df_close_full.index)
    df_high_full.index = pd.to_datetime(df_high_full.index)
    df_low_full.index = pd.to_datetime(df_low_full.index)
    
    # --- Widgets and Figure Setup (unchanged) ---
    if isinstance(default_start_date, str):
        default_start_date = pd.to_datetime(default_start_date).date()
    min_date_available = df_close_full.index.min()
    max_date_available = df_close_full.index.max()
    if default_start_date is None:
        default_start_date = max_date_available.date() - pd.DateOffset(years=1)
    start_date_picker = widgets.DatePicker(description='Start Date:', value=default_start_date, disabled=False)
    calc_period_options = {'1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1)}
    fwd_period_options = {'0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2), '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3)}
    calc_period_dropdown = widgets.Dropdown(options=calc_period_options.keys(), value=default_calc_period, description='Calc Period:')
    fwd_period_dropdown = widgets.Dropdown(options=fwd_period_options.keys(), value=default_fwd_period, description='Fwd Period:')
    metrics = ['Price', 'Sharpe', 'Sharpe (ATR)']
    metric_dropdown = widgets.Dropdown(options=metrics, value=default_metric, description='Metric:')
    rank_options = [1, 5, 10, 20, 30, 40, 50, 75, 100]
    rank_start_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_start, description='Rank Start:')
    rank_end_dropdown = widgets.Dropdown(options=rank_options, value=default_rank_end, description='Rank End:')
    benchmark_ticker_input = widgets.Text(value=default_benchmark_ticker, description='Benchmark:', placeholder='Enter Ticker')
    update_button = widgets.Button(description="Update Chart", button_style='primary')
    ticker_list_output = widgets.Output()
    results_container = [None]
    fig = go.FigureWidget()
    max_traces = 50
    for i in range(max_traces):
        fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name=f'placeholder_{i}', visible=False, showlegend=False))
    fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Benchmark', visible=True, showlegend=True, line=dict(color='black', width=3, dash='dash')))
    fig.add_trace(go.Scatter(x=[None], y=[None], mode='lines', name='Group Portfolio', visible=True, showlegend=True, line=dict(color='green', width=3)))

    def calculate_performance_metrics(price_series: pd.Series):
        if price_series.dropna().shape[0] < 2:
            return {'gain': np.nan, 'sharpe': np.nan}
        gain = (price_series.ffill().iloc[-1] / price_series.bfill().iloc[0]) - 1
        returns = price_series.pct_change()
        std_dev = returns.std()
        if std_dev > 0:
            sharpe = (returns.mean() / std_dev) * np.sqrt(252)
        else:
            sharpe = np.nan
        return {'gain': gain, 'sharpe': sharpe}

    def update_plot(button_click):
        # --- All calculation and plotting logic up to this point is unchanged... ---
        ticker_list_output.clear_output()
        start_date = pd.to_datetime(start_date_picker.value)
        calc_period = calc_period_options[calc_period_dropdown.value]
        fwd_period = fwd_period_options[fwd_period_dropdown.value]
        metric = metric_dropdown.value
        rank_start, rank_end = rank_start_dropdown.value, rank_end_dropdown.value
        benchmark_ticker = benchmark_ticker_input.value.strip().upper()
        if rank_start > rank_end:
            with ticker_list_output: print("Error: 'Rank Start' must be <= 'Rank End'.")
            return
        calc_end_date_theoretical = start_date + calc_period
        viz_end_date_theoretical = calc_end_date_theoretical + fwd_period
        safe_start_date = max(start_date, min_date_available)
        safe_calc_end_date = min(calc_end_date_theoretical, max_date_available)
        safe_viz_end_date = min(viz_end_date_theoretical, max_date_available)
        if safe_start_date >= safe_calc_end_date:
            with ticker_list_output: print(f"Error: Invalid date range. The calculation period has no data.")
            return
        calc_close_raw = df_close_full.loc[safe_start_date:safe_calc_end_date]
        calc_close = calc_close_raw.dropna(axis=1, how='all')
        if calc_close.shape[1] == 0 or len(calc_close) < 2:
            with ticker_list_output: print("Error: Not enough data in the calculation period to rank.")
            return
        metric_values = {}
        first_prices = calc_close.bfill().iloc[0]; last_prices = calc_close.ffill().iloc[-1]
        metric_values['Price'] = (last_prices / first_prices).dropna()
        daily_returns = calc_close.bfill().ffill().pct_change()
        mean_returns, std_returns = daily_returns.mean(), daily_returns.std()
        metric_values['Sharpe'] = (mean_returns / std_returns * np.sqrt(252)).fillna(0)
        valid_tickers = calc_close.columns
        calc_high = df_high_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
        calc_low = df_low_full[valid_tickers].loc[safe_start_date:safe_calc_end_date]
        tr = np.maximum(calc_high - calc_low, abs(calc_high - df_close_full[valid_tickers].shift(1)), abs(calc_low - df_close_full[valid_tickers].shift(1)))
        atr = tr.ewm(alpha=1/14, adjust=False).mean()
        atrp = (atr / calc_close).mean()
        metric_values['Sharpe (ATR)'] = (mean_returns / atrp).fillna(0)
        sorted_tickers = metric_values[metric].sort_values(ascending=False)
        tickers_to_display = sorted_tickers.index[rank_start-1:rank_end].tolist()
        if not tickers_to_display:
            with ticker_list_output: print("Error: No tickers found for the selected rank range.")
            return
        normalized_plot_data = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date]
        normalized_plot_data = normalized_plot_data.div(normalized_plot_data.bfill().iloc[0])
        actual_calc_end_ts = calc_close.index.max()
        actual_viz_start_date = normalized_plot_data.index.min().date()
        actual_viz_end_date = normalized_plot_data.index.max().date()
        with fig.batch_update():
            for i in range(max_traces):
                trace = fig.data[i]
                if i < len(tickers_to_display):
                    ticker = tickers_to_display[i]
                    trace.x, trace.y, trace.name = normalized_plot_data.index, normalized_plot_data[ticker], ticker
                    trace.visible, trace.showlegend = True, True
                else: trace.visible, trace.showlegend = False, False
            benchmark_trace = fig.data[max_traces]
            if benchmark_ticker and benchmark_ticker in df_close_full.columns:
                benchmark_series = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date]
                if not benchmark_series.dropna().empty:
                    normalized_benchmark = benchmark_series / benchmark_series.bfill().iloc[0]
                    benchmark_trace.x, benchmark_trace.y = normalized_benchmark.index, normalized_benchmark
                    benchmark_trace.name = f"Benchmark ({benchmark_ticker})"; benchmark_trace.visible = True
                else: benchmark_trace.visible = False
            else: benchmark_trace.visible = False
            portfolio_trace = fig.data[max_traces + 1]
            portfolio_series = normalized_plot_data.mean(axis=1)
            portfolio_trace.x, portfolio_trace.y = portfolio_series.index, portfolio_series
            portfolio_trace.name = 'Group Portfolio'; portfolio_trace.visible = True
            fig.layout.shapes = []
            fig.add_shape(type="line", x0=actual_calc_end_ts, y0=0, x1=actual_calc_end_ts, y1=1, xref='x', yref='paper', line=dict(color="grey", width=2, dash="dash"))
        
        # --- Create Results DataFrame for ranked tickers ---
        calc_start_prices = calc_close.bfill().iloc[0]
        calc_end_prices = calc_close.ffill().iloc[-1]
        fwd_close_slice = df_close_full.loc[actual_calc_end_ts:safe_viz_end_date]
        viz_end_prices = fwd_close_slice.ffill().iloc[-1] if not fwd_close_slice.empty and len(fwd_close_slice) >= 2 else calc_end_prices
        calc_gains = (calc_end_prices / calc_start_prices) - 1
        fwd_gains = (viz_end_prices / calc_end_prices) - 1
        results_df = pd.DataFrame({
            'Rank': range(rank_start, rank_start + len(tickers_to_display)),
            'Metric': metric,
            'MetricValue': sorted_tickers.loc[tickers_to_display].values,
            'CalcPrice': calc_end_prices.loc[tickers_to_display],
            'CalcGain': calc_gains.loc[tickers_to_display],
            'CalcPeriod': calc_period_dropdown.value,
            'FwdPeriod': fwd_period_dropdown.value,
            'FwdGain': fwd_gains.loc[tickers_to_display]
        }, index=pd.Index(tickers_to_display, name='Ticker'))
        
        # --- NEW: CALCULATE AND APPEND BENCHMARK ROW TO RESULTS DF ---
        if benchmark_trace.visible:
            # Slice benchmark prices for calc and fwd periods
            bench_calc_prices = df_close_full[benchmark_ticker].loc[safe_start_date:actual_calc_end_ts]
            bench_fwd_prices = df_close_full[benchmark_ticker].loc[actual_calc_end_ts:safe_viz_end_date]
            
            # Calculate gains
            bench_start_price = bench_calc_prices.bfill().iloc[0]
            bench_calc_end_price = bench_calc_prices.ffill().iloc[-1]
            bench_fwd_end_price = bench_fwd_prices.ffill().iloc[-1] if not bench_fwd_prices.empty and len(bench_fwd_prices) >= 2 else bench_calc_end_price
            
            bench_calc_gain = (bench_calc_end_price / bench_start_price) - 1
            bench_fwd_gain = (bench_fwd_end_price / bench_calc_end_price) - 1
            
            # Get the metric value for the benchmark during the calculation period
            bench_metric_value = metric_values[metric].get(benchmark_ticker, np.nan)
            
            # Create a new DataFrame for the benchmark row
            benchmark_df_row = pd.DataFrame({
                'Rank': np.nan, 'Metric': metric, 'MetricValue': bench_metric_value,
                'CalcPrice': bench_calc_end_price, 'CalcGain': bench_calc_gain,
                'CalcPeriod': calc_period_dropdown.value, 'FwdPeriod': fwd_period_dropdown.value,
                'FwdGain': bench_fwd_gain
            }, index=pd.Index([f"{benchmark_ticker} (BM)"], name='Ticker'))
            
            # Concatenate with the main results
            results_df = pd.concat([results_df, benchmark_df_row])
        
        # Store the final, combined DataFrame in the container
        results_container[0] = results_df

        # --- Tabular Performance Output (unchanged) ---
        with ticker_list_output:
            print(f"Analyzing from {actual_viz_start_date} to {actual_viz_end_date}.")
            print(f"  - Ranking based on performance from {actual_viz_start_date} to {actual_calc_end_ts.date()}.")
            pprint.pprint(tickers_to_display, width=120, compact=True)
            portfolio_raw = df_close_full[tickers_to_display].loc[safe_start_date:safe_viz_end_date].mean(axis=1)
            benchmark_raw = df_close_full[benchmark_ticker].loc[safe_start_date:safe_viz_end_date] if benchmark_trace.visible else pd.Series(dtype='float64')
            perf_calc = {'port': calculate_performance_metrics(portfolio_raw.loc[:actual_calc_end_ts]), 'bench': calculate_performance_metrics(benchmark_raw.loc[:actual_calc_end_ts])}
            perf_fwd = {'port': calculate_performance_metrics(portfolio_raw.loc[actual_calc_end_ts:]), 'bench': calculate_performance_metrics(benchmark_raw.loc[actual_calc_end_ts:])}
            perf_full = {'port': calculate_performance_metrics(portfolio_raw), 'bench': calculate_performance_metrics(benchmark_raw)}
            rows = []
            rows.append({'Metric': 'Group Portfolio Gain', 'Full': perf_full['port']['gain'], 'Calc': perf_calc['port']['gain'], 'Fwd': perf_fwd['port']['gain']})
            if benchmark_trace.visible:
                rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Gain', 'Full': perf_full['bench']['gain'], 'Calc': perf_calc['bench']['gain'], 'Fwd': perf_fwd['bench']['gain']})
                rows.append({'Metric': 'Gain Delta (vs Bm)', 'Full': perf_full['port']['gain'] - perf_full['bench']['gain'], 'Calc': perf_calc['port']['gain'] - perf_calc['bench']['gain'], 'Fwd': perf_fwd['port']['gain'] - perf_fwd['bench']['gain']})
            rows.append({'Metric': 'Group Portfolio Sharpe', 'Full': perf_full['port']['sharpe'], 'Calc': perf_calc['port']['sharpe'], 'Fwd': perf_fwd['port']['sharpe']})
            if benchmark_trace.visible:
                rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Sharpe', 'Full': perf_full['bench']['sharpe'], 'Calc': perf_calc['bench']['sharpe'], 'Fwd': perf_fwd['bench']['sharpe']})
                rows.append({'Metric': 'Sharpe Delta (vs Bm)', 'Full': perf_full['port']['sharpe'] - perf_full['bench']['sharpe'], 'Calc': perf_calc['port']['sharpe'] - perf_calc['bench']['sharpe'], 'Fwd': perf_fwd['port']['sharpe'] - perf_fwd['bench']['sharpe']})
            report_df = pd.DataFrame(rows).set_index('Metric')
            gain_rows = [row for row in report_df.index if 'Gain' in row or 'Delta' in row]
            sharpe_rows = [row for row in report_df.index if 'Sharpe' in row]
            styled_df = report_df.style.format('{:+.2%}', na_rep='N/A', subset=(gain_rows, report_df.columns)).format('{:+.2f}', na_rep='N/A', subset=(sharpe_rows, report_df.columns)).set_properties(**{'text-align': 'right', 'width': '100px'}).set_table_styles([{'selector': 'th.col_heading', 'props': [('text-align', 'right')]}, {'selector': 'th.row_heading', 'props': [('text-align', 'left')]}])
            print("\n--- Strategy Performance Summary ---")
            display(styled_df)

    # --- FINAL UI LAYOUT (unchanged) ---
    fig.update_layout(title_text='Walk-Forward Performance Analysis', xaxis_title='Date', yaxis_title='Normalized Price (Start = 1)', hovermode='x unified', legend_title_text='Tickers (Ranked)', height=700, margin=dict(t=50))
    fig.add_hline(y=1, line_width=1, line_dash="dash", line_color="grey")
    update_button.on_click(update_plot)
    controls_row1 = widgets.HBox([start_date_picker, calc_period_dropdown, fwd_period_dropdown])
    controls_row2 = widgets.HBox([metric_dropdown, rank_start_dropdown, rank_end_dropdown, benchmark_ticker_input, update_button])
    ui_container = widgets.VBox([controls_row1, controls_row2, ticker_list_output], layout=widgets.Layout(margin='10px 0 20px 0'))
    display(ui_container, fig)
    update_plot(None)
    return results_container

# %%
# --- Example Usage of the Walk-Forward Analyzer ---
# You can specify a starting point, or let it default
# start_of_year = date(2024, 9, 25)
start_of_year = '2023-01-01'

# Call the new function
walk_forward_results = plot_walk_forward_analyzer(
    df_OHLCV,
    default_start_date=start_of_year,
    default_calc_period='6M',
    default_fwd_period='1W',
    default_metric='Sharpe (ATR)',
    default_rank_start=1,
    default_rank_end=10
)
# Out:
# Initializing Walk-Forward Analyzer...
# Pre-processing data (unstacking)...
# VBox(children=(HBox(children=(DatePicker(value=datetime.date(2023, 1, 1), description='Start Date:', step=1), …
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'name': 'placeholder_0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '35760bc7-2a08-436f-b6c8-b9c9d7b83003',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '639b119d-f408-4c6b-a76d-cd8d03720fb1',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5be6c811-e6c3-49fa-81e0-1ef9431fdc25',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0c302bed-663a-4f74-9e41-55a14d240fc1',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_4',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '87439395-7c73-4ec0-9b2a-6648199ae2f6',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_5',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '11d0ee93-5279-49f8-99f6-2d65a0dc4610',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_6',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cc283e4a-b078-48aa-bc65-6d0ac78cd2a6',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_7',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fbb60d7c-61da-4980-8675-a3924448e63e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_8',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4d188c1e-8f00-431e-9f18-7cb2c4fbf1b6',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_9',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '15283470-596b-446a-9f81-b2451f107197',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_10',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7329dab1-ca51-4001-aa90-c8cb764df428',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_11',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '64a5e4d6-1a91-47f4-bb42-adaf1396c49a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_12',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ee4173ae-2dd9-491b-b46f-8b6c5c30544e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_13',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e03b9e6b-490f-4f1b-a2ce-b045a798ab6e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_14',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0de08877-b489-43a0-a25f-ec5b1709d53a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_15',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4b29fc86-af48-48af-94a7-4a1cd6e0f3d2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_16',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6b901ff3-4f95-489d-85d0-42b07ef3ad56',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_17',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '734afffb-140f-4c3e-aa0f-3259a8329373',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_18',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0b7d63b3-e762-4547-a470-7a5a29c20b29',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_19',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e812c6db-7ed9-4597-b0d0-1edaa9d4a67a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_20',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b26dcd95-f8a3-45c2-8168-bba02c5918c8',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_21',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0bd4b40e-7f4b-4ed2-b86f-63daade12d86',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_22',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ad3146a4-5e14-4458-b5b8-b3271d2d634b',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_23',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5990cc8e-49c0-4ccd-bccb-aaa57ab9601c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_24',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '83a52353-247c-47bc-bfd4-14d21fb9d2ef',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_25',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5fed2ffb-b146-4d55-9687-e535d930b5a2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_26',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b1b5a67e-b397-472c-85e2-151e5e750dab',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_27',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c0407fc0-346c-4643-8631-137e214952ff',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_28',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8a5de7f8-e145-459e-9493-e6d5aa937221',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_29',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a1c3d086-a36d-4f93-bcfe-bf2bff4443b7',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_30',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '299e9b10-bc53-4b10-8326-2c2cc6c0fbf5',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_31',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'fda0d2d1-ce50-4df8-bcc2-32ed529ced25',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_32',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e0625298-7b33-4558-84a2-7ef54d96b063',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_33',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5253c1ce-0fbd-4c8b-bf8c-3fd5ee5aeec7',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_34',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '72f231e0-13a1-451a-b44c-af72fe4e7698',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_35',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7450eb90-4fde-4a04-8b3d-746e26700c53',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_36',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9dc64c9a-ef67-4325-9376-ca8f4e9a6260',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_37',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '457ba99b-8ce4-4f27-b310-2427ef142dc6',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_38',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f5b83abb-cd9a-4bb5-9d2d-2bb0df24ab1c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_39',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8d7c81e3-715b-4803-b0f6-40c37577431d',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_40',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1cebd85b-fbe8-48ec-9d65-78116d5107e9',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_41',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '263782ed-2a62-41c0-acdb-8f10f04e6b8a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_42',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '38abe365-e055-4678-96f5-91cc0e063067',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_43',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0b12f28d-4daf-4404-8929-0fd5f53fd306',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_44',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5fd9beb9-5921-4dcd-8958-e1974e63f6c2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_45',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd25cad8e-528e-470d-b109-dfacbcb23341',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_46',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a62b6098-9118-42d1-92a5-19ab9eecd5bf',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_47',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a11826f6-ac6f-4cba-b171-f72a382abd42',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_48',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1fcfedfe-c8e6-48d2-be07-ee724491692e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_49',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8a4453d2-ce90-4994-b5d5-33dce125cc49',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'line': {'color': 'black', 'dash': 'dash', 'width': 3},
#               'mode': 'lines',
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1e9c24d6-438c-4ef4-b1e4-5fe2101bb687',
#               'visible': True,
#               'x': [None],
#               'y': [None]},
#              {'line': {'color': 'green', 'width': 3},
#               'mode': 'lines',
#               'name': 'Group Portfolio',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '04e8d500-a77d-4204-88ea-0200ce854c7e',
#               'visible': True,
#               'x': [None],
#               'y': [None]}],
#     'layout': {'height': 700,
#                'hovermode': 'x unified',
#                'legend': {'title': {'text': 'Tickers (Ranked)'}},
#                'margin': {'t': 50},
#                'shapes': [{'line': {'color': 'grey', 'dash': 'dash', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'x domain',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y'}],
#                'template': '...',
#                'title': {'text': 'Walk-Forward Performance Analysis'},
#                'xaxis': {'title': {'text': 'Date'}},
#                'yaxis': {'title': {'text': 'Normalized Price (Start = 1)'}}}
# })

# %%
print(walk_forward_results[0].columns)
walk_forward_results
# Out:
# Index(['Rank', 'Metric', 'MetricValue', 'CalcPrice', 'CalcGain', 'CalcPeriod', 'FwdPeriod', 'FwdGain'], dtype='object')
# [          Rank        Metric  MetricValue  CalcPrice  CalcGain CalcPeriod FwdPeriod   FwdGain
#  Ticker
#  PLTR      20.0  Sharpe (ATR)     0.318964    19.9900  1.569409         3M        1W -0.147574
#  DYNF      21.0  Sharpe (ATR)     0.315989    36.5875  0.138046         3M        1W -0.020001
#  BOXX      22.0  Sharpe (ATR)     0.313616   102.4740  0.011470         3M        1W  0.000976
#  IONQ      23.0  Sharpe (ATR)     0.312896    19.8600  2.617486         3M        1W -0.228097
#  BBIO      24.0  Sharpe (ATR)     0.307938    34.2700  1.389819         3M        1W -0.058652
#  VRT       25.0  Sharpe (ATR)     0.299978    26.4558  0.790155         3M        1W  0.365247
#  QBTS      26.0  Sharpe (ATR)     0.298445     2.7000  4.590062         3M        1W -0.348148
#  ICSH      27.0  Sharpe (ATR)     0.293728    45.1458  0.011879         3M        1W  0.001794
#  ACHR      28.0  Sharpe (ATR)     0.293715     6.5500  2.226601         3M        1W -0.128244
#  LI        29.0  Sharpe (ATR)     0.291405    44.3700  0.878493         3M        1W -0.039216
#  TM        30.0  Sharpe (ATR)     0.290785   162.4480  0.257153         3M        1W -0.009018
#  VOO (BM)   NaN  Sharpe (ATR)     0.188375   407.9900  0.102774         3M        1W -0.016905]

# %%
_start_date = '2023-05-01'
_calc_period = '3M'
_fwd_period = '1W'
_metric = 'Sharpe (ATR)'
_rank_start = 20
_rank_end = 30

# ```python
# Your original call that produced the results DataFrame
walk_forward_results = plot_walk_forward_analyzer(
    df_OHLCV,
    default_start_date=_start_date, # Using a specific date for reproducibility
    default_calc_period=_calc_period,
    default_fwd_period=_fwd_period,
    default_metric=_metric,
    default_rank_start=_rank_start,
    default_rank_end=_rank_end,
)
# Out:
# Initializing Walk-Forward Analyzer...
# Pre-processing data (unstacking)...
# VBox(children=(HBox(children=(DatePicker(value=datetime.date(2023, 5, 1), description='Start Date:', step=1), …
# FigureWidget({
#     'data': [{'mode': 'lines',
#               'name': 'placeholder_0',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bc6bcfb6-59e9-49cd-a5f0-9727e2859714',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_1',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '63160018-1dff-4bf4-8259-a4fc76638537',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_2',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd34156ad-ea5f-489f-866a-510086f87c03',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_3',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f90be402-fe87-4830-999d-5c162cbd622e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_4',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5e96a0f4-d095-4ac7-9698-ada06e7db04f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_5',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1484e0ba-5422-479a-a281-5924fe6f0a08',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_6',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3e0332b8-85cc-4a2f-9f2c-f45991e478d3',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_7',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9785fa97-b7e4-460a-b3e7-1383cb7b1044',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_8',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5fd7d158-cf86-4d63-a988-df6125c1c141',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_9',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0c316e44-dcfb-4527-bfde-b5999f4fb1d2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_10',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '87742a0b-0007-4ae2-8019-8376d23c2661',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_11',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ca4b85dc-560d-49da-9dc0-2338bdbe49d2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_12',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '38364bc5-6566-4567-b527-e21e8e4edc54',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_13',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f7f8e4f6-0d29-424d-a6a8-4f4e850274be',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_14',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0dbd824f-95df-4b16-b3bd-0e2307bef720',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_15',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9c8d26c4-d303-41cf-9b2b-b51bd2273626',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_16',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c599f90a-aa23-4a98-a34a-089e596e443c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_17',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'd54c56ad-f554-41b3-9019-e406b922909a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_18',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6ec93850-4b1f-48ab-b4df-4e9d504d826a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_19',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '361b4a47-7a1e-4674-84b6-ec80355368f5',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_20',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8d165b33-9429-42f8-81fb-916b4f65321e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_21',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3b5ce198-dff0-481e-b10d-275a7c56e8df',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_22',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b330985b-5140-4b7a-a163-6818d0bf79b2',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_23',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b8cc625a-f2eb-4132-8d80-6549f5248f48',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_24',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '24c3f494-2d53-4031-b85c-c230718ce5cf',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_25',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'de62afce-28f3-408a-9bb8-3880f1c69728',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_26',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0a977e04-744d-47bc-97f6-4b98f05729e3',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_27',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '75bbfada-3c24-4d4d-ab02-9f04eec8da0e',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_28',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '6f90a18b-bc86-486d-a05f-ce8143d4d029',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_29',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0986d548-e5d1-4d9b-bbd8-a533d3e1bd81',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_30',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '17d45763-b85a-45d1-ac56-8a708e4dda6f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_31',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c925e9fc-f4ff-4891-825a-294fa8c78d91',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_32',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e9aa9d25-4ca2-4db4-972f-2ed8d05c3dd8',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_33',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b7a05597-3a7d-4685-8d81-e75394b18b73',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_34',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7e0aff70-0639-485f-9617-66c2d3962947',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_35',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '404ec6d8-e40e-49b3-aa6f-ab46e2a13bcd',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_36',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ec3e540c-935b-472b-ae2f-b740f4e22777',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_37',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '89971973-6592-4331-b063-4b6f8e7a54ba',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_38',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b2281b05-40b2-4036-adc1-5aa2f426e130',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_39',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9f57cf59-997d-4d38-82a6-b3b1921bb6ba',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_40',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4feff4f2-23c6-42cf-bd10-d345d89098a5',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_41',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b507cfff-09b9-4bf7-9e0e-2b2d7d2b86cd',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_42',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '10c50dd4-6304-4ed9-ad19-93d73c0a127c',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_43',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'cea361ca-3896-402f-966a-a4e5523bf652',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_44',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1c666339-9109-4b91-8f94-78874e5bf202',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_45',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '833a11ef-46c0-4580-95ae-4a5fe6a8db14',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_46',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'b7131e69-20c9-45e6-8321-693ec965a23a',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_47',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5a6db25d-5cdc-44d7-a8e2-75e1d6a1a3fd',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_48',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '91310066-86c0-4048-8507-53509964dedb',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'mode': 'lines',
#               'name': 'placeholder_49',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c85f28b5-ff0d-4d34-938b-361c03094a0f',
#               'visible': False,
#               'x': [None],
#               'y': [None]},
#              {'line': {'color': 'black', 'dash': 'dash', 'width': 3},
#               'mode': 'lines',
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '08bcdf74-3d0a-482b-9229-7622f262eae1',
#               'visible': True,
#               'x': [None],
#               'y': [None]},
#              {'line': {'color': 'green', 'width': 3},
#               'mode': 'lines',
#               'name': 'Group Portfolio',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '41b150f1-f64a-4bf7-8316-9f8481876aa4',
#               'visible': True,
#               'x': [None],
#               'y': [None]}],
#     'layout': {'height': 700,
#                'hovermode': 'x unified',
#                'legend': {'title': {'text': 'Tickers (Ranked)'}},
#                'margin': {'t': 50},
#                'shapes': [{'line': {'color': 'grey', 'dash': 'dash', 'width': 1},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'x domain',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y'}],
#                'template': '...',
#                'title': {'text': 'Walk-Forward Performance Analysis'},
#                'xaxis': {'title': {'text': 'Date'}},
#                'yaxis': {'title': {'text': 'Normalized Price (Start = 1)'}}}
# })

# %%
_plotted_tickers = walk_forward_results[0].index.to_list()[:-1]
print(f'plotted tickers: {_plotted_tickers}')
walk_forward_results[0]
# Out:
# plotted tickers: ['PLTR', 'DYNF', 'BOXX', 'IONQ', 'BBIO', 'VRT', 'QBTS', 'ICSH', 'ACHR', 'LI', 'TM']
#           Rank        Metric  MetricValue  CalcPrice  CalcGain CalcPeriod FwdPeriod   FwdGain
# Ticker
# PLTR      20.0  Sharpe (ATR)     0.318964    19.9900  1.569409         3M        1W -0.147574
# DYNF      21.0  Sharpe (ATR)     0.315989    36.5875  0.138046         3M        1W -0.020001
# BOXX      22.0  Sharpe (ATR)     0.313616   102.4740  0.011470         3M        1W  0.000976
# IONQ      23.0  Sharpe (ATR)     0.312896    19.8600  2.617486         3M        1W -0.228097
# BBIO      24.0  Sharpe (ATR)     0.307938    34.2700  1.389819         3M        1W -0.058652
# VRT       25.0  Sharpe (ATR)     0.299978    26.4558  0.790155         3M        1W  0.365247
# QBTS      26.0  Sharpe (ATR)     0.298445     2.7000  4.590062         3M        1W -0.348148
# ICSH      27.0  Sharpe (ATR)     0.293728    45.1458  0.011879         3M        1W  0.001794
# ACHR      28.0  Sharpe (ATR)     0.293715     6.5500  2.226601         3M        1W -0.128244
# LI        29.0  Sharpe (ATR)     0.291405    44.3700  0.878493         3M        1W -0.039216
# TM        30.0  Sharpe (ATR)     0.290785   162.4480  0.257153         3M        1W -0.009018
# VOO (BM)   NaN  Sharpe (ATR)     0.188375   407.9900  0.102774         3M        1W -0.016905

# %%
# import pandas as pd
# import numpy as np
# from datetime import datetime
# from IPython.display import display, Markdown

# def verify_walk_forward_calculation(df_ohlcv, 
#                                     ticker, 
#                                     start_date, 
#                                     calc_period, 
#                                     fwd_period, 
#                                     export_csv=False):
#     """
#     Provides a transparent, step-by-step breakdown of the calculations used in 
#     the walk-forward analyzer for a SINGLE ticker and a specific time slice.
#     If export_csv is True, it generates a file with all intermediate calculations.
#     """
#     # ... (setup part is unchanged) ...
#     display(Markdown(f"## Verification Report for Ticker: `{ticker}`"))
#     period_options = { '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1), '0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2) }
#     try:
#         df_ticker_raw = df_ohlcv.loc[ticker].sort_index()
#         df_ticker = df_ticker_raw.copy()
#         df_ticker.columns = df_ticker.columns.str.strip()
#     except KeyError:
#         print(f"---! ERROR: Ticker '{ticker}' not found in the DataFrame. !---")
#         return
#     adj_close_col = 'Adj Close'; adj_high_col = 'Adj High'; adj_low_col = 'Adj Low'
#     start_date_ts = pd.to_datetime(start_date)
#     calc_offset = period_options[calc_period]; fwd_offset = period_options[fwd_period]
#     calc_end_date_ts = start_date_ts + calc_offset; fwd_end_date_ts = calc_end_date_ts + fwd_offset
#     display(Markdown(f"**Analysis Start Date:** `{start_date_ts.date()}`"))
#     display(Markdown(f"**Requested Calculation Period:** `{start_date_ts.date()}` to `{calc_end_date_ts.date()}` ({calc_period})"))
#     display(Markdown(f"**Requested Forward Period:**   `{calc_end_date_ts.date()}` to `{fwd_end_date_ts.date()}` ({fwd_period})"))

#     display(Markdown("### A. Calculation Period Analysis ('In-Sample')"))
#     calc_df = df_ticker.loc[start_date_ts:calc_end_date_ts].copy()
    
#     # --- DEFINITIVE FIX: Check for at least 2 valid data points ---
#     if calc_df[adj_close_col].notna().sum() < 2:
#         print("\n---! ERROR: Not enough data points (less than 2) in the Calculation Period to proceed. !---")
#         return
        
#     actual_calc_start_date = calc_df.index.min().date()
#     actual_calc_end_date = calc_df.index.max().date()
#     display(Markdown(f"**Actual Dates Used:** `{actual_calc_start_date}` to `{actual_calc_end_date}` ({len(calc_df)} trading days)"))

#     # ... (rest of the function is the same, but now safer) ...
#     # The fix is mainly the check above. The pct_change call below is also updated for robustness.
#     format_dict = {col: '{:,.2f}' for col in calc_df.columns if 'Adj' in col or 'Open' in col}; format_dict['Volume'] = '{:,}'
#     display(pd.concat([calc_df.head(3), calc_df.tail(3)]).style.format(format_dict))
#     calc_start_price = calc_df[adj_close_col].bfill().iloc[0]
#     calc_end_price = calc_df[adj_close_col].ffill().iloc[-1]
#     calc_gain = (calc_end_price / calc_start_price) - 1
#     display(Markdown("#### `CalcPrice` and `CalcGain` Verification:"))
#     print(f"  - Calc Start Price (on {calc_df[adj_close_col].first_valid_index().date()}): ${calc_start_price:.2f}")
#     print(f"  - Calc End Price   (on {calc_df[adj_close_col].last_valid_index().date()}): ${calc_end_price:.2f}  <-- This is 'CalcPrice'")
#     print(f"  - CalcGain = (${calc_end_price:.2f} / ${calc_start_price:.2f}) - 1 = {calc_gain:.2%}")
#     display(Markdown("#### `MetricValue` Verification:"))
#     price_metric = calc_end_price / calc_start_price
#     print(f"\n1. Price Metric:")
#     print(f"   - Formula: Last Price / First Price"); print(f"   - Value: ${calc_end_price:.2f} / ${calc_start_price:.2f} = {price_metric:.4f}")
    
#     daily_returns = calc_df[adj_close_col].bfill().ffill().pct_change()

#     mean_return = daily_returns.mean()
#     std_return = daily_returns.std()
#     sharpe_ratio = (mean_return / std_return * np.sqrt(252)) if std_return > 0 else 0
#     print(f"\n2. Sharpe Ratio Metric:")
#     print(f"   - Mean Daily Return: {mean_return:.6f}"); print(f"   - Std Dev Daily Return: {std_return:.6f}")
#     print(f"   - Formula: (Mean / Std Dev) * sqrt(252)"); print(f"   - Value: ({mean_return:.6f} / {std_return:.6f}) * {np.sqrt(252):.2f} = {sharpe_ratio:.4f}")
#     high_low = calc_df[adj_high_col] - calc_df[adj_low_col]
#     high_prev_close = abs(calc_df[adj_high_col] - calc_df[adj_close_col].shift(1))
#     low_prev_close = abs(calc_df[adj_low_col] - calc_df[adj_close_col].shift(1))
#     tr = np.maximum(high_low, np.maximum(high_prev_close, low_prev_close))
#     atr = tr.ewm(alpha=1/14, adjust=False).mean()
#     atrp_series = atr / calc_df[adj_close_col]
#     atrp_mean = atrp_series.mean()
#     sharpe_atr = (mean_return / atrp_mean) if atrp_mean > 0 else 0
#     print(f"\n3. Sharpe (ATR) Metric:")
#     print(f"   - Mean Daily Return: {mean_return:.6f} (same as above)"); print(f"   - Average ATR Percent (ATRP): {atrp_mean:.6f}")
#     print(f"   - Formula: Mean Daily Return / ATRP"); print(f"   - Value: {mean_return:.6f} / {atrp_mean:.6f} = {sharpe_atr:.4f}")
#     # ... (rest of function is unchanged)
#     display(Markdown("\n### B. Forward Period Analysis ('Out-of-Sample')"))
#     fwd_df = df_ticker.loc[actual_calc_end_date:fwd_end_date_ts].copy()
#     if fwd_df.empty or len(fwd_df) < 2:
#         display(Markdown("**No valid data found in the Forward Period.**"))
#         fwd_end_price = calc_end_price
#         fwd_gain = 0
#     else:
#         actual_fwd_start_date = fwd_df.index.min().date()
#         actual_fwd_end_date = fwd_df.index.max().date()
#         display(Markdown(f"**Actual Dates Used:** `{actual_fwd_start_date}` to `{actual_fwd_end_date}` ({len(fwd_df)} trading days)"))
#         fwd_end_price = fwd_df[adj_close_col].ffill().iloc[-1]
#     fwd_start_price = calc_end_price
#     fwd_gain = (fwd_end_price / fwd_start_price) - 1
#     display(Markdown("#### `FwdGain` Verification:"))
#     print(f"  - Fwd Start Price (same as Calc End Price): ${fwd_start_price:.2f}")
#     if not fwd_df.empty and len(fwd_df) >= 2:
#         print(f"  - Fwd End Price   (on {fwd_df[adj_close_col].last_valid_index().date()}): ${fwd_end_price:.2f}")
#     else:
#         print(f"  - Fwd End Price   (No fwd data, using start price): ${fwd_end_price:.2f}")
#     print(f"  - FwdGain = (${fwd_end_price:.2f} / ${fwd_start_price:.2f}) - 1 = {fwd_gain:.2%}")
#     display(Markdown("### C. Final Summary Table"))
#     summary_data = { 'Metric': ['End of Calc Price', 'Calc Period Gain', 'Forward Period Gain','---','Metric: Price', 'Metric: Sharpe', 'Metric: Sharpe (ATR)'], 'Calculated Value': [f"${calc_end_price:.2f}", f"{calc_gain:.2%}", f"{fwd_gain:.2%}", '---', f"{price_metric:.4f}", f"{sharpe_ratio:.4f}", f"{sharpe_atr:.4f}"], 'Corresponds To DataFrame Column': ['`CalcPrice`', '`CalcGain`', '`FwdGain`', '---', '`MetricValue`', '`MetricValue`', '`MetricValue`'] }
#     summary_df = pd.DataFrame(summary_data)
#     display(summary_df)
#     if export_csv:
#         calc_df['Period'] = 'Calculation'; calc_df['Daily_Return'] = daily_returns; calc_df['High_Minus_Low'] = high_low; calc_df['Abs_High_vs_PrevClose'] = high_prev_close; calc_df['Abs_Low_vs_PrevClose'] = low_prev_close; calc_df['True_Range'] = tr; calc_df['ATR_14'] = atr; calc_df['ATRP'] = atrp_series
#         fwd_df['Period'] = 'Forward'
#         combined_df = pd.concat([calc_df, fwd_df.iloc[1:]])
#         ordered_cols = [ 'Period', adj_close_col, 'Daily_Return', adj_high_col, adj_low_col, 'High_Minus_Low', 'Abs_High_vs_PrevClose', 'Abs_Low_vs_PrevClose', 'True_Range', 'ATR_14', 'ATRP', 'Volume' ]
#         remaining_cols = [col for col in combined_df.columns if col not in ordered_cols]
#         final_cols = ordered_cols + remaining_cols
#         filename = f"verification_{ticker}_{start_date_ts.strftime('%Y%m%d')}.csv"
#         combined_df[final_cols].to_csv(filename, float_format='%.8f')
#         print(f"\n✅ Detailed data for '{ticker}' exported to '{filename}'")

# %%
# The plot_walk_forward_analyzer function remains unchanged from the last version.
# Only verify_walk_forward_calculation is updated.

# --- Function 2: The Detailed Verification Tool (UPDATED) ---
def verify_walk_forward_calculation(df_ohlcv, 
                                    tickers_to_verify, 
                                    benchmark_ticker,
                                    start_date, 
                                    calc_period, 
                                    fwd_period, 
                                    export_csv=False):
    """
    Provides a transparent, step-by-step breakdown of the portfolio and benchmark
    performance calculations used in the walk-forward analyzer.
    If export_csv is True, it generates a file with intermediate calculations.
    """
    # --- 1. INITIAL SETUP AND DATA PREPARATION ---
    display(Markdown(f"## Verification Report for Portfolio vs. Benchmark"))
    display(Markdown(f"**Portfolio Tickers:** `{tickers_to_verify}`"))
    display(Markdown(f"**Benchmark Ticker:** `{benchmark_ticker}`"))

    period_options = { '1M': pd.DateOffset(months=1), '3M': pd.DateOffset(months=3), '6M': pd.DateOffset(months=6), '1Y': pd.DateOffset(years=1), '0D': pd.DateOffset(days=0), '1W': pd.DateOffset(weeks=1), '2W': pd.DateOffset(weeks=2) }
    
    # Unstack the full dataset to easily create portfolio series
    df_close_full = df_ohlcv['Adj Close'].unstack(level=0)

    # Create the raw, equal-weighted portfolio price series
    try:
        portfolio_raw_prices = df_close_full[tickers_to_verify].mean(axis=1)
        benchmark_raw_prices = df_close_full[benchmark_ticker]
    except KeyError as e:
        print(f"---! ERROR: Ticker {e} not found in the DataFrame. !---")
        return

    # Date setup
    start_date_ts = pd.to_datetime(start_date)
    calc_offset = period_options[calc_period]; fwd_offset = period_options[fwd_period]
    calc_end_date_ts_theoretical = start_date_ts + calc_offset
    fwd_end_date_ts_theoretical = calc_end_date_ts_theoretical + fwd_offset
    
    # Find actual end of calc period based on available data
    actual_calc_end_ts = df_close_full.loc[:calc_end_date_ts_theoretical].index.max()

    display(Markdown(f"**Analysis Start Date:** `{start_date_ts.date()}`"))
    display(Markdown(f"**Calculation Period End Date:** `{actual_calc_end_ts.date()}`"))
    display(Markdown(f"**Forward Period End Date:** `{fwd_end_date_ts_theoretical.date()}`"))

    # Helper function for printing formatted stats
    def print_verification_steps(title, price_series):
        display(Markdown(f"#### Verification for: `{title}`"))
        if price_series.dropna().shape[0] < 2:
            print("  - Not enough data points to calculate performance.")
            return {'gain': np.nan, 'sharpe': np.nan}
        
        # Gain Calculation
        start_price = price_series.bfill().iloc[0]
        end_price = price_series.ffill().iloc[-1]
        gain = (end_price / start_price) - 1
        print(f"  - Start Price (on {price_series.first_valid_index().date()}): {start_price:,.2f}")
        print(f"  - End Price   (on {price_series.last_valid_index().date()}): {end_price:,.2f}")
        print(f"  - Gain = ({end_price:,.2f} / {start_price:,.2f}) - 1 = {gain:.2%}")

        # Sharpe Calculation
        returns = price_series.pct_change()
        mean_return = returns.mean()
        std_return = returns.std()
        sharpe = (mean_return / std_return * np.sqrt(252)) if std_return > 0 else np.nan
        print(f"\n  - Mean Daily Return: {mean_return:.6f}")
        print(f"  - Std Dev of Daily Return: {std_return:.6f}")
        print(f"  - Sharpe = ({mean_return:.6f} / {std_return:.6f}) * sqrt(252) = {sharpe:.2f}")
        return {'gain': gain, 'sharpe': sharpe}

    # --- 2. PERIOD-BY-PERIOD ANALYSIS ---
    
    # A. Calculation Period
    display(Markdown("### A. Calculation Period Analysis ('In-Sample')"))
    calc_p = portfolio_raw_prices.loc[start_date_ts:actual_calc_end_ts]
    calc_b = benchmark_raw_prices.loc[start_date_ts:actual_calc_end_ts]
    perf_calc_p = print_verification_steps("Group Portfolio", calc_p)
    perf_calc_b = print_verification_steps(f"Benchmark ({benchmark_ticker})", calc_b)

    # B. Forward Period
    display(Markdown("\n### B. Forward Period Analysis ('Moment of Truth')"))
    fwd_p = portfolio_raw_prices.loc[actual_calc_end_ts:fwd_end_date_ts_theoretical]
    fwd_b = benchmark_raw_prices.loc[actual_calc_end_ts:fwd_end_date_ts_theoretical]
    perf_fwd_p = print_verification_steps("Group Portfolio", fwd_p)
    perf_fwd_b = print_verification_steps(f"Benchmark ({benchmark_ticker})", fwd_b)
    
    # C. Full Period
    display(Markdown("\n### C. Full Period Analysis (Total)"))
    full_p = portfolio_raw_prices.loc[start_date_ts:fwd_end_date_ts_theoretical]
    full_b = benchmark_raw_prices.loc[start_date_ts:fwd_end_date_ts_theoretical]
    perf_full_p = print_verification_steps("Group Portfolio", full_p)
    perf_full_b = print_verification_steps(f"Benchmark ({benchmark_ticker})", full_b)

    # --- 3. FINAL SUMMARY TABLE ---
    display(Markdown("\n### D. Final Summary Table (matches analyzer output)"))
    rows = []
    rows.append({'Metric': 'Group Portfolio Gain', 'Full': perf_full_p['gain'], 'Calc': perf_calc_p['gain'], 'Fwd': perf_fwd_p['gain']})
    rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Gain', 'Full': perf_full_b['gain'], 'Calc': perf_calc_b['gain'], 'Fwd': perf_fwd_b['gain']})
    rows.append({'Metric': 'Gain Delta (vs Bm)', 'Full': perf_full_p['gain'] - perf_full_b['gain'], 'Calc': perf_calc_p['gain'] - perf_calc_b['gain'], 'Fwd': perf_fwd_p['gain'] - perf_fwd_b['gain']})
    rows.append({'Metric': 'Group Portfolio Sharpe', 'Full': perf_full_p['sharpe'], 'Calc': perf_calc_p['sharpe'], 'Fwd': perf_fwd_p['sharpe']})
    rows.append({'Metric': f'Benchmark ({benchmark_ticker}) Sharpe', 'Full': perf_full_b['sharpe'], 'Calc': perf_calc_b['sharpe'], 'Fwd': perf_fwd_b['sharpe']})
    rows.append({'Metric': 'Sharpe Delta (vs Bm)', 'Full': perf_full_p['sharpe'] - perf_full_b['sharpe'], 'Calc': perf_calc_p['sharpe'] - perf_calc_b['sharpe'], 'Fwd': perf_fwd_p['sharpe'] - perf_fwd_b['sharpe']})
    report_df = pd.DataFrame(rows).set_index('Metric')
    gain_rows = [row for row in report_df.index if 'Gain' in row or 'Delta' in row]
    sharpe_rows = [row for row in report_df.index if 'Sharpe' in row]
    styled_df = report_df.style.format('{:+.2%}', na_rep='N/A', subset=(gain_rows, report_df.columns)).format('{:+.2f}', na_rep='N/A', subset=(sharpe_rows, report_df.columns)).set_properties(**{'text-align': 'right', 'width': '100px'}).set_table_styles([{'selector': 'th.col_heading', 'props': [('text-align', 'right')]}, {'selector': 'th.row_heading', 'props': [('text-align', 'left')]}])
    display(styled_df)
    
    # --- 4. CSV EXPORT (Optional) ---
    if export_csv:
        calc_p.name = 'Portfolio_Price'; calc_b.name = 'Benchmark_Price'
        fwd_p.name = 'Portfolio_Price'; fwd_b.name = 'Benchmark_Price'
        
        calc_df = pd.concat([calc_p, calc_b], axis=1)
        calc_df['Period'] = 'Calculation'
        fwd_df = pd.concat([fwd_p, fwd_b], axis=1).iloc[1:] # Drop first row to avoid overlap
        fwd_df['Period'] = 'Forward'

        combined_df = pd.concat([calc_df, fwd_df])
        combined_df['Portfolio_Return'] = combined_df['Portfolio_Price'].pct_change()
        combined_df['Benchmark_Return'] = combined_df['Benchmark_Price'].pct_change()
        
        filename = f"verification_portfolio_{start_date_ts.strftime('%Y%m%d')}.csv"
        combined_df.to_csv(filename, float_format='%.6f')
        print(f"\n✅ Detailed portfolio and benchmark data exported to '{filename}'")

# %%
# Example Usage:

# 1. Run the main analyzer
# walk_forward_results = plot_walk_forward_analyzer(df_OHLCV, ...)

# 2. Suppose the output showed these tickers were selected
selected_tickers = _plotted_tickers
benchmark = 'VOO'
start_date_to_verify = '2023-05-01'
calc_p = '3M'
fwd_p = '1W'

# 3. Run the new verifier with the portfolio details
verify_walk_forward_calculation(
    df_ohlcv=df_OHLCV,
    tickers_to_verify=selected_tickers,
    benchmark_ticker=benchmark,
    start_date=start_date_to_verify,
    calc_period=calc_p,
    fwd_period=fwd_p,
    export_csv=True # Optionally create the detailed CSV
)
# Out:
# ## Verification Report for Portfolio vs. Benchmark
# **Portfolio Tickers:** `['PLTR', 'DYNF', 'BOXX', 'IONQ', 'BBIO', 'VRT', 'QBTS', 'ICSH', 'ACHR', 'LI', 'TM']`
# **Benchmark Ticker:** `VOO`
# **Analysis Start Date:** `2023-05-01`
# **Calculation Period End Date:** `2023-08-01`
# **Forward Period End Date:** `2023-08-08`
# ### A. Calculation Period Analysis ('In-Sample')
# #### Verification for: `Group Portfolio`
#   - Start Price (on 2023-05-01): 34.17
#   - End Price   (on 2023-08-01): 45.53
#   - Gain = (45.53 / 34.17) - 1 = 33.27%
#
#   - Mean Daily Return: 0.004622
#   - Std Dev of Daily Return: 0.010400
#   - Sharpe = (0.004622 / 0.010400) * sqrt(252) = 7.06
# #### Verification for: `Benchmark (VOO)`
#   - Start Price (on 2023-05-01): 369.97
#   - End Price   (on 2023-08-01): 407.99
#   - Gain = (407.99 / 369.97) - 1 = 10.28%
#
#   - Mean Daily Return: 0.001577
#   - Std Dev of Daily Return: 0.006774
#   - Sharpe = (0.001577 / 0.006774) * sqrt(252) = 3.69
# ### B. Forward Period Analysis ('Moment of Truth')
# #### Verification for: `Group Portfolio`
#   - Start Price (on 2023-08-01): 45.53
#   - End Price   (on 2023-08-08): 45.04
#   - Gain = (45.04 / 45.53) - 1 = -1.07%
#
#   - Mean Daily Return: -0.002126
#   - Std Dev of Daily Return: 0.007888
#   - Sharpe = (-0.002126 / 0.007888) * sqrt(252) = -4.28
# #### Verification for: `Benchmark (VOO)`
#   - Start Price (on 2023-08-01): 407.99
#   - End Price   (on 2023-08-08): 401.09
#   - Gain = (401.09 / 407.99) - 1 = -1.69%
#
#   - Mean Daily Return: -0.003377
#   - Std Dev of Daily Return: 0.008167
#   - Sharpe = (-0.003377 / 0.008167) * sqrt(252) = -6.56
# ### C. Full Period Analysis (Total)
# #### Verification for: `Group Portfolio`
#   - Start Price (on 2023-05-01): 34.17
#   - End Price   (on 2023-08-08): 45.04
#   - Gain = (45.04 / 34.17) - 1 = 31.84%
#
#   - Mean Daily Return: 0.004126
#   - Std Dev of Daily Return: 0.010341
#   - Sharpe = (0.004126 / 0.010341) * sqrt(252) = 6.33
# #### Verification for: `Benchmark (VOO)`
#   - Start Price (on 2023-05-01): 369.97
#   - End Price   (on 2023-08-08): 401.09
#   - Gain = (401.09 / 369.97) - 1 = 8.41%
#
#   - Mean Daily Return: 0.001212
#   - Std Dev of Daily Return: 0.006938
#   - Sharpe = (0.001212 / 0.006938) * sqrt(252) = 2.77
# ### D. Final Summary Table (matches analyzer output)
# <style type="text/css">
# #T_7c0e8 th.col_heading {
#   text-align: right;
# }
# #T_7c0e8 th.row_heading {
#   text-align: left;
# }
# #T_7c0e8_row0_col0, #T_7c0e8_row0_col1, #T_7c0e8_row0_col2, #T_7c0e8_row1_col0, #T_7c0e8_row1_col1, #T_7c0e8_row1_col2, #T_7c0e8_row2_col0, #T_7c0e8_row2_col1, #T_7c0e8_row2_col2, #T_7c0e8_row3_col0, #T_7c0e8_row3_col1, #T_7c0e8_row3_col2, #T_7c0e8_row4_col0, #T_7c0e8_row4_col1, #T_7c0e8_row4_col2, #T_7c0e8_row5_col0, #T_7c0e8_row5_col1, #T_7c0e8_row5_col2 {
#   text-align: right;
#   width: 100px;
# }
# </style>
# <table id="T_7c0e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c0e8_level0_col0" class="col_heading level0 col0" >Full</th>
#       <th id="T_7c0e8_level0_col1" class="col_heading level0 col1" >Calc</th>
#       <th id="T_7c0e8_level0_col2" class="col_heading level0 col2" >Fwd</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Metric</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c0e8_level0_row0" class="row_heading level0 row0" >Group Portfolio Gain</th>
#       <td id="T_7c0e8_row0_col0" class="data row0 col0" >+31.84%</td>
#       <td id="T_7c0e8_row0_col1" class="data row0 col1" >+33.27%</td>
#       <td id="T_7c0e8_row0_col2" class="data row0 col2" >-1.07%</td>
#     </tr>
#     <tr>
#       <th id="T_7c0e8_level0_row1" class="row_heading level0 row1" >Benchmark (VOO) Gain</th>
#       <td id="T_7c0e8_row1_col0" class="data row1 col0" >+8.41%</td>
#       <td id="T_7c0e8_row1_col1" class="data row1 col1" >+10.28%</td>
#       <td id="T_7c0e8_row1_col2" class="data row1 col2" >-1.69%</td>
#     </tr>
#     <tr>
#       <th id="T_7c0e8_level0_row2" class="row_heading level0 row2" >Gain Delta (vs Bm)</th>
#       <td id="T_7c0e8_row2_col0" class="data row2 col0" >+23.43%</td>
#       <td id="T_7c0e8_row2_col1" class="data row2 col1" >+22.99%</td>
#       <td id="T_7c0e8_row2_col2" class="data row2 col2" >+0.62%</td>
#     </tr>
#     <tr>
#       <th id="T_7c0e8_level0_row3" class="row_heading level0 row3" >Group Portfolio Sharpe</th>
#       <td id="T_7c0e8_row3_col0" class="data row3 col0" >+6.33</td>
#       <td id="T_7c0e8_row3_col1" class="data row3 col1" >+7.06</td>
#       <td id="T_7c0e8_row3_col2" class="data row3 col2" >-4.28</td>
#     </tr>
#     <tr>
#       <th id="T_7c0e8_level0_row4" class="row_heading level0 row4" >Benchmark (VOO) Sharpe</th>
#       <td id="T_7c0e8_row4_col0" class="data row4 col0" >+2.77</td>
#       <td id="T_7c0e8_row4_col1" class="data row4 col1" >+3.69</td>
#       <td id="T_7c0e8_row4_col2" class="data row4 col2" >-6.56</td>
#     </tr>
#     <tr>
#       <th id="T_7c0e8_level0_row5" class="row_heading level0 row5" >Sharpe Delta (vs Bm)</th>
#       <td id="T_7c0e8_row5_col0" class="data row5 col0" >+3.56</td>
#       <td id="T_7c0e8_row5_col1" class="data row5 col1" >+3.36</td>
#       <td id="T_7c0e8_row5_col2" class="data row5 col2" >+2.29</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Detailed portfolio and benchmark data exported to 'verification_portfolio_20230501.csv'

# %%
# 1. Define your list of tickers and the date range
_portfolio_tickers = ['PLTR', 'DYNF', 'BOXX', 'IONQ', 'BBIO', 'VRT', 'QBTS', 'ICSH', 'ACHR', 'LI', 'TM']
start_date = '2023-05-01'
end_date = '2023-08-08'

# 2. Ensure the DataFrame is sorted for efficient slicing
# (This is good practice, although it's likely already sorted from our previous work)
df_OHLCV = df_OHLCV.sort_index()

# 3. Use .loc to filter by both ticker list and date range simultaneously
# The first part of the tuple filters the 'Ticker' level of the index.
# The second part of the tuple slices the 'Date' level of the index.
# portfolio_data = df_OHLCV.loc[(_portfolio_tickers, start_date:end_date), :]
portfolio_data = df_OHLCV.loc[(_portfolio_tickers, slice(start_date, end_date)), :]

# 4. Display the results to verify
print(f"Filtered data for {len(_portfolio_tickers)} tickers from {start_date} to {end_date}:")
display(portfolio_data)

# You can also check the info to see the size of the resulting DataFrame
print("\nInfo of the filtered DataFrame:")
portfolio_data.info()
# Out:
# Filtered data for 11 tickers from 2023-05-01 to 2023-08-08:
#                    Adj Open  Adj High  Adj Low  Adj Close    Volume
# Ticker Date
# PLTR   2023-05-01     7.750     7.820    7.660      7.780  19134200
#        2023-05-02     7.720     7.910    7.430      7.590  38008000
#        2023-05-03     7.620     7.680    7.450      7.560  24322400
#        2023-05-04     7.470     7.520    7.280      7.380  29989300
#        2023-05-05     7.440     7.550    7.320      7.410  45848800
# ...                     ...       ...      ...        ...       ...
# TM     2023-08-02   164.452   165.785  163.724    164.348    444494
#        2023-08-03   159.224   159.480  157.627    159.357    445975
#        2023-08-04   162.306   162.987  161.323    161.455    219179
#        2023-08-07   162.911   163.913  162.410    163.913    243932
#        2023-08-08   160.122   161.039  159.186    160.983    456659
#
# [759 rows x 5 columns]
# Info of the filtered DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 759 entries, ('PLTR', Timestamp('2023-05-01 00:00:00')) to ('TM', Timestamp('2023-08-08 00:00:00'))
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Open   759 non-null    float64
#  1   Adj High   759 non-null    float64
#  2   Adj Low    759 non-null    float64
#  3   Adj Close  759 non-null    float64
#  4   Volume     759 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 131.6+ KB

# %% [markdown]
# ### Code to Calculate Verification Metrics for a Multi-Ticker DataFrame

# %%
import pandas as pd
import numpy as np

# Assume 'portfolio_data' is your DataFrame from the previous step,
# containing the OHLCV data for all portfolio tickers with a MultiIndex.

# --- Step 1: Ensure data is sorted correctly for time-series operations ---
# This is CRITICAL for .shift() to work correctly within groups.
portfolio_data = portfolio_data.sort_index(level=['Ticker', 'Date'])

# Create a copy to store the results without modifying the original
results_df = portfolio_data.copy()

# --- Step 2: Vectorized Calculations using .groupby('Ticker') ---

# Daily Return
results_df['Daily_Return'] = results_df.groupby('Ticker')['Adj Close'].pct_change()

# Previous Day's Close (we'll need this for True Range)
# Calculate it once and reuse for efficiency.
prev_close = results_df.groupby('Ticker')['Adj Close'].shift(1)

# True Range (TR) Components
results_df['High_Minus_Low'] = results_df['Adj High'] - results_df['Adj Low']
results_df['Abs_High_vs_PrevClose'] = abs(results_df['Adj High'] - prev_close)
results_df['Abs_Low_vs_PrevClose'] = abs(results_df['Adj Low'] - prev_close)

# True Range (the maximum of the three components)
results_df['True_Range'] = np.maximum(
    results_df['High_Minus_Low'],
    np.maximum(results_df['Abs_High_vs_PrevClose'], results_df['Abs_Low_vs_PrevClose'])
)

# ATR_14 (14-period Exponential Moving Average of True Range)
# We use .ewm() for the exponential moving average.
# `adjust=False` is standard for technical indicators like ATR.
results_df['ATR_14'] = results_df.groupby('Ticker')['True_Range'].ewm(span=14, adjust=False).mean().values

# ATRP (Average True Range Percent)
results_df['ATRP'] = results_df['ATR_14'] / results_df['Adj Close']


# --- Step 3: Display the results for verification ---

# Reorder columns for better readability
ordered_cols = [
    'Adj Close', 
    'Daily_Return',
    'Adj High', 
    'Adj Low',
    'High_Minus_Low',
    'Abs_High_vs_PrevClose',
    'Abs_Low_vs_PrevClose',
    'True_Range',
    'ATR_14',
    'ATRP',
    'Volume'
]
# Add any original columns not in the list to the end
final_cols = ordered_cols + [col for col in results_df.columns if col not in ordered_cols]
results_df = results_df[final_cols]

print("DataFrame with all verification calculations:")
# Display the head and tail, or a larger sample, to see the results.
# Notice the NaNs on the first day for each ticker, which is correct.
display(results_df.head(15))
# Out:
# DataFrame with all verification calculations:
#                    Adj Close  Daily_Return  Adj High  Adj Low  High_Minus_Low  Abs_High_vs_PrevClose  Abs_Low_vs_PrevClose  True_Range    ATR_14      ATRP   Volume  Adj Open
# Ticker Date
# ACHR   2023-05-01       2.03           NaN     2.060    1.951           0.109                    NaN                   NaN         NaN       NaN       NaN   875400      1.98
#        2023-05-02       1.95     -0.039409     2.070    1.930           0.140                  0.040                  0.10       0.140  0.140000  0.071795  1291500      2.02
#        2023-05-03       2.06      0.056410     2.115    1.970           0.145                  0.165                  0.02       0.165  0.143333  0.069579  1188400      1.97
#        2023-05-04       2.03     -0.014563     2.129    2.010           0.119                  0.069                  0.05       0.119  0.140089  0.069009   970500      2.06
#        2023-05-05       2.12      0.044335     2.120    2.050           0.070                  0.090                  0.02       0.090  0.133410  0.062929   999400      2.06
#        2023-05-08       2.14      0.009434     2.230    2.110           0.120                  0.110                  0.01       0.120  0.131622  0.061506  1344000      2.12
#        2023-05-09       2.25      0.051402     2.280    2.120           0.160                  0.140                  0.02       0.160  0.135406  0.060180  1495500      2.20
#        2023-05-10       2.38      0.057778     2.420    2.280           0.140                  0.170                  0.03       0.170  0.140019  0.058831  2049300      2.32
#        2023-05-11       2.37     -0.004202     2.420    2.300           0.120                  0.040                  0.08       0.120  0.137349  0.057953  1116400      2.38
#        2023-05-12       2.00     -0.156118     2.330    1.910           0.420                  0.040                  0.46       0.460  0.180369  0.090185  2569400      2.27
#        2023-05-15       2.37      0.185000     2.370    2.100           0.270                  0.370                  0.10       0.370  0.205654  0.086774  2289200      2.11
#        2023-05-16       2.60      0.097046     2.620    2.330           0.290                  0.250                  0.04       0.290  0.216900  0.083423  3608100      2.35
#        2023-05-17       2.93      0.126923     2.930    2.590           0.340                  0.330                  0.01       0.340  0.233313  0.079629  3528600      2.60
#        2023-05-18       3.15      0.075085     3.180    2.900           0.280                  0.250                  0.03       0.280  0.239538  0.076044  3275400      2.96
#        2023-05-19       3.25      0.031746     3.370    3.100           0.270                  0.220                  0.05       0.270  0.243600  0.074954  8614700      3.26

# %%
print(f'results_df:\n{results_df}')
# Out:
# results_df:
#                    Adj Close  Daily_Return  Adj High  Adj Low  High_Minus_Low  Abs_High_vs_PrevClose  Abs_Low_vs_PrevClose  True_Range    ATR_14      ATRP    Volume  Adj Open
# Ticker Date
# ACHR   2023-05-01     2.0300           NaN    2.0600   1.9510          0.1090                    NaN                   NaN         NaN       NaN       NaN    875400    1.9800
#        2023-05-02     1.9500     -0.039409    2.0700   1.9300          0.1400                 0.0400                0.1000      0.1400  0.140000  0.071795   1291500    2.0200
#        2023-05-03     2.0600      0.056410    2.1150   1.9700          0.1450                 0.1650                0.0200      0.1650  0.143333  0.069579   1188400    1.9700
#        2023-05-04     2.0300     -0.014563    2.1290   2.0100          0.1190                 0.0690                0.0500      0.1190  0.140089  0.069009    970500    2.0600
#        2023-05-05     2.1200      0.044335    2.1200   2.0500          0.0700                 0.0900                0.0200      0.0900  0.133410  0.062929    999400    2.0600
# ...                      ...           ...       ...      ...             ...                    ...                   ...         ...       ...       ...       ...       ...
# VRT    2023-08-02    34.1941      0.292499   35.2810  31.4817          3.7993                 8.8252                5.0259      8.8252  1.914481  0.055989  38579449   32.9077
#        2023-08-03    34.4035      0.006124   34.4932  32.9675          1.5257                 0.2991                1.2266      1.5257  1.862644  0.054141  12872018   34.0046
#        2023-08-04    35.6101      0.035072   36.4926  34.6627          1.8299                 2.0891                0.2592      2.0891  1.892838  0.053155   9966288   34.8622
#        2023-08-07    35.6201      0.000281   36.3081  34.7625          1.5456                 0.6980                0.8476      1.5456  1.846539  0.051840  14171453   34.9021
#        2023-08-08    36.1187      0.013998   36.3680  34.8622          1.5058                 0.7479                0.7579      1.5058  1.801107  0.049866   7799524   35.4505
#
# [759 rows x 12 columns]

# %%
# --- Define the filename ---
# It's good practice to make the filename descriptive.
filename = "verification_portfolio_calculations.csv"

# --- Write the DataFrame to a CSV file ---

# Option 1: Basic export
# results_df.to_csv(filename)

# Option 2: Recommended export with better formatting
#    - float_format='%.6f': Saves floating point numbers with 6 decimal places for precision.
#    - index=True: Includes the MultiIndex (Ticker, Date) in the CSV, which is important.
results_df.to_csv(filename, float_format='%.6f', index=True)

# --- Confirmation message ---
print(f"✅ Successfully exported the verification data to '{filename}'")
# Out:
# ✅ Successfully exported the verification data to 'verification_portfolio_calculations.csv'

# %%
_export_csv = True

# Now, let's verify top-ranked ticker from the results
_verify_ticker = walk_forward_results[0].index[9] 

# Verify the calculation for 'BIL' using the same parameters
verify_walk_forward_calculation(
    df_ohlcv=df_OHLCV,
    ticker=_verify_ticker,
    start_date=_start_date,
    calc_period=_calc_period,
    fwd_period=_fwd_period,
    export_csv=_export_csv  # Set to True to get the data in Excel
)
# Out:
# ## Verification Report for Ticker: `ERJ`
# **Analysis Start Date:** `2023-01-01`
# **Requested Calculation Period:** `2023-01-01` to `2023-04-01` (3M)
# **Requested Forward Period:**   `2023-04-01` to `2023-04-08` (1W)
# ### A. Calculation Period Analysis ('In-Sample')
# **Actual Dates Used:** `2023-01-03` to `2023-03-31` (62 trading days)
# <style type="text/css">
# </style>
# <table id="T_b2e49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2e49_level0_col0" class="col_heading level0 col0" >Adj Open</th>
#       <th id="T_b2e49_level0_col1" class="col_heading level0 col1" >Adj High</th>
#       <th id="T_b2e49_level0_col2" class="col_heading level0 col2" >Adj Low</th>
#       <th id="T_b2e49_level0_col3" class="col_heading level0 col3" >Adj Close</th>
#       <th id="T_b2e49_level0_col4" class="col_heading level0 col4" >Volume</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2e49_level0_row0" class="row_heading level0 row0" >2023-01-03 00:00:00</th>
#       <td id="T_b2e49_row0_col0" class="data row0 col0" >10.74</td>
#       <td id="T_b2e49_row0_col1" class="data row0 col1" >10.91</td>
#       <td id="T_b2e49_row0_col2" class="data row0 col2" >10.66</td>
#       <td id="T_b2e49_row0_col3" class="data row0 col3" >10.66</td>
#       <td id="T_b2e49_row0_col4" class="data row0 col4" >1,127,700</td>
#     </tr>
#     <tr>
#       <th id="T_b2e49_level0_row1" class="row_heading level0 row1" >2023-01-04 00:00:00</th>
#       <td id="T_b2e49_row1_col0" class="data row1 col0" >10.48</td>
#       <td id="T_b2e49_row1_col1" class="data row1 col1" >11.03</td>
#       <td id="T_b2e49_row1_col2" class="data row1 col2" >10.46</td>
#       <td id="T_b2e49_row1_col3" class="data row1 col3" >11.02</td>
#       <td id="T_b2e49_row1_col4" class="data row1 col4" >1,055,200</td>
#     </tr>
#     <tr>
#       <th id="T_b2e49_level0_row2" class="row_heading level0 row2" >2023-01-05 00:00:00</th>
#       <td id="T_b2e49_row2_col0" class="data row2 col0" >11.14</td>
#       <td id="T_b2e49_row2_col1" class="data row2 col1" >11.18</td>
#       <td id="T_b2e49_row2_col2" class="data row2 col2" >10.93</td>
#       <td id="T_b2e49_row2_col3" class="data row2 col3" >11.06</td>
#       <td id="T_b2e49_row2_col4" class="data row2 col4" >1,496,800</td>
#     </tr>
#     <tr>
#       <th id="T_b2e49_level0_row3" class="row_heading level0 row3" >2023-03-29 00:00:00</th>
#       <td id="T_b2e49_row3_col0" class="data row3 col0" >16.01</td>
#       <td id="T_b2e49_row3_col1" class="data row3 col1" >16.34</td>
#       <td id="T_b2e49_row3_col2" class="data row3 col2" >15.92</td>
#       <td id="T_b2e49_row3_col3" class="data row3 col3" >16.28</td>
#       <td id="T_b2e49_row3_col4" class="data row3 col4" >1,531,000</td>
#     </tr>
#     <tr>
#       <th id="T_b2e49_level0_row4" class="row_heading level0 row4" >2023-03-30 00:00:00</th>
#       <td id="T_b2e49_row4_col0" class="data row4 col0" >16.50</td>
#       <td id="T_b2e49_row4_col1" class="data row4 col1" >16.54</td>
#       <td id="T_b2e49_row4_col2" class="data row4 col2" >16.18</td>
#       <td id="T_b2e49_row4_col3" class="data row4 col3" >16.32</td>
#       <td id="T_b2e49_row4_col4" class="data row4 col4" >1,627,900</td>
#     </tr>
#     <tr>
#       <th id="T_b2e49_level0_row5" class="row_heading level0 row5" >2023-03-31 00:00:00</th>
#       <td id="T_b2e49_row5_col0" class="data row5 col0" >16.50</td>
#       <td id="T_b2e49_row5_col1" class="data row5 col1" >16.61</td>
#       <td id="T_b2e49_row5_col2" class="data row5 col2" >16.31</td>
#       <td id="T_b2e49_row5_col3" class="data row5 col3" >16.37</td>
#       <td id="T_b2e49_row5_col4" class="data row5 col4" >1,912,200</td>
#     </tr>
#   </tbody>
# </table>
# #### `CalcPrice` and `CalcGain` Verification:
#   - Calc Start Price (on 2023-01-03): $10.66
#   - Calc End Price   (on 2023-03-31): $16.37  <-- This is 'CalcPrice'
#   - CalcGain = ($16.37 / $10.66) - 1 = 53.56%
# #### `MetricValue` Verification:
# 1. Price Metric:
#    - Formula: Last Price / First Price
#    - Value: $16.37 / $10.66 = 1.5356
#
# 2. Sharpe Ratio Metric:
#    - Mean Daily Return: 0.007236
#    - Std Dev Daily Return: 0.019189
#    - Formula: (Mean / Std Dev) * sqrt(252)
#    - Value: (0.007236 / 0.019189) * 15.87 = 5.9861
#
# 3. Sharpe (ATR) Metric:
#    - Mean Daily Return: 0.007236 (same as above)
#    - Average ATR Percent (ATRP): 0.033780
#    - Formula: Mean Daily Return / ATRP
#    - Value: 0.007236 / 0.033780 = 0.2142
# ### B. Forward Period Analysis ('Out-of-Sample')
# **Actual Dates Used:** `2023-03-31` to `2023-04-06` (5 trading days)
# #### `FwdGain` Verification:
#   - Fwd Start Price (same as Calc End Price): $16.37
#   - Fwd End Price   (on 2023-04-06): $15.54
#   - FwdGain = ($15.54 / $16.37) - 1 = -5.07%
# ### C. Final Summary Table
#                  Metric Calculated Value Corresponds To DataFrame Column
# 0     End of Calc Price           $16.37                     `CalcPrice`
# 1      Calc Period Gain           53.56%                      `CalcGain`
# 2   Forward Period Gain           -5.07%                       `FwdGain`
# 3                   ---              ---                             ---
# 4         Metric: Price           1.5356                   `MetricValue`
# 5        Metric: Sharpe           5.9861                   `MetricValue`
# 6  Metric: Sharpe (ATR)           0.2142                   `MetricValue`
# ✅ Detailed data for 'ERJ' exported to 'verification_ERJ_20230101.csv'

# %%
df_OHLCV.loc[_verify_ticker].tail(50)
# Out:
#             Adj Open  Adj High  Adj Low  Adj Close   Volume
# Date
# 2023-03-15     14.83     14.87    14.42      14.69  3352000
# 2023-03-14     14.75     15.06    14.66      14.87  2769700
# 2023-03-13     14.35     14.42    14.06      14.17  2018300
# 2023-03-10     14.66     15.03    14.40      14.42  5730300
# 2023-03-09     14.16     14.20    13.80      13.83  1365200
# 2023-03-08     14.11     14.21    13.95      14.08  1028800
# 2023-03-07     13.87     14.07    13.81      13.99  1080300
# 2023-03-06     13.84     14.05    13.78      13.87  1277500
# 2023-03-03     13.72     13.87    13.49      13.75  1917400
# 2023-03-02     12.99     13.33    12.86      13.32  1736300
# 2023-03-01     12.96     12.99    12.76      12.93  1055200
# 2023-02-28     12.54     12.83    12.38      12.70  2305500
# 2023-02-27     12.35     12.50    12.29      12.34   702400
# 2023-02-24     12.28     12.39    12.20      12.35   670600
# 2023-02-23     12.73     12.81    12.41      12.52   926500
# 2023-02-22     12.46     12.63    12.40      12.46   927700
# 2023-02-21     12.68     12.82    12.21      12.40  1597300
# 2023-02-17     12.58     12.83    12.33      12.78  1539300
# 2023-02-16     12.36     12.53    12.26      12.43   662600
# 2023-02-15     12.42     12.58    12.32      12.56   806000
# 2023-02-14     12.39     12.64    12.27      12.48  1425500
# 2023-02-13     12.34     12.45    12.28      12.36   951200
# 2023-02-10     12.41     12.43    12.11      12.32   993600
# 2023-02-09     12.71     12.79    12.30      12.35  1118400
# 2023-02-08     13.00     13.02    12.59      12.75  1113300
# 2023-02-07     12.91     13.17    12.72      13.02  1555800
# 2023-02-06     12.68     12.79    12.63      12.70  1736700
# 2023-02-03     12.81     13.10    12.78      12.81  1024100
# 2023-02-02     13.12     13.34    12.95      13.04  1233800
# 2023-02-01     13.00     13.04    12.70      12.91  1274400
# 2023-01-31     13.18     13.18    12.78      12.89  1838000
# 2023-01-30     12.98     13.00    12.63      12.65   944900
# 2023-01-27     12.85     13.02    12.75      12.81  1146300
# 2023-01-26     13.18     13.41    13.06      13.09  1642300
# 2023-01-25     13.11     13.34    12.99      13.20  1932700
# 2023-01-24     12.99     13.08    12.75      13.06  1560400
# 2023-01-23     12.47     12.71    12.38      12.59   930500
# 2023-01-20     12.61     12.73    12.49      12.51   836800
# 2023-01-19     12.64     12.75    12.39      12.64  1220900
# 2023-01-18     13.14     13.27    12.60      12.61  2415800
# 2023-01-17     12.70     13.04    12.60      12.84  2804100
# 2023-01-13     12.22     12.48    12.22      12.34  1203900
# 2023-01-12     12.46     12.58    12.14      12.37  2169800
# 2023-01-11     11.70     12.11    11.64      12.04  2010100
# 2023-01-10     11.25     11.67    11.17      11.56  1177800
# 2023-01-09     11.33     11.42    11.23      11.25  1165100
# 2023-01-06     11.24     11.33    11.11      11.12  1143000
# 2023-01-05     11.14     11.18    10.93      11.06  1496800
# 2023-01-04     10.48     11.03    10.46      11.02  1055200
# 2023-01-03     10.74     10.91    10.66      10.66  1127700

# %% [markdown]
# ### **J. Welles Wilder Jr. definition ATR that captures overnight gaps.**
#
# Let's be precise:
#
# *   **We WILL calculate** the **True Range (TR)** for each day, which is the maximum of:
#     1.  `(Today's High - Today's Low)`
#     2.  `abs(Today's High - Yesterday's Close)`
#     3.  `abs(Today's Low - Yesterday's Close)`
# *   Then, we will typically calculate the **Average True Range (ATR)**, which is a **Exponential Moving Average** of this True Range value. This is the standard industry indicator for volatility that includes intraday and overnight movement.

# %% [markdown]
# ### **Return/ATR Calculation**
#
# You are correct that the ATR calculation should be tied to the `Period` dropdown, but here's how we'll do it in a standard, robust way:
#
# **Step 1: Pre-computation (Done once for all stocks)**
#
# First, for the entire historical dataset, we will calculate a standard **14-day Average True Range (ATR)**. This is the industry standard lookback period defined by Wilder. This step creates a new, continuous ATR data series for every single stock, just like we have an 'Adj Close' series.
#
# **Step 2: On-the-Fly Calculation (When you click "Update Chart")**
#
# This is where your interpretation comes in. When you make your selections in the dropdowns (e.g., `Metric: Return/ATR`, `Period: 3M`):
#
# 1.  We slice the **daily returns** data to get only the last **3 months**.
# 2.  We also slice the pre-computed **14-day ATR** data to get only the last **3 months**.
# 3.  We then calculate:
#     *   **Numerator:** The `mean()` of the daily returns over those 3 months.
#     *   **Denominator:** The `mean()` of the ATR values over those 3 months.
# 4.  The final score for the new metric is `Numerator / Denominator`.
#
# **In short: The `Period` dropdown defines the window of data we analyze, not the lookback period of the ATR indicator itself.**
#
# This is the best practice because it ensures we are always comparing apples to apples. We're using a consistent measure of volatility (14-day ATR) and seeing how it behaves over different analysis windows (1D, 3M, 1Y, etc.).

# %% [markdown]
# ### ATR_14 Calculation  `pandas.ewm(..., adjust=False)`
# You have hit upon the most subtle, confusing, and important aspect of how pandas calculates Exponential Moving Averages.
#
# Your thinking is perfectly logical, and your calculation of the 14-period simple average (`4.33614...`) is **100% correct.** The reason it doesn't match the CSV is the key detail.
#
# The discrepancy arises because the method we are using, `pandas.ewm(..., adjust=False)`, **does not use a simple average as a "seed" value.** This is a very common misconception because the "SMA seed" method is often taught for manual calculation.
#
# Instead, `ewm(adjust=False)` applies the exponential smoothing formula **recursively from the very first data point.**
#
# ### How `ewm(adjust=False)` Actually Works
#
# Let's trace it with your data.
# `alpha = 1/14` and `1 - alpha = 13/14`.
#
# 1.  **First Valid `True_Range` (Jan 4):** `4.283`
#     *   The `ewm` starts here. The first ATR is simply the first value.
#     *   **ATR on Jan 4 = 4.283**. (Matches your CSV)
#
# 2.  **Second Valid `True_Range` (Jan 5):** `3.956`
#     *   `ATR = (Current_TR * 1/14) + (Previous_ATR * 13/14)`
#     *   `ATR = (3.956 * 1/14) + (4.283 * 13/14)`
#     *   `ATR = 0.2825714 + 3.9774286`
#     *   **ATR on Jan 5 = 4.25999...**. (Rounds to `4.25964...` in your CSV due to higher precision floating point math). This is a match.
